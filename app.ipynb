# %%
import requests
import pandas as pd
import json
from config import API_Key
import csv
import numpy as np
import pprint
from pandas.io.json import json_normalize

# %%
# df = pd.read_csv('data/Satellite-Exploration-CSV.csv')

# %%
# df
# Out:
#           name  satid                      source  \
# 0        HYSIS  43719                       India
# 1     GAOFEN-5  43461  People's Republic of China
# 2      NUSAT 5  43204                   Argentina
# 3      NUSAT 4  43195                   Argentina
# 4       VRSS-2  42954                   Venezuela
# ..         ...    ...                         ...
# 144  LANDSAT 4  13367               United States
# 145   SEASAT 1  10967               United States
# 146  LANDSAT 3  10702               United States
# 147  LANDSAT 2   7615               United States
# 148  LANDSAT 1   6126               United States
#
#                                        launchsite       lat      long
# 0                               SRIHARIKOTA (SRI)  13.72590   80.2266
# 1               Taiyuan Space Center, China (TSC)  38.84280  111.6051
# 2    Jiuquan Satellite Launch Center, China (JSC)  40.98450  100.2087
# 3    Jiuquan Satellite Launch Center, China (JSC)  40.98450  100.2087
# 4    Jiuquan Satellite Launch Center, China (JSC)  40.98450  100.2087
# ..                                            ...       ...       ...
# 144          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
# 145          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
# 146          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
# 147          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
# 148          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
#
# [149 rows x 6 columns]

# %%
# df.set_index(["name"])
# Out:
#            satid                      source  \
# name
# HYSIS      43719                       India
# GAOFEN-5   43461  People's Republic of China
# NUSAT 5    43204                   Argentina
# NUSAT 4    43195                   Argentina
# VRSS-2     42954                   Venezuela
# ...          ...                         ...
# LANDSAT 4  13367               United States
# SEASAT 1   10967               United States
# LANDSAT 3  10702               United States
# LANDSAT 2   7615               United States
# LANDSAT 1   6126               United States
#
#                                              launchsite       lat      long
# name
# HYSIS                                 SRIHARIKOTA (SRI)  13.72590   80.2266
# GAOFEN-5              Taiyuan Space Center, China (TSC)  38.84280  111.6051
# NUSAT 5    Jiuquan Satellite Launch Center, China (JSC)  40.98450  100.2087
# NUSAT 4    Jiuquan Satellite Launch Center, China (JSC)  40.98450  100.2087
# VRSS-2     Jiuquan Satellite Launch Center, China (JSC)  40.98450  100.2087
# ...                                                 ...       ...       ...
# LANDSAT 4          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
# SEASAT 1           AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
# LANDSAT 3          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
# LANDSAT 2          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
# LANDSAT 1          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
#
# [149 rows x 5 columns]

# %%
array = np.array(df)
id= array[:,1]

print(id)
# Out:
# [43719 43461 43204 43195 42954 42901 42063 41898 41877 41848 41599 41558
#  41558 41557 41557 41556 41456 41386 41335 40968 40931 40701 40697 40536
#  40360 40336 40118 40072 40053 39766 39731 39455 39422 39419 39418 39186
#  39160 39159 39150 39086 39084 39030 38782 38755 38708 38707 38248 38038
#  37794 37781 37387 36985 36795 36795 36415 36414 36413 36121 36110 35931
#  35870 34839 33331 33105 32783 32476 32382 29710 29709 29268 29228 29079
#  28931 28893 28891 28649 28220 28376 28254 28220 28057 28051 27840 27597
#  27559 27430 27424 27421 27386 27004 27003 27001 26997 26957 26620 26619
#  26548 26032 25994 25940 25919 25860 25789 25758 25757 25756 25693 25682
#  25636 25616 25504 25397 25396 25395 25394 25260 24971 24883 24277 23940
#  23827 23751 23710 23657 23560 23342 23323 23317 22823 22076 21688 21574
#  21397 20510 20478 20436 19274 18960 18214 17527 16881 16613 15331 14780
#  13367 10967 10702 7615 6126]

# %%
# satellites = []
# for x in id:
#     base_url = f"https://api.n2yo.com/rest/v1/satellite/positions/{x}/40.0583/74.4057/0/1/&apiKey=RSNS74-FAEMYM-S26ZDF-4LIZ"
#     response = requests.get(base_url)
#     data = response.json()
#     satellite_x = json.dumps(data, sort_keys=True,separators=(',', ': '))
#     satellites.append(satellite_x.strip())

# %%
satellites = []
for x in id:
    base_url = f"https://api.n2yo.com/rest/v1/satellite/positions/{x}/40.0583/74.4057/0/1/&apiKey=RSNS74-FAEMYM-S26ZDF-4LIZ"
    response = requests.get(base_url)
    data = response.json()
    satellite_data = data
    satellites.append(satellite_data)

# %%
satellites=satellites

satellites
# Out:
# [{'info': {'satname': 'HYSIS', 'satid': 43719, 'transactionscount': 447},
#   'positions': [{'satlatitude': -39.51716233,
#     'satlongitude': -45.80802678,
#     'sataltitude': 651.22,
#     'azimuth': 250.87,
#     'elevation': -66.32,
#     'ra': 21.18413333,
#     'dec': -43.78267554,
#     'timestamp': 1607045295,
#     'eclipsed': True}]},
#  {'info': {'satname': 'GAOFEN-5', 'satid': 43461, 'transactionscount': 448},
#   'positions': [{'satlatitude': -30.80012755,
#     'satlongitude': -6.47883252,
#     'sataltitude': 711.32,
#     'azimuth': 240.79,
#     'elevation': -49.08,
#     'ra': 46.54701039,
#     'dec': -47.01477833,
#     'timestamp': 1607045295,
#     'eclipsed': True}]},
#  {'info': {'satname': 'NUSAT 5', 'satid': 43204, 'transactionscount': 449},
#   'positions': [{'satlatitude': -56.58486844,
#     'satlongitude': 23.1487831,
#     'sataltitude': 510.83,
#     'azimuth': 206.71,
#     'elevation': -51.3,
#     'ra': 39.4021953,
#     'dec': -68.51037878,
#     'timestamp': 1607045296,
#     'eclipsed': False}]},
#  {'info': {'satname': 'NUSAT 4', 'satid': 43195, 'transactionscount': 450},
#   'positions': [{'satlatitude': 68.50928381,
#     'satlongitude': -149.20508347,
#     'sataltitude': 505.93,
#     'azimuth': 16,
#     'elevation': -30.06,
#     'ra': 335.04996702,
#     'dec': 18.25481316,
#     'timestamp': 1607045297,
#     'eclipsed': False}]},
#  {'info': {'satname': 'VRSS-2', 'satid': 42954, 'transactionscount': 451},
#   'positions': [{'satlatitude': 54.38645184,
#     'satlongitude': 147.04375733,
#     'sataltitude': 641.53,
#     'azimuth': 47.48,
#     'elevation': -18.51,
#     'ra': 302.79639022,
#     'dec': 16.60975757,
#     'timestamp': 1607045297,
#     'eclipsed': False}]},
#  {'info': {'satname': 'VENUS', 'satid': 42901, 'transactionscount': 452},
#   'positions': [{'satlatitude': 10.46963399,
#     'satlongitude': -46.6565577,
#     'sataltitude': 694.96,
#     'azimuth': 299.04,
#     'elevation': -50.59,
#     'ra': 24.66730115,
#     'dec': -15.29040616,
#     'timestamp': 1607045298,
#     'eclipsed': True}]},
#  {'info': {'satname': 'SENTINEL 2B', 'satid': 42063, 'transactionscount': 453},
#   'positions': [{'satlatitude': -39.40989957,
#     'satlongitude': 128.3719862,
#     'sataltitude': 804.7,
#     'azimuth': 141.04,
#     'elevation': -43.53,
#     'ra': 279.12689736,
#     'dec': -60.99740081,
#     'timestamp': 1607045298,
#     'eclipsed': False}]},
#  {'info': {'satname': 'TANSAT', 'satid': 41898, 'transactionscount': 454},
#   'positions': [{'satlatitude': 12.23213982,
#     'satlongitude': -177.41321757,
#     'sataltitude': 697.87,
#     'azimuth': 68.79,
#     'elevation': -45.05,
#     'ra': 306.52409015,
#     'dec': -15.16761593,
#     'timestamp': 1607045299,
#     'eclipsed': False}]},
#  {'info': {'satname': 'RESOURCESAT 2A',
#    'satid': 41877,
#    'transactionscount': 455},
#   'positions': [{'satlatitude': -29.90764131,
#     'satlongitude': -42.03484337,
#     'sataltitude': 831.92,
#     'azimuth': 260.63,
#     'elevation': -62.28,
#     'ra': 25.70859887,
#     'dec': -39.01701803,
#     'timestamp': 1607045299,
#     'eclipsed': True}]},
#  {'info': {'satname': 'WORLDVIEW-4', 'satid': 41848, 'transactionscount': 456},
#   'positions': [{'satlatitude': -37.33779839,
#     'satlongitude': 10.58413593,
#     'sataltitude': 415.8,
#     'azimuth': 226.21,
#     'elevation': -46.89,
#     'ra': 52.38052776,
#     'dec': -56.39141583,
#     'timestamp': 1607045300,
#     'eclipsed': True}]},
#  {'info': {'satname': 'CARTOSAT 2C', 'satid': 41599, 'transactionscount': 457},
#   'positions': [{'satlatitude': -25.95337303,
#     'satlongitude': 116.9825546,
#     'sataltitude': 525.08,
#     'azimuth': 141.18,
#     'elevation': -35.62,
#     'ra': 263.62527096,
#     'dec': -59.21213985,
#     'timestamp': 1607045301,
#     'eclipsed': False}]},
#  {'info': {'satname': 'NUSAT 2 (BATATA)',
#    'satid': 41558,
#    'transactionscount': 458},
#   'positions': [{'satlatitude': 40.79333201,
#     'satlongitude': 162.15250238,
#     'sataltitude': 475.66,
#     'azimuth': 57.56,
#     'elevation': -28.54,
#     'ra': 301.65593907,
#     'dec': 3.03870312,
#     'timestamp': 1607045301,
#     'eclipsed': False}]},
#  {'info': {'satname': 'NUSAT 2 (BATATA)',
#    'satid': 41558,
#    'transactionscount': 459},
#   'positions': [{'satlatitude': 40.73029555,
#     'satlongitude': 162.13403779,
#     'sataltitude': 475.64,
#     'azimuth': 57.63,
#     'elevation': -28.55,
#     'ra': 301.62213728,
#     'dec': 2.99110115,
#     'timestamp': 1607045302,
#     'eclipsed': False}]},
#  {'info': {'satname': 'NUSAT 1 (FRESCO)',
#    'satid': 41557,
#    'transactionscount': 460},
#   'positions': [{'satlatitude': 15.34514803,
#     'satlongitude': 154.80909547,
#     'sataltitude': 475.57,
#     'azimuth': 83.94,
#     'elevation': -33.66,
#     'ra': 289.69521549,
#     'dec': -16.82011337,
#     'timestamp': 1607045302,
#     'eclipsed': False}]},
#  {'info': {'satname': 'NUSAT 1 (FRESCO)',
#    'satid': 41557,
#    'transactionscount': 461},
#   'positions': [{'satlatitude': 15.28155166,
#     'satlongitude': 154.79609178,
#     'sataltitude': 475.56,
#     'azimuth': 84,
#     'elevation': -33.68,
#     'ra': 289.6808039,
#     'dec': -16.86969758,
#     'timestamp': 1607045303,
#     'eclipsed': False}]},
#  {'info': {'satname': 'ZIYUAN 3-2', 'satid': 41556, 'transactionscount': 462},
#   'positions': [{'satlatitude': 12.8844471,
#     'satlongitude': -46.81030715,
#     'sataltitude': 505.38,
#     'azimuth': 300.84,
#     'elevation': -50.29,
#     'ra': 24.03996742,
#     'dec': -14.29022531,
#     'timestamp': 1607045304,
#     'eclipsed': True}]},
#  {'info': {'satname': 'SENTINEL 1B', 'satid': 41456, 'transactionscount': 463},
#   'positions': [{'satlatitude': 44.83947509,
#     'satlongitude': -120.15554472,
#     'sataltitude': 701.8,
#     'azimuth': 10.3,
#     'elevation': -44.28,
#     'ra': 342.19753639,
#     'dec': 5.00652033,
#     'timestamp': 1607045305,
#     'eclipsed': False}]},
#  {'info': {'satname': 'RESURS P3', 'satid': 41386, 'transactionscount': 464},
#   'positions': [{'satlatitude': 12.4072337,
#     'satlongitude': 149.94168628,
#     'sataltitude': 467.8,
#     'azimuth': 89.42,
#     'elevation': -32.66,
#     'ra': 285.97568865,
#     'dec': -19.90683604,
#     'timestamp': 1607045305,
#     'eclipsed': False}]},
#  {'info': {'satname': 'SENTINEL-3A', 'satid': 41335, 'transactionscount': 465},
#   'positions': [{'satlatitude': -60.5881931,
#     'satlongitude': -36.56732285,
#     'sataltitude': 826.77,
#     'azimuth': 219.99,
#     'elevation': -65.61,
#     'ra': 17.87997474,
#     'dec': -56.0674677,
#     'timestamp': 1607045306,
#     'eclipsed': False}]},
#  {'info': {'satname': 'BISONSAT', 'satid': 40968, 'transactionscount': 466},
#   'positions': [{'satlatitude': 64.04342614,
#     'satlongitude': -21.46264056,
#     'sataltitude': 631.76,
#     'azimuth': 328.69,
#     'elevation': -23.57,
#     'ra': 19.96564355,
#     'dec': 19.8817275,
#     'timestamp': 1607045306,
#     'eclipsed': True}]},
#  {'info': {'satname': 'LAPAN A2 (IO-86)',
#    'satid': 40931,
#    'transactionscount': 467},
#   'positions': [{'satlatitude': -5.81902648,
#     'satlongitude': 5.16144549,
#     'sataltitude': 638.88,
#     'azimuth': 252.07,
#     'elevation': -35.7,
#     'ra': 59.30527516,
#     'dec': -34.57483866,
#     'timestamp': 1607045307,
#     'eclipsed': True}]},
#  {'info': {'satname': 'GAOFEN 8', 'satid': 40701, 'transactionscount': 468},
#   'positions': [{'satlatitude': 42.54337697,
#     'satlongitude': -167.4698045,
#     'sataltitude': 505.69,
#     'azimuth': 41.25,
#     'elevation': -37.54,
#     'ra': 318.01736026,
#     'dec': 3.6271236,
#     'timestamp': 1607045307,
#     'eclipsed': False}]},
#  {'info': {'satname': 'SENTINEL 2A', 'satid': 40697, 'transactionscount': 469},
#   'positions': [{'satlatitude': 39.78983235,
#     'satlongitude': -51.76676578,
#     'sataltitude': 794.08,
#     'azimuth': 321.57,
#     'elevation': -39.57,
#     'ra': 18.27589085,
#     'dec': 2.84629643,
#     'timestamp': 1607045308,
#     'eclipsed': True}]},
#  {'info': {'satname': 'KOMPSAT 3A', 'satid': 40536, 'transactionscount': 470},
#   'positions': [{'satlatitude': 12.72591801,
#     'satlongitude': 179.49008431,
#     'sataltitude': 531.41,
#     'azimuth': 70.48,
#     'elevation': -44.3,
#     'ra': 305.14837037,
#     'dec': -15.55471721,
#     'timestamp': 1607045309,
#     'eclipsed': False}]},
#  {'info': {'satname': 'RESURS P2', 'satid': 40360, 'transactionscount': 471},
#   'positions': [{'satlatitude': -44.4145407,
#     'satlongitude': -23.80162911,
#     'sataltitude': 476.44,
#     'azimuth': 236.74,
#     'elevation': -59.81,
#     'ra': 30.6154576,
#     'dec': -50.25124747,
#     'timestamp': 1607045309,
#     'eclipsed': True}]},
#  {'info': {'satname': 'CBERS-4', 'satid': 40336, 'transactionscount': 472},
#   'positions': [{'satlatitude': 43.56884247,
#     'satlongitude': -54.35242494,
#     'sataltitude': 779.46,
#     'azimuth': 325.41,
#     'elevation': -38.61,
#     'ra': 16.06451496,
#     'dec': 5.05522459,
#     'timestamp': 1607045310,
#     'eclipsed': True}]},
#  {'info': {'satname': 'GAOFEN 2', 'satid': 40118, 'transactionscount': 473},
#   'positions': [{'satlatitude': -74.17876128,
#     'satlongitude': 108.04770112,
#     'sataltitude': 654.53,
#     'azimuth': 170.21,
#     'elevation': -56.56,
#     'ra': 331.35336652,
#     'dec': -72.40119445,
#     'timestamp': 1607045311,
#     'eclipsed': False}]},
#  {'info': {'satname': 'SKYSAT 2', 'satid': 40072, 'transactionscount': 474},
#   'positions': [{'satlatitude': 69.80260951,
#     'satlongitude': 47.58041481,
#     'sataltitude': 638.5,
#     'azimuth': 343.28,
#     'elevation': -7.28,
#     'ra': 11.57369056,
#     'dec': 40.13247585,
#     'timestamp': 1607045311,
#     'eclipsed': True}]},
#  {'info': {'satname': 'SPOT 7', 'satid': 40053, 'transactionscount': 475},
#   'positions': [{'satlatitude': -18.81159405,
#     'satlongitude': 125.09227619,
#     'sataltitude': 705.27,
#     'azimuth': 130.63,
#     'elevation': -33.81,
#     'ra': 266.47248264,
#     'dec': -50.49959585,
#     'timestamp': 1607045312,
#     'eclipsed': False}]},
#  {'info': {'satname': 'ALOS 2', 'satid': 39766, 'transactionscount': 476},
#   'positions': [{'satlatitude': -27.60869363,
#     'satlongitude': -18.07826656,
#     'sataltitude': 641.87,
#     'azimuth': 249.85,
#     'elevation': -52.58,
#     'ra': 39.98780496,
#     'dec': -42.29672949,
#     'timestamp': 1607045312,
#     'eclipsed': True}]},
#  {'info': {'satname': 'KAZEOSAT 1', 'satid': 39731, 'transactionscount': 477},
#   'positions': [{'satlatitude': 23.13735094,
#     'satlongitude': 135.76200905,
#     'sataltitude': 754.12,
#     'azimuth': 88.71,
#     'elevation': -20.63,
#     'ra': 276.45055731,
#     'dec': -12.10930344,
#     'timestamp': 1607045313,
#     'eclipsed': False}]},
#  {'info': {'satname': 'SHIYAN-5 (SY-5)',
#    'satid': 39455,
#    'transactionscount': 478},
#   'positions': [{'satlatitude': -38.24400757,
#     'satlongitude': 173.80239651,
#     'sataltitude': 751.33,
#     'azimuth': 116.45,
#     'elevation': -58.03,
#     'ra': 305.91509414,
#     'dec': -46.68877732,
#     'timestamp': 1607045313,
#     'eclipsed': False}]},
#  {'info': {'satname': 'STSAT 3', 'satid': 39422, 'transactionscount': 479},
#   'positions': [{'satlatitude': -1.70786964,
#     'satlongitude': 87.51130382,
#     'sataltitude': 617.27,
#     'azimuth': 160.67,
#     'elevation': -15.07,
#     'ra': 209.05513975,
#     'dec': -59.70528951,
#     'timestamp': 1607045314,
#     'eclipsed': False}]},
#  {'info': {'satname': 'DUBAISAT 2', 'satid': 39419, 'transactionscount': 480},
#   'positions': [{'satlatitude': -48.24236452,
#     'satlongitude': 102.30179787,
#     'sataltitude': 610.66,
#     'azimuth': 161.72,
#     'elevation': -43.31,
#     'ra': 278.42019837,
#     'dec': -75.99512508,
#     'timestamp': 1607045315,
#     'eclipsed': False}]},
#  {'info': {'satname': 'SKYSAT 1', 'satid': 39418, 'transactionscount': 481},
#   'positions': [{'satlatitude': 10.7883605,
#     'satlongitude': 140.732163,
#     'sataltitude': 586.27,
#     'azimuth': 96.87,
#     'elevation': -28.54,
#     'ra': 278.44730508,
#     'dec': -22.79076251,
#     'timestamp': 1607045315,
#     'eclipsed': False}]},
#  {'info': {'satname': 'RESURS P1', 'satid': 39186, 'transactionscount': 482},
#   'positions': [{'satlatitude': -36.36738309,
#     'satlongitude': 119.41486608,
#     'sataltitude': 467.1,
#     'azimuth': 145.03,
#     'elevation': -41.3,
#     'ra': 273.53690416,
#     'dec': -63.6056298,
#     'timestamp': 1607045316,
#     'eclipsed': False}]},
#  {'info': {'satname': 'VNREDSAT 1', 'satid': 39160, 'transactionscount': 483},
#   'positions': [{'satlatitude': -60.67940183,
#     'satlongitude': -27.46303929,
#     'sataltitude': 707.71,
#     'azimuth': 218.82,
#     'elevation': -63.48,
#     'ra': 20.93022066,
#     'dec': -57.50500568,
#     'timestamp': 1607045316,
#     'eclipsed': False}]},
#  {'info': {'satname': 'PROBA V', 'satid': 39159, 'transactionscount': 484},
#   'positions': [{'satlatitude': 46.93089917,
#     'satlongitude': 123.3698213,
#     'sataltitude': 824.64,
#     'azimuth': 62.32,
#     'elevation': -7.09,
#     'ra': 283.72898359,
#     'dec': 15.9047699,
#     'timestamp': 1607045317,
#     'eclipsed': False}]},
#  {'info': {'satname': 'GAOFEN 1', 'satid': 39150, 'transactionscount': 485},
#   'positions': [{'satlatitude': -79.39673039,
#     'satlongitude': 3.09168946,
#     'sataltitude': 656.12,
#     'azimuth': 192.55,
#     'elevation': -61.65,
#     'ra': 4.95594454,
#     'dec': -67.23028424,
#     'timestamp': 1607045317,
#     'eclipsed': False}]},
#  {'info': {'satname': 'SARAL', 'satid': 39086, 'transactionscount': 486},
#   'positions': [{'satlatitude': 33.60411602,
#     'satlongitude': -107.73840615,
#     'sataltitude': 788.36,
#     'azimuth': 1.86,
#     'elevation': -50.65,
#     'ra': 348.45510571,
#     'dec': -0.80316883,
#     'timestamp': 1607045318,
#     'eclipsed': False}]},
#  {'info': {'satname': 'LANDSAT 8', 'satid': 39084, 'transactionscount': 487},
#   'positions': [{'satlatitude': -74.40681593,
#     'satlongitude': 100.06829765,
#     'sataltitude': 730.64,
#     'azimuth': 172.51,
#     'elevation': -55.99,
#     'ra': 334.63655017,
#     'dec': -73.43304095,
#     'timestamp': 1607045319,
#     'eclipsed': False}]},
#  {'info': {'satname': 'GOKTURK 2', 'satid': 39030, 'transactionscount': 488},
#   'positions': [{'satlatitude': -11.21977179,
#     'satlongitude': -54.17940883,
#     'sataltitude': 658.48,
#     'azimuth': 287.97,
#     'elevation': -61.71,
#     'ra': 20.06918101,
#     'dec': -27.12830318,
#     'timestamp': 1607045319,
#     'eclipsed': True}]},
#  {'info': {'satname': 'VRSS-1', 'satid': 38782, 'transactionscount': 489},
#   'positions': [{'satlatitude': 53.53055746,
#     'satlongitude': 127.74843459,
#     'sataltitude': 660.7,
#     'azimuth': 50.98,
#     'elevation': -10.8,
#     'ra': 295.11331692,
#     'dec': 20.65755549,
#     'timestamp': 1607045320,
#     'eclipsed': False}]},
#  {'info': {'satname': 'SPOT 6', 'satid': 38755, 'transactionscount': 490},
#   'positions': [{'satlatitude': 22.79815994,
#     'satlongitude': -55.91430024,
#     'sataltitude': 700.32,
#     'azimuth': 314.12,
#     'elevation': -48.54,
#     'ra': 18.29611858,
#     'dec': -7.58315399,
#     'timestamp': 1607045320,
#     'eclipsed': True}]},
#  {'info': {'satname': 'BKA 2', 'satid': 38708, 'transactionscount': 491},
#   'positions': [{'satlatitude': 13.7807522,
#     'satlongitude': -31.9205577,
#     'sataltitude': 507.87,
#     'azimuth': 291.12,
#     'elevation': -44.49,
#     'ra': 33.13778666,
#     'dec': -14.78815283,
#     'timestamp': 1607045321,
#     'eclipsed': True}]},
#  {'info': {'satname': 'KANOPUS-V 1', 'satid': 38707, 'transactionscount': 492},
#   'positions': [{'satlatitude': -78.76444822,
#     'satlongitude': -158.6887159,
#     'sataltitude': 536.63,
#     'azimuth': 166.87,
#     'elevation': -67.25,
#     'ra': 338.90648058,
#     'dec': -61.96633921,
#     'timestamp': 1607045322,
#     'eclipsed': False}]},
#  {'info': {'satname': 'RISAT 1', 'satid': 38248, 'transactionscount': 493},
#   'positions': [{'satlatitude': -66.57992717,
#     'satlongitude': -91.53964825,
#     'sataltitude': 561.74,
#     'azimuth': 192.19,
#     'elevation': -75.73,
#     'ra': 354.70998309,
#     'dec': -54.06050706,
#     'timestamp': 1607045322,
#     'eclipsed': False}]},
#  {'info': {'satname': 'ZY 1', 'satid': 38038, 'transactionscount': 494},
#   'positions': [{'satlatitude': -28.30091711,
#     'satlongitude': 112.62978886,
#     'sataltitude': 784.45,
#     'azimuth': 145.84,
#     'elevation': -34.33,
#     'ra': 258.38892406,
#     'dec': -62.30850496,
#     'timestamp': 1607045323,
#     'eclipsed': False}]},
#  {'info': {'satname': 'SICH 2', 'satid': 37794, 'transactionscount': 495},
#   'positions': [{'satlatitude': -64.33860155,
#     'satlongitude': -48.89635553,
#     'sataltitude': 720.52,
#     'azimuth': 214.34,
#     'elevation': -68.79,
#     'ra': 11.04271652,
#     'dec': -56.10089815,
#     'timestamp': 1607045323,
#     'eclipsed': False}]},
#  {'info': {'satname': 'HAIYANG 2A', 'satid': 37781, 'transactionscount': 496},
#   'positions': [{'satlatitude': 15.15990252,
#     'satlongitude': -114.31846966,
#     'sataltitude': 970.63,
#     'azimuth': 10.17,
#     'elevation': -59.89,
#     'ra': 344.48547515,
#     'dec': -10.44486701,
#     'timestamp': 1607045324,
#     'eclipsed': False}]},
#  {'info': {'satname': 'RESOURCESAT 2',
#    'satid': 37387,
#    'transactionscount': 497},
#   'positions': [{'satlatitude': 78.30532995,
#     'satlongitude': -177.46100878,
#     'sataltitude': 834.78,
#     'azimuth': 13.73,
#     'elevation': -20.43,
#     'ra': 335.14041709,
#     'dec': 28.06765024,
#     'timestamp': 1607045324,
#     'eclipsed': False}]},
#  {'info': {'satname': 'TIANHUI 1', 'satid': 36985, 'transactionscount': 498},
#   'positions': [{'satlatitude': -77.57705512,
#     'satlongitude': 110.4695075,
#     'sataltitude': 540.95,
#     'azimuth': 171.54,
#     'elevation': -58.58,
#     'ra': 336.11925223,
#     'dec': -70.78976298,
#     'timestamp': 1607045325,
#     'eclipsed': False}]},
#  {'info': {'satname': 'CARTOSAT 2B', 'satid': 36795, 'transactionscount': 499},
#   'positions': [{'satlatitude': -47.50899199,
#     'satlongitude': 111.47303139,
#     'sataltitude': 643.9,
#     'azimuth': 155.77,
#     'elevation': -44.19,
#     'ra': 280.19253104,
#     'dec': -71.6305936,
#     'timestamp': 1607045325,
#     'eclipsed': False}]},
#  {'info': {'satname': 'CARTOSAT 2B', 'satid': 36795, 'transactionscount': 500},
#   'positions': [{'satlatitude': -47.56929285,
#     'satlongitude': 111.45039381,
#     'sataltitude': 643.92,
#     'azimuth': 155.82,
#     'elevation': -44.22,
#     'ra': 280.28387009,
#     'dec': -71.6585621,
#     'timestamp': 1607045326,
#     'eclipsed': False}]},
#  {'info': {'satname': 'YAOGAN 9C', 'satid': 36415, 'transactionscount': 501},
#   'positions': [{'satlatitude': 57.04509411,
#     'satlongitude': 129.49289032,
#     'sataltitude': 958.54,
#     'azimuth': 45.33,
#     'elevation': -8.27,
#     'ra': 298.04635517,
#     'dec': 26.04173177,
#     'timestamp': 1607045326,
#     'eclipsed': False}]},
#  {'info': {'satname': 'YAOGAN 9B', 'satid': 36414, 'transactionscount': 502},
#   'positions': [{'satlatitude': 55.19600406,
#     'satlongitude': 124.38396194,
#     'sataltitude': 947.67,
#     'azimuth': 48.15,
#     'elevation': -5.98,
#     'ra': 294.01077113,
#     'dec': 26.10287773,
#     'timestamp': 1607045327,
#     'eclipsed': False}]},
#  {'info': {'satname': 'YAOGAN 9A', 'satid': 36413, 'transactionscount': 503},
#   'positions': [{'satlatitude': 39.68188557,
#     'satlongitude': 103.46227127,
#     'sataltitude': 873.64,
#     'azimuth': 81.51,
#     'elevation': 6.97,
#     'ra': 259.65922627,
#     'dec': 10.89444377,
#     'timestamp': 1607045327,
#     'eclipsed': False}]},
#  {'info': {'satname': 'YAOGAN 8', 'satid': 36121, 'transactionscount': 504},
#   'positions': [{'satlatitude': -47.36566136,
#     'satlongitude': 3.77573316,
#     'sataltitude': 1249.03,
#     'azimuth': 222.32,
#     'elevation': -50.04,
#     'ra': 46.83856007,
#     'dec': -59.01481763,
#     'timestamp': 1607045328,
#     'eclipsed': False}]},
#  {'info': {'satname': 'YAOGAN 7', 'satid': 36110, 'transactionscount': 505},
#   'positions': [{'satlatitude': 21.90994626,
#     'satlongitude': 79.47161505,
#     'sataltitude': 629.35,
#     'azimuth': 165.1,
#     'elevation': 6.71,
#     'ra': 189.52420121,
#     'dec': -41.22222359,
#     'timestamp': 1607045328,
#     'eclipsed': False}]},
#  {'info': {'satname': 'OCEANSAT 2', 'satid': 35931, 'transactionscount': 506},
#   'positions': [{'satlatitude': 28.99459624,
#     'satlongitude': 160.93949364,
#     'sataltitude': 726.44,
#     'azimuth': 68.85,
#     'elevation': -30.22,
#     'ra': 295.70544102,
#     'dec': -4.90089473,
#     'timestamp': 1607045329,
#     'eclipsed': False}]},
#  {'info': {'satname': 'SUMBANDILA', 'satid': 35870, 'transactionscount': 507},
#   'positions': [{'satlatitude': -74.13916914,
#     'satlongitude': 65.33440729,
#     'sataltitude': 384.8,
#     'azimuth': 182.73,
#     'elevation': -56.17,
#     'ra': 355.06955779,
#     'dec': -73.93899081,
#     'timestamp': 1607045329,
#     'eclipsed': False}]},
#  {'info': {'satname': 'YAOGAN 6', 'satid': 34839, 'transactionscount': 508},
#   'positions': [{'satlatitude': 49.09444765,
#     'satlongitude': -125.83659275,
#     'sataltitude': 490.19,
#     'azimuth': 13.1,
#     'elevation': -42.4,
#     'ra': 339.98011318,
#     'dec': 6.54753661,
#     'timestamp': 1607045330,
#     'eclipsed': False}]},
#  {'info': {'satname': 'GEOEYE 1', 'satid': 33331, 'transactionscount': 509},
#   'positions': [{'satlatitude': -20.75096111,
#     'satlongitude': -41.61764226,
#     'sataltitude': 688.52,
#     'azimuth': 269.83,
#     'elevation': -59.76,
#     'ra': 27.04878657,
#     'dec': -33.99910143,
#     'timestamp': 1607045331,
#     'eclipsed': True}]},
#  {'info': {'satname': 'JASON 2', 'satid': 33105, 'transactionscount': 510},
#   'positions': [{'satlatitude': -37.17399061,
#     'satlongitude': 84.65085411,
#     'sataltitude': 1320.07,
#     'azimuth': 171.62,
#     'elevation': -32.24,
#     'ra': 212.57591076,
#     'dec': -79.55678948,
#     'timestamp': 1607045331,
#     'eclipsed': False}]},
#  {'info': {'satname': 'CARTOSAT 2A', 'satid': 32783, 'transactionscount': 511},
#   'positions': [{'satlatitude': 60.07428796,
#     'satlongitude': -73.23062595,
#     'sataltitude': 647.04,
#     'azimuth': 344.04,
#     'elevation': -34.72,
#     'ra': 3.17341297,
#     'dec': 13.64017751,
#     'timestamp': 1607045332,
#     'eclipsed': True}]},
#  {'info': {'satname': 'TECSAR', 'satid': 32476, 'transactionscount': 512},
#   'positions': [{'satlatitude': -40.18132081,
#     'satlongitude': -58.35297904,
#     'sataltitude': 530.47,
#     'azimuth': 254.66,
#     'elevation': -71.42,
#     'ra': 14.26896906,
#     'dec': -42.51806913,
#     'timestamp': 1607045332,
#     'eclipsed': False}]},
#  {'info': {'satname': 'RADARSAT 2', 'satid': 32382, 'transactionscount': 513},
#   'positions': [{'satlatitude': -43.79660934,
#     'satlongitude': -104.11669121,
#     'sataltitude': 809.25,
#     'azimuth': 197.43,
#     'elevation': -88.11,
#     'ra': 350.44270335,
#     'dec': -42.00773414,
#     'timestamp': 1607045333,
#     'eclipsed': False}]},
#  {'info': {'satname': 'CARTOSAT 2AT',
#    'satid': 29710,
#    'transactionscount': 514},
#   'positions': [{'satlatitude': 75.53346658,
#     'satlongitude': 163.37069031,
#     'sataltitude': 542.47,
#     'azimuth': 18.73,
#     'elevation': -20.76,
#     'ra': 330.15582799,
#     'dec': 26.62596315,
#     'timestamp': 1607045333,
#     'eclipsed': False}]},
#  {'info': {'satname': 'LAPAN-TUBSAT',
#    'satid': 29709,
#    'transactionscount': 515},
#   'positions': [{'satlatitude': -76.38674084,
#     'satlongitude': -14.27703647,
#     'sataltitude': 642.46,
#     'azimuth': 197.64,
#     'elevation': -62.98,
#     'ra': 8.66913704,
#     'dec': -64.90597078,
#     'timestamp': 1607045334,
#     'eclipsed': False}]},
#  {'info': {'satname': 'KOMPSAT 2', 'satid': 29268, 'transactionscount': 516},
#   'positions': [{'satlatitude': -39.49809333,
#     'satlongitude': -62.64706332,
#     'sataltitude': 707.42,
#     'azimuth': 257.41,
#     'elevation': -72.77,
#     'ra': 12.48115702,
#     'dec': -41.69663641,
#     'timestamp': 1607045334,
#     'eclipsed': False}]},
#  {'info': {'satname': 'RESURS DK-1', 'satid': 29228, 'transactionscount': 517},
#   'positions': [{'satlatitude': 53.46281442,
#     'satlongitude': 171.28950072,
#     'sataltitude': 568.36,
#     'azimuth': 41.84,
#     'elevation': -27.22,
#     'ra': 312.3441802,
#     'dec': 12.24261936,
#     'timestamp': 1607045335,
#     'eclipsed': False}]},
#  {'info': {'satname': 'EROS B', 'satid': 29079, 'transactionscount': 518},
#   'positions': [{'satlatitude': 26.21579283,
#     'satlongitude': -175.5064691,
#     'sataltitude': 499.26,
#     'azimuth': 57.47,
#     'elevation': -41.33,
#     'ra': 310.1053846,
#     'dec': -6.69341436,
#     'timestamp': 1607045335,
#     'eclipsed': False}]},
#  {'info': {'satname': 'ALOS', 'satid': 28931, 'transactionscount': 519},
#   'positions': [{'satlatitude': -3.92354267,
#     'satlongitude': -138.38018736,
#     'sataltitude': 687.59,
#     'azimuth': 47.75,
#     'elevation': -65.31,
#     'ra': 330.24431917,
#     'dec': -21.83185653,
#     'timestamp': 1607045336,
#     'eclipsed': False}]},
#  {'info': {'satname': 'SINAH 1', 'satid': 28893, 'transactionscount': 520},
#   'positions': [{'satlatitude': 37.13498337,
#     'satlongitude': 2.93467621,
#     'sataltitude': 693.31,
#     'azimuth': 291.6,
#     'elevation': -21.46,
#     'ra': 49.69845769,
#     'dec': 1.39844796,
#     'timestamp': 1607045337,
#     'eclipsed': True}]},
#  {'info': {'satname': 'TOPSAT', 'satid': 28891, 'transactionscount': 521},
#   'positions': [{'satlatitude': -54.11682578,
#     'satlongitude': 19.55159069,
#     'sataltitude': 721.8,
#     'azimuth': 209.99,
#     'elevation': -50.31,
#     'ra': 43.70984249,
#     'dec': -66.83465322,
#     'timestamp': 1607045338,
#     'eclipsed': False}]},
#  {'info': {'satname': 'CARTOSAT-1', 'satid': 28649, 'transactionscount': 522},
#   'positions': [{'satlatitude': 63.6533116,
#     'satlongitude': -67.36193303,
#     'sataltitude': 628.58,
#     'azimuth': 343.19,
#     'elevation': -32.3,
#     'ra': 4.47426923,
#     'dec': 15.83486675,
#     'timestamp': 1607045338,
#     'eclipsed': True}]},
#  {'info': {'satname': 'TANSUO 1', 'satid': 28220, 'transactionscount': 523},
#   'positions': [{'satlatitude': 55.74990779,
#     'satlongitude': -157.40807997,
#     'sataltitude': 562.39,
#     'azimuth': 27.34,
#     'elevation': -34.15,
#     'ra': 326.88808559,
#     'dec': 11.48525037,
#     'timestamp': 1607045339,
#     'eclipsed': False}]},
#  {'info': {'satname': 'AURA', 'satid': 28376, 'transactionscount': 524},
#   'positions': [{'satlatitude': -63.76827588,
#     'satlongitude': -13.16720786,
#     'sataltitude': 727.86,
#     'azimuth': 212.56,
#     'elevation': -60.56,
#     'ra': 23.35679941,
#     'dec': -61.4409951,
#     'timestamp': 1607045340,
#     'eclipsed': False}]},
#  {'info': {'satname': 'ROCSAT 2', 'satid': 28254, 'transactionscount': 525},
#   'positions': [{'satlatitude': -15.39001959,
#     'satlongitude': 86.70743838,
#     'sataltitude': 896.03,
#     'azimuth': 165.69,
#     'elevation': -21.31,
#     'ra': 206.84948633,
#     'dec': -67.49625848,
#     'timestamp': 1607045340,
#     'eclipsed': False}]},
#  {'info': {'satname': 'TANSUO 1', 'satid': 28220, 'transactionscount': 526},
#   'positions': [{'satlatitude': 55.87150641,
#     'satlongitude': -157.47043101,
#     'sataltitude': 562.41,
#     'azimuth': 27.29,
#     'elevation': -34.08,
#     'ra': 326.91225551,
#     'dec': 11.56097544,
#     'timestamp': 1607045341,
#     'eclipsed': False}]},
#  {'info': {'satname': 'CBERS 2', 'satid': 28057, 'transactionscount': 527},
#   'positions': [{'satlatitude': -46.25702249,
#     'satlongitude': -5.3779114,
#     'sataltitude': 792.13,
#     'azimuth': 227.4,
#     'elevation': -53.63,
#     'ra': 40.52684706,
#     'dec': -55.69368103,
#     'timestamp': 1607045342,
#     'eclipsed': False}]},
#  {'info': {'satname': 'IRS P6', 'satid': 28051, 'transactionscount': 528},
#   'positions': [{'satlatitude': 4.95324276,
#     'satlongitude': 137.5478847,
#     'sataltitude': 764.8,
#     'azimuth': 103.96,
#     'elevation': -28.24,
#     'ra': 274.44818376,
#     'dec': -27.81441371,
#     'timestamp': 1607045343,
#     'eclipsed': False}]},
#  {'info': {'satname': 'MONITOR-E/SL-19',
#    'satid': 27840,
#    'transactionscount': 529},
#   'positions': [{'satlatitude': -39.14171937,
#     'satlongitude': 23.51128591,
#     'sataltitude': 732.08,
#     'azimuth': 217.23,
#     'elevation': -42.89,
#     'ra': 61.82553619,
#     'dec': -62.22413746,
#     'timestamp': 1607045345,
#     'eclipsed': False}]},
#  {'info': {'satname': 'ADEOS 2', 'satid': 27597, 'transactionscount': 530},
#   'positions': [{'satlatitude': -7.31308575,
#     'satlongitude': 5.83671358,
#     'sataltitude': 803.98,
#     'azimuth': 250.49,
#     'elevation': -35.19,
#     'ra': 60.80750719,
#     'dec': -35.45479217,
#     'timestamp': 1607045345,
#     'eclipsed': True}]},
#  {'info': {'satname': 'ALSAT 1', 'satid': 27559, 'transactionscount': 531},
#   'positions': [{'satlatitude': -19.83081911,
#     'satlongitude': 25.93229417,
#     'sataltitude': 658.64,
#     'azimuth': 227.01,
#     'elevation': -33.8,
#     'ra': 74.13482354,
#     'dec': -52.41870399,
#     'timestamp': 1607045346,
#     'eclipsed': False}]},
#  {'info': {'satname': 'HAIYANG 1', 'satid': 27430, 'transactionscount': 532},
#   'positions': [{'satlatitude': 76.06815171,
#     'satlongitude': 49.55289635,
#     'sataltitude': 806.71,
#     'azimuth': 350.44,
#     'elevation': -8.94,
#     'ra': 2.0350206,
#     'dec': 40.08911362,
#     'timestamp': 1607045348,
#     'eclipsed': False}]},
#  {'info': {'satname': 'AQUA', 'satid': 27424, 'transactionscount': 533},
#   'positions': [{'satlatitude': -80.75561554,
#     'satlongitude': -116.59169302,
#     'sataltitude': 731.57,
#     'azimuth': 177.29,
#     'elevation': -68.53,
#     'ra': 347.69409581,
#     'dec': -61.61764101,
#     'timestamp': 1607045348,
#     'eclipsed': False}]},
#  {'info': {'satname': 'SPOT 5', 'satid': 27421, 'transactionscount': 534},
#   'positions': [{'satlatitude': -9.67028373,
#     'satlongitude': -46.96401967,
#     'sataltitude': 665.92,
#     'azimuth': 283.72,
#     'elevation': -58.33,
#     'ra': 24.67638827,
#     'dec': -27.0404388,
#     'timestamp': 1607045350,
#     'eclipsed': True}]},
#  {'info': {'satname': 'ENVISAT', 'satid': 27386, 'transactionscount': 535},
#   'positions': [{'satlatitude': 47.24270202,
#     'satlongitude': -127.2604762,
#     'sataltitude': 771.71,
#     'azimuth': 14.52,
#     'elevation': -42.08,
#     'ra': 338.97006615,
#     'dec': 6.66876509,
#     'timestamp': 1607045351,
#     'eclipsed': False}]},
#  {'info': {'satname': 'MAROC TUBSAT',
#    'satid': 27004,
#    'transactionscount': 536},
#   'positions': [{'satlatitude': -60.06924383,
#     'satlongitude': 32.18196662,
#     'sataltitude': 1008.04,
#     'azimuth': 200.55,
#     'elevation': -49.85,
#     'ra': 38.94904534,
#     'dec': -72.66978479,
#     'timestamp': 1607045351,
#     'eclipsed': False}]},
#  {'info': {'satname': 'BADR B', 'satid': 27003, 'transactionscount': 537},
#   'positions': [{'satlatitude': 19.98424176,
#     'satlongitude': -161.4478759,
#     'sataltitude': 1011.28,
#     'azimuth': 52.24,
#     'elevation': -46.78,
#     'ra': 316.57544475,
#     'dec': -8.55985339,
#     'timestamp': 1607045352,
#     'eclipsed': False}]},
#  {'info': {'satname': 'METEOR 3M', 'satid': 27001, 'transactionscount': 538},
#   'positions': [{'satlatitude': -71.94390974,
#     'satlongitude': 168.86748058,
#     'sataltitude': 1029,
#     'azimuth': 156.34,
#     'elevation': -62.59,
#     'ra': 325.24133572,
#     'dec': -63.45375088,
#     'timestamp': 1607045352,
#     'eclipsed': False}]},
#  {'info': {'satname': 'JASON', 'satid': 26997, 'transactionscount': 539},
#   'positions': [{'satlatitude': -64.25923333,
#     'satlongitude': 126.47239178,
#     'sataltitude': 1343,
#     'azimuth': 158.16,
#     'elevation': -52.39,
#     'ra': 306.26061966,
#     'dec': -70.72970617,
#     'timestamp': 1607045353,
#     'eclipsed': False}]},
#  {'info': {'satname': 'TES', 'satid': 26957, 'transactionscount': 540},
#   'positions': [{'satlatitude': 10.41075504,
#     'satlongitude': 4.7973615,
#     'sataltitude': 506.49,
#     'azimuth': 265.04,
#     'elevation': -30.6,
#     'ra': 58.11032261,
#     'dec': -22.72921126,
#     'timestamp': 1607045354,
#     'eclipsed': True}]},
#  {'info': {'satname': 'SAC C', 'satid': 26620, 'transactionscount': 541},
#   'positions': [{'satlatitude': 81.30367896,
#     'satlongitude': 120.10804328,
#     'sataltitude': 709.3,
#     'azimuth': 8.95,
#     'elevation': -14.73,
#     'ra': 339.19858752,
#     'dec': 34.43887818,
#     'timestamp': 1607045355,
#     'eclipsed': False}]},
#  {'info': {'satname': 'EO 1', 'satid': 26619, 'transactionscount': 542},
#   'positions': [{'satlatitude': 67.20370583,
#     'satlongitude': 63.56398472,
#     'sataltitude': 685.79,
#     'azimuth': 350.99,
#     'elevation': -2.26,
#     'ra': 2.88765953,
#     'dec': 46.73638788,
#     'timestamp': 1607045355,
#     'eclipsed': False}]},
#  {'info': {'satname': 'TIUNGSAT 1', 'satid': 26548, 'transactionscount': 543},
#   'positions': [{'satlatitude': -48.94534142,
#     'satlongitude': -122.83613778,
#     'sataltitude': 611.8,
#     'azimuth': 130.62,
#     'elevation': -82.2,
#     'ra': 341.36819696,
#     'dec': -44.98611537,
#     'timestamp': 1607045356,
#     'eclipsed': False}]},
#  {'info': {'satname': 'KOMPSAT', 'satid': 26032, 'transactionscount': 544},
#   'positions': [{'satlatitude': 13.72196362,
#     'satlongitude': -166.44088021,
#     'sataltitude': 663.22,
#     'azimuth': 60.09,
#     'elevation': -48.72,
#     'ra': 313.76831152,
#     'dec': -13.45075585,
#     'timestamp': 1607045356,
#     'eclipsed': False}]},
#  {'info': {'satname': 'TERRA', 'satid': 25994, 'transactionscount': 545},
#   'positions': [{'satlatitude': 17.4104913,
#     'satlongitude': -47.37619405,
#     'sataltitude': 704.66,
#     'azimuth': 304.34,
#     'elevation': -48.04,
#     'ra': 24.03139961,
#     'dec': -11.08707465,
#     'timestamp': 1607045357,
#     'eclipsed': True}]},
#  {'info': {'satname': 'CBERS 1', 'satid': 25940, 'transactionscount': 546},
#   'positions': [{'satlatitude': 77.41064774,
#     'satlongitude': 50.45146451,
#     'sataltitude': 786.71,
#     'azimuth': 351.84,
#     'elevation': -9.97,
#     'ra': 0.09307588,
#     'dec': 39.28571379,
#     'timestamp': 1607045357,
#     'eclipsed': False}]},
#  {'info': {'satname': 'IKONOS 2', 'satid': 25919, 'transactionscount': 547},
#   'positions': [{'satlatitude': 32.80640487,
#     'satlongitude': -154.74772236,
#     'sataltitude': 614.52,
#     'azimuth': 39.59,
#     'elevation': -44.61,
#     'ra': 322.81423917,
#     'dec': -1.89198261,
#     'timestamp': 1607045358,
#     'eclipsed': False}]},
#  {'info': {'satname': 'OKEAN O', 'satid': 25860, 'transactionscount': 548},
#   'positions': [{'satlatitude': 74.45970483,
#     'satlongitude': -125.77785875,
#     'sataltitude': 651.27,
#     'azimuth': 5.88,
#     'elevation': -27.99,
#     'ra': 344.24353736,
#     'dec': 21.58357878,
#     'timestamp': 1607045359,
#     'eclipsed': False}]},
#  {'info': {'satname': 'QUIKSCAT', 'satid': 25789, 'transactionscount': 549},
#   'positions': [{'satlatitude': 80.07306798,
#     'satlongitude': -27.09079608,
#     'sataltitude': 778.3,
#     'azimuth': 347.7,
#     'elevation': -19.68,
#     'ra': 3.07147728,
#     'dec': 29.08814395,
#     'timestamp': 1607045359,
#     'eclipsed': True}]},
#  {'info': {'satname': 'IRS P4 (OCEANSAT 1)',
#    'satid': 25758,
#    'transactionscount': 550},
#   'positions': [{'satlatitude': 26.64705627,
#     'satlongitude': -72.78588522,
#     'sataltitude': 719.48,
#     'azimuth': 329.67,
#     'elevation': -51.02,
#     'ra': 8.40798766,
#     'dec': -5.0076798,
#     'timestamp': 1607045360,
#     'eclipsed': True}]},
#  {'info': {'satname': 'TUBSAT', 'satid': 25757, 'transactionscount': 551},
#   'positions': [{'satlatitude': -27.47533256,
#     'satlongitude': -13.02098947,
#     'sataltitude': 741.87,
#     'azimuth': 247.14,
#     'elevation': -50.3,
#     'ra': 43.80086314,
#     'dec': -43.29534215,
#     'timestamp': 1607045360,
#     'eclipsed': True}]},
#  {'info': {'satname': 'KITSAT 3', 'satid': 25756, 'transactionscount': 552},
#   'positions': [{'satlatitude': 2.85886301,
#     'satlongitude': 8.60922058,
#     'sataltitude': 723.61,
#     'azimuth': 256.27,
#     'elevation': -30.46,
#     'ra': 62.84739891,
#     'dec': -28.88186335,
#     'timestamp': 1607045361,
#     'eclipsed': True}]},
#  {'info': {'satname': 'OSCAR 36 (UOSAT 12)',
#    'satid': 25693,
#    'transactionscount': 553},
#   'positions': [{'satlatitude': 16.31569406,
#     'satlongitude': -99.97615362,
#     'sataltitude': 648.05,
#     'azimuth': 353.55,
#     'elevation': -60.14,
#     'ra': 353.04511045,
#     'dec': -10.42901267,
#     'timestamp': 1607045361,
#     'eclipsed': False}]},
#  {'info': {'satname': 'LANDSAT 7', 'satid': 25682, 'transactionscount': 554},
#   'positions': [{'satlatitude': -43.83663399,
#     'satlongitude': 113.1006083,
#     'sataltitude': 720.16,
#     'azimuth': 153.03,
#     'elevation': -42.4,
#     'ra': 274.88832131,
#     'dec': -69.65132052,
#     'timestamp': 1607045362,
#     'eclipsed': False}]},
#  {'info': {'satname': 'SUNSAT', 'satid': 25636, 'transactionscount': 555},
#   'positions': [{'satlatitude': 33.57635434,
#     'satlongitude': 30.64119606,
#     'sataltitude': 798.36,
#     'azimuth': 273.62,
#     'elevation': -7.14,
#     'ra': 71.98451558,
#     'dec': -1.78930425,
#     'timestamp': 1607045362,
#     'eclipsed': True}]},
#  {'info': {'satname': 'ROCSAT 1', 'satid': 25616, 'transactionscount': 556},
#   'positions': [{'satlatitude': 20.93779405,
#     'satlongitude': -33.11851659,
#     'sataltitude': 477.28,
#     'azimuth': 297.11,
#     'elevation': -42.46,
#     'ra': 31.65382817,
#     'dec': -10.3176047,
#     'timestamp': 1607045363,
#     'eclipsed': True}]},
#  {'info': {'satname': 'SCD 2', 'satid': 25504, 'transactionscount': 557},
#   'positions': [{'satlatitude': 7.7987354,
#     'satlongitude': -159.91324406,
#     'sataltitude': 730.52,
#     'azimuth': 59.29,
#     'elevation': -53.2,
#     'ra': 317.30443847,
#     'dec': -16.43564489,
#     'timestamp': 1607045363,
#     'eclipsed': False}]},
#  {'info': {'satname': 'TECHSAT 1B', 'satid': 25397, 'transactionscount': 558},
#   'positions': [{'satlatitude': 16.07527954,
#     'satlongitude': 6.24662391,
#     'sataltitude': 815.53,
#     'azimuth': 268.94,
#     'elevation': -25.97,
#     'ra': 60.00040275,
#     'dec': -17.13505787,
#     'timestamp': 1607045364,
#     'eclipsed': True}]},
#  {'info': {'satname': 'TMSAT', 'satid': 25396, 'transactionscount': 559},
#   'positions': [{'satlatitude': -49.72101188,
#     'satlongitude': -6.61132522,
#     'sataltitude': 828.04,
#     'azimuth': 224.82,
#     'elevation': -54.99,
#     'ra': 37.92001632,
#     'dec': -57.05953457,
#     'timestamp': 1607045365,
#     'eclipsed': False}]},
#  {'info': {'satname': 'FASAT B', 'satid': 25395, 'transactionscount': 560},
#   'positions': [{'satlatitude': -21.89429876,
#     'satlongitude': 0.31999513,
#     'sataltitude': 814.14,
#     'azimuth': 243.52,
#     'elevation': -42.98,
#     'ra': 54.46784453,
#     'dec': -43.54028248,
#     'timestamp': 1607045365,
#     'eclipsed': True}]},
#  {'info': {'satname': 'RESURS O1-N4',
#    'satid': 25394,
#    'transactionscount': 561},
#   'positions': [{'satlatitude': 54.89863271,
#     'satlongitude': 166.67202553,
#     'sataltitude': 819.72,
#     'azimuth': 41.92,
#     'elevation': -23.68,
#     'ra': 310.46711112,
#     'dec': 15.13702695,
#     'timestamp': 1607045366,
#     'eclipsed': False}]},
#  {'info': {'satname': 'SPOT 4', 'satid': 25260, 'transactionscount': 562},
#   'positions': [{'satlatitude': 61.01840838,
#     'satlongitude': 166.49295423,
#     'sataltitude': 730.29,
#     'azimuth': 35.46,
#     'elevation': -22.63,
#     'ra': 315.38741152,
#     'dec': 19.09029153,
#     'timestamp': 1607045366,
#     'eclipsed': False}]},
#  {'info': {'satname': 'IRS 1D', 'satid': 24971, 'transactionscount': 563},
#   'positions': [{'satlatitude': 81.21095481,
#     'satlongitude': 82.86195655,
#     'sataltitude': 755.77,
#     'azimuth': 1.96,
#     'elevation': -12.21,
#     'ra': 347.33071984,
#     'dec': 37.56991255,
#     'timestamp': 1607045367,
#     'eclipsed': False}]},
#  {'info': {'satname': 'ORBVIEW 2 (SEASTAR)',
#    'satid': 24883,
#    'transactionscount': 564},
#   'positions': [{'satlatitude': -63.7198697,
#     'satlongitude': 13.73960808,
#     'sataltitude': 803.4,
#     'azimuth': 205.24,
#     'elevation': -54.99,
#     'ra': 29.76442134,
#     'dec': -67.68981126,
#     'timestamp': 1607045367,
#     'eclipsed': False}]},
#  {'info': {'satname': 'ADEOS', 'satid': 24277, 'transactionscount': 565},
#   'positions': [{'satlatitude': -11.92668872,
#     'satlongitude': -136.08019285,
#     'sataltitude': 799.15,
#     'azimuth': 51.96,
#     'elevation': -69.27,
#     'ra': 331.77837151,
#     'dec': -25.91477696,
#     'timestamp': 1607045368,
#     'eclipsed': False}]},
#  {'info': {'satname': 'TOMS EP', 'satid': 23940, 'transactionscount': 566},
#   'positions': [{'satlatitude': -81.50058828,
#     'satlongitude': 111.82079395,
#     'sataltitude': 726.67,
#     'azimuth': 173.79,
#     'elevation': -59.99,
#     'ra': 340.67513447,
#     'dec': -69.78886793,
#     'timestamp': 1607045369,
#     'eclipsed': False}]},
#  {'info': {'satname': 'IRS B3', 'satid': 23827, 'transactionscount': 567},
#   'positions': [{'satlatitude': 68.17139412,
#     'satlongitude': 35.95172275,
#     'sataltitude': 829.01,
#     'azimuth': 336.1,
#     'elevation': -6.47,
#     'ra': 20.6492347,
#     'dec': 38.44326841,
#     'timestamp': 1607045369,
#     'eclipsed': True}]},
#  {'info': {'satname': 'IRS 1C', 'satid': 23751, 'transactionscount': 568},
#   'positions': [{'satlatitude': -70.89668439,
#     'satlongitude': -12.74911468,
#     'sataltitude': 843.6,
#     'azimuth': 204.22,
#     'elevation': -61.57,
#     'ra': 16.3742048,
#     'dec': -64.03804669,
#     'timestamp': 1607045370,
#     'eclipsed': False}]},
#  {'info': {'satname': 'RADARSAT', 'satid': 23710, 'transactionscount': 569},
#   'positions': [{'satlatitude': 43.91859695,
#     'satlongitude': -118.50479723,
#     'sataltitude': 795.17,
#     'azimuth': 9.3,
#     'elevation': -44.56,
#     'ra': 343.21346592,
#     'dec': 4.82944441,
#     'timestamp': 1607045370,
#     'eclipsed': False}]},
#  {'info': {'satname': 'SICH 1', 'satid': 23657, 'transactionscount': 570},
#   'positions': [{'satlatitude': 82.56513945,
#     'satlongitude': 145.10531267,
#     'sataltitude': 630.15,
#     'azimuth': 9.5,
#     'elevation': -17.91,
#     'ra': 339.28839995,
#     'dec': 31.29400261,
#     'timestamp': 1607045371,
#     'eclipsed': False}]},
#  {'info': {'satname': 'ERS 2', 'satid': 23560, 'transactionscount': 571},
#   'positions': [{'satlatitude': 22.94401102,
#     'satlongitude': -116.10129702,
#     'sataltitude': 500.14,
#     'azimuth': 10.78,
#     'elevation': -56.74,
#     'ra': 343.91885417,
#     'dec': -7.3026377,
#     'timestamp': 1607045371,
#     'eclipsed': False}]},
#  {'info': {'satname': 'RESURS O1', 'satid': 23342, 'transactionscount': 572},
#   'positions': [{'satlatitude': 39.30784652,
#     'satlongitude': -76.74654814,
#     'sataltitude': 636.89,
#     'azimuth': 337.94,
#     'elevation': -45.75,
#     'ra': 5.06952123,
#     'dec': 1.79404235,
#     'timestamp': 1607045372,
#     'eclipsed': True}]},
#  {'info': {'satname': 'IRS P2', 'satid': 23323, 'transactionscount': 573},
#   'positions': [{'satlatitude': 45.16894534,
#     'satlongitude': -150.49792187,
#     'sataltitude': 818.75,
#     'azimuth': 29.95,
#     'elevation': -39.17,
#     'ra': 326.9470465,
#     'dec': 6.05022392,
#     'timestamp': 1607045372,
#     'eclipsed': False}]},
#  {'info': {'satname': 'OKEAN 4', 'satid': 23317, 'transactionscount': 574},
#   'positions': [{'satlatitude': -78.72047372,
#     'satlongitude': 132.5476115,
#     'sataltitude': 631.11,
#     'azimuth': 168.4,
#     'elevation': -60.39,
#     'ra': 334.00569513,
#     'dec': -68.5587623,
#     'timestamp': 1607045373,
#     'eclipsed': False}]},
#  {'info': {'satname': 'SPOT 3', 'satid': 22823, 'transactionscount': 575},
#   'positions': [{'satlatitude': 5.3238397,
#     'satlongitude': 65.74275937,
#     'sataltitude': 827.67,
#     'azimuth': 194.99,
#     'elevation': -7,
#     'ra': 143.85853435,
#     'dec': -54.17133631,
#     'timestamp': 1607045373,
#     'eclipsed': False}]},
#  {'info': {'satname': 'TOPEX/POSEIDON',
#    'satid': 22076,
#    'transactionscount': 576},
#   'positions': [{'satlatitude': 65.97427224,
#     'satlongitude': 12.7329616,
#     'sataltitude': 1353.7,
#     'azimuth': 328,
#     'elevation': -7.53,
#     'ra': 29.11180357,
#     'dec': 33.85574205,
#     'timestamp': 1607045374,
#     'eclipsed': True}]},
#  {'info': {'satname': 'IRS 1B', 'satid': 21688, 'transactionscount': 577},
#   'positions': [{'satlatitude': -80.7456235,
#     'satlongitude': -88.92803905,
#     'sataltitude': 948.79,
#     'azimuth': 184.06,
#     'elevation': -68.07,
#     'ra': 353.12688218,
#     'dec': -62.02604598,
#     'timestamp': 1607045375,
#     'eclipsed': False}]},
#  {'info': {'satname': 'ERS 1', 'satid': 21574, 'transactionscount': 578},
#   'positions': [{'satlatitude': -65.80778403,
#     'satlongitude': -2.68516841,
#     'sataltitude': 797.37,
#     'azimuth': 208.04,
#     'elevation': -58.72,
#     'ra': 24.22936297,
#     'dec': -64.35930823,
#     'timestamp': 1607045375,
#     'eclipsed': False}]},
#  {'info': {'satname': 'OKEAN 3', 'satid': 21397, 'transactionscount': 579},
#   'positions': [{'satlatitude': -69.84749239,
#     'satlongitude': 120.57712647,
#     'sataltitude': 611.73,
#     'azimuth': 163.96,
#     'elevation': -55.86,
#     'ra': 321.13207547,
#     'dec': -71.10782042,
#     'timestamp': 1607045376,
#     'eclipsed': False}]},
#  {'info': {'satname': 'OKEAN 2', 'satid': 20510, 'transactionscount': 580},
#   'positions': [{'satlatitude': -43.63747867,
#     'satlongitude': 126.72172828,
#     'sataltitude': 593.8,
#     'azimuth': 144.62,
#     'elevation': -45.73,
#     'ra': 283.80191975,
#     'dec': -63.70571725,
#     'timestamp': 1607045376,
#     'eclipsed': False}]},
#  {'info': {'satname': 'MOS 1B (MOMO 1B)',
#    'satid': 20478,
#    'transactionscount': 581},
#   'positions': [{'satlatitude': 34.6344125,
#     'satlongitude': 69.59901601,
#     'sataltitude': 915.92,
#     'azimuth': 216.75,
#     'elevation': 45.87,
#     'ra': 145.23247202,
#     'dec': 2.38785124,
#     'timestamp': 1607045377,
#     'eclipsed': False}]},
#  {'info': {'satname': 'SPOT 2', 'satid': 20436, 'transactionscount': 582},
#   'positions': [{'satlatitude': -32.59730208,
#     'satlongitude': -114.37779083,
#     'sataltitude': 614.29,
#     'azimuth': 44.92,
#     'elevation': -84.5,
#     'ra': 345.05815219,
#     'dec': -36.20564346,
#     'timestamp': 1607045377,
#     'eclipsed': False}]},
#  {'info': {'satname': 'OKEAN 1', 'satid': 19274, 'transactionscount': 583},
#   'positions': [{'satlatitude': -6.48307195,
#     'satlongitude': -97.00860898,
#     'sataltitude': 544.16,
#     'azimuth': 344.89,
#     'elevation': -71.93,
#     'ra': 354.88880432,
#     'dec': -22.64460801,
#     'timestamp': 1607045378,
#     'eclipsed': False}]},
#  {'info': {'satname': 'IRS 1A', 'satid': 18960, 'transactionscount': 584},
#   'positions': [{'satlatitude': 73.17049152,
#     'satlongitude': 164.11838637,
#     'sataltitude': 918,
#     'azimuth': 21.63,
#     'elevation': -18.12,
#     'ra': 326.51715417,
#     'dec': 28.33736367,
#     'timestamp': 1607045378,
#     'eclipsed': False}]},
#  {'info': {'satname': 'COSMOS 1869', 'satid': 18214, 'transactionscount': 585},
#   'positions': [{'satlatitude': -28.8772838,
#     'satlongitude': 27.04383027,
#     'sataltitude': 532.59,
#     'azimuth': 220.81,
#     'elevation': -38.21,
#     'ra': 70.07582101,
#     'dec': -58.56816333,
#     'timestamp': 1607045379,
#     'eclipsed': False}]},
#  {'info': {'satname': 'MOS 1A (MOMO 1)',
#    'satid': 17527,
#    'transactionscount': 586},
#   'positions': [{'satlatitude': 6.38465017,
#     'satlongitude': -74.40743693,
#     'sataltitude': 882.29,
#     'azimuth': 320.96,
#     'elevation': -60.71,
#     'ra': 8.56254848,
#     'dec': -15.84048467,
#     'timestamp': 1607045380,
#     'eclipsed': True}]},
#  {'info': {'satname': 'COSMOS 1766', 'satid': 16881, 'transactionscount': 587},
#   'positions': [{'satlatitude': -40.36924423,
#     'satlongitude': -45.09293236,
#     'sataltitude': 559.1,
#     'azimuth': 249.48,
#     'elevation': -66.37,
#     'ra': 21.51131147,
#     'dec': -44.27294028,
#     'timestamp': 1607045380,
#     'eclipsed': True}]},
#  {'info': {'satname': 'SPOT 1', 'satid': 16613, 'transactionscount': 588},
#   'positions': [{'satlatitude': -19.362737,
#     'satlongitude': 19.65163455,
#     'sataltitude': 686.26,
#     'azimuth': 232.11,
#     'elevation': -35.51,
#     'ra': 69.18326583,
#     'dec': -49.23879513,
#     'timestamp': 1607045381,
#     'eclipsed': True}]},
#  {'info': {'satname': 'COSMOS 1602', 'satid': 15331, 'transactionscount': 589},
#   'positions': [{'satlatitude': -3.56648626,
#     'satlongitude': -112.14778207,
#     'sataltitude': 521.08,
#     'azimuth': 10.86,
#     'elevation': -70.65,
#     'ra': 346.04178658,
#     'dec': -21.06712465,
#     'timestamp': 1607045381,
#     'eclipsed': False}]},
#  {'info': {'satname': 'LANDSAT 5', 'satid': 14780, 'transactionscount': 590},
#   'positions': [{'satlatitude': 9.54235046,
#     'satlongitude': -131.74386337,
#     'sataltitude': 650.98,
#     'azimuth': 31.88,
#     'elevation': -60.88,
#     'ra': 334.51418149,
#     'dec': -14.31295361,
#     'timestamp': 1607045382,
#     'eclipsed': False}]},
#  {'info': {'satname': 'LANDSAT 4', 'satid': 13367, 'transactionscount': 591},
#   'positions': [{'satlatitude': 12.50548724,
#     'satlongitude': -10.73766989,
#     'sataltitude': 509.54,
#     'azimuth': 276.72,
#     'elevation': -36.43,
#     'ra': 47.11798979,
#     'dec': -18.10130768,
#     'timestamp': 1607045382,
#     'eclipsed': True}]},
#  {'info': {'satname': 'SEASAT 1', 'satid': 10967, 'transactionscount': 592},
#   'positions': [{'satlatitude': -58.76513061,
#     'satlongitude': 1.8531916,
#     'sataltitude': 767.46,
#     'azimuth': 213.49,
#     'elevation': -55.76,
#     'ra': 33.17474192,
#     'dec': -63.15298323,
#     'timestamp': 1607045383,
#     'eclipsed': False}]},
#  {'info': {'satname': 'LANDSAT 3', 'satid': 10702, 'transactionscount': 593},
#   'positions': [{'satlatitude': -79.02532229,
#     'satlongitude': -5.61399444,
#     'sataltitude': 926.91,
#     'azimuth': 193.77,
#     'elevation': -61.84,
#     'ra': 6.45641778,
#     'dec': -66.80255775,
#     'timestamp': 1607045383,
#     'eclipsed': False}]},
#  {'info': {'satname': 'LANDSAT 2', 'satid': 7615, 'transactionscount': 594},
#   'positions': [{'satlatitude': -76.20246844,
#     'satlongitude': 14.01928595,
#     'sataltitude': 937.99,
#     'azimuth': 194.33,
#     'elevation': -59.08,
#     'ra': 10.73091257,
#     'dec': -69.06667062,
#     'timestamp': 1607045384,
#     'eclipsed': False}]},
#  {'info': {'satname': 'LANDSAT 1 (ERTS 1)',
#    'satid': 6126,
#    'transactionscount': 595},
#   'positions': [{'satlatitude': -79.24550651,
#     'satlongitude': -31.26482523,
#     'sataltitude': 931.24,
#     'azimuth': 194.16,
#     'elevation': -64.44,
#     'ra': 4.05434493,
#     'dec': -64.38877986,
#     'timestamp': 1607045385,
#     'eclipsed': False}]}]

# %%
#  def Convert(satellites):
# #     it = iter(satellites)
# #     res_dct = dict(zip(it,it))
# #     return res_dct
# # lst = satellites
# # print(Convert(lst))

# %%
with open('app.geojson', 'a+') as f:
   json.dump(satellites,f)

# %%
earth_sat = []

search_url = f"https://api.n2yo.com/rest/v1/satellite/above/40.0583/74.4057/0/50/0/&apiKey={API_Key}"
response_earth = requests.get(search_url)
earth_data = response_earth.json()
earth_sat.append(earth_data)

# %%
earth_sat
# Out:
# [{'info': {'category': 'ANY', 'transactionscount': 8, 'satcount': 678},
#   'above': [{'satid': 159,
#     'satname': 'THOR ABLESTAR DEB',
#     'intDesignator': '1961-015AV',
#     'launchDate': '1961-06-29',
#     'satlat': 32.4385,
#     'satlng': 73.7953,
#     'satalt': 1542.2348},
#    {'satid': 273,
#     'satname': 'MIDAS 5 DEB',
#     'intDesignator': '1962-010C',
#     'launchDate': '1962-04-09',
#     'satlat': 33.0186,
#     'satlng': 91.0707,
#     'satalt': 2895.33},
#    {'satid': 337,
#     'satname': 'THOR ABLESTAR DEB',
#     'intDesignator': '1961-015DP',
#     'launchDate': '1961-06-29',
#     'satlat': 43.1059,
#     'satlng': 69.4563,
#     'satalt': 1046.27},
#    {'satid': 634,
#     'satname': 'SYNCOM 2 (A 26)',
#     'intDesignator': '1963-031A',
#     'launchDate': '1963-07-26',
#     'satlat': 32.7707,
#     'satlng': 82.4692,
#     'satalt': 35777.5006},
#    {'satid': 692,
#     'satname': 'VELA 1',
#     'intDesignator': '1963-039C',
#     'launchDate': '1963-10-17',
#     'satlat': 15.1604,
#     'satlng': 95.194,
#     'satalt': 160725.3653},
#    {'satid': 728,
#     'satname': 'GGSE 1 (GGRS)',
#     'intDesignator': '1964-001B',
#     'launchDate': '1964-01-11',
#     'satlat': 40.906,
#     'satlng': 72.9575,
#     'satalt': 906.7462},
#    {'satid': 743,
#     'satname': 'THOR AGENA B DEB',
#     'intDesignator': '1964-004D',
#     'launchDate': '1964-01-25',
#     'satlat': 44.387,
#     'satlng': 67.1893,
#     'satalt': 1162.7758},
#    {'satid': 902,
#     'satname': 'CALSPHERE 2',
#     'intDesignator': '1964-063E',
#     'launchDate': '1964-10-06',
#     'satlat': 41.482,
#     'satlng': 74.8536,
#     'satalt': 1063.129},
#    {'satid': 1618,
#     'satname': 'SL-8 DEB',
#     'intDesignator': '1965-073K',
#     'launchDate': '1965-09-18',
#     'satlat': 49.0065,
#     'satlng': 78.0192,
#     'satalt': 1679.3844},
#    {'satid': 2222,
#     'satname': 'TITAN 3C TRANSTAGE R/B',
#     'intDesignator': '1966-053J',
#     'launchDate': '1966-06-16',
#     'satlat': -2.0244,
#     'satlng': 75.4603,
#     'satalt': 34549.2792},
#    {'satid': 2359,
#     'satname': 'WESTFORD NEEDLES',
#     'intDesignator': '1963-014J',
#     'launchDate': '1963-05-09',
#     'satlat': 59.5214,
#     'satlng': 77.5171,
#     'satalt': 3594.3596},
#    {'satid': 2700,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1965-089C',
#     'launchDate': '1965-11-06',
#     'satlat': 39.9252,
#     'satlng': 63.2527,
#     'satalt': 1801.0305},
#    {'satid': 3038,
#     'satname': 'SL-8 DEB',
#     'intDesignator': '1965-020EN',
#     'launchDate': '1965-03-15',
#     'satlat': 40.1666,
#     'satlng': 74.2279,
#     'satalt': 1069.4657},
#    {'satid': 3266,
#     'satname': 'OPS 7869 (DMSP 4B F1)',
#     'intDesignator': '1968-042A',
#     'launchDate': '1968-05-23',
#     'satlat': 36.9796,
#     'satlng': 68.8306,
#     'satalt': 883.907},
#    {'satid': 3290,
#     'satname': 'OPS 9347 (IDSCS 26)',
#     'intDesignator': '1968-050G',
#     'launchDate': '1968-06-13',
#     'satlat': -1.1347,
#     'satlng': 79.2914,
#     'satalt': 34062.5182},
#    {'satid': 3334,
#     'satname': 'OPS 2222',
#     'intDesignator': '1968-063A',
#     'launchDate': '1968-08-06',
#     'satlat': 10.8077,
#     'satlng': 89.7701,
#     'satalt': 34508.5477},
#    {'satid': 3713,
#     'satname': 'COSMOS 252 DEB *',
#     'intDesignator': '1968-097AQ',
#     'launchDate': '1968-11-01',
#     'satlat': 44.6434,
#     'satlng': 78.6738,
#     'satalt': 1554.9892},
#    {'satid': 3793,
#     'satname': 'COSMOS 249 DEB',
#     'intDesignator': '1968-091BA',
#     'launchDate': '1968-10-20',
#     'satlat': 41.1802,
#     'satlng': 74.0149,
#     'satalt': 1716.6672},
#    {'satid': 3848,
#     'satname': 'EXPLORER 38 DEB',
#     'intDesignator': '1968-055C',
#     'launchDate': '1968-07-04',
#     'satlat': 35.9444,
#     'satlng': 81.7467,
#     'satalt': 5856.4001},
#    {'satid': 4068,
#     'satname': 'ATS 5',
#     'intDesignator': '1969-069A',
#     'launchDate': '1969-08-12',
#     'satlat': 5.0319,
#     'satlng': 49.4138,
#     'satalt': 36011.0401},
#    {'satid': 4418,
#     'satname': 'OPS 5346',
#     'intDesignator': '1970-046A',
#     'launchDate': '1970-06-19',
#     'satlat': 2.805,
#     'satlng': 73.5633,
#     'satalt': 35770.9957},
#    {'satid': 4607,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025K',
#     'launchDate': '1970-04-08',
#     'satlat': 37.8584,
#     'satlng': 71.2779,
#     'satalt': 1351.8633},
#    {'satid': 4881,
#     'satname': 'INTELSAT 4-F2',
#     'intDesignator': '1971-006A',
#     'launchDate': '1971-01-26',
#     'satlat': 9.0137,
#     'satlng': 54.9593,
#     'satalt': 36143.3889},
#    {'satid': 5054,
#     'satname': 'TITAN 34B AGENA D R/B',
#     'intDesignator': '1971-021B',
#     'launchDate': '1971-03-21',
#     'satlat': 50.6082,
#     'satlng': 47.3349,
#     'satalt': 24205.7663},
#    {'satid': 5098,
#     'satname': 'COSMOS 397 DEB',
#     'intDesignator': '1971-015X',
#     'launchDate': '1971-02-25',
#     'satlat': 45.1473,
#     'satlng': 59.7702,
#     'satalt': 1572.5324},
#    {'satid': 5220,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025KG',
#     'launchDate': '1970-04-08',
#     'satlat': 31.1026,
#     'satlng': 83.8137,
#     'satalt': 1596.0536},
#    {'satid': 5998,
#     'satname': 'TITAN 3C TRANSTAGE DEB',
#     'intDesignator': '1965-108T',
#     'launchDate': '1965-12-21',
#     'satlat': 23.6522,
#     'satlng': 43.3667,
#     'satalt': 26450.5828},
#    {'satid': 6120,
#     'satname': 'COSMOS 507',
#     'intDesignator': '1972-057D',
#     'launchDate': '1972-07-20',
#     'satlat': 32.4409,
#     'satlng': 76.6709,
#     'satalt': 1418.6832},
#    {'satid': 6197,
#     'satname': 'EXPLORER 47 (IMP-7)',
#     'intDesignator': '1972-073A',
#     'launchDate': '1972-09-23',
#     'satlat': 31.5379,
#     'satlng': 37.6367,
#     'satalt': 242829.5733},
#    {'satid': 6252,
#     'satname': 'SL-8 DEB *',
#     'intDesignator': '1965-020FD',
#     'launchDate': '1965-03-15',
#     'satlat': 47.0414,
#     'satlng': 85.7754,
#     'satalt': 1441.756},
#    {'satid': 6278,
#     'satname': 'ANIK A1 (TELESAT 1)',
#     'intDesignator': '1972-090A',
#     'launchDate': '1972-11-10',
#     'satlat': 10.5271,
#     'satlng': 67.606,
#     'satalt': 36173.9749},
#    {'satid': 6380,
#     'satname': 'OPS 6063',
#     'intDesignator': '1973-013A',
#     'launchDate': '1973-03-06',
#     'satlat': 5.3455,
#     'satlng': 74.7647,
#     'satalt': 35822.2319},
#    {'satid': 6791,
#     'satname': 'OPS 7724',
#     'intDesignator': '1973-056A',
#     'launchDate': '1973-08-21',
#     'satlat': 62.1317,
#     'satlng': 63.5888,
#     'satalt': 39251.4001},
#    {'satid': 6973,
#     'satname': 'OPS 9433 (DSCS 2-3)',
#     'intDesignator': '1973-100A',
#     'launchDate': '1973-12-13',
#     'satlat': 10.2471,
#     'satlng': 70.2861,
#     'satalt': 36535.5932},
#    {'satid': 6976,
#     'satname': 'TITAN 3C TRANSTAGE R/B',
#     'intDesignator': '1973-100D',
#     'launchDate': '1973-12-13',
#     'satlat': 10.8587,
#     'satlng': 98.8628,
#     'satalt': 36413.8537},
#    {'satid': 6992,
#     'satname': 'COSMOS 624',
#     'intDesignator': '1973-104H',
#     'launchDate': '1973-12-19',
#     'satlat': 42.9997,
#     'satlng': 64.8663,
#     'satalt': 1359.5839},
#    {'satid': 7291,
#     'satname': 'COSMOS 651',
#     'intDesignator': '1974-029A',
#     'launchDate': '1974-05-15',
#     'satlat': 37.7373,
#     'satlng': 68.8175,
#     'satalt': 949.5831},
#    {'satid': 7578,
#     'satname': 'SYMPHONIE 1',
#     'intDesignator': '1974-101A',
#     'launchDate': '1974-12-19',
#     'satlat': 9.5577,
#     'satlng': 79.0854,
#     'satalt': 35885.2193},
#    {'satid': 7688,
#     'satname': 'TITAN 34B R/B',
#     'intDesignator': '1975-017B',
#     'launchDate': '1975-03-10',
#     'satlat': 59.563,
#     'satlng': 80.4831,
#     'satalt': 19335.2244},
#    {'satid': 7780,
#     'satname': 'MOLNIYA 1-29',
#     'intDesignator': '1975-036A',
#     'launchDate': '1975-04-29',
#     'satlat': 54.6239,
#     'satlng': 101.7048,
#     'satalt': 39109.8661},
#    {'satid': 8018,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1975-063D',
#     'launchDate': '1975-07-08',
#     'satlat': 23.7319,
#     'satlng': 58.5822,
#     'satalt': 6025.2962},
#    {'satid': 8195,
#     'satname': 'MOLNIYA 2-14',
#     'intDesignator': '1975-081A',
#     'launchDate': '1975-09-09',
#     'satlat': 59.5321,
#     'satlng': 56.9247,
#     'satalt': 37737.9244},
#    {'satid': 8513,
#     'satname': 'RADUGA 1',
#     'intDesignator': '1975-123A',
#     'launchDate': '1975-12-22',
#     'satlat': 7.9198,
#     'satlng': 67.2253,
#     'satalt': 35790.8366},
#    {'satid': 8601,
#     'satname': 'MOLNIYA 1-32',
#     'intDesignator': '1976-006A',
#     'launchDate': '1976-01-22',
#     'satlat': 59.0914,
#     'satlng': 122.3415,
#     'satalt': 29416.8748},
#    {'satid': 8620,
#     'satname': 'INTELSAT 4A-F2',
#     'intDesignator': '1976-010A',
#     'launchDate': '1976-01-29',
#     'satlat': 11.9841,
#     'satlng': 101.4801,
#     'satalt': 35966.1771},
#    {'satid': 8748,
#     'satname': 'SOLRAD 11A',
#     'intDesignator': '1976-023C',
#     'launchDate': '1976-03-15',
#     'satlat': 19.3238,
#     'satlng': 59.2754,
#     'satalt': 117223.6074},
#    {'satid': 8753,
#     'satname': 'SOLRAD 11B AKM',
#     'intDesignator': '1976-023H',
#     'launchDate': '1976-03-15',
#     'satlat': 27.6261,
#     'satlng': 124.08,
#     'satalt': 120444.262},
#    {'satid': 9416,
#     'satname': 'RADUGA 2',
#     'intDesignator': '1976-092A',
#     'launchDate': '1976-09-11',
#     'satlat': 8.2356,
#     'satlng': 85.3527,
#     'satalt': 35851.0066},
#    {'satid': 9503,
#     'satname': 'EKRAN 1',
#     'intDesignator': '1976-107A',
#     'launchDate': '1976-10-26',
#     'satlat': 8.5462,
#     'satlng': 60.1227,
#     'satalt': 35583.7229},
#    {'satid': 10000,
#     'satname': 'OPS 9437 (DSCS 2-7)',
#     'intDesignator': '1977-034A',
#     'launchDate': '1977-05-12',
#     'satlat': 12.7286,
#     'satlng': 75.3738,
#     'satalt': 36869.7157},
#    {'satid': 10025,
#     'satname': 'ATLAS CENTAUR R/B',
#     'intDesignator': '1977-041B',
#     'launchDate': '1977-05-26',
#     'satlat': 10.924,
#     'satlng': 72.9422,
#     'satalt': 34580.9137},
#    {'satid': 10089,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1977-047D',
#     'launchDate': '1977-06-16',
#     'satlat': 27.3996,
#     'satlng': 86.3527,
#     'satalt': 36521.0665},
#    {'satid': 10155,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1977-054D',
#     'launchDate': '1977-06-24',
#     'satlat': 36.8869,
#     'satlng': 38.2354,
#     'satalt': 22763.7088},
#    {'satid': 10159,
#     'satname': 'RADUGA 3',
#     'intDesignator': '1977-071A',
#     'launchDate': '1977-07-23',
#     'satlat': 8.0391,
#     'satlng': 42.5352,
#     'satalt': 35829.3444},
#    {'satid': 10294,
#     'satname': 'SIRIO',
#     'intDesignator': '1977-080A',
#     'launchDate': '1977-08-25',
#     'satlat': 11.2304,
#     'satlng': 73.9775,
#     'satalt': 35754.7324},
#    {'satid': 10365,
#     'satname': 'EKRAN 2',
#     'intDesignator': '1977-092A',
#     'launchDate': '1977-09-20',
#     'satlat': 8.6642,
#     'satlng': 51.0332,
#     'satalt': 35848.5768},
#    {'satid': 10436,
#     'satname': 'COSMOS 839 DEB',
#     'intDesignator': '1976-067M',
#     'launchDate': '1976-07-08',
#     'satlat': 32.6935,
#     'satlng': 63.6903,
#     'satalt': 1622.1013},
#    {'satid': 10452,
#     'satname': 'COSMOS 839 DEB',
#     'intDesignator': '1976-067AD',
#     'launchDate': '1976-07-08',
#     'satlat': 40.656,
#     'satlng': 88.224,
#     'satalt': 1513.5973},
#    {'satid': 10792,
#     'satname': 'YURI (BSE)',
#     'intDesignator': '1978-039A',
#     'launchDate': '1978-04-07',
#     'satlat': 9.0389,
#     'satlng': 107.6542,
#     'satalt': 35844.7996},
#    {'satid': 10842,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1976-077CN',
#     'launchDate': '1976-07-29',
#     'satlat': 48.2148,
#     'satlng': 71.1192,
#     'satalt': 1407.3644},
#    {'satid': 10855,
#     'satname': 'OTS 2',
#     'intDesignator': '1978-044A',
#     'launchDate': '1978-05-11',
#     'satlat': 12.1408,
#     'satlng': 84.9266,
#     'satalt': 36127.7684},
#    {'satid': 10893,
#     'satname': 'OPS 5112 (NAVSTAR 2)',
#     'intDesignator': '1978-047A',
#     'launchDate': '1978-05-13',
#     'satlat': 45.9868,
#     'satlng': 48.8567,
#     'satalt': 18795.3804},
#    {'satid': 10987,
#     'satname': 'RADUGA 4',
#     'intDesignator': '1978-073A',
#     'launchDate': '1978-07-18',
#     'satlat': 9.6775,
#     'satlng': 82.6951,
#     'satalt': 35781.8269},
#    {'satid': 11057,
#     'satname': 'MOLNIYA 3-10',
#     'intDesignator': '1978-095A',
#     'launchDate': '1978-10-13',
#     'satlat': 53.6865,
#     'satlng': 66.5784,
#     'satalt': 19582.3141},
#    {'satid': 11147,
#     'satname': 'TITAN 3C TRANSTAGE R/B',
#     'intDesignator': '1978-113D',
#     'launchDate': '1978-12-14',
#     'satlat': 14.1747,
#     'satlng': 73.156,
#     'satalt': 36965.8038},
#    {'satid': 11158,
#     'satname': 'GORIZONT 1',
#     'intDesignator': '1978-118A',
#     'launchDate': '1978-12-19',
#     'satlat': 7.1062,
#     'satlng': 52.627,
#     'satalt': 34752.164},
#    {'satid': 11273,
#     'satname': 'EKRAN 3',
#     'intDesignator': '1979-015A',
#     'launchDate': '1979-02-21',
#     'satlat': 10.043,
#     'satlng': 74.7109,
#     'satalt': 35912.4165},
#    {'satid': 11343,
#     'satname': 'RADUGA 5',
#     'intDesignator': '1979-035A',
#     'launchDate': '1979-04-25',
#     'satlat': 10.2026,
#     'satlng': 78.304,
#     'satalt': 35779.4965},
#    {'satid': 11353,
#     'satname': 'OPS 6392 (FLTSATCOM 2)',
#     'intDesignator': '1979-038A',
#     'launchDate': '1979-05-04',
#     'satlat': 9.7551,
#     'satlng': 54.6254,
#     'satalt': 36211.2775},
#    {'satid': 11397,
#     'satname': 'OPS 7484',
#     'intDesignator': '1979-053A',
#     'launchDate': '1979-06-10',
#     'satlat': 11.7222,
#     'satlng': 80.8968,
#     'satalt': 36249.889},
#    {'satid': 11417,
#     'satname': 'COSMOS 1109',
#     'intDesignator': '1979-058A',
#     'launchDate': '1979-06-27',
#     'satlat': 56.1376,
#     'satlng': 119.4635,
#     'satalt': 29541.7922},
#    {'satid': 11436,
#     'satname': 'TITAN 3C TRANSTAGE R/B',
#     'intDesignator': '1979-053C',
#     'launchDate': '1979-06-10',
#     'satlat': 11.4004,
#     'satlng': 92.7279,
#     'satalt': 36225.4996},
#    {'satid': 11440,
#     'satname': 'GORIZONT 2',
#     'intDesignator': '1979-062A',
#     'launchDate': '1979-07-05',
#     'satlat': 10.4297,
#     'satlng': 70.1154,
#     'satalt': 35787.0274},
#    {'satid': 11561,
#     'satname': 'EKRAN 4',
#     'intDesignator': '1979-087A',
#     'launchDate': '1979-10-03',
#     'satlat': 9.5274,
#     'satlng': 54.2549,
#     'satalt': 35789.5939},
#    {'satid': 11581,
#     'satname': 'EKRAN 2 DEB',
#     'intDesignator': '1977-092H',
#     'launchDate': '1977-09-20',
#     'satlat': 9.0159,
#     'satlng': 83.0812,
#     'satalt': 35766.732},
#    {'satid': 11621,
#     'satname': 'OPS 9443 (DSCS 2-13)',
#     'intDesignator': '1979-098A',
#     'launchDate': '1979-11-21',
#     'satlat': 14.1027,
#     'satlng': 105.3413,
#     'satalt': 37109.8222},
#    {'satid': 11648,
#     'satname': 'GORIZONT 3',
#     'intDesignator': '1979-105A',
#     'launchDate': '1979-12-28',
#     'satlat': 9.7171,
#     'satlng': 106.0316,
#     'satalt': 35773.5728},
#    {'satid': 11705,
#     'satname': 'ATLAS 35F R/B',
#     'intDesignator': '1980-011B',
#     'launchDate': '1980-02-09',
#     'satlat': 59.1476,
#     'satlng': 104.4907,
#     'satalt': 12841.6184},
#    {'satid': 11708,
#     'satname': 'RADUGA 6',
#     'intDesignator': '1980-016A',
#     'launchDate': '1980-02-20',
#     'satlat': 9.603,
#     'satlng': 104.4463,
#     'satalt': 35777.959},
#    {'satid': 11847,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1980-050B',
#     'launchDate': '1980-06-14',
#     'satlat': 25.2153,
#     'satlng': 69.3494,
#     'satalt': 36127.9529},
#    {'satid': 11862,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1980-049F',
#     'launchDate': '1980-06-14',
#     'satlat': 9.2784,
#     'satlng': 45.4387,
#     'satalt': 36497.0552},
#    {'satid': 11909,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1980-063D',
#     'launchDate': '1980-07-18',
#     'satlat': 62.7075,
#     'satlng': 38.3983,
#     'satalt': 38386.8822},
#    {'satid': 12032,
#     'satname': 'COSMOS 1217',
#     'intDesignator': '1980-085A',
#     'launchDate': '1980-10-24',
#     'satlat': 45.9764,
#     'satlng': 124.6684,
#     'satalt': 36780.6879},
#    {'satid': 12089,
#     'satname': 'INTELSAT 502',
#     'intDesignator': '1980-098A',
#     'launchDate': '1980-12-06',
#     'satlat': 13.9938,
#     'satlng': 107.7362,
#     'satalt': 36227.4912},
#    {'satid': 12120,
#     'satname': 'EKRAN 6',
#     'intDesignator': '1980-104A',
#     'launchDate': '1980-12-26',
#     'satlat': 10.5921,
#     'satlng': 97.662,
#     'satalt': 35778.3707},
#    {'satid': 12309,
#     'satname': 'ESIAFI 1 (COMSTAR 4)',
#     'intDesignator': '1981-018A',
#     'launchDate': '1981-02-21',
#     'satlat': 11.5804,
#     'satlng': 76.3782,
#     'satalt': 35765.1055},
#    {'satid': 12363,
#     'satname': 'ATLAS CENTAUR R/B',
#     'intDesignator': '1981-018B',
#     'launchDate': '1981-02-21',
#     'satlat': 20.5066,
#     'satlng': 92.6185,
#     'satalt': 27479.7824},
#    {'satid': 12446,
#     'satname': 'TITAN 34B R/B',
#     'intDesignator': '1981-038B',
#     'launchDate': '1981-04-24',
#     'satlat': 45.5591,
#     'satlng': 92.9962,
#     'satalt': 19610.7373},
#    {'satid': 12471,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1980-104E',
#     'launchDate': '1980-12-26',
#     'satlat': 10.0249,
#     'satlng': 92.4974,
#     'satalt': 35380.9704},
#    {'satid': 12545,
#     'satname': 'APPLE',
#     'intDesignator': '1981-057B',
#     'launchDate': '1981-06-19',
#     'satlat': 10.8855,
#     'satlng': 107.027,
#     'satalt': 35803.1834},
#    {'satid': 12564,
#     'satname': 'EKRAN 7',
#     'intDesignator': '1981-061A',
#     'launchDate': '1981-06-26',
#     'satlat': 9.3946,
#     'satlng': 51.6436,
#     'satalt': 35757.253},
#    {'satid': 12627,
#     'satname': 'COSMOS 1285',
#     'intDesignator': '1981-071A',
#     'launchDate': '1981-08-04',
#     'satlat': 21.9392,
#     'satlng': 73.1387,
#     'satalt': 17215.5539},
#    {'satid': 12679,
#     'satname': 'DELTA 1 R/B(2)',
#     'intDesignator': '1981-070E',
#     'launchDate': '1981-08-03',
#     'satlat': 27.5411,
#     'satlng': 77.3228,
#     'satalt': 16033.6623},
#    {'satid': 12680,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1981-071D',
#     'launchDate': '1981-08-04',
#     'satlat': 57.0205,
#     'satlng': 48.5224,
#     'satalt': 7068.4758},
#    {'satid': 12827,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1981-088F',
#     'launchDate': '1981-09-11',
#     'satlat': 60.9953,
#     'satlng': 98.5468,
#     'satalt': 8944.9666},
#    {'satid': 12851,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1981-061F',
#     'launchDate': '1981-06-26',
#     'satlat': 10.1381,
#     'satlng': 101.2139,
#     'satalt': 35574.5246},
#    {'satid': 12897,
#     'satname': 'RADUGA 10',
#     'intDesignator': '1981-102A',
#     'launchDate': '1981-10-09',
#     'satlat': 11.2736,
#     'satlng': 84.8891,
#     'satalt': 35781.27},
#    {'satid': 13012,
#     'satname': 'MOLNIYA 1-52',
#     'intDesignator': '1981-123A',
#     'launchDate': '1981-12-23',
#     'satlat': 47.0886,
#     'satlng': 76.7191,
#     'satalt': 36194.0108},
#    {'satid': 13070,
#     'satname': 'MOLNIYA 1-53',
#     'intDesignator': '1982-015A',
#     'launchDate': '1982-02-26',
#     'satlat': 62.3965,
#     'satlng': 69.8294,
#     'satalt': 39132.7656},
#    {'satid': 13086,
#     'satname': 'OPS 8701',
#     'intDesignator': '1982-019A',
#     'launchDate': '1982-03-06',
#     'satlat': 9.5804,
#     'satlng': 53.0379,
#     'satalt': 36384.4849},
#    {'satid': 13124,
#     'satname': 'COSMOS 1348',
#     'intDesignator': '1982-029A',
#     'launchDate': '1982-04-07',
#     'satlat': 41.0465,
#     'satlng': 65.7813,
#     'satalt': 17170.4099},
#    {'satid': 13129,
#     'satname': 'INSAT 1A',
#     'intDesignator': '1982-031A',
#     'launchDate': '1982-04-10',
#     'satlat': 10.4807,
#     'satlng': 63.3276,
#     'satalt': 35731.0967},
#    {'satid': 13177,
#     'satname': 'COSMOS 1366',
#     'intDesignator': '1982-044A',
#     'launchDate': '1982-05-17',
#     'satlat': 12.4198,
#     'satlng': 76.4775,
#     'satalt': 35756.3421},
#    {'satid': 13269,
#     'satname': 'WESTAR 5',
#     'intDesignator': '1982-058A',
#     'launchDate': '1982-06-09',
#     'satlat': 14.6004,
#     'satlng': 111.1303,
#     'satalt': 36138.9838},
#    {'satid': 13375,
#     'satname': 'COSMOS 1388',
#     'intDesignator': '1982-073A',
#     'launchDate': '1982-07-21',
#     'satlat': 45.6599,
#     'satlng': 66.4268,
#     'satalt': 1469.6748},
#    {'satid': 13493,
#     'satname': 'N-1 R/B',
#     'intDesignator': '1982-087B',
#     'launchDate': '1982-09-03',
#     'satlat': 44.7255,
#     'satlng': 78.0933,
#     'satalt': 1208.3553},
#    {'satid': 13533,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1976-077EF',
#     'launchDate': '1976-07-29',
#     'satlat': 36.7099,
#     'satlng': 62.1714,
#     'satalt': 1990.9041},
#    {'satid': 13554,
#     'satname': 'EKRAN 9',
#     'intDesignator': '1982-093A',
#     'launchDate': '1982-09-16',
#     'satlat': 9.9897,
#     'satlng': 59.4555,
#     'satalt': 35782.5069},
#    {'satid': 13636,
#     'satname': 'DSCS 2-15',
#     'intDesignator': '1982-106A',
#     'launchDate': '1982-10-30',
#     'satlat': 14.4525,
#     'satlng': 95.7314,
#     'satalt': 37296.3243},
#    {'satid': 13651,
#     'satname': 'SBS 3',
#     'intDesignator': '1982-110B',
#     'launchDate': '1982-11-11',
#     'satlat': 7.1484,
#     'satlng': 60.0825,
#     'satalt': 35852.1486},
#    {'satid': 13652,
#     'satname': 'ANIK C3 (TELESAT-5)',
#     'intDesignator': '1982-110C',
#     'launchDate': '1982-11-11',
#     'satlat': 14.0886,
#     'satlng': 106.1123,
#     'satalt': 35881.1409},
#    {'satid': 13911,
#     'satname': 'SL-6 DEB',
#     'intDesignator': '1981-088L',
#     'launchDate': '1981-09-11',
#     'satlat': 46.7177,
#     'satlng': 51.2312,
#     'satalt': 9369.8137},
#    {'satid': 13954,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1982-113F',
#     'launchDate': '1982-11-26',
#     'satlat': 9.8124,
#     'satlng': 55.5129,
#     'satalt': 36644.8787},
#    {'satid': 13957,
#     'satname': 'TITAN 3C TRANSTAGE DEB',
#     'intDesignator': '1965-108W',
#     'launchDate': '1965-12-21',
#     'satlat': 11.1293,
#     'satlng': 104.2957,
#     'satalt': 28674.0026},
#    {'satid': 13974,
#     'satname': 'RADUGA 12',
#     'intDesignator': '1983-028A',
#     'launchDate': '1983-04-08',
#     'satlat': 11.4633,
#     'satlng': 73.8549,
#     'satalt': 35768.0288},
#    {'satid': 13984,
#     'satname': 'SATCOM 1R',
#     'intDesignator': '1983-030A',
#     'launchDate': '1983-04-11',
#     'satlat': 14.6,
#     'satlng': 113.9671,
#     'satalt': 35873.6919},
#    {'satid': 14077,
#     'satname': 'INTELSAT 506',
#     'intDesignator': '1983-047A',
#     'launchDate': '1983-05-19',
#     'satlat': 4.674,
#     'satlng': 48.3428,
#     'satalt': 36075.5637},
#    {'satid': 14086,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1983-016F',
#     'launchDate': '1983-03-12',
#     'satlat': 9.1869,
#     'satlng': 53.209,
#     'satalt': 35595.5113},
#    {'satid': 14128,
#     'satname': 'EUTELSAT 1-F1 (ECS 1)',
#     'intDesignator': '1983-058A',
#     'launchDate': '1983-06-16',
#     'satlat': 13.8008,
#     'satlng': 99.6383,
#     'satalt': 36159.4957},
#    {'satid': 14135,
#     'satname': 'ANIK C2 R/B(PAM-D)',
#     'intDesignator': '1983-059D',
#     'launchDate': '1983-06-18',
#     'satlat': 22.1542,
#     'satlng': 85.1234,
#     'satalt': 26788.2654},
#    {'satid': 14365,
#     'satname': 'GALAXY 2',
#     'intDesignator': '1983-098A',
#     'launchDate': '1983-09-22',
#     'satlat': 6.1996,
#     'satlng': 63.1833,
#     'satalt': 35792.9183},
#    {'satid': 14377,
#     'satname': 'EKRAN 11',
#     'intDesignator': '1983-100A',
#     'launchDate': '1983-09-29',
#     'satlat': 8.3344,
#     'satlng': 47.1265,
#     'satalt': 35784.2834},
#    {'satid': 14548,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1983-118F',
#     'launchDate': '1983-11-30',
#     'satlat': 11.0761,
#     'satlng': 71.7901,
#     'satalt': 35886.0855},
#    {'satid': 14592,
#     'satname': 'COSMOS 1521 (GLONASS)',
#     'intDesignator': '1983-127C',
#     'launchDate': '1983-12-29',
#     'satlat': 38.5754,
#     'satlng': 92.4724,
#     'satalt': 19213.167},
#    {'satid': 14608,
#     'satname': 'SL-12 R/B(AUX MOTOR)',
#     'intDesignator': '1983-127H',
#     'launchDate': '1983-12-29',
#     'satlat': 46.7599,
#     'satlng': 38.1456,
#     'satalt': 14553.3013},
#    {'satid': 14621,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1981-070K',
#     'launchDate': '1981-08-03',
#     'satlat': 55.0509,
#     'satlng': 71.4816,
#     'satalt': 19947.1683},
#    {'satid': 14659,
#     'satname': 'YURI 2A (BS-2A)',
#     'intDesignator': '1984-005A',
#     'launchDate': '1984-01-23',
#     'satlat': 13.9287,
#     'satlng': 105.759,
#     'satalt': 36138.3646},
#    {'satid': 14725,
#     'satname': 'RADUGA 14',
#     'intDesignator': '1984-016A',
#     'launchDate': '1984-02-15',
#     'satlat': 11.8538,
#     'satlng': 81.0929,
#     'satalt': 35778.3124},
#    {'satid': 14783,
#     'satname': 'COSMOS 1540',
#     'intDesignator': '1984-022A',
#     'launchDate': '1984-03-02',
#     'satlat': 12.907,
#     'satlng': 79.0573,
#     'satalt': 35797.3449},
#    {'satid': 14867,
#     'satname': 'COSMOS 1546',
#     'intDesignator': '1984-031A',
#     'launchDate': '1984-03-29',
#     'satlat': 11.0643,
#     'satlng': 71.1875,
#     'satalt': 35781.6805},
#    {'satid': 14930,
#     'satname': 'OPS 7641',
#     'intDesignator': '1984-037A',
#     'launchDate': '1984-04-14',
#     'satlat': 11.9339,
#     'satlng': 73.1458,
#     'satalt': 36262.0874},
#    {'satid': 14931,
#     'satname': 'TITAN 34D AGENA D R/B',
#     'intDesignator': '1984-037B',
#     'launchDate': '1984-04-14',
#     'satlat': 11.8557,
#     'satlng': 80.2376,
#     'satalt': 35645.0257},
#    {'satid': 14940,
#     'satname': 'GORIZONT 9',
#     'intDesignator': '1984-041A',
#     'launchDate': '1984-04-22',
#     'satlat': 9.6118,
#     'satlng': 59.6087,
#     'satalt': 35805.4842},
#    {'satid': 14943,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1984-041D',
#     'launchDate': '1984-04-22',
#     'satlat': 7.9471,
#     'satlng': 48.3955,
#     'satalt': 36284.8227},
#    {'satid': 14984,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1984-047F',
#     'launchDate': '1984-05-19',
#     'satlat': 37.2291,
#     'satlng': 94.5887,
#     'satalt': 19145.5836},
#    {'satid': 14985,
#     'satname': 'CHINASAT 5 (SPACENET 1)',
#     'intDesignator': '1984-049A',
#     'launchDate': '1984-05-23',
#     'satlat': 12.9859,
#     'satlng': 104.3746,
#     'satalt': 35900.3328},
#    {'satid': 15057,
#     'satname': 'RADUGA 15',
#     'intDesignator': '1984-063A',
#     'launchDate': '1984-06-22',
#     'satlat': 7.0035,
#     'satlng': 43.0835,
#     'satalt': 35805.7959},
#    {'satid': 15139,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1984-028F',
#     'launchDate': '1984-03-16',
#     'satlat': 11.2561,
#     'satlng': 90.8903,
#     'satalt': 35457.3581},
#    {'satid': 15141,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1983-066F',
#     'launchDate': '1983-06-30',
#     'satlat': 13.3216,
#     'satlng': 110.8402,
#     'satalt': 36507.1761},
#    {'satid': 15181,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1984-078F',
#     'launchDate': '1984-08-01',
#     'satlat': 8.6301,
#     'satlng': 53.7108,
#     'satalt': 35797.5077},
#    {'satid': 15226,
#     'satname': 'USA 4',
#     'intDesignator': '1984-091A',
#     'launchDate': '1984-08-28',
#     'satlat': 55.9842,
#     'satlng': 17.1567,
#     'satalt': 27224.1154},
#    {'satid': 15271,
#     'satname': 'NAVSTAR 10 (USA 5)',
#     'intDesignator': '1984-097A',
#     'launchDate': '1984-09-08',
#     'satlat': 22.2499,
#     'satlng': 43.8464,
#     'satalt': 21247.8804},
#    {'satid': 15429,
#     'satname': 'MOLNIYA 1-63',
#     'intDesignator': '1984-124A',
#     'launchDate': '1984-12-14',
#     'satlat': 47.9468,
#     'satlng': 47.5164,
#     'satalt': 24391.6887},
#    {'satid': 15454,
#     'satname': 'TITAN 34D R/B(2)',
#     'intDesignator': '1984-129B',
#     'launchDate': '1984-12-22',
#     'satlat': 11.4732,
#     'satlng': 71.2645,
#     'satalt': 35542.8603},
#    {'satid': 15693,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1984-063F',
#     'launchDate': '1984-06-22',
#     'satlat': 9.3887,
#     'satlng': 62.7763,
#     'satalt': 35009.2451},
#    {'satid': 15762,
#     'satname': 'COSMOS 886 DEB',
#     'intDesignator': '1976-126BU',
#     'launchDate': '1976-12-27',
#     'satlat': 34.3108,
#     'satlng': 64.7546,
#     'satalt': 1995.1907},
#    {'satid': 15824,
#     'satname': 'MORELOS 1',
#     'intDesignator': '1985-048B',
#     'launchDate': '1985-06-17',
#     'satlat': 2.8511,
#     'satlng': 50.5199,
#     'satalt': 35995.6342},
#    {'satid': 15837,
#     'satname': 'TELSTAR 3D R/B(PAM-D)',
#     'intDesignator': '1985-048H',
#     'launchDate': '1985-06-17',
#     'satlat': 25.5844,
#     'satlng': 99.1542,
#     'satalt': 25368.3317},
#    {'satid': 16117,
#     'satname': 'USA 12',
#     'intDesignator': '1985-092C',
#     'launchDate': '1985-10-03',
#     'satlat': 14.248,
#     'satlng': 111.6468,
#     'satalt': 36122.2935},
#    {'satid': 16137,
#     'satname': 'ATLAS 55E R/B',
#     'intDesignator': '1985-093B',
#     'launchDate': '1985-10-09',
#     'satlat': 63.6571,
#     'satlng': 95.6109,
#     'satalt': 6926.7079},
#    {'satid': 16199,
#     'satname': 'COSMOS 1700',
#     'intDesignator': '1985-102A',
#     'launchDate': '1985-10-25',
#     'satlat': 11.7076,
#     'satlng': 79.2062,
#     'satalt': 35798.8917},
#    {'satid': 16276,
#     'satname': 'SATCOM K2',
#     'intDesignator': '1985-109D',
#     'launchDate': '1985-11-27',
#     'satlat': 1.7283,
#     'satlng': 55.8292,
#     'satalt': 35995.937},
#    {'satid': 16396,
#     'satname': 'COSMOS 1710 (GLONASS)',
#     'intDesignator': '1985-118A',
#     'launchDate': '1985-12-24',
#     'satlat': 16.8656,
#     'satlng': 79.4122,
#     'satalt': 19163.6628},
#    {'satid': 16446,
#     'satname': 'SL-12 R/B(AUX MOTOR)',
#     'intDesignator': '1985-118L',
#     'launchDate': '1985-12-24',
#     'satlat': 32.1777,
#     'satlng': 69.4646,
#     'satalt': 3249.6825},
#    {'satid': 16526,
#     'satname': 'STTW-1',
#     'intDesignator': '1986-010A',
#     'launchDate': '1986-02-01',
#     'satlat': 9.6971,
#     'satlng': 65.4158,
#     'satalt': 35766.0228},
#    {'satid': 16650,
#     'satname': 'BRAZILSAT 2',
#     'intDesignator': '1986-026B',
#     'launchDate': '1986-03-28',
#     'satlat': 6.54,
#     'satlng': 72.5972,
#     'satalt': 35952.4271},
#    {'satid': 16676,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1986-027F',
#     'launchDate': '1986-04-04',
#     'satlat': 11.4532,
#     'satlng': 69.6638,
#     'satalt': 36406.919},
#    {'satid': 16870,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1986-007F',
#     'launchDate': '1986-01-17',
#     'satlat': 9.0026,
#     'satlng': 57.6826,
#     'satalt': 36473.4441},
#    {'satid': 17065,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1986-082F',
#     'launchDate': '1986-10-25',
#     'satlat': 7.8834,
#     'satlng': 54.7503,
#     'satalt': 36535.2976},
#    {'satid': 17081,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1986-089D',
#     'launchDate': '1986-11-15',
#     'satlat': 64.0474,
#     'satlng': 105.687,
#     'satalt': 38458.1934},
#    {'satid': 17083,
#     'satname': 'GORIZONT 13',
#     'intDesignator': '1986-090A',
#     'launchDate': '1986-11-18',
#     'satlat': 11.2081,
#     'satlng': 72.5136,
#     'satalt': 36799.3035},
#    {'satid': 17706,
#     'satname': 'AGILA 1 (PALAPA B2P)',
#     'intDesignator': '1987-029A',
#     'launchDate': '1987-03-20',
#     'satlat': 10.865,
#     'satlng': 90.6599,
#     'satalt': 35869.2819},
#    {'satid': 17872,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1976-092F',
#     'launchDate': '1976-09-11',
#     'satlat': 8.5541,
#     'satlng': 68.9762,
#     'satalt': 35722.532},
#    {'satid': 17873,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1979-035E',
#     'launchDate': '1979-04-25',
#     'satlat': 9.3337,
#     'satlng': 53.6171,
#     'satalt': 35888.1878},
#    {'satid': 17874,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1984-016F',
#     'launchDate': '1984-02-15',
#     'satlat': 12.2502,
#     'satlng': 89.4413,
#     'satalt': 35796.6625},
#    {'satid': 18331,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1987-073D',
#     'launchDate': '1987-09-03',
#     'satlat': 11.6214,
#     'satlng': 81.6768,
#     'satalt': 35413.2329},
#    {'satid': 18356,
#     'satname': 'COSMOS 1884 (GLONASS)',
#     'intDesignator': '1987-079B',
#     'launchDate': '1987-09-16',
#     'satlat': 49.0402,
#     'satlng': 98.3173,
#     'satalt': 19185.116},
#    {'satid': 18360,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1987-079F',
#     'launchDate': '1987-09-16',
#     'satlat': 37.8983,
#     'satlng': 86.2719,
#     'satalt': 19127.8561},
#    {'satid': 18375,
#     'satname': 'SL-12 R/B(AUX MOTOR)',
#     'intDesignator': '1987-079H',
#     'launchDate': '1987-09-16',
#     'satlat': 52.0581,
#     'satlng': 32.5282,
#     'satalt': 19514.8737},
#    {'satid': 18384,
#     'satname': 'COSMOS 1888',
#     'intDesignator': '1987-084A',
#     'launchDate': '1987-10-01',
#     'satlat': 7.9984,
#     'satlng': 58.2138,
#     'satalt': 35815.4286},
#    {'satid': 18575,
#     'satname': 'COSMOS 1897',
#     'intDesignator': '1987-096A',
#     'launchDate': '1987-11-26',
#     'satlat': 9.8624,
#     'satlng': 68.8002,
#     'satalt': 35775.5314},
#    {'satid': 18634,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1987-100D',
#     'launchDate': '1987-12-10',
#     'satlat': 12.554,
#     'satlng': 96.2784,
#     'satalt': 34967.2856},
#    {'satid': 18680,
#     'satname': 'SL-14 DEB',
#     'intDesignator': '1986-101L',
#     'launchDate': '1986-12-18',
#     'satlat': 45.4355,
#     'satlng': 79.7763,
#     'satalt': 891.1336},
#    {'satid': 18688,
#     'satname': 'WESTFORD NEEDLES',
#     'intDesignator': '1963-014DM',
#     'launchDate': '1963-05-09',
#     'satlat': 57.8414,
#     'satlng': 79.8404,
#     'satalt': 3644.5244},
#    {'satid': 18803,
#     'satname': 'COSMOS 1823 DEB',
#     'intDesignator': '1987-020AP',
#     'launchDate': '1987-02-20',
#     'satlat': 41.9703,
#     'satlng': 77.5898,
#     'satalt': 1481.4859},
#    {'satid': 18922,
#     'satname': 'STTW-2',
#     'intDesignator': '1988-014A',
#     'launchDate': '1988-03-07',
#     'satlat': 10.374,
#     'satlng': 80.4762,
#     'satalt': 35773.578},
#    {'satid': 19020,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1988-028D',
#     'launchDate': '1988-03-31',
#     'satlat': 9.5975,
#     'satlng': 65.9205,
#     'satalt': 36420.1133},
#    {'satid': 19309,
#     'satname': 'COSMOS 252 DEB',
#     'intDesignator': '1968-097ES',
#     'launchDate': '1968-11-01',
#     'satlat': 45.9235,
#     'satlng': 57.4957,
#     'satalt': 1937.1387},
#    {'satid': 19330,
#     'satname': 'INSAT 1C',
#     'intDesignator': '1988-063A',
#     'launchDate': '1988-07-21',
#     'satlat': 8.8101,
#     'satlng': 63.1424,
#     'satalt': 35761.8255},
#    {'satid': 19344,
#     'satname': 'COSMOS 1961',
#     'intDesignator': '1988-066A',
#     'launchDate': '1988-08-01',
#     'satlat': 9.7192,
#     'satlng': 69.838,
#     'satalt': 35766.8167},
#    {'satid': 19484,
#     'satname': 'SBS 5',
#     'intDesignator': '1988-081B',
#     'launchDate': '1988-09-08',
#     'satlat': 9.065,
#     'satlng': 96.7825,
#     'satalt': 35927.2906},
#    {'satid': 19501,
#     'satname': 'COSMOS 1970 (GLONASS)',
#     'intDesignator': '1988-085A',
#     'launchDate': '1988-09-16',
#     'satlat': 56.503,
#     'satlng': 106.5284,
#     'satalt': 19120.7329},
#    {'satid': 19503,
#     'satname': 'COSMOS 1972 (GLONASS)',
#     'intDesignator': '1988-085C',
#     'launchDate': '1988-09-16',
#     'satlat': 5.9077,
#     'satlng': 66.6295,
#     'satalt': 19137.4183},
#    {'satid': 19592,
#     'satname': 'TITAN 3C TRANSTAGE DEB',
#     'intDesignator': '1965-108AA',
#     'launchDate': '1965-12-21',
#     'satlat': 9.7704,
#     'satlng': 88.5579,
#     'satalt': 21491.4044},
#    {'satid': 19689,
#     'satname': 'ARIANE 44LP R/B',
#     'intDesignator': '1988-109C',
#     'launchDate': '1988-12-11',
#     'satlat': 5.1435,
#     'satlng': 60.7044,
#     'satalt': 31350.4909},
#    {'satid': 19710,
#     'satname': 'STTW-3',
#     'intDesignator': '1988-111A',
#     'launchDate': '1988-12-22',
#     'satlat': 13.8817,
#     'satlng': 109.686,
#     'satalt': 35768.3137},
#    {'satid': 19776,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1989-004F',
#     'launchDate': '1989-01-26',
#     'satlat': 13.8731,
#     'satlng': 98.4175,
#     'satalt': 36330.8011},
#    {'satid': 19810,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1989-014D',
#     'launchDate': '1989-02-15',
#     'satlat': 64.2657,
#     'satlng': 35.0083,
#     'satalt': 36970.7662},
#    {'satid': 19874,
#     'satname': 'JCSAT 1',
#     'intDesignator': '1989-020A',
#     'launchDate': '1989-03-06',
#     'satlat': 1.458,
#     'satlng': 55.581,
#     'satalt': 35985.3462},
#    {'satid': 19876,
#     'satname': 'METEOSAT 4 (MOP 1)',
#     'intDesignator': '1989-020B',
#     'launchDate': '1989-03-06',
#     'satlat': 13.7474,
#     'satlng': 101.8507,
#     'satalt': 36694.1381},
#    {'satid': 19970,
#     'satname': 'IUS R/B(1)',
#     'intDesignator': '1989-033C',
#     'launchDate': '1989-05-04',
#     'satlat': 27.1236,
#     'satlng': 49.9556,
#     'satalt': 18953.3848},
#    {'satid': 19976,
#     'satname': 'USA 37',
#     'intDesignator': '1989-035A',
#     'launchDate': '1989-05-10',
#     'satlat': 5.1228,
#     'satlng': 86.7971,
#     'satalt': 35807.7673},
#    {'satid': 20127,
#     'satname': 'ARIANE 3 DEB',
#     'intDesignator': '1988-063E',
#     'launchDate': '1988-07-21',
#     'satlat': 4.6696,
#     'satlng': 74.7247,
#     'satalt': 34783.8992},
#    {'satid': 20129,
#     'satname': 'SL-14 DEB',
#     'intDesignator': '1989-080E',
#     'launchDate': '1989-09-28',
#     'satlat': 46.6704,
#     'satlng': 67.1852,
#     'satalt': 2088.2617},
#    {'satid': 20169,
#     'satname': 'HIPPARCOS',
#     'intDesignator': '1989-062B',
#     'launchDate': '1989-08-08',
#     'satlat': 4.223,
#     'satlng': 95.8437,
#     'satalt': 24835.269},
#    {'satid': 20202,
#     'satname': 'USA 43',
#     'intDesignator': '1989-069A',
#     'launchDate': '1989-09-04',
#     'satlat': 3.9377,
#     'satlng': 47.7173,
#     'satalt': 36308.9368},
#    {'satid': 20203,
#     'satname': 'USA 44',
#     'intDesignator': '1989-069B',
#     'launchDate': '1989-09-04',
#     'satlat': 6.7771,
#     'satlng': 88.7631,
#     'satalt': 36077.3761},
#    {'satid': 20205,
#     'satname': 'TITAN 34D IUS R/B(2)',
#     'intDesignator': '1989-069D',
#     'launchDate': '1989-09-04',
#     'satlat': 5.7284,
#     'satlng': 49.1027,
#     'satalt': 35491.2823},
#    {'satid': 20217,
#     'satname': 'HIMAWARI 4 (GMS 4)',
#     'intDesignator': '1989-070A',
#     'launchDate': '1989-09-05',
#     'satlat': 5.4826,
#     'satlng': 62.9738,
#     'satalt': 36543.6305},
#    {'satid': 20253,
#     'satname': 'FLTSATCOM 8 (USA 46)',
#     'intDesignator': '1989-077A',
#     'launchDate': '1989-09-25',
#     'satlat': 5.8091,
#     'satlng': 71.3502,
#     'satalt': 35788.4533},
#    {'satid': 20263,
#     'satname': 'GORIZONT 19',
#     'intDesignator': '1989-081A',
#     'launchDate': '1989-09-28',
#     'satlat': 14.0741,
#     'satlng': 111.557,
#     'satalt': 35787.9343},
#    {'satid': 20317,
#     'satname': 'HIMAWARI 4 AKM',
#     'intDesignator': '1989-070C',
#     'launchDate': '1989-09-05',
#     'satlat': 14.1711,
#     'satlng': 110.8141,
#     'satalt': 35789.223},
#    {'satid': 20410,
#     'satname': 'LEASAT 5',
#     'intDesignator': '1990-002B',
#     'launchDate': '1990-01-09',
#     'satlat': 10.0249,
#     'satlng': 102.2963,
#     'satalt': 35954.8872},
#    {'satid': 20412,
#     'satname': 'COSMOS 1481 DEB',
#     'intDesignator': '1983-070F',
#     'launchDate': '1983-07-08',
#     'satlat': 63.5161,
#     'satlng': 103.4393,
#     'satalt': 19444.9913},
#    {'satid': 20443,
#     'satname': 'ARIANE 40 R/B',
#     'intDesignator': '1990-005H',
#     'launchDate': '1990-01-22',
#     'satlat': 35.6474,
#     'satlng': 76.9496,
#     'satalt': 776.0141},
#    {'satid': 20473,
#     'satname': 'STTW-4',
#     'intDesignator': '1990-011A',
#     'launchDate': '1990-02-04',
#     'satlat': 2.9537,
#     'satlng': 54.7182,
#     'satalt': 35779.0114},
#    {'satid': 20555,
#     'satname': 'COSMOS 2070',
#     'intDesignator': '1990-029G',
#     'launchDate': '1990-04-06',
#     'satlat': 39.142,
#     'satlng': 60.8525,
#     'satalt': 1458.0298},
#    {'satid': 20620,
#     'satname': 'COSMOS 2080 (GLONASS)',
#     'intDesignator': '1990-045B',
#     'launchDate': '1990-05-19',
#     'satlat': 4.1153,
#     'satlng': 60.5367,
#     'satalt': 19086.1816},
#    {'satid': 20643,
#     'satname': 'INSAT 1D',
#     'intDesignator': '1990-051A',
#     'launchDate': '1990-06-12',
#     'satlat': 5.039,
#     'satlng': 70.5595,
#     'satalt': 35810.0871},
#    {'satid': 20659,
#     'satname': 'GORIZONT 20',
#     'intDesignator': '1990-054A',
#     'launchDate': '1990-06-20',
#     'satlat': 10.911,
#     'satlng': 80.7672,
#     'satalt': 35800.2358},
#    {'satid': 20662,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1990-054D',
#     'launchDate': '1990-06-20',
#     'satlat': 11.0288,
#     'satlng': 81.5704,
#     'satalt': 35643.1812},
#    {'satid': 20693,
#     'satname': 'COSMOS 2085',
#     'intDesignator': '1990-061A',
#     'launchDate': '1990-07-18',
#     'satlat': 9.6191,
#     'satlng': 74.075,
#     'satalt': 35768.5392},
#    {'satid': 20696,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1990-061D',
#     'launchDate': '1990-07-18',
#     'satlat': 14.3202,
#     'satlng': 113.583,
#     'satalt': 35746.4681},
#    {'satid': 20706,
#     'satname': 'DFS 2',
#     'intDesignator': '1990-063B',
#     'launchDate': '1990-07-24',
#     'satlat': 10.2376,
#     'satlng': 107.035,
#     'satalt': 35999.859},
#    {'satid': 20836,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1974-060F',
#     'launchDate': '1974-07-29',
#     'satlat': 5.2868,
#     'satlng': 97.4961,
#     'satalt': 35697.2917},
#    {'satid': 20947,
#     'satname': 'ARIANE 42P R/B',
#     'intDesignator': '1990-100C',
#     'launchDate': '1990-11-20',
#     'satlat': 4.7307,
#     'satlng': 62.549,
#     'satalt': 20636.8603},
#    {'satid': 21016,
#     'satname': 'RADUGA 26',
#     'intDesignator': '1990-112A',
#     'launchDate': '1990-12-20',
#     'satlat': 11.9947,
#     'satlng': 89.4531,
#     'satalt': 35744.7686},
#    {'satid': 21038,
#     'satname': 'RADUGA 1-2',
#     'intDesignator': '1990-116A',
#     'launchDate': '1990-12-27',
#     'satlat': 7.5312,
#     'satlng': 65.2217,
#     'satalt': 35741.7435},
#    {'satid': 21056,
#     'satname': 'EUTELSAT 2-F2',
#     'intDesignator': '1991-003B',
#     'launchDate': '1991-01-15',
#     'satlat': 4.4606,
#     'satlng': 75.6242,
#     'satalt': 36156.7365},
#    {'satid': 21111,
#     'satname': 'COSMOS 2133',
#     'intDesignator': '1991-010A',
#     'launchDate': '1991-02-14',
#     'satlat': 7.4815,
#     'satlng': 69.6834,
#     'satalt': 35785.4413},
#    {'satid': 21121,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1991-012D',
#     'launchDate': '1991-02-15',
#     'satlat': 64.6037,
#     'satlng': 129.4238,
#     'satalt': 35507.7032},
#    {'satid': 21199,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1991-022D',
#     'launchDate': '1991-03-22',
#     'satlat': 57.9129,
#     'satlng': 76.085,
#     'satalt': 29054.0267},
#    {'satid': 21339,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1975-052BH',
#     'launchDate': '1975-06-12',
#     'satlat': 45.836,
#     'satlng': 79.3219,
#     'satalt': 1369.6885},
#    {'satid': 21550,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1975-052HE',
#     'launchDate': '1975-06-12',
#     'satlat': 46.255,
#     'satlng': 73.6829,
#     'satalt': 1296.7566},
#    {'satid': 21637,
#     'satname': 'CRRES DEB (CANISTER)',
#     'intDesignator': '1990-065P',
#     'launchDate': '1990-07-25',
#     'satlat': 12.0989,
#     'satlng': 99.9507,
#     'satalt': 24308.5331},
#    {'satid': 21692,
#     'satname': 'TITAN 3C TRANSTAGE DEB',
#     'intDesignator': '1965-108AF',
#     'launchDate': '1965-12-21',
#     'satlat': 20.3214,
#     'satlng': 109.7102,
#     'satalt': 19760.4919},
#    {'satid': 21803,
#     'satname': 'EUTELSAT 2-F3',
#     'intDesignator': '1991-083A',
#     'launchDate': '1991-12-07',
#     'satlat': 8.1036,
#     'satlng': 92.1412,
#     'satalt': 36057.4884},
#    {'satid': 21814,
#     'satname': 'INMARSAT 2-F3',
#     'intDesignator': '1991-084B',
#     'launchDate': '1991-12-16',
#     'satlat': 1.8632,
#     'satlng': 74.8427,
#     'satalt': 36948.7979},
#    {'satid': 21940,
#     'satname': 'INMARSAT 2-F4',
#     'intDesignator': '1992-021B',
#     'launchDate': '1992-04-15',
#     'satlat': 5.3891,
#     'satlng': 96.7877,
#     'satalt': 36444.4656},
#    {'satid': 22044,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1992-043D',
#     'launchDate': '1992-07-14',
#     'satlat': 9.7668,
#     'satlng': 80.9751,
#     'satalt': 36496.3505},
#    {'satid': 22116,
#     'satname': 'HISPASAT 1A',
#     'intDesignator': '1992-060A',
#     'launchDate': '1992-09-10',
#     'satlat': 7.2924,
#     'satlng': 99.8711,
#     'satalt': 36071.4273},
#    {'satid': 22178,
#     'satname': 'MOLNIYA 3-42',
#     'intDesignator': '1992-067A',
#     'launchDate': '1992-10-14',
#     'satlat': 62.5693,
#     'satlng': 74.1538,
#     'satalt': 34781.8542},
#    {'satid': 22181,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1992-067D',
#     'launchDate': '1992-10-14',
#     'satlat': 50.79,
#     'satlng': 95.6038,
#     'satalt': 25020.1077},
#    {'satid': 22210,
#     'satname': 'EKRAN 20',
#     'intDesignator': '1992-074A',
#     'launchDate': '1992-10-30',
#     'satlat': 11.9389,
#     'satlng': 94.2798,
#     'satalt': 35787.7188},
#    {'satid': 22238,
#     'satname': 'COSMOS 2222',
#     'intDesignator': '1992-081A',
#     'launchDate': '1992-11-25',
#     'satlat': 12.8565,
#     'satlng': 67.3266,
#     'satalt': 38682.3072},
#    {'satid': 22248,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1992-082D',
#     'launchDate': '1992-11-27',
#     'satlat': 5.0834,
#     'satlng': 62.2117,
#     'satalt': 36383.4094},
#    {'satid': 22694,
#     'satname': 'HGS 4 (GALAXY 4)',
#     'intDesignator': '1993-039A',
#     'launchDate': '1993-06-25',
#     'satlat': 5.091,
#     'satlng': 72.0331,
#     'satalt': 35801.3261},
#    {'satid': 22719,
#     'satname': 'USA 93',
#     'intDesignator': '1993-046A',
#     'launchDate': '1993-07-19',
#     'satlat': -1.5997,
#     'satlng': 61.6182,
#     'satalt': 36114.6487},
#    {'satid': 22818,
#     'satname': 'TITAN 34D TRANSTAGE DEB',
#     'intDesignator': '1988-077F',
#     'launchDate': '1988-09-02',
#     'satlat': 26.9954,
#     'satlng': 62.5094,
#     'satalt': 15911.0858},
#    {'satid': 22836,
#     'satname': 'RADUGA 30',
#     'intDesignator': '1993-062A',
#     'launchDate': '1993-09-30',
#     'satlat': 6.4838,
#     'satlng': 69.4539,
#     'satalt': 35777.4096},
#    {'satid': 22842,
#     'satname': 'SL-8 DEB',
#     'intDesignator': '1991-009CM',
#     'launchDate': '1991-02-12',
#     'satlat': 47.6343,
#     'satlng': 85.2414,
#     'satalt': 1505.1167},
#    {'satid': 22877,
#     'satname': 'NAVSTAR 35 (USA 96)',
#     'intDesignator': '1993-068A',
#     'launchDate': '1993-10-26',
#     'satlat': 12.3645,
#     'satlng': 97.766,
#     'satalt': 21295.9107},
#    {'satid': 22979,
#     'satname': 'VEP',
#     'intDesignator': '1994-007B',
#     'launchDate': '1994-02-03',
#     'satlat': 20.2691,
#     'satlng': 84.4888,
#     'satalt': 32035.1262},
#    {'satid': 22981,
#     'satname': 'RADUGA 1-3',
#     'intDesignator': '1994-008A',
#     'launchDate': '1994-02-05',
#     'satlat': 5.705,
#     'satlng': 67.3111,
#     'satalt': 35788.0863},
#    {'satid': 23010,
#     'satname': 'RADUGA 31',
#     'intDesignator': '1994-012A',
#     'launchDate': '1994-02-18',
#     'satlat': 12.015,
#     'satlng': 98.4986,
#     'satalt': 35752.0686},
#    {'satid': 23018,
#     'satname': 'DELTA 2 R/B(2)',
#     'intDesignator': '1994-013C',
#     'launchDate': '1994-02-19',
#     'satlat': 18.6904,
#     'satlng': 67.9813,
#     'satalt': 33474.896},
#    {'satid': 23038,
#     'satname': 'TITAN 34D TRANSTAGE DEB',
#     'intDesignator': '1988-077H',
#     'launchDate': '1988-09-02',
#     'satlat': 1.9119,
#     'satlng': 63.4962,
#     'satalt': 26390.0367},
#    {'satid': 23040,
#     'satname': 'TITAN 34D TRANSTAGE DEB',
#     'intDesignator': '1988-077K',
#     'launchDate': '1988-09-02',
#     'satlat': 11.1666,
#     'satlng': 62.3043,
#     'satalt': 26209.786},
#    {'satid': 23041,
#     'satname': 'TITAN 34D TRANSTAGE DEB',
#     'intDesignator': '1988-077L',
#     'launchDate': '1988-09-02',
#     'satlat': 11.1239,
#     'satlng': 51.1456,
#     'satalt': 18751.8674},
#    {'satid': 23043,
#     'satname': 'COSMOS 2276 (GLONASS)',
#     'intDesignator': '1994-021A',
#     'launchDate': '1994-04-11',
#     'satlat': 41.2646,
#     'satlng': 76.9752,
#     'satalt': 19173.0518},
#    {'satid': 23045,
#     'satname': 'COSMOS 2275 (GLONASS)',
#     'intDesignator': '1994-021C',
#     'launchDate': '1994-04-11',
#     'satlat': 36.4765,
#     'satlng': 72.7744,
#     'satalt': 19067.4265},
#    {'satid': 23048,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1994-021F',
#     'launchDate': '1994-04-11',
#     'satlat': 21.3279,
#     'satlng': 62.4312,
#     'satalt': 19143.3733},
#    {'satid': 23111,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1994-030D',
# ...
#     'satalt': 35789.3546},
#    {'satid': 44076,
#     'satname': 'TIANLIAN 2-01',
#     'intDesignator': '2019-017A',
#     'launchDate': '2019-03-31',
#     'satlat': 1.4859,
#     'satlng': 79.6754,
#     'satalt': 35827.2357},
#    {'satid': 44103,
#     'satname': 'AISTECHSAT-3',
#     'intDesignator': '2019-018AB',
#     'launchDate': '2019-04-01',
#     'satlat': 44.3363,
#     'satlng': 73.286,
#     'satalt': 502.4881},
#    {'satid': 44187,
#     'satname': 'FALCON 9 R/B',
#     'intDesignator': '2019-021B',
#     'launchDate': '2019-04-11',
#     'satlat': 19.826,
#     'satlng': 63.4539,
#     'satalt': 29569.0271},
#    {'satid': 44204,
#     'satname': 'BEIDOU 3 IGSO-1',
#     'intDesignator': '2019-023A',
#     'launchDate': '2019-04-20',
#     'satlat': 9.4243,
#     'satlng': 106.6062,
#     'satalt': 35855.4175},
#    {'satid': 44453,
#     'satname': 'MERIDIAN 8',
#     'intDesignator': '2019-046A',
#     'launchDate': '2019-07-30',
#     'satlat': 58.2433,
#     'satlng': 83.4947,
#     'satalt': 36069.8026},
#    {'satid': 44454,
#     'satname': 'FREGAT R/B',
#     'intDesignator': '2019-046B',
#     'launchDate': '2019-07-30',
#     'satlat': 44.4332,
#     'satlng': 106.9009,
#     'satalt': 25009.1323},
#    {'satid': 44476,
#     'satname': 'INTELSAT 39',
#     'intDesignator': '2019-049B',
#     'launchDate': '2019-08-06',
#     'satlat': 0.0284,
#     'satlng': 61.9405,
#     'satalt': 35787.7714},
#    {'satid': 44481,
#     'satname': 'AEHF 5 (USA 292)',
#     'intDesignator': '2019-051A',
#     'launchDate': '2019-08-08',
#     'satlat': 5.1589,
#     'satlng': 54.4118,
#     'satalt': 35793.0586},
#    {'satid': 44524,
#     'satname': 'USA 40 R/B DEB',
#     'intDesignator': '1989-061BX',
#     'launchDate': '1989-08-08',
#     'satlat': 50.8198,
#     'satlng': 84.3078,
#     'satalt': 2861.1785},
#    {'satid': 44544,
#     'satname': 'YZ-1 R/B',
#     'intDesignator': '2019-061C',
#     'launchDate': '2019-09-22',
#     'satlat': 53.4831,
#     'satlng': 41.9298,
#     'satalt': 22196.1675},
#    {'satid': 44552,
#     'satname': 'COSMOS 2541',
#     'intDesignator': '2019-065A',
#     'launchDate': '2019-09-26',
#     'satlat': 63.3178,
#     'satlng': 137.2638,
#     'satalt': 38697.9661},
#    {'satid': 44553,
#     'satname': 'FREGAT R/B',
#     'intDesignator': '2019-065B',
#     'launchDate': '2019-09-26',
#     'satlat': 62.8864,
#     'satlng': 130.6968,
#     'satalt': 38137.0255},
#    {'satid': 44582,
#     'satname': 'LUCH DEB',
#     'intDesignator': '1994-082G',
#     'launchDate': '1994-12-16',
#     'satlat': 2.4103,
#     'satlng': 60.684,
#     'satalt': 35604.215},
#    {'satid': 44637,
#     'satname': 'TJS-4',
#     'intDesignator': '2019-070A',
#     'launchDate': '2019-10-17',
#     'satlat': -0.0019,
#     'satlng': 83.5597,
#     'satalt': 35792.56},
#    {'satid': 44644,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079E',
#     'launchDate': '2018-10-17',
#     'satlat': 5.9842,
#     'satlng': 57.9184,
#     'satalt': 32811.8906},
#    {'satid': 44645,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079F',
#     'launchDate': '2018-10-17',
#     'satlat': 4.6819,
#     'satlng': 55.4842,
#     'satalt': 33768.6902},
#    {'satid': 44648,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079J',
#     'launchDate': '2018-10-17',
#     'satlat': 2.1019,
#     'satlng': 76.9403,
#     'satalt': 30337.8425},
#    {'satid': 44653,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079P',
#     'launchDate': '2018-10-17',
#     'satlat': -0.4242,
#     'satlng': 72.0621,
#     'satalt': 31792.7326},
#    {'satid': 44655,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079R',
#     'launchDate': '2018-10-17',
#     'satlat': 2.6119,
#     'satlng': 61.9132,
#     'satalt': 33955.8319},
#    {'satid': 44663,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079Z',
#     'launchDate': '2018-10-17',
#     'satlat': 5.7561,
#     'satlng': 51.6766,
#     'satalt': 34685.4192},
#    {'satid': 44670,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079AG',
#     'launchDate': '2018-10-17',
#     'satlat': 5.7242,
#     'satlng': 55.7698,
#     'satalt': 34223.1143},
#    {'satid': 44672,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079AJ',
#     'launchDate': '2018-10-17',
#     'satlat': 2.7097,
#     'satlng': 62.1756,
#     'satalt': 34377.0135},
#    {'satid': 44675,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079AM',
#     'launchDate': '2018-10-17',
#     'satlat': 2.6069,
#     'satlng': 71.2966,
#     'satalt': 31178.6848},
#    {'satid': 44682,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079AU',
#     'launchDate': '2018-10-17',
#     'satlat': 6.3519,
#     'satlng': 50.605,
#     'satalt': 34721.0936},
#    {'satid': 44683,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079AV',
#     'launchDate': '2018-10-17',
#     'satlat': 4.5653,
#     'satlng': 61.1776,
#     'satalt': 33766.694},
#    {'satid': 44685,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079AX',
#     'launchDate': '2018-10-17',
#     'satlat': 7.1881,
#     'satlng': 61.3728,
#     'satalt': 32442.8581},
#    {'satid': 44695,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079BH',
#     'launchDate': '2018-10-17',
#     'satlat': 5.0422,
#     'satlng': 54.806,
#     'satalt': 34878.9327},
#    {'satid': 44709,
#     'satname': 'BEIDOU 3 IGSO-3',
#     'intDesignator': '2019-073A',
#     'launchDate': '2019-11-04',
#     'satlat': 44.4256,
#     'satlng': 125.7206,
#     'satalt': 35763.8537},
#    {'satid': 44793,
#     'satname': 'BEIDOU 3M21',
#     'intDesignator': '2019-078A',
#     'launchDate': '2019-11-23',
#     'satlat': 35.0352,
#     'satlng': 80.2162,
#     'satalt': 21522.9207},
#    {'satid': 44803,
#     'satname': 'ARIANE 5 DEB (SYLDA)',
#     'intDesignator': '2019-080D',
#     'launchDate': '2019-11-26',
#     'satlat': -0.7214,
#     'satlng': 76.5175,
#     'satalt': 27115.2337},
#    {'satid': 44846,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2014-055CE',
#     'launchDate': '2014-09-17',
#     'satlat': 21.6347,
#     'satlng': 62.1337,
#     'satalt': 34157.6545},
#    {'satid': 44847,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2014-055CF',
#     'launchDate': '2014-09-17',
#     'satlat': 21.992,
#     'satlng': 95.7079,
#     'satalt': 20050.4451},
#    {'satid': 44848,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2014-055CG',
#     'launchDate': '2014-09-17',
#     'satlat': 19.539,
#     'satlng': 70.2926,
#     'satalt': 26494.7192},
#    {'satid': 44867,
#     'satname': 'CZ-3B R/B',
#     'intDesignator': '2019-090D',
#     'launchDate': '2019-12-16',
#     'satlat': 49.0435,
#     'satlng': 34.9159,
#     'satalt': 12748.7497},
#    {'satid': 44903,
#     'satname': 'ELEKTRO-L 3',
#     'intDesignator': '2019-095A',
#     'launchDate': '2019-12-24',
#     'satlat': 0.0008,
#     'satlng': 76.0393,
#     'satalt': 35788.4825},
#    {'satid': 44985,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079BR',
#     'launchDate': '2018-10-17',
#     'satlat': 0.0649,
#     'satlng': 72.9555,
#     'satalt': 32069.0763},
#    {'satid': 44986,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079BS',
#     'launchDate': '2018-10-17',
#     'satlat': 0.0719,
#     'satlng': 83.4833,
#     'satalt': 29272.8485},
#    {'satid': 45020,
#     'satname': 'OBJECT E',
#     'intDesignator': '2020-003E',
#     'launchDate': '2020-01-15',
#     'satlat': 40.5571,
#     'satlng': 72.7123,
#     'satalt': 482.0428},
#    {'satid': 45026,
#     'satname': 'GSAT 30',
#     'intDesignator': '2020-005A',
#     'launchDate': '2020-01-16',
#     'satlat': 0.0034,
#     'satlng': 82.9737,
#     'satalt': 35786.1649},
#    {'satid': 45067,
#     'satname': 'STARLINK-1150',
#     'intDesignator': '2020-006Z',
#     'launchDate': '2020-01-29',
#     'satlat': 37.7797,
#     'satlng': 71.4408,
#     'satalt': 552.2105},
#    {'satid': 45117,
#     'satname': 'AEROCUBE 15B',
#     'intDesignator': '2019-071G',
#     'launchDate': '2019-11-02',
#     'satlat': 39.6694,
#     'satlng': 75.519,
#     'satalt': 471.7695},
#    {'satid': 45344,
#     'satname': 'BEIDOU 3 G2',
#     'intDesignator': '2020-017A',
#     'launchDate': '2020-03-09',
#     'satlat': 2.5121,
#     'satlng': 80.0237,
#     'satalt': 35790.6618},
#    {'satid': 45345,
#     'satname': 'CZ-3B R/B',
#     'intDesignator': '2020-017B',
#     'launchDate': '2020-03-09',
#     'satlat': 21.912,
#     'satlng': 48.1068,
#     'satalt': 15831.3339},
#    {'satid': 45471,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079BT',
#     'launchDate': '2018-10-17',
#     'satlat': 6.3847,
#     'satlng': 52.19,
#     'satalt': 34888.7128},
#    {'satid': 45475,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079BX',
#     'launchDate': '2018-10-17',
#     'satlat': 4.6364,
#     'satlng': 60.0249,
#     'satalt': 34066.436},
#    {'satid': 45609,
#     'satname': 'FREGAT R/B',
#     'intDesignator': '2020-031B',
#     'launchDate': '2020-05-22',
#     'satlat': 63.6219,
#     'satlng': 43.3459,
#     'satalt': 38205.4215},
#    {'satid': 45618,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037M',
#     'launchDate': '2011-07-18',
#     'satlat': 40.0605,
#     'satlng': 87.5161,
#     'satalt': 1479.704},
#    {'satid': 45642,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037AJ',
#     'launchDate': '2011-07-18',
#     'satlat': 39.8812,
#     'satlng': 84.265,
#     'satalt': 1252.9743},
#    {'satid': 45648,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037AQ',
#     'launchDate': '2011-07-18',
#     'satlat': 36.2911,
#     'satlng': 82.6215,
#     'satalt': 1311.0859},
#    {'satid': 45808,
#     'satname': 'CZ-3B R/B',
#     'intDesignator': '2020-040B',
#     'launchDate': '2020-06-23',
#     'satlat': 22.7729,
#     'satlng': 35.9031,
#     'satalt': 29997.0966},
#    {'satid': 45872,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037CW',
#     'launchDate': '2011-07-18',
#     'satlat': 30.7498,
#     'satlng': 82.2227,
#     'satalt': 2114.4337},
#    {'satid': 45884,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037DD',
#     'launchDate': '2011-07-18',
#     'satlat': 49.534,
#     'satlng': 83.0942,
#     'satalt': 1639.086},
#    {'satid': 45933,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037EX',
#     'launchDate': '2011-07-18',
#     'satlat': 43.8558,
#     'satlng': 78.7714,
#     'satalt': 1402.3453},
#    {'satid': 45947,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037FC',
#     'launchDate': '2011-07-18',
#     'satlat': 41.0169,
#     'satlng': 79.8297,
#     'satalt': 1266.4148},
#    {'satid': 45977,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037GJ',
#     'launchDate': '2011-07-18',
#     'satlat': 37.4699,
#     'satlng': 63.0624,
#     'satalt': 1949.074},
#    {'satid': 45986,
#     'satname': 'OBJECT B',
#     'intDesignator': '2020-053B',
#     'launchDate': '2020-07-30',
#     'satlat': 0.1498,
#     'satlng': 71.8911,
#     'satalt': 34496.3441},
#    {'satid': 46105,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037JQ',
#     'launchDate': '2011-07-18',
#     'satlat': 40.5125,
#     'satlng': 79.7767,
#     'satalt': 1142.634},
#    {'satid': 46108,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037JT',
#     'launchDate': '2011-07-18',
#     'satlat': 42.4795,
#     'satlng': 73.9098,
#     'satalt': 2235.9832},
#    {'satid': 46114,
#     'satname': 'GALAXY 30',
#     'intDesignator': '2020-056C',
#     'launchDate': '2020-08-15',
#     'satlat': 0.0293,
#     'satlng': 91.5289,
#     'satalt': 35666.8424},
#    {'satid': 46326,
#     'satname': 'STARLINK-1654',
#     'intDesignator': '2020-062B',
#     'launchDate': '2020-09-03',
#     'satlat': 41.1531,
#     'satlng': 77.8648,
#     'satalt': 552.5103},
#    {'satid': 46429,
#     'satname': 'SL-12 DEB',
#     'intDesignator': '2010-007AR',
#     'launchDate': '2010-03-01',
#     'satlat': 12.1878,
#     'satlng': 66.0488,
#     'satalt': 14588.6069},
#    {'satid': 46485,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079BY',
#     'launchDate': '2018-10-17',
#     'satlat': 1.5823,
#     'satlng': 56.3568,
#     'satalt': 31591.6904},
#    {'satid': 46605,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079CD',
#     'launchDate': '2018-10-17',
#     'satlat': 7.0831,
#     'satlng': 52.6701,
#     'satalt': 33134.4334},
#    {'satid': 46608,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079CG',
#     'launchDate': '2018-10-17',
#     'satlat': 0.8161,
#     'satlng': 79.233,
#     'satalt': 28966.1722},
#    {'satid': 46638,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2014-055CN',
#     'launchDate': '2014-09-17',
#     'satlat': 18.243,
#     'satlng': 60.3544,
#     'satalt': 31433.5802},
#    {'satid': 46643,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2014-055CT',
#     'launchDate': '2014-09-17',
#     'satlat': 21.8902,
#     'satlng': 100.3426,
#     'satalt': 17547.602},
#    {'satid': 46651,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2014-055DB',
#     'launchDate': '2014-09-17',
#     'satlat': 21.7847,
#     'satlng': 92.2207,
#     'satalt': 18180.3717},
#    {'satid': 46652,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2014-055DC',
#     'launchDate': '2014-09-17',
#     'satlat': 21.4475,
#     'satlng': 86.1449,
#     'satalt': 18853.4727},
#    {'satid': 46654,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2014-055DE',
#     'launchDate': '2014-09-17',
#     'satlat': 21.6062,
#     'satlng': 90.6157,
#     'satalt': 23356.4668},
#    {'satid': 46657,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079CK',
#     'launchDate': '2018-10-17',
#     'satlat': -0.1035,
#     'satlng': 85.278,
#     'satalt': 31404.2713},
#    {'satid': 46661,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079CP',
#     'launchDate': '2018-10-17',
#     'satlat': 4.0976,
#     'satlng': 61.6539,
#     'satalt': 32720.5945},
#    {'satid': 46662,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079CQ',
#     'launchDate': '2018-10-17',
#     'satlat': 5.502,
#     'satlng': 50.2071,
#     'satalt': 33108.5458},
#    {'satid': 46663,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079CR',
#     'launchDate': '2018-10-17',
#     'satlat': 6.6647,
#     'satlng': 49.3017,
#     'satalt': 34834.6709},
#    {'satid': 46665,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079CT',
#     'launchDate': '2018-10-17',
#     'satlat': 0.5736,
#     'satlng': 84.6502,
#     'satalt': 25799.9436},
#    {'satid': 46816,
#     'satname': 'FLOCK 4 EP 8',
#     'intDesignator': '2020-077D',
#     'launchDate': '2020-10-28',
#     'satlat': 35.9045,
#     'satlng': 76.3182,
#     'satalt': 528.177},
#    {'satid': 46826,
#     'satname': 'NAVSTAR 80 (USA 309)',
#     'intDesignator': '2020-078A',
#     'launchDate': '2020-11-05',
#     'satlat': 47.8167,
#     'satlng': 103.2417,
#     'satalt': 20190.3858},
#    {'satid': 46842,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079CX',
#     'launchDate': '2018-10-17',
#     'satlat': 2.2607,
#     'satlng': 80.6511,
#     'satalt': 27509.8423},
#    {'satid': 46846,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079DB',
#     'launchDate': '2018-10-17',
#     'satlat': 8.8926,
#     'satlng': 41.052,
#     'satalt': 36934.3002},
#    {'satid': 46849,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079DE',
#     'launchDate': '2018-10-17',
#     'satlat': 6.804,
#     'satlng': 44.6509,
#     'satalt': 39061.2793},
#    {'satid': 46863,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079DU',
#     'launchDate': '2018-10-17',
#     'satlat': 1.6707,
#     'satlng': 67.8935,
#     'satalt': 34486.7696},
#    {'satid': 46865,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2018-079DW',
#     'launchDate': '2018-10-17',
#     'satlat': 4.0611,
#     'satlng': 67.573,
#     'satalt': 31921.5435},
#    {'satid': 47097,
#     'satname': "CHANG'E 5",
#     'intDesignator': '2020-087A',
#     'launchDate': '2020-11-23',
#     'satlat': 12.3567,
#     'satlng': 77.8171,
#     'satalt': 202469.6259},
#    {'satid': 47120,
#     'satname': 'ATLAS 5 CENTAUR DEB',
#     'intDesignator': '2014-055DG',
#     'launchDate': '2014-09-17',
#     'satlat': 11.9565,
#     'satlng': 53.2969,
#     'satalt': 27000.9594}]}]

# %%
with open('satlaunch.json', 'a+') as f:
   json.dump(earth_sat,f)
