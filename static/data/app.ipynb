# %%
import requests
import pandas as pd
import json
from api_key import API_Key
import csv
import numpy as np
import pprint

# %%
df = pd.read_csv('../data/Satellite-Exploration-CSV.csv')
df
# Out:
#           name  satid                      source  \
# 0        HYSIS  43719                       India
# 1     GAOFEN-5  43461  People's Republic of China
# 2      NUSAT 5  43204                   Argentina
# 3      NUSAT 4  43195                   Argentina
# 4       VRSS-2  42954                   Venezuela
# ..         ...    ...                         ...
# 144  LANDSAT 4  13367               United States
# 145   SEASAT 1  10967               United States
# 146  LANDSAT 3  10702               United States
# 147  LANDSAT 2   7615               United States
# 148  LANDSAT 1   6126               United States
#
#                                        launchsite     LSlat    LSlong  \
# 0                               SRIHARIKOTA (SRI)  13.72590   80.2266
# 1               Taiyuan Space Center, China (TSC)  38.84280  111.6051
# 2    Jiuquan Satellite Launch Center, China (JSC)  40.98450  100.2087
# 3    Jiuquan Satellite Launch Center, China (JSC)  40.98450  100.2087
# 4    Jiuquan Satellite Launch Center, China (JSC)  40.98450  100.2087
# ..                                            ...       ...       ...
# 144          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
# 145          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
# 146          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
# 147          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
# 148          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
#
#         Clat     Clong
# 0    20.5837   78.9629
# 1    35.8617  104.1954
# 2    38.4161   63.6167
# 3    38.4161   63.6167
# 4     6.4238   66.5897
# ..       ...       ...
# 144  37.0902   95.7129
# 145  37.0902   95.7129
# 146  37.0902   95.7129
# 147  37.0902   95.7129
# 148  37.0902   95.7129
#
# [149 rows x 8 columns]

# %%
df.set_index(["name"])
# Out:
#            satid                      source  \
# name
# HYSIS      43719                       India
# GAOFEN-5   43461  People's Republic of China
# NUSAT 5    43204                   Argentina
# NUSAT 4    43195                   Argentina
# VRSS-2     42954                   Venezuela
# ...          ...                         ...
# LANDSAT 4  13367               United States
# SEASAT 1   10967               United States
# LANDSAT 3  10702               United States
# LANDSAT 2   7615               United States
# LANDSAT 1   6126               United States
#
#                                              launchsite     LSlat    LSlong  \
# name
# HYSIS                                 SRIHARIKOTA (SRI)  13.72590   80.2266
# GAOFEN-5              Taiyuan Space Center, China (TSC)  38.84280  111.6051
# NUSAT 5    Jiuquan Satellite Launch Center, China (JSC)  40.98450  100.2087
# NUSAT 4    Jiuquan Satellite Launch Center, China (JSC)  40.98450  100.2087
# VRSS-2     Jiuquan Satellite Launch Center, China (JSC)  40.98450  100.2087
# ...                                                 ...       ...       ...
# LANDSAT 4          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
# SEASAT 1           AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
# LANDSAT 3          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
# LANDSAT 2          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
# LANDSAT 1          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
#
#               Clat     Clong
# name
# HYSIS      20.5837   78.9629
# GAOFEN-5   35.8617  104.1954
# NUSAT 5    38.4161   63.6167
# NUSAT 4    38.4161   63.6167
# VRSS-2      6.4238   66.5897
# ...            ...       ...
# LANDSAT 4  37.0902   95.7129
# SEASAT 1   37.0902   95.7129
# LANDSAT 3  37.0902   95.7129
# LANDSAT 2  37.0902   95.7129
# LANDSAT 1  37.0902   95.7129
#
# [149 rows x 7 columns]

# %%
array = np.array(df)
id= array[:,1]

print(id)
# Out:
# [43719 43461 43204 43195 42954 42901 42063 41898 41877 41848 41599 41558
#  41558 41557 41557 41556 41456 41386 41335 40968 40931 40701 40697 40536
#  40360 40336 40118 40072 40053 39766 39731 39455 39422 39419 39418 39186
#  39160 39159 39150 39086 39084 39030 38782 38755 38708 38707 38248 38038
#  37794 37781 37387 36985 36795 36795 36415 36414 36413 36121 36110 35931
#  35870 34839 33331 33105 32783 32476 32382 29710 29709 29268 29228 29079
#  28931 28893 28891 28649 28220 28376 28254 28220 28057 28051 27840 27597
#  27559 27430 27424 27421 27386 27004 27003 27001 26997 26957 26620 26619
#  26548 26032 25994 25940 25919 25860 25789 25758 25757 25756 25693 25682
#  25636 25616 25504 25397 25396 25395 25394 25260 24971 24883 24277 23940
#  23827 23751 23710 23657 23560 23342 23323 23317 22823 22076 21688 21574
#  21397 20510 20478 20436 19274 18960 18214 17527 16881 16613 15331 14780
#  13367 10967 10702 7615 6126]

# %%
# satellites = []
# for x in id:
#     base_url = f"https://api.n2yo.com/rest/v1/satellite/positions/{x}/40.0583/74.4057/0/1/&apiKey=RSNS74-FAEMYM-S26ZDF-4LIZ"
#     response = requests.get(base_url)
#     data = response.json()
#     satellite_x = json.dumps(data, sort_keys=True,separators=(',', ': '))
#     satellites.append(satellite_x.strip())

# %%
satellites = []
for x in id:
    base_url = f"https://api.n2yo.com/rest/v1/satellite/positions/{x}/40.0583/74.4057/0/1/&apiKey={API_Key}"
    response = requests.get(base_url)
    data = response.json()
    satellite_data = data
    satellites.append(satellite_data)

# %%
satellites

# %%
#  def Convert(satellites):
# #     it = iter(satellites)
# #     res_dct = dict(zip(it,it))
# #     return res_dct
# # lst = satellites
# # print(Convert(lst))

# %%
with open('app.geojson', 'a+') as f:
   json.dump(satellites,f)

# %%
earth_sat = []

search_url = f"https://api.n2yo.com/rest/v1/satellite/above/40.0583/74.4057/0/50/0/&apiKey={API_Key}"
response_earth = requests.get(search_url)
earth_data = response_earth.json()
earth_sat.append(earth_data)

# %%
earth_sat

# %%
with open('satlaunch.json', 'a+') as f:
   json.dump(earth_sat,f)

# %%
earth_sat2 = []

search_url = f"https://api.n2yo.com/rest/v1/satellite/above/40.0583/74.4057/0/90/0/&apiKey={API_Key}"
response_earth = requests.get(search_url)
earth_data2 = response_earth.json()
earth_sat2.append(earth_data2)
earth_sat2
# Out:
# [{'info': {'category': 'ANY', 'transactionscount': 150, 'satcount': 2905},
#   'above': [{'satid': 53,
#     'satname': 'ECHO 1 DEB (METAL OBJ)',
#     'intDesignator': '1960-009E',
#     'launchDate': '1960-08-12',
#     'satlat': 6.8913,
#     'satlng': 87.8851,
#     'satalt': 1642.6116},
#    {'satid': 134,
#     'satname': 'THOR ABLESTAR DEB',
#     'intDesignator': '1961-015U',
#     'launchDate': '1961-06-29',
#     'satlat': 62.206,
#     'satlng': 96.4719,
#     'satalt': 925.0266},
#    {'satid': 152,
#     'satname': 'THOR ABLESTAR DEB',
#     'intDesignator': '1961-015AN',
#     'launchDate': '1961-06-29',
#     'satlat': 37.8026,
#     'satlng': 70.7348,
#     'satalt': 850.9937},
#    {'satid': 163,
#     'satname': 'MIDAS 3',
#     'intDesignator': '1961-018A',
#     'launchDate': '1961-07-12',
#     'satlat': 39.2505,
#     'satlng': 132.2194,
#     'satalt': 3545.8138},
#    {'satid': 178,
#     'satname': 'THOR ABLESTAR DEB',
#     'intDesignator': '1961-015BC',
#     'launchDate': '1961-06-29',
#     'satlat': 28.4444,
#     'satlng': 56.1115,
#     'satalt': 979.7194},
#    {'satid': 194,
#     'satname': 'MIDAS 4 DEB',
#     'intDesignator': '1961-028C',
#     'launchDate': '1961-10-21',
#     'satlat': 84.1883,
#     'satlng': 112.3971,
#     'satalt': 3563.3424},
#    {'satid': 228,
#     'satname': 'DELTA 1 DEB (YO)',
#     'intDesignator': '1962-002C',
#     'launchDate': '1962-02-08',
#     'satlat': 47.8025,
#     'satlng': 98.4967,
#     'satalt': 566.1143},
#    {'satid': 261,
#     'satname': 'THOR ABLESTAR DEB',
#     'intDesignator': '1961-015CH',
#     'launchDate': '1961-06-29',
#     'satlat': 35.6835,
#     'satlng': 60.5667,
#     'satalt': 938.9496},
#    {'satid': 273,
#     'satname': 'MIDAS 5 DEB',
#     'intDesignator': '1962-010C',
#     'launchDate': '1962-04-09',
#     'satlat': 55.3832,
#     'satlng': 61.5395,
#     'satalt': 2950.2612},
#    {'satid': 355,
#     'satname': 'THOR ABLESTAR DEB',
#     'intDesignator': '1961-015DV',
#     'launchDate': '1961-06-29',
#     'satlat': 20.6795,
#     'satlng': 87.7725,
#     'satalt': 1323.0931},
#    {'satid': 397,
#     'satname': 'TIROS 6',
#     'intDesignator': '1962-047A',
#     'launchDate': '1962-09-18',
#     'satlat': 41.4212,
#     'satlng': 102.0298,
#     'satalt': 608.3382},
#    {'satid': 414,
#     'satname': 'THOR ABLESTAR DEB',
#     'intDesignator': '1961-015EP',
#     'launchDate': '1961-06-29',
#     'satlat': 50.3818,
#     'satlng': 100.3691,
#     'satalt': 1014.6272},
#    {'satid': 530,
#     'satname': 'THOR ABLESTAR DEB',
#     'intDesignator': '1961-015FU',
#     'launchDate': '1961-06-29',
#     'satlat': 29.4525,
#     'satlng': 69.6584,
#     'satalt': 856.8523},
#    {'satid': 553,
#     'satname': 'SYNCOM 1',
#     'intDesignator': '1963-004A',
#     'launchDate': '1963-02-14',
#     'satlat': 28.727,
#     'satlng': 80.8581,
#     'satalt': 29227.2382},
#    {'satid': 559,
#     'satname': 'THOR ABLESTAR DEB',
#     'intDesignator': '1961-015GR',
#     'launchDate': '1961-06-29',
#     'satlat': 58.9588,
#     'satlng': 86.04,
#     'satalt': 781.1395},
#    {'satid': 575,
#     'satname': 'DELTA 1 R/B',
#     'intDesignator': '1963-013B',
#     'launchDate': '1963-05-07',
#     'satlat': 0.5957,
#     'satlng': 88.7345,
#     'satalt': 4741.9458},
#    {'satid': 589,
#     'satname': 'DASH 1',
#     'intDesignator': '1963-014D',
#     'launchDate': '1963-05-09',
#     'satlat': 77.5242,
#     'satlng': 50.4913,
#     'satalt': 3827.4941},
#    {'satid': 602,
#     'satname': 'WESTFORD NEEDLES',
#     'intDesignator': '1963-014E',
#     'launchDate': '1963-05-09',
#     'satlat': 53.3636,
#     'satlng': 40.8962,
#     'satalt': 3666.1889},
#    {'satid': 629,
#     'satname': 'WESTFORD NEEDLES',
#     'intDesignator': '1963-014G',
#     'launchDate': '1963-05-09',
#     'satlat': 62.253,
#     'satlng': 44.0911,
#     'satalt': 3764.9038},
#    {'satid': 634,
#     'satname': 'SYNCOM 2 (A 26)',
#     'intDesignator': '1963-031A',
#     'launchDate': '1963-07-26',
#     'satlat': 33.122,
#     'satlng': 87.8731,
#     'satalt': 35768.9586},
#    {'satid': 674,
#     'satname': 'VELA 2',
#     'intDesignator': '1963-039A',
#     'launchDate': '1963-10-17',
#     'satlat': -8.6159,
#     'satlng': 150.0465,
#     'satalt': 128344.6846},
#    {'satid': 692,
#     'satname': 'VELA 1',
#     'intDesignator': '1963-039C',
#     'launchDate': '1963-10-17',
#     'satlat': 14.2569,
#     'satlng': 40.3861,
#     'satalt': 169367.9018},
#    {'satid': 701,
#     'satname': 'ATLAS CENTAUR 2 DEB',
#     'intDesignator': '1963-047G',
#     'launchDate': '1963-11-27',
#     'satlat': 26.9116,
#     'satlng': 111.7212,
#     'satalt': 1283.259},
#    {'satid': 750,
#     'satname': 'ELEKTRON 1 DEB',
#     'intDesignator': '1964-006C',
#     'launchDate': '1964-01-30',
#     'satlat': 48.308,
#     'satlng': 64.1326,
#     'satalt': 2215.2093},
#    {'satid': 812,
#     'satname': 'OPS 4467 A',
#     'intDesignator': '1964-031A',
#     'launchDate': '1964-06-18',
#     'satlat': 53.2328,
#     'satlng': 91.3219,
#     'satalt': 824.3379},
#    {'satid': 829,
#     'satname': 'ELEKTRON 3',
#     'intDesignator': '1964-038A',
#     'launchDate': '1964-07-10',
#     'satlat': -11.3001,
#     'satlng': 95.4314,
#     'satalt': 6121.786},
#    {'satid': 836,
#     'satname': 'OPS 3662 (VELA 3)',
#     'intDesignator': '1964-040A',
#     'launchDate': '1964-07-17',
#     'satlat': 25.6443,
#     'satlng': -24.0764,
#     'satalt': 167529.892},
#    {'satid': 837,
#     'satname': 'OPS 3674 (VELA 4)',
#     'intDesignator': '1964-040B',
#     'launchDate': '1964-07-17',
#     'satlat': -25.6316,
#     'satlng': 27.8554,
#     'satalt': 81643.4137},
#    {'satid': 1335,
#     'satname': 'SL-8 DEB',
#     'intDesignator': '1965-020E',
#     'launchDate': '1965-03-15',
#     'satlat': 51.7437,
#     'satlng': 101.5502,
#     'satalt': 1208.8673},
#    {'satid': 1359,
#     'satname': 'TITAN 3A TRANSTAGE R/B',
#     'intDesignator': '1965-034A',
#     'launchDate': '1965-05-06',
#     'satlat': 31.562,
#     'satlng': 46.0421,
#     'satalt': 3072.9926},
#    {'satid': 1361,
#     'satname': 'LCS 1',
#     'intDesignator': '1965-034C',
#     'launchDate': '1965-05-06',
#     'satlat': 9.5591,
#     'satlng': 92.7919,
#     'satalt': 2785.389},
#    {'satid': 1389,
#     'satname': 'OPS 4682 DEB',
#     'intDesignator': '1965-027D',
#     'launchDate': '1965-04-03',
#     'satlat': 55.4,
#     'satlng': 91.0429,
#     'satalt': 1221.7566},
#    {'satid': 1458,
#     'satname': 'OPS 6577 (VELA 5)',
#     'intDesignator': '1965-058A',
#     'launchDate': '1965-07-20',
#     'satlat': 20.9498,
#     'satlng': 114.584,
#     'satalt': 169875.8508},
#    {'satid': 1459,
#     'satname': 'OPS 6564 (VELA 6)',
#     'intDesignator': '1965-058B',
#     'launchDate': '1965-07-20',
#     'satlat': 28.5749,
#     'satlng': 172.2182,
#     'satalt': 105092.194},
#    {'satid': 1478,
#     'satname': 'SL-8 DEB',
#     'intDesignator': '1965-020BC',
#     'launchDate': '1965-03-15',
#     'satlat': 47.4871,
#     'satlng': 101.3309,
#     'satalt': 1528.1714},
#    {'satid': 1504,
#     'satname': 'THOR ABLESTAR DEB',
#     'intDesignator': '1965-065A',
#     'launchDate': '1965-08-13',
#     'satlat': 39.4446,
#     'satlng': 95.4698,
#     'satalt': 1073.293},
#    {'satid': 1506,
#     'satname': 'SECOR 5 (EGRS 5)',
#     'intDesignator': '1965-063A',
#     'launchDate': '1965-08-10',
#     'satlat': 58.2571,
#     'satlng': 102.4067,
#     'satalt': 1903.0423},
#    {'satid': 1511,
#     'satname': 'THOR ABLESTAR DEB',
#     'intDesignator': '1965-065D',
#     'launchDate': '1965-08-13',
#     'satlat': 62.9017,
#     'satlng': 57.8631,
#     'satalt': 1091.7969},
#    {'satid': 1515,
#     'satname': 'NAVSPASUR ROD 1',
#     'intDesignator': '1965-065G',
#     'launchDate': '1965-08-13',
#     'satlat': 31.6414,
#     'satlng': 56.2199,
#     'satalt': 1117.8797},
#    {'satid': 1586,
#     'satname': 'COSMOS 88',
#     'intDesignator': '1965-073C',
#     'launchDate': '1965-09-18',
#     'satlat': 40.792,
#     'satlng': 37.1913,
#     'satalt': 1384.7787},
#    {'satid': 1618,
#     'satname': 'SL-8 DEB',
#     'intDesignator': '1965-073K',
#     'launchDate': '1965-09-18',
#     'satlat': 53.0217,
#     'satlng': 43.6623,
#     'satalt': 1683.763},
#    {'satid': 1729,
#     'satname': 'DELTA 1 R/B',
#     'intDesignator': '1965-089B',
#     'launchDate': '1965-11-06',
#     'satlat': 27.6533,
#     'satlng': 34.6267,
#     'satalt': 2258.5591},
#    {'satid': 1738,
#     'satname': 'EXPLORER 30',
#     'intDesignator': '1965-093A',
#     'launchDate': '1965-11-19',
#     'satlat': 19.3427,
#     'satlng': 60.9511,
#     'satalt': 845.9758},
#    {'satid': 1863,
#     'satname': 'TITAN 3C TRANSTAGE R/B',
#     'intDesignator': '1965-108A',
#     'launchDate': '1965-12-21',
#     'satlat': 19.4881,
#     'satlng': 13.4741,
#     'satalt': 5096.9619},
#    {'satid': 1864,
#     'satname': 'OPS 1509 (TRANSIT 10)',
#     'intDesignator': '1965-109A',
#     'launchDate': '1965-12-22',
#     'satlat': 21.9595,
#     'satlng': 89.1146,
#     'satalt': 1052.4755},
#    {'satid': 1942,
#     'satname': 'THOR ABLESTAR DEB',
#     'intDesignator': '1961-015HS',
#     'launchDate': '1961-06-29',
#     'satlat': 25.2691,
#     'satlng': 79.278,
#     'satalt': 1024.4048},
#    {'satid': 2009,
#     'satname': 'MIDAS 4 DEB',
#     'intDesignator': '1961-028E',
#     'launchDate': '1961-10-21',
#     'satlat': 82.1814,
#     'satlng': 134.1883,
#     'satalt': 3509.8894},
#    {'satid': 2050,
#     'satname': 'TITAN 3C TRANSTAGE DEB',
#     'intDesignator': '1965-082JL',
#     'launchDate': '1965-10-15',
#     'satlat': 31.672,
#     'satlng': 101.0437,
#     'satalt': 712.6886},
#    {'satid': 2096,
#     'satname': 'DELTA 1 R/B',
#     'intDesignator': '1966-016B',
#     'launchDate': '1966-02-28',
#     'satlat': 39.7584,
#     'satlng': 87.1723,
#     'satalt': 1418.4592},
#    {'satid': 2174,
#     'satname': 'THOR AGENA B R/B',
#     'intDesignator': '1966-040B',
#     'launchDate': '1966-05-15',
#     'satlat': 42.1354,
#     'satlng': 58.7064,
#     'satalt': 1088.7046},
#    {'satid': 2216,
#     'satname': 'OPS 9312 (IDSCS 2)',
#     'intDesignator': '1966-053C',
#     'launchDate': '1966-06-16',
#     'satlat': 2.6853,
#     'satlng': 105.371,
#     'satalt': 33872.898},
#    {'satid': 2217,
#     'satname': 'OPS 9313 (IDSCS 3)',
#     'intDesignator': '1966-053D',
#     'launchDate': '1966-06-16',
#     'satlat': -1.5347,
#     'satlng': 54.9808,
#     'satalt': 33939.4913},
#    {'satid': 2218,
#     'satname': 'OPS 9314 (IDSCS 4)',
#     'intDesignator': '1966-053E',
#     'launchDate': '1966-06-16',
#     'satlat': 4.4955,
#     'satlng': 141.8394,
#     'satalt': 33822.2402},
#    {'satid': 2219,
#     'satname': 'OPS 9315 (IDSCS 5)',
#     'intDesignator': '1966-053F',
#     'launchDate': '1966-06-16',
#     'satlat': 2.8439,
#     'satlng': 110.3725,
#     'satalt': 33934.766},
#    {'satid': 2220,
#     'satname': 'OPS 9316 (IDSCS 6)',
#     'intDesignator': '1966-053G',
#     'launchDate': '1966-06-16',
#     'satlat': -2.6237,
#     'satlng': 40.2977,
#     'satalt': 34188.1978},
#    {'satid': 2221,
#     'satname': 'OPS 9317 (IDSCS 7)',
#     'intDesignator': '1966-053H',
#     'launchDate': '1966-06-16',
#     'satlat': -4.2321,
#     'satlng': 7.4217,
#     'satalt': 34329.8002},
#    {'satid': 2255,
#     'satname': 'THOR AGENA D R/B',
#     'intDesignator': '1966-056B',
#     'launchDate': '1966-06-24',
#     'satlat': 61.5209,
#     'satlng': 19.9529,
#     'satalt': 4244.2028},
#    {'satid': 2375,
#     'satname': 'WESTFORD NEEDLES',
#     'intDesignator': '1963-014W',
#     'launchDate': '1963-05-09',
#     'satlat': 79.1596,
#     'satlng': 155.159,
#     'satalt': 5379.8211},
#    {'satid': 2377,
#     'satname': 'WESTFORD NEEDLES',
#     'intDesignator': '1963-014X',
#     'launchDate': '1963-05-09',
#     'satlat': 85.1885,
#     'satlng': 163.6749,
#     'satalt': 4524.549},
#    {'satid': 2380,
#     'satname': 'WESTFORD NEEDLES',
#     'intDesignator': '1963-014AA',
#     'launchDate': '1963-05-09',
#     'satlat': 27.5283,
#     'satlng': 112.274,
#     'satalt': 3283.6064},
#    {'satid': 2381,
#     'satname': 'WESTFORD NEEDLES',
#     'intDesignator': '1963-014AB',
#     'launchDate': '1963-05-09',
#     'satlat': 64.6018,
#     'satlng': 129.5212,
#     'satalt': 4040.7504},
#    {'satid': 2403,
#     'satname': 'OPS 0856',
#     'intDesignator': '1966-077A',
#     'launchDate': '1966-08-19',
#     'satlat': 9.7908,
#     'satlng': 89.7096,
#     'satalt': 3696.7259},
#    {'satid': 2412,
#     'satname': 'ERS 15',
#     'intDesignator': '1966-077C',
#     'launchDate': '1966-08-19',
#     'satlat': 34.8116,
#     'satlng': 90.7497,
#     'satalt': 3705.5273},
#    {'satid': 2436,
#     'satname': 'DELTA 1 R/B',
#     'intDesignator': '1966-087B',
#     'launchDate': '1966-10-02',
#     'satlat': 7.7017,
#     'satlng': 59.5786,
#     'satalt': 1441.9807},
#    {'satid': 2514,
#     'satname': 'INTELSAT 2-F1',
#     'intDesignator': '1966-096A',
#     'launchDate': '1966-10-26',
#     'satlat': 2.38,
#     'satlng': 95.9691,
#     'satalt': 34328.6548},
#    {'satid': 2529,
#     'satname': 'LES 2 DEB',
#     'intDesignator': '1965-034D',
#     'launchDate': '1965-05-06',
#     'satlat': -24.6824,
#     'satlng': 67.4206,
#     'satalt': 11955.8957},
#    {'satid': 2608,
#     'satname': 'ATS 1',
#     'intDesignator': '1966-110A',
#     'launchDate': '1966-12-07',
#     'satlat': -0.0621,
#     'satlng': 6.7848,
#     'satalt': 35779.5895},
#    {'satid': 2639,
#     'satname': 'INTELSAT 2-F2',
#     'intDesignator': '1967-001A',
#     'launchDate': '1967-01-11',
#     'satlat': 1.5025,
#     'satlng': -3.3216,
#     'satalt': 35773.7056},
#    {'satid': 2650,
#     'satname': 'OPS 9323 (IDSCS 10)',
#     'intDesignator': '1967-003C',
#     'launchDate': '1967-01-18',
#     'satlat': -4.072,
#     'satlng': 10.3199,
#     'satalt': 33759.5965},
#    {'satid': 2651,
#     'satname': 'OPS 9324 (IDSCS 11)',
#     'intDesignator': '1967-003D',
#     'launchDate': '1967-01-18',
#     'satlat': -4.0209,
#     'satlng': 10.8461,
#     'satalt': 33757.0195},
#    {'satid': 2652,
#     'satname': 'OPS 9325 (IDSCS 12)',
#     'intDesignator': '1967-003E',
#     'launchDate': '1967-01-18',
#     'satlat': -2.4845,
#     'satlng': 40.2226,
#     'satalt': 33682.7732},
#    {'satid': 2654,
#     'satname': 'OPS 9327 (IDSCS 14)',
#     'intDesignator': '1967-003G',
#     'launchDate': '1967-01-18',
#     'satlat': -3.7416,
#     'satlng': 14.7634,
#     'satalt': 33752.6277},
#    {'satid': 2765,
#     'satname': 'OPS 6638 (VELA 7)',
#     'intDesignator': '1967-040A',
#     'launchDate': '1967-04-28',
#     'satlat': 27.5347,
#     'satlng': 131.2882,
#     'satalt': 124622.7661},
#    {'satid': 2770,
#     'satname': 'TITAN 3C TRANSTAGE R/B',
#     'intDesignator': '1967-040F',
#     'launchDate': '1967-04-28',
#     'satlat': 19.5873,
#     'satlng': 17.0436,
#     'satalt': 61830.8208},
#    {'satid': 2807,
#     'satname': 'OPS 7218 (TRANSIT 16)',
#     'intDesignator': '1967-048A',
#     'launchDate': '1967-05-18',
#     'satlat': 39.4797,
#     'satlng': 71.9576,
#     'satalt': 1065.9399},
#    {'satid': 2811,
#     'satname': 'SCOUT A R/B',
#     'intDesignator': '1967-048B',
#     'launchDate': '1967-05-18',
#     'satlat': 63.8065,
#     'satlng': 75.1149,
#     'satalt': 1072.2572},
#    {'satid': 2861,
#     'satname': 'SECOR 9 (EGRS 9)',
#     'intDesignator': '1967-065A',
#     'launchDate': '1967-06-29',
#     'satlat': 88.7364,
#     'satlng': -38.0605,
#     'satalt': 3924.3105},
#    {'satid': 2863,
#     'satname': 'OPS 9332 (IDSCS 17)',
#     'intDesignator': '1967-066B',
#     'launchDate': '1967-07-01',
#     'satlat': 2.2464,
#     'satlng': 14.9462,
#     'satalt': 33159.184},
#    {'satid': 2864,
#     'satname': 'OPS 9333 (IDSCS 18)',
#     'intDesignator': '1967-066C',
#     'launchDate': '1967-07-01',
#     'satlat': -0.9943,
#     'satlng': 127.1323,
#     'satalt': 33566.0381},
#    {'satid': 2868,
#     'satname': 'TITAN 3C TRANSTAGE R/B',
#     'intDesignator': '1967-066G',
#     'launchDate': '1967-07-01',
#     'satlat': 1.2853,
#     'satlng': 80.2393,
#     'satalt': 33834.7103},
#    {'satid': 2997,
#     'satname': 'WESTFORD NEEDLES',
#     'intDesignator': '1963-014AU',
#     'launchDate': '1963-05-09',
#     'satlat': -2.9284,
#     'satlng': 64.7983,
#     'satalt': 2647.1005},
#    {'satid': 3045,
#     'satname': 'SL-8 DEB *',
#     'intDesignator': '1965-070G',
#     'launchDate': '1965-09-03',
#     'satlat': 37.6133,
#     'satlng': 111.4627,
#     'satalt': 1279.6724},
#    {'satid': 3133,
#     'satname': 'OPS 7034 (TRANSIT 18)',
#     'intDesignator': '1968-012A',
#     'launchDate': '1968-03-02',
#     'satlat': 36.0899,
#     'satlng': 107.1617,
#     'satalt': 1070.2247},
#    {'satid': 3257,
#     'satname': 'WESTFORD NEEDLES',
#     'intDesignator': '1963-014BX',
#     'launchDate': '1963-05-09',
#     'satlat': 63.2374,
#     'satlng': 1.4463,
#     'satalt': 3982.8898},
#    {'satid': 3285,
#     'satname': 'OPS 9342 (IDSCS 21)',
#     'intDesignator': '1968-050B',
#     'launchDate': '1968-06-13',
#     'satlat': -2.8955,
#     'satlng': 12.768,
#     'satalt': 33845.4154},
#    {'satid': 3286,
#     'satname': 'OPS 9343 (IDSCS 22)',
#     'intDesignator': '1968-050C',
#     'launchDate': '1968-06-13',
#     'satlat': 0.4037,
#     'satlng': 83.7362,
#     'satalt': 33805.4353},
#    {'satid': 3289,
#     'satname': 'OPS 9346 (IDSCS 25)',
#     'intDesignator': '1968-050F',
#     'launchDate': '1968-06-13',
#     'satlat': -1.8127,
#     'satlng': 39.9061,
#     'satalt': 34025.1708},
#    {'satid': 3291,
#     'satname': 'OPS 9348 (IDSCS 27)',
#     'intDesignator': '1968-050H',
#     'launchDate': '1968-06-13',
#     'satlat': 1.6161,
#     'satlng': 113.6552,
#     'satalt': 33845.9223},
#    {'satid': 3292,
#     'satname': 'TITAN 3C TRANSTAGE R/B',
#     'intDesignator': '1968-050J',
#     'launchDate': '1968-06-13',
#     'satlat': 2.5685,
#     'satlng': 126.3775,
#     'satalt': 34340.4398},
#    {'satid': 3307,
#     'satname': 'EXPLORER 38 (RAE-A)',
#     'intDesignator': '1968-055A',
#     'launchDate': '1968-07-04',
#     'satlat': 58.5512,
#     'satlng': 99.5343,
#     'satalt': 5850.5823},
#    {'satid': 3334,
#     'satname': 'OPS 2222',
#     'intDesignator': '1968-063A',
#     'launchDate': '1968-08-06',
#     'satlat': 10.9254,
#     'satlng': 59.6956,
#     'satalt': 34787.1729},
#    {'satid': 3428,
#     'satname': 'OV2-5',
#     'intDesignator': '1968-081A',
#     'launchDate': '1968-09-26',
#     'satlat': 2.7467,
#     'satlng': 16.6497,
#     'satalt': 35259.2758},
#    {'satid': 3576,
#     'satname': 'COSMOS 256',
#     'intDesignator': '1968-106A',
#     'launchDate': '1968-11-30',
#     'satlat': 38.0255,
#     'satlng': 48.5459,
#     'satalt': 1219.5164},
#    {'satid': 3674,
#     'satname': 'INTELSAT 3-F3',
#     'intDesignator': '1969-011A',
#     'launchDate': '1969-02-06',
#     'satlat': 2.9874,
#     'satlng': 140.2687,
#     'satalt': 41483.9186},
#    {'satid': 3753,
#     'satname': 'COSMOS 249 DEB *',
#     'intDesignator': '1968-091AR',
#     'launchDate': '1968-10-20',
#     'satlat': 61.8725,
#     'satlng': 93.0685,
#     'satalt': 770.3881},
#    {'satid': 3843,
#     'satname': 'COSMOS 252 DEB',
#     'intDesignator': '1968-097BG',
#     'launchDate': '1968-11-01',
#     'satlat': 47.4238,
#     'satlng': 103.3835,
#     'satalt': 775.1905},
#    {'satid': 3911,
#     'satname': 'COSMOS 249 DEB',
#     'intDesignator': '1968-091BP',
#     'launchDate': '1968-10-20',
#     'satlat': 48.6019,
#     'satlng': 61.8931,
#     'satalt': 1428.1729},
#    {'satid': 3912,
#     'satname': 'COSMOS 249 DEB',
#     'intDesignator': '1968-091BQ',
#     'launchDate': '1968-10-20',
#     'satlat': 55.362,
#     'satlng': 69.9982,
#     'satalt': 1052.421},
#    {'satid': 3947,
#     'satname': 'INTELSAT 3-F4',
#     'intDesignator': '1969-045A',
#     'launchDate': '1969-05-22',
#     'satlat': 8.9506,
#     'satlng': 61.1569,
#     'satalt': 38879.4531},
#    {'satid': 3954,
#     'satname': 'OPS 6909 (VELA 9)',
#     'intDesignator': '1969-046D',
#     'launchDate': '1969-05-23',
#     'satlat': -27.8088,
#     'satlng': 69.4804,
#     'satalt': 202535.0346},
#    {'satid': 3956,
#     'satname': 'TITAN 3C TRANSTAGE R/B',
#     'intDesignator': '1969-046F',
#     'launchDate': '1969-05-23',
#     'satlat': 18.9939,
#     'satlng': 84.0717,
#     'satalt': 118028.9265},
#    {'satid': 3974,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1968-069E',
#     'launchDate': '1968-08-16',
#     'satlat': 23.3288,
#     'satlng': 58.7784,
#     'satalt': 1438.9054},
#    {'satid': 4026,
#     'satname': 'SCOUT X-1 DEB',
#     'intDesignator': '1961-004G',
#     'launchDate': '1961-02-16',
#     'satlat': 38.8183,
#     'satlng': 37.8433,
#     'satalt': 1274.1354},
#    {'satid': 4048,
#     'satname': 'THOR BURNER 2 R/B',
#     'intDesignator': '1969-062B',
#     'launchDate': '1969-07-23',
#     'satlat': 39.3059,
#     'satlng': 49.4202,
#     'satalt': 808.6308},
#    {'satid': 4068,
#     'satname': 'ATS 5',
#     'intDesignator': '1969-069A',
#     'launchDate': '1969-08-12',
#     'satlat': 5.0613,
#     'satlng': 26.7989,
#     'satalt': 36010.4215},
#    {'satid': 4069,
#     'satname': 'ATLAS CENTAUR R/B',
#     'intDesignator': '1969-069B',
#     'launchDate': '1969-08-12',
#     'satlat': 14.1235,
#     'satlng': 86.4973,
#     'satalt': 5144.7376},
#    {'satid': 4145,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1969-082P',
#     'launchDate': '1969-09-30',
#     'satlat': 49.5687,
#     'satlng': 37.2387,
#     'satalt': 831.6261},
#    {'satid': 4149,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1969-082T',
#     'launchDate': '1969-09-30',
#     'satlat': 51.1287,
#     'satlng': 57.751,
#     'satalt': 826.9322},
#    {'satid': 4209,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1969-082BY',
#     'launchDate': '1969-09-30',
#     'satlat': 58.9295,
#     'satlng': 44.924,
#     'satalt': 860.3356},
#    {'satid': 4214,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1969-082CD',
#     'launchDate': '1969-09-30',
#     'satlat': 28.5676,
#     'satlng': 52.8871,
#     'satalt': 717.1409},
#    {'satid': 4320,
#     'satname': 'ITOS 1 (TIROS M)',
#     'intDesignator': '1970-008A',
#     'launchDate': '1970-01-23',
#     'satlat': 52.2395,
#     'satlng': 54.0002,
#     'satalt': 1484.068},
#    {'satid': 4322,
#     'satname': 'DELTA 1 R/B',
#     'intDesignator': '1970-008C',
#     'launchDate': '1970-01-23',
#     'satlat': 38.1691,
#     'satlng': 48.2446,
#     'satalt': 1478.4157},
#    {'satid': 4366,
#     'satname': 'OPS 7044 (VELA 12)',
#     'intDesignator': '1970-027A',
#     'launchDate': '1970-04-08',
#     'satlat': -35.6865,
#     'satlng': 52.8693,
#     'satalt': 210106.0036},
#    {'satid': 4368,
#     'satname': 'OPS 7033 (VELA 11)',
#     'intDesignator': '1970-027B',
#     'launchDate': '1970-04-08',
#     'satlat': 1.4203,
#     'satlng': 80.3193,
#     'satalt': 79149.3366},
#    {'satid': 4376,
#     'satname': 'INTELSAT 3-F7',
#     'intDesignator': '1970-032A',
#     'launchDate': '1970-04-23',
#     'satlat': 2.4353,
#     'satlng': -2.8699,
#     'satalt': 35773.6035},
#    {'satid': 4377,
#     'satname': 'DELTA 1 R/B',
#     'intDesignator': '1970-032B',
#     'launchDate': '1970-04-23',
#     'satlat': -10.4733,
#     'satlng': 99.685,
#     'satalt': 10293.7459},
#    {'satid': 4418,
#     'satname': 'OPS 5346',
#     'intDesignator': '1970-046A',
#     'launchDate': '1970-06-19',
#     'satlat': 2.1684,
#     'satlng': 72.9312,
#     'satalt': 35761.7557},
#    {'satid': 4449,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1969-082EU',
#     'launchDate': '1969-09-30',
#     'satlat': 18.581,
#     'satlng': 73.8053,
#     'satalt': 761.9236},
#    {'satid': 4603,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025F',
#     'launchDate': '1970-04-08',
#     'satlat': 49.3861,
#     'satlng': 39.1884,
#     'satalt': 975.4554},
#    {'satid': 4607,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025K',
#     'launchDate': '1970-04-08',
#     'satlat': 36.4739,
#     'satlng': 51.857,
#     'satalt': 1231.5375},
#    {'satid': 4630,
#     'satname': 'OPS 5960',
#     'intDesignator': '1970-093A',
#     'launchDate': '1970-11-06',
#     'satlat': -8.1363,
#     'satlng': 45.7631,
#     'satalt': 33306.7965},
#    {'satid': 4632,
#     'satname': 'TITAN 3C TRANSTAGE R/B',
#     'intDesignator': '1970-093B',
#     'launchDate': '1970-11-06',
#     'satlat': 5.0236,
#     'satlng': 115.1882,
#     'satalt': 36159.6174},
#    {'satid': 4645,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025AD',
#     'launchDate': '1970-04-08',
#     'satlat': 4.3142,
#     'satlng': 66.1884,
#     'satalt': 1570.0979},
#    {'satid': 4656,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025AQ',
#     'launchDate': '1970-04-08',
#     'satlat': 24.7198,
#     'satlng': 95.4784,
#     'satalt': 1003.1106},
#    {'satid': 4772,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025DS',
#     'launchDate': '1970-04-08',
#     'satlat': 24.7772,
#     'satlng': 76.1917,
#     'satalt': 1252.977},
#    {'satid': 4786,
#     'satname': 'COSMOS 382',
#     'intDesignator': '1970-103A',
#     'launchDate': '1970-12-02',
#     'satlat': 20.3814,
#     'satlng': 57.912,
#     'satalt': 4256.9683},
#    {'satid': 4841,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1968-055D',
#     'launchDate': '1968-07-04',
#     'satlat': 46.3025,
#     'satlng': 115.662,
#     'satalt': 1270.8246},
#    {'satid': 4881,
#     'satname': 'INTELSAT 4-F2',
#     'intDesignator': '1971-006A',
#     'launchDate': '1971-01-26',
#     'satlat': 7.8857,
#     'satlng': 13.2119,
#     'satalt': 36133.9193},
#    {'satid': 4912,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025FJ',
#     'launchDate': '1970-04-08',
#     'satlat': 28.1034,
#     'satlng': 84.6468,
#     'satalt': 819.2888},
#    {'satid': 4922,
#     'satname': 'COSMOS 394',
#     'intDesignator': '1971-010A',
#     'launchDate': '1971-02-09',
#     'satlat': 33.0755,
#     'satlng': 53.777,
#     'satalt': 488.9047},
#    {'satid': 4945,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025GF',
#     'launchDate': '1970-04-08',
#     'satlat': 14.2096,
#     'satlng': 90.4702,
#     'satalt': 1015.9309},
#    {'satid': 4964,
#     'satname': 'COSMOS 397',
#     'intDesignator': '1971-015A',
#     'launchDate': '1971-02-25',
#     'satlat': 21.1758,
#     'satlng': 90.4755,
#     'satalt': 896.9978},
#    {'satid': 4980,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025HA',
#     'launchDate': '1970-04-08',
#     'satlat': 28.3588,
#     'satlng': 70.6936,
#     'satalt': 1038.2683},
#    {'satid': 5054,
#     'satname': 'TITAN 34B AGENA D R/B',
#     'intDesignator': '1971-021B',
#     'launchDate': '1971-03-21',
#     'satlat': 32.9068,
#     'satlng': 144.1995,
#     'satalt': 15444.1002},
#    {'satid': 5091,
#     'satname': 'COSMOS 397 DEB',
#     'intDesignator': '1971-015S',
#     'launchDate': '1971-02-25',
#     'satlat': 63.9115,
#     'satlng': 40.003,
#     'satalt': 1371.3519},
#    {'satid': 5105,
#     'satname': 'COSMOS 402',
#     'intDesignator': '1971-025A',
#     'launchDate': '1971-04-01',
#     'satlat': 63.4043,
#     'satlng': 47.2712,
#     'satalt': 1025.9585},
#    {'satid': 5153,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025JW',
#     'launchDate': '1970-04-08',
#     'satlat': 57.2173,
#     'satlng': 44.882,
#     'satalt': 1082.7885},
#    {'satid': 5212,
#     'satname': 'COSMOS 413',
#     'intDesignator': '1971-041C',
#     'launchDate': '1971-05-07',
#     'satlat': 44.5854,
#     'satlng': 63.9536,
#     'satalt': 1501.3528},
#    {'satid': 5272,
#     'satname': 'COSMOS 397 DEB',
#     'intDesignator': '1971-015BB',
#     'launchDate': '1971-02-25',
#     'satlat': 36.1141,
#     'satlng': 61.241,
#     'satalt': 579.3605},
#    {'satid': 5392,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025KX',
#     'launchDate': '1970-04-08',
#     'satlat': 30.8584,
#     'satlng': 60.5706,
#     'satalt': 885.2118},
#    {'satid': 5457,
#     'satname': 'TITAN 3C TRANSTAGE DEB',
#     'intDesignator': '1965-108J',
#     'launchDate': '1965-12-21',
#     'satlat': 8.1021,
#     'satlng': 139.3833,
#     'satalt': 22076.5048},
#    {'satid': 5515,
#     'satname': 'TITAN 3C TRANSTAGE DEB',
#     'intDesignator': '1965-108M',
#     'launchDate': '1965-12-21',
#     'satlat': 16.6123,
#     'satlng': 7.7524,
#     'satalt': 27947.4152},
#    {'satid': 5519,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1969-082HY',
#     'launchDate': '1969-09-30',
#     'satlat': 36.4863,
#     'satlng': 87.4818,
#     'satalt': 740.7718},
#    {'satid': 5551,
#     'satname': 'COSMOS 448',
#     'intDesignator': '1971-086E',
#     'launchDate': '1971-10-13',
#     'satlat': 67.7358,
#     'satlng': 68.9539,
#     'satalt': 1523.2116},
#    {'satid': 5560,
#     'satname': 'ASTEX 1',
#     'intDesignator': '1971-089A',
#     'launchDate': '1971-10-17',
#     'satlat': 28.6473,
#     'satlng': 91.4479,
#     'satalt': 737.7569},
#    {'satid': 5581,
#     'satname': 'BLACK ARROW R/B',
#     'intDesignator': '1971-093B',
#     'launchDate': '1971-10-28',
#     'satlat': 60.0154,
#     'satlng': 96.7119,
#     'satalt': 1315.029},
#    {'satid': 5589,
#     'satname': 'TITAN 3C TRANSTAGE R/B',
#     'intDesignator': '1971-095C',
#     'launchDate': '1971-11-03',
#     'satlat': 1.8532,
#     'satlng': 121.0123,
#     'satalt': 36110.2144},
#    {'satid': 5632,
#     'satname': 'TITAN 3C TRANSTAGE DEB',
#     'intDesignator': '1965-108N',
#     'launchDate': '1965-12-21',
#     'satlat': 4.1098,
#     'satlng': 3.7285,
#     'satalt': 17050.0206},
#    {'satid': 5683,
#     'satname': 'COSMOS 465',
#     'intDesignator': '1971-111A',
#     'launchDate': '1971-12-15',
#     'satlat': 15.3933,
#     'satlng': 65.7304,
#     'satalt': 1001.134},
#    {'satid': 5775,
#     'satname': 'INTELSAT 4-F4',
#     'intDesignator': '1972-003A',
#     'launchDate': '1972-01-23',
#     'satlat': 6.5145,
#     'satlng': 115.0077,
#     'satalt': 35908.0451},
#    {'satid': 5998,
#     'satname': 'TITAN 3C TRANSTAGE DEB',
#     'intDesignator': '1965-108T',
#     'launchDate': '1965-12-21',
#     'satlat': 26.3433,
#     'satlng': 35.6123,
#     'satalt': 27178.861},
#    {'satid': 6014,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025MR',
#     'launchDate': '1970-04-08',
#     'satlat': 60.2149,
#     'satlng': 107.0153,
#     'satalt': 881.7871},
#    {'satid': 6058,
#     'satname': 'ATLAS CENTAUR R/B',
#     'intDesignator': '1972-041B',
#     'launchDate': '1972-06-13',
#     'satlat': -8.3932,
#     'satlng': 47.1558,
#     'satalt': 28320.5519},
#    {'satid': 6119,
#     'satname': 'COSMOS 506',
#     'intDesignator': '1972-057C',
#     'launchDate': '1972-07-20',
#     'satlat': 46.9751,
#     'satlng': 34.4907,
#     'satalt': 1450.9954},
#    {'satid': 6173,
#     'satname': 'TRIAD 1',
#     'intDesignator': '1972-069A',
#     'launchDate': '1972-09-02',
#     'satlat': 60.4964,
#     'satlng': 50.4901,
#     'satalt': 715.4776},
#    {'satid': 6176,
#     'satname': 'COSMOS 249 DEB *',
#     'intDesignator': '1968-091CG',
#     'launchDate': '1968-10-20',
#     'satlat': 29.8101,
#     'satlng': 35.8513,
#     'satalt': 1476.6228},
#    {'satid': 6237,
#     'satname': 'DELTA 1 R/B',
#     'intDesignator': '1972-082C',
#     'launchDate': '1972-10-15',
#     'satlat': 44.9063,
#     'satlng': 84.1812,
#     'satalt': 1415.8171},
#    {'satid': 6252,
#     'satname': 'SL-8 DEB *',
#     'intDesignator': '1965-020FD',
#     'launchDate': '1965-03-15',
#     'satlat': 39.3381,
#     'satlng': 51.8479,
#     'satalt': 1437.5121},
#    {'satid': 6278,
#     'satname': 'ANIK A1 (TELESAT 1)',
#     'intDesignator': '1972-090A',
#     'launchDate': '1972-11-10',
#     'satlat': 9.2822,
#     'satlng': 25.5151,
#     'satalt': 36187.9671},
#    {'satid': 6317,
#     'satname': 'OPS 9390',
#     'intDesignator': '1972-101A',
#     'launchDate': '1972-12-20',
#     'satlat': 2.9435,
#     'satlng': 103.1876,
#     'satalt': 39256.5087},
#    {'satid': 6380,
#     'satname': 'OPS 6063',
#     'intDesignator': '1973-013A',
#     'launchDate': '1973-03-06',
#     'satlat': 4.2827,
#     'satlng': 74.7027,
#     'satalt': 35781.5015},
#    {'satid': 6677,
#     'satname': 'COSMOS 566',
#     'intDesignator': '1973-037C',
#     'launchDate': '1973-06-08',
#     'satlat': 24.566,
#     'satlng': 60.5263,
#     'satalt': 1472.7521},
#    {'satid': 6691,
#     'satname': 'OPS 6157',
#     'intDesignator': '1973-040A',
#     'launchDate': '1973-06-12',
#     'satlat': 5.9013,
#     'satlng': 29.9073,
#     'satalt': 35920.3946},
#    {'satid': 6748,
#     'satname': 'THOR ABLESTAR DEB',
#     'intDesignator': '1961-015KN',
#     'launchDate': '1961-06-29',
#     'satlat': 34.546,
#     'satlng': 98.2011,
#     'satalt': 804.2961},
#    {'satid': 6791,
#     'satname': 'OPS 7724',
#     'intDesignator': '1973-056A',
#     'launchDate': '1973-08-21',
#     'satlat': 60.3057,
#     'satlng': 66.2223,
#     'satalt': 34280.2957},
#    {'satid': 6796,
#     'satname': 'INTELSAT 4-F7',
#     'intDesignator': '1973-058A',
#     'launchDate': '1973-08-23',
#     'satlat': 2.2042,
#     'satlng': 140.8758,
#     'satalt': 36090.0233},
#    {'satid': 6842,
#     'satname': 'THOR ABLESTAR DEB',
#     'intDesignator': '1961-015KP',
#     'launchDate': '1961-06-29',
#     'satlat': 32.9954,
#     'satlng': 49.6138,
#     'satalt': 1744.7205},
#    {'satid': 6847,
#     'satname': 'COSMOS 590',
#     'intDesignator': '1973-069C',
#     'launchDate': '1973-10-02',
#     'satlat': 58.6155,
#     'satlng': 79.7585,
#     'satalt': 1464.4754},
#    {'satid': 6916,
#     'satname': 'COSMOS 606',
#     'intDesignator': '1973-084A',
#     'launchDate': '1973-11-02',
#     'satlat': 49.0242,
#     'satlng': -164.0882,
#     'satalt': 25789.0079},
#    {'satid': 6973,
#     'satname': 'OPS 9433 (DSCS 2-3)',
#     'intDesignator': '1973-100A',
#     'launchDate': '1973-12-13',
#     'satlat': 6.2666,
#     'satlng': -5.8211,
#     'satalt': 36636.1492},
#    {'satid': 6985,
#     'satname': 'COSMOS 617',
#     'intDesignator': '1973-104A',
#     'launchDate': '1973-12-19',
#     'satlat': 60.2267,
#     'satlng': 65.5468,
#     'satalt': 1493.7242},
#    {'satid': 6989,
#     'satname': 'COSMOS 621',
#     'intDesignator': '1973-104E',
#     'launchDate': '1973-12-19',
#     'satlat': 51.7586,
#     'satlng': 96.7954,
#     'satalt': 1467.1693},
#    {'satid': 7037,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086AD',
#     'launchDate': '1973-11-06',
#     'satlat': 63.378,
#     'satlng': 75.9568,
#     'satalt': 1981.3434},
#    {'satid': 7039,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086AF',
#     'launchDate': '1973-11-06',
#     'satlat': 51.3414,
#     'satlng': 87.5829,
#     'satalt': 1430.0702},
#    {'satid': 7071,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086BP',
#     'launchDate': '1973-11-06',
#     'satlat': 27.0298,
#     'satlng': 38.0675,
#     'satalt': 1504.9298},
#    {'satid': 7080,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086BY',
#     'launchDate': '1973-11-06',
#     'satlat': 62.7559,
#     'satlng': 113.3929,
#     'satalt': 1402.0049},
#    {'satid': 7135,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086CZ',
#     'launchDate': '1973-11-06',
#     'satlat': 71.7437,
#     'satlng': 65.8792,
#     'satalt': 1520.5352},
#    {'satid': 7146,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086DL',
#     'launchDate': '1973-11-06',
#     'satlat': 10.3199,
#     'satlng': 87.045,
#     'satalt': 1547.5258},
#    {'satid': 7149,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086DP',
#     'launchDate': '1973-11-06',
#     'satlat': 64.8404,
#     'satlng': 72.9626,
#     'satalt': 1507.7862},
#    {'satid': 7164,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086EC',
#     'launchDate': '1973-11-06',
#     'satlat': 43.9988,
#     'satlng': 32.7084,
#     'satalt': 1303.0697},
#    {'satid': 7167,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086EF',
#     'launchDate': '1973-11-06',
#     'satlat': 50.6962,
#     'satlng': 106.1429,
#     'satalt': 1439.9794},
#    {'satid': 7194,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086FC',
#     'launchDate': '1973-11-06',
#     'satlat': -0.4268,
#     'satlng': 83.4983,
#     'satalt': 2307.1754},
#    {'satid': 7276,
#     'satname': 'MOLNIYA 2-9',
#     'intDesignator': '1974-026A',
#     'launchDate': '1974-04-26',
#     'satlat': 64.0204,
#     'satlng': 62.7476,
#     'satalt': 30386.5644},
#    {'satid': 7369,
#     'satname': 'OPS 7518 (NTS 1)',
#     'intDesignator': '1974-054A',
#     'launchDate': '1974-07-14',
#     'satlat': 5.4311,
#     'satlng': 40.7268,
#     'satalt': 13521.215},
#    {'satid': 7376,
#     'satname': 'MOLNIYA 2-10',
#     'intDesignator': '1974-056A',
#     'launchDate': '1974-07-23',
#     'satlat': 60.1836,
#     'satlng': -74.1559,
#     'satalt': 37242.1534},
#    {'satid': 7392,
#     'satname': 'MOLNIYA 1-S',
#     'intDesignator': '1974-060A',
#     'launchDate': '1974-07-29',
#     'satlat': 6.469,
#     'satlng': 41.4298,
#     'satalt': 35788.3287},
#    {'satid': 7476,
#     'satname': 'COSMOS 689',
#     'intDesignator': '1974-079A',
#     'launchDate': '1974-10-18',
#     'satlat': 41.2028,
#     'satlng': 49.1425,
#     'satalt': 1019.1272},
#    {'satid': 7544,
#     'satname': 'INTELSAT 4-F8',
#     'intDesignator': '1974-093A',
#     'launchDate': '1974-11-21',
#     'satlat': 1.9558,
#     'satlng': 148.4594,
#     'satalt': 35915.7684},
#    {'satid': 7545,
#     'satname': 'ATLAS CENTAUR R/B',
#     'intDesignator': '1974-093B',
#     'launchDate': '1974-11-21',
#     'satlat': 26.5277,
#     'satlng': 110.3769,
#     'satalt': 36466.7664},
#    {'satid': 7547,
#     'satname': 'SKYNET 2B',
#     'intDesignator': '1974-094A',
#     'launchDate': '1974-11-23',
#     'satlat': 7.0502,
#     'satlng': 13.6324,
#     'satalt': 35793.2884},
#    {'satid': 7578,
#     'satname': 'SYMPHONIE 1',
#     'intDesignator': '1974-101A',
#     'launchDate': '1974-12-19',
#     'satlat': 8.9068,
#     'satlng': 69.6798,
#     'satalt': 35887.0653},
#    {'satid': 7663,
#     'satname': 'COSMOS 708',
#     'intDesignator': '1975-012A',
#     'launchDate': '1975-02-12',
#     'satlat': 63.6749,
#     'satlng': 115.584,
#     'satalt': 1406.5474},
#    {'satid': 7688,
#     'satname': 'TITAN 34B R/B',
#     'intDesignator': '1975-017B',
#     'launchDate': '1975-03-10',
#     'satlat': 61.7337,
#     'satlng': 104.511,
#     'satalt': 18470.1118},
#    {'satid': 7714,
#     'satname': 'METEOR 1-21',
#     'intDesignator': '1975-023A',
#     'launchDate': '1975-04-01',
#     'satlat': 22.6588,
#     'satlng': 48.6734,
#     'satalt': 879.0091},
#    {'satid': 7780,
#     'satname': 'MOLNIYA 1-29',
#     'intDesignator': '1975-036A',
#     'launchDate': '1975-04-29',
#     'satlat': 44.7977,
#     'satlng': 90.126,
#     'satalt': 33885.554},
#    {'satid': 7800,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1975-036D',
#     'launchDate': '1975-04-29',
#     'satlat': 52.9028,
#     'satlng': 92.6149,
#     'satalt': 20691.6476},
#    {'satid': 7815,
#     'satname': 'INTELSAT 4-F1',
#     'intDesignator': '1975-042A',
#     'launchDate': '1975-05-22',
#     'satlat': 2.9944,
#     'satlng': 144.9523,
#     'satalt': 36046.62},
#    {'satid': 7963,
#     'satname': 'OPS 4966',
#     'intDesignator': '1975-055A',
#     'launchDate': '1975-06-18',
#     'satlat': 3.4496,
#     'satlng': 109.3522,
#     'satalt': 41420.5544},
#    {'satid': 7964,
#     'satname': 'ATLAS AGENA R/B',
#     'intDesignator': '1975-055B',
#     'launchDate': '1975-06-18',
#     'satlat': 5.1691,
#     'satlng': 92.9935,
#     'satalt': 35374.9678},
#    {'satid': 8039,
#     'satname': 'SL-3 DEB',
#     'intDesignator': '1975-064C',
#     'launchDate': '1975-07-11',
#     'satlat': 52.2924,
#     'satlng': 39.2169,
#     'satalt': 861.3212},
#    {'satid': 8132,
#     'satname': 'SYMPHONIE 2',
#     'intDesignator': '1975-077A',
#     'launchDate': '1975-08-27',
#     'satlat': 1.9917,
#     'satlng': 123.4676,
#     'satalt': 35895.7944},
#    {'satid': 8195,
#     'satname': 'MOLNIYA 2-14',
#     'intDesignator': '1975-081A',
#     'launchDate': '1975-09-09',
#     'satlat': 44.1295,
#     'satlng': 59.784,
#     'satalt': 35442.5401},
#    {'satid': 8306,
#     'satname': 'THORAD DELTA 1 DEB',
#     'intDesignator': '1974-089BP',
#     'launchDate': '1974-11-15',
#     'satlat': 23.3745,
#     'satlng': 99.6193,
#     'satalt': 1422.2833},
#    {'satid': 8326,
#     'satname': 'SL-8 R/B',
#     'intDesignator': '1975-089B',
#     'launchDate': '1975-09-24',
#     'satlat': 15.3822,
#     'satlng': 79.126,
#     'satalt': 1193.5118},
#    {'satid': 8357,
#     'satname': 'COSMOS 775',
#     'intDesignator': '1975-097A',
#     'launchDate': '1975-10-08',
#     'satlat': 2.9113,
#     'satlng': 106.5181,
#     'satalt': 35765.2096},
#    {'satid': 8482,
#     'satname': 'OPS 3165',
#     'intDesignator': '1975-118A',
#     'launchDate': '1975-12-14',
#     'satlat': 7.2971,
#     'satlng': 48.2899,
#     'satalt': 35820.7378},
#    {'satid': 8513,
#     'satname': 'RADUGA 1',
#     'intDesignator': '1975-123A',
#     'launchDate': '1975-12-22',
#     'satlat': 7.0836,
#     'satlng': 67.9768,
#     'satalt': 35780.1536},
#    {'satid': 8516,
#     'satname': 'TITAN 3C TRANSTAGE R/B',
#     'intDesignator': '1975-118C',
#     'launchDate': '1975-12-14',
#     'satlat': 5.6708,
#     'satlng': -1.3059,
#     'satalt': 35718.7267},
#    {'satid': 8562,
#     'satname': 'THORAD DELTA 1 DEB',
#     'intDesignator': '1974-089CZ',
#     'launchDate': '1974-11-15',
#     'satlat': 15.4248,
#     'satlng': 79.4193,
#     'satalt': 1537.2169},
#    {'satid': 8601,
#     'satname': 'MOLNIYA 1-32',
#     'intDesignator': '1976-006A',
#     'launchDate': '1976-01-22',
#     'satlat': 62.5479,
#     'satlng': 116.4908,
#     'satalt': 35642.724},
#    {'satid': 8620,
#     'satname': 'INTELSAT 4A-F2',
#     'intDesignator': '1976-010A',
#     'launchDate': '1976-01-29',
#     'satlat': 11.5585,
#     'satlng': 84.5781,
#     'satalt': 35966.0745},
#    {'satid': 8679,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1975-004G',
#     'launchDate': '1975-01-22',
#     'satlat': 53.0143,
#     'satlng': 78.3473,
#     'satalt': 857.748},
#    {'satid': 8788,
#     'satname': 'THORAD DELTA 1 DEB',
#     'intDesignator': '1974-089DQ',
#     'launchDate': '1974-11-15',
#     'satlat': 25.1381,
#     'satlng': 79.1781,
#     'satalt': 1567.9969},
#    {'satid': 8820,
#     'satname': 'LAGEOS 1',
#     'intDesignator': '1976-039A',
#     'launchDate': '1976-05-04',
#     'satlat': 26.0963,
#     'satlng': 55.8282,
#     'satalt': 5937.0171},
#    {'satid': 8836,
#     'satname': 'SSU 2',
#     'intDesignator': '1976-038D',
#     'launchDate': '1976-04-30',
#     'satlat': 19.251,
#     'satlng': 65.4039,
#     'satalt': 1238.7974},
#    {'satid': 8916,
#     'satname': 'OPS 2112',
#     'intDesignator': '1976-059A',
#     'launchDate': '1976-06-26',
#     'satlat': 6.429,
#     'satlng': 1.7697,
#     'satalt': 36019.1921},
#    {'satid': 8964,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1975-004AW',
#     'launchDate': '1975-01-22',
#     'satlat': 36.4509,
#     'satlng': 48.8945,
#     'satalt': 841.6678},
#    {'satid': 9016,
#     'satname': 'SL-8 DEB',
#     'intDesignator': '1976-067C',
#     'launchDate': '1976-07-08',
#     'satlat': 15.38,
#     'satlng': 57.1519,
#     'satalt': 2048.3648},
#    {'satid': 9022,
#     'satname': 'COSMOS 841',
#     'intDesignator': '1976-069A',
#     'launchDate': '1976-07-15',
#     'satlat': 55.7045,
#     'satlng': 73.1792,
#     'satalt': 791.1975},
#    {'satid': 9271,
#     'satname': 'TITAN 34B AGENA R/B',
#     'intDesignator': '1976-080B',
#     'launchDate': '1976-08-06',
#     'satlat': 33.9295,
#     'satlng': 114.38,
#     'satalt': 18315.971},
#    {'satid': 9330,
#     'satname': 'THORAD DELTA 1 R/B(2)',
#     'intDesignator': '1974-101G',
#     'launchDate': '1974-12-19',
#     'satlat': -4.4166,
#     'satlng': 30.3607,
#     'satalt': 27068.1629},
#    {'satid': 9415,
#     'satname': 'OPS 5721',
#     'intDesignator': '1976-091A',
#     'launchDate': '1976-09-11',
#     'satlat': 28.7135,
#     'satlng': 49.9616,
#     'satalt': 805.4046},
#    {'satid': 9416,
#     'satname': 'RADUGA 2',
#     'intDesignator': '1976-092A',
#     'launchDate': '1976-09-11',
#     'satlat': 6.3365,
#     'satlng': 85.7745,
#     'satalt': 35888.0289},
#    {'satid': 9443,
#     'satname': 'COSMOS 858',
#     'intDesignator': '1976-098A',
#     'launchDate': '1976-09-29',
#     'satlat': 53.6409,
#     'satlng': 51.631,
#     'satalt': 777.1043},
#    {'satid': 9478,
#     'satname': 'MARISAT 2',
#     'intDesignator': '1976-101A',
#     'launchDate': '1976-10-14',
#     'satlat': 10.0031,
#     'satlng': 63.0262,
#     'satalt': 36882.9119},
#    {'satid': 9494,
#     'satname': 'COSMOS 861',
#     'intDesignator': '1976-104A',
#     'launchDate': '1976-10-21',
#     'satlat': 27.4249,
#     'satlng': 57.3212,
#     'satalt': 969.9688},
#    {'satid': 9495,
#     'satname': 'COSMOS 862',
#     'intDesignator': '1976-105A',
#     'launchDate': '1976-10-22',
#     'satlat': 68.028,
#     'satlng': -66.697,
#     'satalt': 29630.2456},
#    {'satid': 9503,
#     'satname': 'EKRAN 1',
#     'intDesignator': '1976-107A',
#     'launchDate': '1976-10-26',
#     'satlat': 8.2163,
#     'satlng': 61.9031,
#     'satalt': 35514.5352},
#    {'satid': 9651,
#     'satname': 'COSMOS 886 DEB',
#     'intDesignator': '1976-126H',
#     'launchDate': '1976-12-27',
#     'satlat': 45.7814,
#     'satlng': 34.4471,
#     'satalt': 1754.3011},
#    {'satid': 9696,
#     'satname': 'THORAD DELTA 1 DEB',
#     'intDesignator': '1974-089DV',
#     'launchDate': '1974-11-15',
#     'satlat': 19.0486,
#     'satlng': 62.9051,
#     'satalt': 1669.8456},
#    {'satid': 9803,
#     'satname': 'OPS 3151',
#     'intDesignator': '1977-007A',
#     'launchDate': '1977-02-06',
#     'satlat': 4.9653,
#     'satlng': 110.0501,
#     'satalt': 36914.4312},
#    {'satid': 9880,
#     'satname': 'MOLNIYA 1-36',
#     'intDesignator': '1977-021A',
#     'launchDate': '1977-03-24',
#     'satlat': 55.9772,
#     'satlng': 56.0823,
#     'satalt': 22171.9018},
#    {'satid': 9896,
#     'satname': 'COSMOS 862 DEB',
#     'intDesignator': '1976-105N',
#     'launchDate': '1976-10-22',
#     'satlat': 38.6562,
#     'satlng': 175.5283,
#     'satalt': 37708.4963},
#    {'satid': 9951,
#     'satname': 'COSMOS 886 DEB',
#     'intDesignator': '1976-126AR',
#     'launchDate': '1976-12-27',
#     'satlat': 38.573,
#     'satlng': 82.7942,
#     'satalt': 1388.6354},
#    {'satid': 9964,
#     'satname': 'COSMOS 886 DEB',
#     'intDesignator': '1976-126BE',
#     'launchDate': '1976-12-27',
#     'satlat': 33.0012,
#     'satlng': 44.3756,
#     'satalt': 821.8247},
#    {'satid': 9966,
#     'satname': 'COSMOS 886 DEB',
#     'intDesignator': '1976-126BG',
#     'launchDate': '1976-12-27',
#     'satlat': 56.2178,
#     'satlng': 117.9989,
#     'satalt': 1541.5622},
#    {'satid': 9979,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086GJ',
#     'launchDate': '1973-11-06',
#     'satlat': 50.8465,
#     'satlng': 72.4665,
#     'satalt': 2284.5327},
#    {'satid': 9987,
#     'satname': 'THORAD DELTA 1 DEB',
#     'intDesignator': '1974-089EE',
#     'launchDate': '1974-11-15',
#     'satlat': 52.1237,
#     'satlng': 26.937,
#     'satalt': 1445.1919},
#    {'satid': 9998,
#     'satname': 'SMS 1 AKM',
#     'intDesignator': '1974-033F',
#     'launchDate': '1974-05-17',
#     'satlat': -2.648,
#     'satlng': 20.6033,
#     'satalt': 31144.0484},
#    {'satid': 10001,
#     'satname': 'OPS 9438 (DSCS 2-8)',
#     'intDesignator': '1977-034B',
#     'launchDate': '1977-05-12',
#     'satlat': 5.8417,
#     'satlng': 127.847,
#     'satalt': 37107.3074},
#    {'satid': 10002,
#     'satname': 'TITAN 3C TRANSTAGE R/B',
#     'intDesignator': '1977-034C',
#     'launchDate': '1977-05-12',
#     'satlat': 3.5459,
#     'satlng': 135.2782,
#     'satalt': 37632.2054},
#    {'satid': 10016,
#     'satname': 'OPS 9751',
#     'intDesignator': '1977-038A',
#     'launchDate': '1977-05-23',
#     'satlat': 8.5953,
#     'satlng': 50.527,
#     'satalt': 31083.9552},
#    {'satid': 10025,
#     'satname': 'ATLAS CENTAUR R/B',
#     'intDesignator': '1977-041B',
#     'launchDate': '1977-05-26',
#     'satlat': 11.3949,
#     'satlng': 43.0263,
#     'satalt': 35938.3299},
#    {'satid': 10061,
#     'satname': 'GOES 2',
#     'intDesignator': '1977-048A',
#     'launchDate': '1977-06-16',
#     'satlat': 5.2663,
#     'satlng': -3.4374,
#     'satalt': 35973.2246},
#    {'satid': 10089,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1977-047D',
#     'launchDate': '1977-06-16',
#     'satlat': 23.3395,
#     'satlng': 62.1942,
#     'satalt': 37460.9744},
#    {'satid': 10091,
#     'satname': 'NTS 2',
#     'intDesignator': '1977-053A',
#     'launchDate': '1977-06-23',
#     'satlat': 13.8086,
#     'satlng': 6.2889,
#     'satalt': 20342.8904},
#    {'satid': 10150,
#     'satname': 'COSMOS 931',
#     'intDesignator': '1977-068A',
#     'launchDate': '1977-07-20',
#     'satlat': 42.9883,
#     'satlng': -16.7602,
#     'satalt': 15735.3584},
#    {'satid': 10155,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1977-054D',
#     'launchDate': '1977-06-24',
#     'satlat': 30.8586,
#     'satlng': 15.8338,
#     'satalt': 19654.8519},
#    {'satid': 10159,
#     'satname': 'RADUGA 3',
#     'intDesignator': '1977-071A',
#     'launchDate': '1977-07-23',
#     'satlat': 9.1316,
#     'satlng': 41.4399,
#     'satalt': 35822.4427},
#    {'satid': 10167,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1977-068D',
#     'launchDate': '1977-07-20',
#     'satlat': -27.6944,
#     'satlng': 56.1119,
#     'satalt': 35323.8064},
#    {'satid': 10261,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1977-065CN',
#     'launchDate': '1977-07-14',
#     'satlat': 25.3569,
#     'satlng': 103.3162,
#     'satalt': 957.124},
#    {'satid': 10294,
#     'satname': 'SIRIO',
#     'intDesignator': '1977-080A',
#     'launchDate': '1977-08-25',
#     'satlat': 11.3971,
#     'satlng': 74.5511,
#     'satalt': 35751.9233},
#    {'satid': 10365,
#     'satname': 'EKRAN 2',
# ...
#     'satalt': 1660.6644},
#    {'satid': 23492,
#     'satname': 'SL-19 DEB',
#     'intDesignator': '1994-085Q',
#     'launchDate': '1994-12-26',
#     'satlat': 38.2021,
#     'satlng': 93.8604,
#     'satalt': 1951.8673},
#    {'satid': 23511,
#     'satname': 'COSMOS 2307 (GLONASS)',
#     'intDesignator': '1995-009A',
#     'launchDate': '1995-03-07',
#     'satlat': 62.6704,
#     'satlng': 141.744,
#     'satalt': 19129.895},
#    {'satid': 23523,
#     'satname': 'H-2 R/B(2)',
#     'intDesignator': '1995-011C',
#     'launchDate': '1995-03-18',
#     'satlat': 5.1635,
#     'satlng': 64.9652,
#     'satalt': 7010.9548},
#    {'satid': 23528,
#     'satname': 'INTELSAT 705',
#     'intDesignator': '1995-013A',
#     'launchDate': '1995-03-22',
#     'satlat': -6.2267,
#     'satlng': 16.1519,
#     'satalt': 36160.7444},
#    {'satid': 23538,
#     'satname': 'ARIANE 44LP+ R/B',
#     'intDesignator': '1995-016C',
#     'launchDate': '1995-03-28',
#     'satlat': 5.5945,
#     'satlng': -0.3278,
#     'satalt': 22790.2468},
#    {'satid': 23567,
#     'satname': 'USA 110',
#     'intDesignator': '1995-022A',
#     'launchDate': '1995-05-14',
#     'satlat': 12.7421,
#     'satlng': 98.2529,
#     'satalt': 35685.1051},
#    {'satid': 23568,
#     'satname': 'TITAN 4 CENTAUR R/B',
#     'intDesignator': '1995-022B',
#     'launchDate': '1995-05-14',
#     'satlat': 16.5973,
#     'satlng': 117.8158,
#     'satalt': 35730.9212},
#    {'satid': 23590,
#     'satname': 'ATLAS 2 CENTAUR R/B',
#     'intDesignator': '1995-027B',
#     'launchDate': '1995-05-31',
#     'satlat': -13.9929,
#     'satlng': 23.6804,
#     'satalt': 20037.6597},
#    {'satid': 23598,
#     'satname': 'DIRECTV 3 (DBS/NIMIQ 3)',
#     'intDesignator': '1995-029A',
#     'launchDate': '1995-06-10',
#     'satlat': 5.0478,
#     'satlng': 99.5129,
#     'satalt': 36129.293},
#    {'satid': 23609,
#     'satname': 'USA 112',
#     'intDesignator': '1995-034A',
#     'launchDate': '1995-07-10',
#     'satlat': 27.9972,
#     'satlng': 162.5562,
#     'satalt': 14141.9656},
#    {'satid': 23613,
#     'satname': 'TDRS 7',
#     'intDesignator': '1995-035B',
#     'launchDate': '1995-07-13',
#     'satlat': 12.9768,
#     'satlng': 84.149,
#     'satalt': 35696.4021},
#    {'satid': 23615,
#     'satname': 'IUS R/B(2)',
#     'intDesignator': '1995-035D',
#     'launchDate': '1995-07-13',
#     'satlat': 16.8976,
#     'satlng': 105.8532,
#     'satalt': 35676.0295},
#    {'satid': 23619,
#     'satname': 'TITAN 34D TRANSTAGE DEB',
#     'intDesignator': '1988-077N',
#     'launchDate': '1988-09-02',
#     'satlat': 24.1732,
#     'satlng': 161.2027,
#     'satalt': 37062.9837},
#    {'satid': 23620,
#     'satname': 'COSMOS 2316 (GLONASS)',
#     'intDesignator': '1995-037A',
#     'launchDate': '1995-07-24',
#     'satlat': 20.9066,
#     'satlng': 93.8659,
#     'satalt': 19097.1489},
#    {'satid': 23628,
#     'satname': 'USA 113',
#     'intDesignator': '1995-038A',
#     'launchDate': '1995-07-31',
#     'satlat': 9.9937,
#     'satlng': 103.0612,
#     'satalt': 35790.593},
#    {'satid': 23636,
#     'satname': 'INTELSAT 4 (PAS 4)',
#     'intDesignator': '1995-040A',
#     'launchDate': '1995-08-03',
#     'satlat': -5.3336,
#     'satlng': 27.8009,
#     'satalt': 36764.8594},
#    {'satid': 23639,
#     'satname': 'KOREASAT 1',
#     'intDesignator': '1995-041A',
#     'launchDate': '1995-08-05',
#     'satlat': -2.9353,
#     'satlng': 17.9815,
#     'satalt': 35942.3047},
#    {'satid': 23642,
#     'satname': 'MOLNIYA 3-47',
#     'intDesignator': '1995-042A',
#     'launchDate': '1995-08-09',
#     'satlat': 56.3419,
#     'satlng': -159.4238,
#     'satalt': 23800.5739},
#    {'satid': 23645,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1995-042D',
#     'launchDate': '1995-08-09',
#     'satlat': 26.8714,
#     'satlng': 3.811,
#     'satalt': 22322.6313},
#    {'satid': 23647,
#     'satname': 'TITAN 34B DEB',
#     'intDesignator': '1981-038C',
#     'launchDate': '1981-04-24',
#     'satlat': 57.2257,
#     'satlng': 176.3099,
#     'satalt': 27374.2992},
#    {'satid': 23648,
#     'satname': 'ATLAS 2 CENTAUR R/B(2)',
#     'intDesignator': '1995-038C',
#     'launchDate': '1995-07-31',
#     'satlat': 1.5658,
#     'satlng': 23.0555,
#     'satalt': 35531.4314},
#    {'satid': 23671,
#     'satname': 'ARIANE 42L+3 R/B',
#     'intDesignator': '1995-049B',
#     'launchDate': '1995-09-24',
#     'satlat': -4.2294,
#     'satlng': 22.453,
#     'satalt': 9467.2109},
#    {'satid': 23680,
#     'satname': 'LUCH 1',
#     'intDesignator': '1995-054A',
#     'launchDate': '1995-10-11',
#     'satlat': 9.9375,
#     'satlng': 72.8221,
#     'satalt': 35754.5805},
#    {'satid': 23683,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1995-054D',
#     'launchDate': '1995-10-11',
#     'satlat': -4.3668,
#     'satlng': 13.7035,
#     'satalt': 35746.0678},
#    {'satid': 23686,
#     'satname': 'ASTRA 1E',
#     'intDesignator': '1995-055A',
#     'launchDate': '1995-10-19',
#     'satlat': 1.5103,
#     'satlng': 80.3315,
#     'satalt': 36187.9051},
#    {'satid': 23687,
#     'satname': 'ARIANE 42L+3 R/B',
#     'intDesignator': '1995-055B',
#     'launchDate': '1995-10-19',
#     'satlat': 4.1845,
#     'satlng': 15.885,
#     'satalt': 25297.4163},
#    {'satid': 23696,
#     'satname': 'UFO 6 (USA 114)',
#     'intDesignator': '1995-057A',
#     'launchDate': '1995-10-22',
#     'satlat': 4.6166,
#     'satlng': 65.7515,
#     'satalt': 36209.5384},
#    {'satid': 23704,
#     'satname': 'COSMOS 2322',
#     'intDesignator': '1995-058A',
#     'launchDate': '1995-10-31',
#     'satlat': 59.9577,
#     'satlng': 49.1965,
#     'satalt': 864.3962},
#    {'satid': 23706,
#     'satname': 'SL-16 DEB',
#     'intDesignator': '1995-058C',
#     'launchDate': '1995-10-31',
#     'satlat': 40.9158,
#     'satlng': 94.9003,
#     'satalt': 857.1651},
#    {'satid': 23713,
#     'satname': 'TITAN 401 CENTAUR R/B',
#     'intDesignator': '1995-060B',
#     'launchDate': '1995-11-06',
#     'satlat': 4.8924,
#     'satlng': 49.824,
#     'satalt': 35803.6037},
#    {'satid': 23716,
#     'satname': 'ARIANE 44P+3 R/B',
#     'intDesignator': '1995-062B',
#     'launchDate': '1995-11-17',
#     'satlat': -3.688,
#     'satlng': -1.6264,
#     'satalt': 68649.4618},
#    {'satid': 23720,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1995-063D',
#     'launchDate': '1995-11-17',
#     'satlat': 13.513,
#     'satlng': 134.8566,
#     'satalt': 35618.8922},
#    {'satid': 23730,
#     'satname': 'TELECOM 2C',
#     'intDesignator': '1995-067A',
#     'launchDate': '1995-12-06',
#     'satlat': 0.9784,
#     'satlng': 49.329,
#     'satalt': 36471.5163},
#    {'satid': 23735,
#     'satname': 'COSMOS 2324 (GLONASS)',
#     'intDesignator': '1995-068B',
#     'launchDate': '1995-12-14',
#     'satlat': 11.5158,
#     'satlng': 98.4081,
#     'satalt': 19123.0185},
#    {'satid': 23736,
#     'satname': 'COSMOS 2323 (GLONASS)',
#     'intDesignator': '1995-068C',
#     'launchDate': '1995-12-14',
#     'satlat': 62.2724,
#     'satlng': -17.6288,
#     'satalt': 19148.3833},
#    {'satid': 23754,
#     'satname': 'ECHOSTAR 1',
#     'intDesignator': '1995-073A',
#     'launchDate': '1995-12-28',
#     'satlat': 2.8369,
#     'satlng': 147.8471,
#     'satalt': 36164.2537},
#    {'satid': 23765,
#     'satname': 'AFRICASAT 1 (MEASAT 1)',
#     'intDesignator': '1996-002B',
#     'launchDate': '1996-01-12',
#     'satlat': 9.276,
#     'satlng': 158.5474,
#     'satalt': 36151.9794},
#    {'satid': 23766,
#     'satname': 'ARIANE 44L+3 R/B',
#     'intDesignator': '1996-002C',
#     'launchDate': '1996-01-12',
#     'satlat': 2.2462,
#     'satlng': 55.7201,
#     'satalt': 22108.241},
#    {'satid': 23775,
#     'satname': 'GORIZONT 31',
#     'intDesignator': '1996-005A',
#     'launchDate': '1996-01-25',
#     'satlat': -1.9311,
#     'satlng': 17.9467,
#     'satalt': 35956.9653},
#    {'satid': 23778,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1996-005D',
#     'launchDate': '1996-01-25',
#     'satlat': 4.1346,
#     'satlng': 43.1752,
#     'satalt': 36543.8171},
#    {'satid': 23781,
#     'satname': 'NSTAR B',
#     'intDesignator': '1996-007A',
#     'launchDate': '1996-02-05',
#     'satlat': 8.7195,
#     'satlng': 113.8038,
#     'satalt': 36118.8459},
#    {'satid': 23793,
#     'satname': 'SL-14 R/B',
#     'intDesignator': '1996-009G',
#     'launchDate': '1996-02-19',
#     'satlat': 71.6533,
#     'satlng': 48.8036,
#     'satalt': 1427.4843},
#    {'satid': 23802,
#     'satname': 'POLAR',
#     'intDesignator': '1996-013A',
#     'launchDate': '1996-02-24',
#     'satlat': 75.1564,
#     'satlng': 34.2834,
#     'satalt': 50883.0286},
#    {'satid': 23806,
#     'satname': 'TITAN 34B DEB',
#     'intDesignator': '1981-038D',
#     'launchDate': '1981-04-24',
#     'satlat': 63.1008,
#     'satlng': 89.9628,
#     'satalt': 64563.769},
#    {'satid': 23812,
#     'satname': 'TITAN 34B AGENA D DEB',
#     'intDesignator': '1983-078D',
#     'launchDate': '1983-07-31',
#     'satlat': 57.9494,
#     'satlng': 121.5612,
#     'satalt': 8950.7845},
#    {'satid': 23816,
#     'satname': 'INTELSAT 707',
#     'intDesignator': '1996-015A',
#     'launchDate': '1996-03-14',
#     'satlat': -5.5255,
#     'satlng': 16.9323,
#     'satalt': 36010.0445},
#    {'satid': 23829,
#     'satname': 'OPS 0856 DEB',
#     'intDesignator': '1966-077F',
#     'launchDate': '1966-08-19',
#     'satlat': 28.9728,
#     'satlng': 51.3277,
#     'satalt': 4559.9727},
#    {'satid': 23839,
#     'satname': 'INMARSAT 3-F1',
#     'intDesignator': '1996-020A',
#     'launchDate': '1996-04-03',
#     'satlat': 5.9772,
#     'satlng': 144.5331,
#     'satalt': 35873.3241},
#    {'satid': 23840,
#     'satname': 'ATLAS 2A CENTAUR R/B',
#     'intDesignator': '1996-020B',
#     'launchDate': '1996-04-03',
#     'satlat': 21.9922,
#     'satlng': 105.885,
#     'satalt': 23427.327},
#    {'satid': 23845,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1996-021D',
#     'launchDate': '1996-04-08',
#     'satlat': 8.2294,
#     'satlng': 110.972,
#     'satalt': 16229.9733},
#    {'satid': 23846,
#     'satname': 'MSAT M1',
#     'intDesignator': '1996-022A',
#     'launchDate': '1996-04-20',
#     'satlat': 3.348,
#     'satlng': 76.2297,
#     'satalt': 36311.384},
#    {'satid': 23847,
#     'satname': 'ARIANE 42P+3 R/B',
#     'intDesignator': '1996-022B',
#     'launchDate': '1996-04-20',
#     'satlat': 2.0445,
#     'satlng': 138.8277,
#     'satalt': 26224.913},
#    {'satid': 23855,
#     'satname': 'USA 118',
#     'intDesignator': '1996-026A',
#     'launchDate': '1996-04-24',
#     'satlat': 5.9273,
#     'satlng': 51.0625,
#     'satalt': 36775.965},
#    {'satid': 23864,
#     'satname': 'PALAPA C2',
#     'intDesignator': '1996-030A',
#     'launchDate': '1996-05-16',
#     'satlat': 5.4123,
#     'satlng': 109.6236,
#     'satalt': 36132.7703},
#    {'satid': 23867,
#     'satname': 'ARIANE 44L+3 DEB (SPELDA',
#     'intDesignator': '1996-030D',
#     'launchDate': '1996-05-16',
#     'satlat': 4.057,
#     'satlng': 91.5696,
#     'satalt': 22531.0223},
#    {'satid': 23880,
#     'satname': 'GORIZONT 32',
#     'intDesignator': '1996-034A',
#     'launchDate': '1996-05-25',
#     'satlat': 10.9743,
#     'satlng': 74.7058,
#     'satalt': 35811.413},
#    {'satid': 23893,
#     'satname': 'USA 119',
#     'intDesignator': '1996-029A',
#     'launchDate': '1996-05-12',
#     'satlat': 22.7184,
#     'satlng': 113.3411,
#     'satalt': 8022.292},
#    {'satid': 23943,
#     'satname': 'APSTAR 1A',
#     'intDesignator': '1996-039A',
#     'launchDate': '1996-07-03',
#     'satlat': -3.7124,
#     'satlng': 26.7554,
#     'satalt': 36010.1725},
#    {'satid': 23948,
#     'satname': 'ARABSAT 2A',
#     'intDesignator': '1996-040A',
#     'launchDate': '1996-07-09',
#     'satlat': -0.3542,
#     'satlng': 37.1573,
#     'satalt': 36072.5238},
#    {'satid': 23949,
#     'satname': 'TURKSAT 1C',
#     'intDesignator': '1996-040B',
#     'launchDate': '1996-07-09',
#     'satlat': 8.3943,
#     'satlng': 126.5468,
#     'satalt': 35774.8424},
#    {'satid': 23953,
#     'satname': 'NAVSTAR 38 (USA 126)',
#     'intDesignator': '1996-041A',
#     'launchDate': '1996-07-16',
#     'satlat': 35.2752,
#     'satlng': 162.9535,
#     'satalt': 21161.0643},
#    {'satid': 23966,
#     'satname': 'ARIANE 2 DEB',
#     'intDesignator': '1988-098F',
#     'launchDate': '1988-10-28',
#     'satlat': 3.6164,
#     'satlng': 73.8466,
#     'satalt': 21822.9319},
#    {'satid': 23968,
#     'satname': 'ATLAS 2 CENTAUR R/B',
#     'intDesignator': '1996-042B',
#     'launchDate': '1996-07-25',
#     'satlat': 21.6302,
#     'satlng': 41.3638,
#     'satalt': 20573.8128},
#    {'satid': 24209,
#     'satname': 'TELECOM 2D',
#     'intDesignator': '1996-044B',
#     'launchDate': '1996-08-08',
#     'satlat': -5.2257,
#     'satlng': 22.9001,
#     'satalt': 36231.5705},
#    {'satid': 24285,
#     'satname': 'FAST',
#     'intDesignator': '1996-049A',
#     'launchDate': '1996-08-21',
#     'satlat': 82.3831,
#     'satlng': 129.2576,
#     'satalt': 3206.9539},
#    {'satid': 24299,
#     'satname': 'SL-16 DEB',
#     'intDesignator': '1996-051C',
#     'launchDate': '1996-09-04',
#     'satlat': 30.0019,
#     'satlng': 92.4692,
#     'satalt': 853.232},
#    {'satid': 24307,
#     'satname': 'INMARSAT 3-F2',
#     'intDesignator': '1996-053A',
#     'launchDate': '1996-09-06',
#     'satlat': -4.7752,
#     'satlng': 21.7655,
#     'satalt': 35862.6853},
#    {'satid': 24435,
#     'satname': 'EXPRESS 2',
#     'intDesignator': '1996-058A',
#     'launchDate': '1996-09-26',
#     'satlat': 5.983,
#     'satlng': 49.141,
#     'satalt': 35760.221},
#    {'satid': 24438,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1996-058D',
#     'launchDate': '1996-09-26',
#     'satlat': 10.761,
#     'satlng': 68.2204,
#     'satalt': 35762.7415},
#    {'satid': 24602,
#     'satname': 'PEGASUS DEB',
#     'intDesignator': '1994-029ZE',
#     'launchDate': '1994-05-19',
#     'satlat': 27.6267,
#     'satlng': 103.4395,
#     'satalt': 826.0081},
#    {'satid': 24665,
#     'satname': 'EUTE 48A (HB2)',
#     'intDesignator': '1996-067A',
#     'launchDate': '1996-11-21',
#     'satlat': -6.5826,
#     'satlng': 12.9148,
#     'satalt': 36339.7153},
#    {'satid': 24679,
#     'satname': 'SL-19 DEB',
#     'intDesignator': '1994-085Y',
#     'launchDate': '1994-12-26',
#     'satlat': 52.5019,
#     'satlng': 62.2112,
#     'satalt': 1886.8963},
#    {'satid': 24700,
#     'satname': 'ISO DEB',
#     'intDesignator': '1995-062C',
#     'launchDate': '1995-11-17',
#     'satlat': -3.1722,
#     'satlng': 13.5424,
#     'satalt': 48664.1436},
#    {'satid': 24724,
#     'satname': 'ARIANE 44L DEB',
#     'intDesignator': '1991-003G',
#     'launchDate': '1991-01-15',
#     'satlat': 5.0041,
#     'satlng': 69.1057,
#     'satalt': 8317.2457},
#    {'satid': 24732,
#     'satname': 'INTELSAT 26 (JCSAT 4)',
#     'intDesignator': '1997-007A',
#     'launchDate': '1997-02-17',
#     'satlat': 1.0394,
#     'satlng': 63.5704,
#     'satalt': 35792.0346},
#    {'satid': 24737,
#     'satname': 'USA 130',
#     'intDesignator': '1997-008A',
#     'launchDate': '1997-02-23',
#     'satlat': -5.9492,
#     'satlng': 8.2805,
#     'satalt': 35782.9649},
#    {'satid': 24739,
#     'satname': 'IUS R/B(1)',
#     'intDesignator': '1997-008C',
#     'launchDate': '1997-02-23',
#     'satlat': 15.3432,
#     'satlng': 2.0814,
#     'satalt': 27855.0759},
#    {'satid': 24741,
#     'satname': 'ARIANE 44L DEB',
#     'intDesignator': '1991-003H',
#     'launchDate': '1991-01-15',
#     'satlat': 0.1969,
#     'satlng': 26.8845,
#     'satalt': 19567.3837},
#    {'satid': 24768,
#     'satname': 'THAICOM 3',
#     'intDesignator': '1997-016A',
#     'launchDate': '1997-04-16',
#     'satlat': -2.8779,
#     'satlng': 37.5248,
#     'satalt': 35858.9838},
#    {'satid': 24786,
#     'satname': 'GOES 10',
#     'intDesignator': '1997-019A',
#     'launchDate': '1997-04-25',
#     'satlat': 1.516,
#     'satlng': 57.3255,
#     'satalt': 36222.2495},
#    {'satid': 24798,
#     'satname': 'DFH-3 2',
#     'intDesignator': '1997-021A',
#     'launchDate': '1997-05-11',
#     'satlat': 11.442,
#     'satlng': 117.9202,
#     'satalt': 35771.0636},
#    {'satid': 24800,
#     'satname': 'COSMOS 2342',
#     'intDesignator': '1997-022A',
#     'launchDate': '1997-05-14',
#     'satlat': -21.13,
#     'satlng': 76.0277,
#     'satalt': 34206.2088},
#    {'satid': 24803,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1997-022D',
#     'launchDate': '1997-05-14',
#     'satlat': 64.6208,
#     'satlng': 154.8742,
#     'satalt': 5232.4647},
#    {'satid': 24808,
#     'satname': 'THOR 2A',
#     'intDesignator': '1997-025A',
#     'launchDate': '1997-05-20',
#     'satlat': 8.7205,
#     'satlng': 142.6876,
#     'satalt': 36174.7368},
#    ...]}]

# %%
with open('satlaunch90.json', 'w') as f:
    json.dump(earth_sat2, f)
