# %%
import requests
import pandas as pd
import json
from config import API_Key
import csv
import numpy as np
import pprint

# %%
df = pd.read_csv('data/Satellite-Exploration-CSV.csv')
df
# Out:
#           name  satid                      source  \
# 0        HYSIS  43719                       India
# 1     GAOFEN-5  43461  People's Republic of China
# 2      NUSAT 5  43204                   Argentina
# 3      NUSAT 4  43195                   Argentina
# 4       VRSS-2  42954                   Venezuela
# ..         ...    ...                         ...
# 144  LANDSAT 4  13367               United States
# 145   SEASAT 1  10967               United States
# 146  LANDSAT 3  10702               United States
# 147  LANDSAT 2   7615               United States
# 148  LANDSAT 1   6126               United States
#
#                                        launchsite     LSlat    LSlong  \
# 0                               SRIHARIKOTA (SRI)  13.72590   80.2266
# 1               Taiyuan Space Center, China (TSC)  38.84280  111.6051
# 2    Jiuquan Satellite Launch Center, China (JSC)  40.98450  100.2087
# 3    Jiuquan Satellite Launch Center, China (JSC)  40.98450  100.2087
# 4    Jiuquan Satellite Launch Center, China (JSC)  40.98450  100.2087
# ..                                            ...       ...       ...
# 144          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
# 145          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
# 146          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
# 147          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
# 148          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
#
#         Clat     Clong
# 0    20.5837   78.9629
# 1    35.8617  104.1954
# 2    38.4161   63.6167
# 3    38.4161   63.6167
# 4     6.4238   66.5897
# ..       ...       ...
# 144  37.0902   95.7129
# 145  37.0902   95.7129
# 146  37.0902   95.7129
# 147  37.0902   95.7129
# 148  37.0902   95.7129
#
# [149 rows x 8 columns]

# %%
df.set_index(["name"])
# Out:
#            satid                      source  \
# name
# HYSIS      43719                       India
# GAOFEN-5   43461  People's Republic of China
# NUSAT 5    43204                   Argentina
# NUSAT 4    43195                   Argentina
# VRSS-2     42954                   Venezuela
# ...          ...                         ...
# LANDSAT 4  13367               United States
# SEASAT 1   10967               United States
# LANDSAT 3  10702               United States
# LANDSAT 2   7615               United States
# LANDSAT 1   6126               United States
#
#                                              launchsite     LSlat    LSlong  \
# name
# HYSIS                                 SRIHARIKOTA (SRI)  13.72590   80.2266
# GAOFEN-5              Taiyuan Space Center, China (TSC)  38.84280  111.6051
# NUSAT 5    Jiuquan Satellite Launch Center, China (JSC)  40.98450  100.2087
# NUSAT 4    Jiuquan Satellite Launch Center, China (JSC)  40.98450  100.2087
# VRSS-2     Jiuquan Satellite Launch Center, China (JSC)  40.98450  100.2087
# ...                                                 ...       ...       ...
# LANDSAT 4          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
# SEASAT 1           AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
# LANDSAT 3          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
# LANDSAT 2          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
# LANDSAT 1          AIR FORCE WESTERN TEST RANGE (AFWTR)  32.84256 -112.2580
#
#               Clat     Clong
# name
# HYSIS      20.5837   78.9629
# GAOFEN-5   35.8617  104.1954
# NUSAT 5    38.4161   63.6167
# NUSAT 4    38.4161   63.6167
# VRSS-2      6.4238   66.5897
# ...            ...       ...
# LANDSAT 4  37.0902   95.7129
# SEASAT 1   37.0902   95.7129
# LANDSAT 3  37.0902   95.7129
# LANDSAT 2  37.0902   95.7129
# LANDSAT 1  37.0902   95.7129
#
# [149 rows x 7 columns]

# %%
array = np.array(df)
id= array[:,1]

print(id)
# Out:
# [43719 43461 43204 43195 42954 42901 42063 41898 41877 41848 41599 41558
#  41558 41557 41557 41556 41456 41386 41335 40968 40931 40701 40697 40536
#  40360 40336 40118 40072 40053 39766 39731 39455 39422 39419 39418 39186
#  39160 39159 39150 39086 39084 39030 38782 38755 38708 38707 38248 38038
#  37794 37781 37387 36985 36795 36795 36415 36414 36413 36121 36110 35931
#  35870 34839 33331 33105 32783 32476 32382 29710 29709 29268 29228 29079
#  28931 28893 28891 28649 28220 28376 28254 28220 28057 28051 27840 27597
#  27559 27430 27424 27421 27386 27004 27003 27001 26997 26957 26620 26619
#  26548 26032 25994 25940 25919 25860 25789 25758 25757 25756 25693 25682
#  25636 25616 25504 25397 25396 25395 25394 25260 24971 24883 24277 23940
#  23827 23751 23710 23657 23560 23342 23323 23317 22823 22076 21688 21574
#  21397 20510 20478 20436 19274 18960 18214 17527 16881 16613 15331 14780
#  13367 10967 10702 7615 6126]

# %%
# satellites = []
# for x in id:
#     base_url = f"https://api.n2yo.com/rest/v1/satellite/positions/{x}/40.0583/74.4057/0/1/&apiKey=RSNS74-FAEMYM-S26ZDF-4LIZ"
#     response = requests.get(base_url)
#     data = response.json()
#     satellite_x = json.dumps(data, sort_keys=True,separators=(',', ': '))
#     satellites.append(satellite_x.strip())

# %%
satellites = []
for x in id:
    base_url = f"https://api.n2yo.com/rest/v1/satellite/positions/{x}/40.0583/74.4057/0/1/&apiKey=RSNS74-FAEMYM-S26ZDF-4LIZ"
    response = requests.get(base_url)
    data = response.json()
    satellite_data = data
    satellites.append(satellite_data)

# %%
satellites

# %%
#  def Convert(satellites):
# #     it = iter(satellites)
# #     res_dct = dict(zip(it,it))
# #     return res_dct
# # lst = satellites
# # print(Convert(lst))

# %%
with open('app.geojson', 'a+') as f:
   json.dump(satellites,f)

# %%
earth_sat = []

search_url = f"https://api.n2yo.com/rest/v1/satellite/above/40.0583/74.4057/0/50/0/&apiKey={API_Key}"
response_earth = requests.get(search_url)
earth_data = response_earth.json()
earth_sat.append(earth_data)

# %%
earth_sat
# Out:
# [{'info': {'category': 'ANY', 'transactionscount': 2, 'satcount': 542},
#   'above': [{'satid': 309,
#     'satname': 'TIROS 5',
#     'intDesignator': '1962-025A',
#     'launchDate': '1962-06-19',
#     'satlat': 40.4541,
#     'satlng': 75.4964,
#     'satalt': 764.3805},
#    {'satid': 515,
#     'satname': 'DELTA 1 R/B',
#     'intDesignator': '1962-068B',
#     'launchDate': '1962-12-13',
#     'satlat': 38.3934,
#     'satlng': 76.8131,
#     'satalt': 6082.5012},
#    {'satid': 702,
#     'satname': 'WESTFORD NEEDLES',
#     'intDesignator': '1963-014H',
#     'launchDate': '1963-05-09',
#     'satlat': 56.4619,
#     'satlng': 75.5642,
#     'satalt': 3902.2555},
#    {'satid': 743,
#     'satname': 'THOR AGENA B DEB',
#     'intDesignator': '1964-004D',
#     'launchDate': '1964-01-25',
#     'satlat': 41.901,
#     'satlng': 65.506,
#     'satalt': 1295.8063},
#    {'satid': 2153,
#     'satname': 'THOR AGENA B DEB',
#     'intDesignator': '1965-098J',
#     'launchDate': '1965-11-29',
#     'satlat': 47.5447,
#     'satlng': 67.1748,
#     'satalt': 1449.477},
#    {'satid': 2645,
#     'satname': 'OPS 9321 (IDSCS 8)',
#     'intDesignator': '1967-003A',
#     'launchDate': '1967-01-18',
#     'satlat': 3.3432,
#     'satlng': 68.0225,
#     'satalt': 33620.7358},
#    {'satid': 2655,
#     'satname': 'OPS 9328 (IDSCS 15)',
#     'intDesignator': '1967-003H',
#     'launchDate': '1967-01-18',
#     'satlat': 2.8996,
#     'satlng': 72.2152,
#     'satalt': 34184.2749},
#    {'satid': 2684,
#     'satname': 'DIAMANT DEB',
#     'intDesignator': '1967-014C',
#     'launchDate': '1967-02-15',
#     'satlat': 35.6366,
#     'satlng': 79.3567,
#     'satalt': 1270.876},
#    {'satid': 2865,
#     'satname': 'OPS 9334 (IDSCS 19)',
#     'intDesignator': '1967-066D',
#     'launchDate': '1967-07-01',
#     'satlat': -2.3374,
#     'satlng': 67.5559,
#     'satalt': 33364.0476},
#    {'satid': 3244,
#     'satname': 'WESTFORD NEEDLES',
#     'intDesignator': '1963-014BJ',
#     'launchDate': '1963-05-09',
#     'satlat': 56.3489,
#     'satlng': 79.7137,
#     'satalt': 3681.3891},
#    {'satid': 3284,
#     'satname': 'OPS 9341 (IDSCS 20)',
#     'intDesignator': '1968-050A',
#     'launchDate': '1968-06-13',
#     'satlat': 1.2432,
#     'satlng': 94.5294,
#     'satalt': 33763.3951},
#    {'satid': 3287,
#     'satname': 'OPS 9344 (IDSCS 23)',
#     'intDesignator': '1968-050D',
#     'launchDate': '1968-06-13',
#     'satlat': 1.4973,
#     'satlng': 89.4502,
#     'satalt': 33791.4602},
#    {'satid': 3288,
#     'satname': 'OPS 9345 (IDSCS 24)',
#     'intDesignator': '1968-050E',
#     'launchDate': '1968-06-13',
#     'satlat': 2.0716,
#     'satlng': 74.8369,
#     'satalt': 33790.0421},
#    {'satid': 3669,
#     'satname': 'ISIS 1',
#     'intDesignator': '1969-009A',
#     'launchDate': '1969-01-30',
#     'satlat': 52.0436,
#     'satlng': 62.0633,
#     'satalt': 2766.7584},
#    {'satid': 4418,
#     'satname': 'OPS 5346',
#     'intDesignator': '1970-046A',
#     'launchDate': '1970-06-19',
#     'satlat': -2.9217,
#     'satlng': 73.5797,
#     'satalt': 35806.8434},
#    {'satid': 4685,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025BJ',
#     'launchDate': '1970-04-08',
#     'satlat': 44.0886,
#     'satlng': 70.1337,
#     'satalt': 1076.9674},
#    {'satid': 4786,
#     'satname': 'COSMOS 382',
#     'intDesignator': '1970-103A',
#     'launchDate': '1970-12-02',
#     'satlat': 19.7612,
#     'satlng': 77.9272,
#     'satalt': 4117.1753},
#    {'satid': 6797,
#     'satname': 'ATLAS CENTAUR R/B',
#     'intDesignator': '1973-058B',
#     'launchDate': '1973-08-23',
#     'satlat': 26.5886,
#     'satlng': 93.0509,
#     'satalt': 35612.9606},
#    {'satid': 6916,
#     'satname': 'COSMOS 606',
#     'intDesignator': '1973-084A',
#     'launchDate': '1973-11-02',
#     'satlat': 18.1065,
#     'satlng': 41.1739,
#     'satalt': 35461.4602},
#    {'satid': 7017,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086H',
#     'launchDate': '1973-11-06',
#     'satlat': 39.5409,
#     'satlng': 62.12,
#     'satalt': 1518.0369},
#    {'satid': 7376,
#     'satname': 'MOLNIYA 2-10',
#     'intDesignator': '1974-056A',
#     'launchDate': '1974-07-23',
#     'satlat': 55.5657,
#     'satlng': 73.9463,
#     'satalt': 21804.526},
#    {'satid': 7532,
#     'satname': 'THORAD DELTA 1 R/B',
#     'intDesignator': '1974-089D',
#     'launchDate': '1974-11-15',
#     'satlat': 41.6465,
#     'satlng': 76.1424,
#     'satalt': 1505.8616},
#    {'satid': 7940,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1972-058CF',
#     'launchDate': '1972-07-23',
#     'satlat': 45.0127,
#     'satlng': 76.6915,
#     'satalt': 986.0476},
#    {'satid': 8018,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1975-063D',
#     'launchDate': '1975-07-08',
#     'satlat': 32.1592,
#     'satlng': 41.245,
#     'satalt': 20482.0392},
#    {'satid': 9495,
#     'satname': 'COSMOS 862',
#     'intDesignator': '1976-105A',
#     'launchDate': '1976-10-22',
#     'satlat': 61.6046,
#     'satlng': 84.6528,
#     'satalt': 35704.7853},
#    {'satid': 9666,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025NK',
#     'launchDate': '1970-04-08',
#     'satlat': 36.2201,
#     'satlng': 76.7164,
#     'satalt': 961.1275},
#    {'satid': 9896,
#     'satname': 'COSMOS 862 DEB',
#     'intDesignator': '1976-105N',
#     'launchDate': '1976-10-22',
#     'satlat': 54.3366,
#     'satlng': 22.3812,
#     'satalt': 33550.2239},
#    {'satid': 9921,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1977-027D',
#     'launchDate': '1977-04-11',
#     'satlat': 39.7431,
#     'satlng': 113.8738,
#     'satalt': 34429.9037},
#    {'satid': 10455,
#     'satname': 'MOLNIYA 3-8',
#     'intDesignator': '1977-105A',
#     'launchDate': '1977-10-28',
#     'satlat': 61.2073,
#     'satlng': 69.9828,
#     'satalt': 39637.6257},
#    {'satid': 10485,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1977-105E',
#     'launchDate': '1977-10-28',
#     'satlat': 59.996,
#     'satlng': 128.0371,
#     'satalt': 39022.2131},
#    {'satid': 10684,
#     'satname': 'OPS 5111 (NAVSTAR 1)',
#     'intDesignator': '1978-020A',
#     'launchDate': '1978-02-22',
#     'satlat': 55.7524,
#     'satlng': 122.1285,
#     'satalt': 20428.9901},
#    {'satid': 10925,
#     'satname': 'MOLNIYA 1-40',
#     'intDesignator': '1978-055A',
#     'launchDate': '1978-06-02',
#     'satlat': 62.57,
#     'satlng': 90.6809,
#     'satalt': 37716.1446},
#    {'satid': 10949,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1978-055E',
#     'launchDate': '1978-06-02',
#     'satlat': 58.8084,
#     'satlng': 86.4435,
#     'satalt': 33104.1407},
#    {'satid': 11142,
#     'satname': 'ATLAS F R/B',
#     'intDesignator': '1978-112B',
#     'launchDate': '1978-12-11',
#     'satlat': 39.7884,
#     'satlng': 44.2072,
#     'satalt': 13946.1824},
#    {'satid': 11690,
#     'satname': 'OPS 5117 (NAVSTAR 5)',
#     'intDesignator': '1980-011A',
#     'launchDate': '1980-02-09',
#     'satlat': 48.1287,
#     'satlng': 21.2798,
#     'satalt': 21191.3359},
#    {'satid': 11699,
#     'satname': 'SL-8 R/B',
#     'intDesignator': '1980-012J',
#     'launchDate': '1980-02-11',
#     'satlat': 46.2015,
#     'satlng': 71.2375,
#     'satalt': 1628.9456},
#    {'satid': 11984,
#     'satname': 'DELTA 1 R/B(2)',
#     'intDesignator': '1967-026C',
#     'launchDate': '1967-03-23',
#     'satlat': 24.8925,
#     'satlng': 70.4766,
#     'satalt': 3874.0318},
#    {'satid': 12815,
#     'satname': 'COSMOS 931 DEB',
#     'intDesignator': '1977-068E',
#     'launchDate': '1977-07-20',
#     'satlat': 28.0569,
#     'satlng': 76.526,
#     'satalt': 25296.4243},
#    {'satid': 12857,
#     'satname': 'TANSEI 3 DEB',
#     'intDesignator': '1977-012H',
#     'launchDate': '1977-02-19',
#     'satlat': 47.3805,
#     'satlng': 71.6142,
#     'satalt': 1209.3454},
#    {'satid': 12940,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1981-108D',
#     'launchDate': '1981-10-31',
#     'satlat': 62.6669,
#     'satlng': 48.9052,
#     'satalt': 8447.7545},
#    {'satid': 13271,
#     'satname': 'COSMOS 1378',
#     'intDesignator': '1982-059A',
#     'launchDate': '1982-06-10',
#     'satlat': 40.7222,
#     'satlng': 69.568,
#     'satalt': 497.4321},
#    {'satid': 13302,
#     'satname': 'SL-8 R/B',
#     'intDesignator': '1982-066B',
#     'launchDate': '1982-06-29',
#     'satlat': 35.6195,
#     'satlng': 80.3955,
#     'satalt': 1031.2604},
#    {'satid': 13796,
#     'satname': 'COSMOS 1275 DEB',
#     'intDesignator': '1981-053GT',
#     'launchDate': '1981-06-04',
#     'satlat': 42.2658,
#     'satlng': 76.5268,
#     'satalt': 894.9395},
#    {'satid': 13875,
#     'satname': 'MOLNIYA 3-20',
#     'intDesignator': '1983-015A',
#     'launchDate': '1983-03-11',
#     'satlat': 52.4848,
#     'satlng': 93.0431,
#     'satalt': 20892.9892},
#    {'satid': 13890,
#     'satname': 'MOLNIYA 1-56',
#     'intDesignator': '1983-019A',
#     'launchDate': '1983-03-16',
#     'satlat': 61.349,
#     'satlng': 46.7773,
#     'satalt': 39468.3011},
#    {'satid': 13897,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1983-019D',
#     'launchDate': '1983-03-16',
#     'satlat': 55.0111,
#     'satlng': 63.1024,
#     'satalt': 36341.5992},
#    {'satid': 13910,
#     'satname': 'SL-6 DEB',
#     'intDesignator': '1981-088K',
#     'launchDate': '1981-09-11',
#     'satlat': 39.6244,
#     'satlng': 52.1893,
#     'satalt': 10979.0092},
#    {'satid': 14182,
#     'satname': 'COSMOS 1481',
#     'intDesignator': '1983-070A',
#     'launchDate': '1983-07-08',
#     'satlat': 41.4983,
#     'satlng': 40.0211,
#     'satalt': 35749.3508},
#    {'satid': 14191,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1983-070D',
#     'launchDate': '1983-07-08',
#     'satlat': 22.4196,
#     'satlng': 59.1103,
#     'satalt': 35462.6775},
#    {'satid': 14238,
#     'satname': 'TITAN 34B AGENA D R/B',
#     'intDesignator': '1983-078B',
#     'launchDate': '1983-07-31',
#     'satlat': 29.8985,
#     'satlng': 42.2749,
#     'satalt': 12140.0528},
#    {'satid': 14260,
#     'satname': 'COSMOS 1492 (GLONASS)',
#     'intDesignator': '1983-084C',
#     'launchDate': '1983-08-10',
#     'satlat': 54.8877,
#     'satlng': 64.0014,
#     'satalt': 19164.2609},
#    {'satid': 14264,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1983-084F',
#     'launchDate': '1983-08-10',
#     'satlat': 41.9611,
#     'satlng': 45.4155,
#     'satalt': 19169.6533},
#    {'satid': 14497,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1977-065FN',
#     'launchDate': '1977-07-14',
#     'satlat': 29.3416,
#     'satlng': 67.7464,
#     'satalt': 2351.1344},
#    {'satid': 14621,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1981-070K',
#     'launchDate': '1981-08-03',
#     'satlat': 63.5616,
#     'satlng': 87.7028,
#     'satalt': 12958.6134},
#    {'satid': 14884,
#     'satname': 'COSMOS 1547',
#     'intDesignator': '1984-033A',
#     'launchDate': '1984-04-04',
#     'satlat': 51.6209,
#     'satlng': 102.0315,
#     'satalt': 28466.4975},
#    {'satid': 14894,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1984-033D',
#     'launchDate': '1984-04-04',
#     'satlat': 37.5114,
#     'satlng': 69.0272,
#     'satalt': 34233.4232},
#    {'satid': 15245,
#     'satname': 'SBS 4 R/B(PAM-D)',
#     'intDesignator': '1984-093F',
#     'launchDate': '1984-08-30',
#     'satlat': 22.375,
#     'satlng': 58.5355,
#     'satalt': 25975.69},
#    {'satid': 15259,
#     'satname': 'COSMOS 1593 (GLONASS)',
#     'intDesignator': '1984-095A',
#     'launchDate': '1984-09-04',
#     'satlat': 63.3811,
#     'satlng': 94.0519,
#     'satalt': 19169.7252},
#    {'satid': 15620,
#     'satname': 'COSMOS 1638',
#     'intDesignator': '1985-023D',
#     'launchDate': '1985-03-21',
#     'satlat': 30.239,
#     'satlng': 76.0674,
#     'satalt': 1468.1103},
#    {'satid': 15697,
#     'satname': 'COSMOS 1650 (GLONASS)',
#     'intDesignator': '1985-037A',
#     'launchDate': '1985-05-17',
#     'satlat': 43.72,
#     'satlng': 46.799,
#     'satalt': 19058.1517},
#    {'satid': 15738,
#     'satname': 'MOLNIYA 3-24',
#     'intDesignator': '1985-040A',
#     'launchDate': '1985-05-29',
#     'satlat': 20.4778,
#     'satlng': 65.5278,
#     'satalt': 16866.0405},
#    {'satid': 15741,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1985-040D',
#     'launchDate': '1985-05-29',
#     'satlat': 56.47,
#     'satlng': 116.9904,
#     'satalt': 37447.7723},
#    {'satid': 15832,
#     'satname': 'MORELOS 1 R/B(PAM-D)',
#     'intDesignator': '1985-048F',
#     'launchDate': '1985-06-17',
#     'satlat': 25.4288,
#     'satlng': 57.5266,
#     'satalt': 15574.0151},
#    {'satid': 16276,
#     'satname': 'SATCOM K2',
#     'intDesignator': '1985-109D',
#     'launchDate': '1985-11-27',
#     'satlat': 3.2201,
#     'satlng': 52.7824,
#     'satalt': 35965.3129},
#    {'satid': 16650,
#     'satname': 'BRAZILSAT 2',
#     'intDesignator': '1986-026B',
#     'launchDate': '1986-03-28',
#     'satlat': -1.8431,
#     'satlng': 69.7329,
#     'satalt': 35983.3928},
#    {'satid': 16961,
#     'satname': 'COSMOS 1778 (GLONASS)',
#     'intDesignator': '1986-071A',
#     'launchDate': '1986-09-16',
#     'satlat': 27.7792,
#     'satlng': 33.0982,
#     'satalt': 19143.1853},
#    {'satid': 16962,
#     'satname': 'COSMOS 1779 (GLONASS)',
#     'intDesignator': '1986-071B',
#     'launchDate': '1986-09-16',
#     'satlat': 61.8227,
#     'satlng': 82.9785,
#     'satalt': 19117.776},
#    {'satid': 16963,
#     'satname': 'COSMOS 1780 (GLONASS)',
#     'intDesignator': '1986-071C',
#     'launchDate': '1986-09-16',
#     'satlat': 57.7884,
#     'satlng': 68.3611,
#     'satalt': 19139.805},
#    {'satid': 16993,
#     'satname': 'COSMOS 1783',
#     'intDesignator': '1986-075A',
#     'launchDate': '1986-10-03',
#     'satlat': 59.776,
#     'satlng': 96.8017,
#     'satalt': 13136.0433},
#    {'satid': 17328,
#     'satname': 'MOLNIYA 3-31',
#     'intDesignator': '1987-008A',
#     'launchDate': '1987-01-22',
#     'satlat': 12.0969,
#     'satlng': 71.0371,
#     'satalt': 13917.2553},
#    {'satid': 17563,
#     'satname': 'DELTA 1 R/B(2)',
#     'intDesignator': '1987-022C',
#     'launchDate': '1987-02-26',
#     'satlat': 17.6957,
#     'satlng': 107.4626,
#     'satalt': 21898.578},
#    {'satid': 18357,
#     'satname': 'COSMOS 1885 (GLONASS)',
#     'intDesignator': '1987-079C',
#     'launchDate': '1987-09-16',
#     'satlat': 11.5871,
#     'satlng': 77.6219,
#     'satalt': 19095.9007},
#    {'satid': 18606,
#     'satname': 'COSMOS 839 DEB',
#     'intDesignator': '1976-067BP',
#     'launchDate': '1976-07-08',
#     'satlat': 52.3576,
#     'satlng': 74.0286,
#     'satalt': 1729.3474},
#    {'satid': 18881,
#     'satname': 'COSMOS 1922',
#     'intDesignator': '1988-013A',
#     'launchDate': '1988-02-26',
#     'satlat': 60.5045,
#     'satlng': 93.0921,
#     'satalt': 7397.0446},
#    {'satid': 19059,
#     'satname': 'WESTFORD NEEDLES',
#     'intDesignator': '1963-014EG',
#     'launchDate': '1963-05-09',
#     'satlat': 50.579,
#     'satlng': 73.9148,
#     'satalt': 3724.4328},
#    {'satid': 19165,
#     'satname': 'COSMOS 1948 (GLONASS)',
#     'intDesignator': '1988-043C',
#     'launchDate': '1988-05-21',
#     'satlat': 57.8433,
#     'satlng': 69.1991,
#     'satalt': 19138.3352},
#    {'satid': 19168,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1988-043F',
#     'launchDate': '1988-05-21',
#     'satlat': 36.4954,
#     'satlng': 38.3433,
#     'satalt': 19133.0737},
#    {'satid': 19505,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1988-085E',
#     'launchDate': '1988-09-16',
#     'satlat': 19.125,
#     'satlng': 68.9857,
#     'satalt': 19095.5858},
#    {'satid': 19754,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1989-001F',
#     'launchDate': '1989-01-10',
#     'satlat': 51.4316,
#     'satlng': 54.1892,
#     'satalt': 19145.4183},
#    {'satid': 19874,
#     'satname': 'JCSAT 1',
#     'intDesignator': '1989-020A',
#     'launchDate': '1989-03-06',
#     'satlat': 3.5322,
#     'satlng': 52.4128,
#     'satalt': 36000.9842},
#    {'satid': 19976,
#     'satname': 'USA 37',
#     'intDesignator': '1989-035A',
#     'launchDate': '1989-05-10',
#     'satlat': -0.5148,
#     'satlng': 66.0458,
#     'satalt': 37565.4256},
#    {'satid': 20168,
#     'satname': 'TVSAT 2',
#     'intDesignator': '1989-062A',
#     'launchDate': '1989-08-08',
#     'satlat': 4.6248,
#     'satlng': 50.1656,
#     'satalt': 35905.6588},
#    {'satid': 20203,
#     'satname': 'USA 44',
#     'intDesignator': '1989-069B',
#     'launchDate': '1989-09-04',
#     'satlat': -1.8318,
#     'satlng': 83.0186,
#     'satalt': 36163.9646},
#    {'satid': 20253,
#     'satname': 'FLTSATCOM 8 (USA 46)',
#     'intDesignator': '1989-077A',
#     'launchDate': '1989-09-25',
#     'satlat': -2.5082,
#     'satlng': 71.6613,
#     'satalt': 35783.7239},
#    {'satid': 20413,
#     'satname': 'SL-12 R/B',
#     'intDesignator': '1983-020D',
#     'launchDate': '1983-03-23',
#     'satlat': 14.3483,
#     'satlng': 118.4982,
#     'satalt': 152619.7176},
#    {'satid': 20473,
#     'satname': 'STTW-4',
#     'intDesignator': '1990-011A',
#     'launchDate': '1990-02-04',
#     'satlat': 1.0555,
#     'satlng': 55.2225,
#     'satalt': 35801.5704},
#    {'satid': 20619,
#     'satname': 'COSMOS 2079 (GLONASS)',
#     'intDesignator': '1990-045A',
#     'launchDate': '1990-05-19',
#     'satlat': 45.05,
#     'satlng': 46.8157,
#     'satalt': 19118.0911},
#    {'satid': 20631,
#     'satname': 'SL-12 R/B(AUX MOTOR)',
#     'intDesignator': '1990-045G',
#     'launchDate': '1990-05-19',
#     'satlat': 40.2258,
#     'satlng': 43.9741,
#     'satalt': 17581.6602},
#    {'satid': 20643,
#     'satname': 'INSAT 1D',
#     'intDesignator': '1990-051A',
#     'launchDate': '1990-06-12',
#     'satlat': -1.2404,
#     'satlng': 71.2253,
#     'satalt': 35755.5434},
#    {'satid': 21007,
#     'satname': 'COSMOS 2110 (GLONASS)',
#     'intDesignator': '1990-110B',
#     'launchDate': '1990-12-08',
#     'satlat': 62.7986,
#     'satlng': 127.3778,
#     'satalt': 19149.8974},
#    {'satid': 21056,
#     'satname': 'EUTELSAT 2-F2',
#     'intDesignator': '1991-003B',
#     'launchDate': '1991-01-15',
#     'satlat': 1.012,
#     'satlng': 69.3698,
#     'satalt': 36167.0887},
#    {'satid': 21118,
#     'satname': 'MOLNIYA 1-80',
#     'intDesignator': '1991-012A',
#     'launchDate': '1991-02-15',
#     'satlat': 32.4339,
#     'satlng': 75.4048,
#     'satalt': 23118.2931},
#    {'satid': 21196,
#     'satname': 'MOLNIYA 3-40',
#     'intDesignator': '1991-022A',
#     'launchDate': '1991-03-22',
#     'satlat': 26.6188,
#     'satlng': 72.4383,
#     'satalt': 18722.4661},
#    {'satid': 21253,
#     'satname': 'SL-8 DEB',
#     'intDesignator': '1991-009BL',
#     'launchDate': '1991-02-12',
#     'satlat': 51.5907,
#     'satlng': 78.6424,
#     'satalt': 1688.8449},
#    {'satid': 21278,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1975-052P',
#     'launchDate': '1975-06-12',
#     'satlat': 44.2944,
#     'satlng': 73.993,
#     'satalt': 1656.8262},
#    {'satid': 21426,
#     'satname': 'MOLNIYA 1-81',
#     'intDesignator': '1991-043A',
#     'launchDate': '1991-06-18',
#     'satlat': 49.9555,
#     'satlng': 76.2536,
#     'satalt': 27362.3008},
#    {'satid': 21429,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1991-043D',
#     'launchDate': '1991-06-18',
#     'satlat': 48.8383,
#     'satlng': 30.1518,
#     'satalt': 24798.9891},
#    {'satid': 21706,
#     'satname': 'MOLNIYA 3-41',
#     'intDesignator': '1991-065A',
#     'launchDate': '1991-09-17',
#     'satlat': 47.3947,
#     'satlng': 132.1941,
#     'satalt': 29154.4504},
#    {'satid': 21814,
#     'satname': 'INMARSAT 2-F3',
#     'intDesignator': '1991-084B',
#     'launchDate': '1991-12-16',
#     'satlat': 5.9692,
#     'satlng': 53.8099,
#     'satalt': 37042.4374},
#    {'satid': 21819,
#     'satname': 'INTERCOSMOS 25',
#     'intDesignator': '1991-086A',
#     'launchDate': '1991-12-18',
#     'satlat': 32.3608,
#     'satlng': 74.7705,
#     'satalt': 2049.2956},
#    {'satid': 21826,
#     'satname': 'SL-14 DEB',
#     'intDesignator': '1991-086C',
#     'launchDate': '1991-12-18',
#     'satlat': 32.6789,
#     'satlng': 76.809,
#     'satalt': 960.338},
#    {'satid': 21855,
#     'satname': 'COSMOS 2179 (GLONASS)',
#     'intDesignator': '1992-005C',
#     'launchDate': '1992-01-29',
#     'satlat': 52.9895,
#     'satlng': 56.1959,
#     'satalt': 19163.6164},
#    {'satid': 21858,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1992-005F',
#     'launchDate': '1992-01-29',
#     'satlat': 53.5934,
#     'satlng': 56.8123,
#     'satalt': 19113.3742},
#    {'satid': 21940,
#     'satname': 'INMARSAT 2-F4',
#     'intDesignator': '1992-021B',
#     'launchDate': '1992-04-15',
#     'satlat': -0.6345,
#     'satlng': 85.0618,
#     'satalt': 36451.0436},
#    {'satid': 22044,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1992-043D',
#     'launchDate': '1992-07-14',
#     'satlat': -3.0349,
#     'satlng': 69.315,
#     'satalt': 36429.3525},
#    {'satid': 22066,
#     'satname': 'SL-12 R/B(AUX MOTOR)',
#     'intDesignator': '1992-047G',
#     'launchDate': '1992-07-30',
#     'satlat': 63.8781,
#     'satlng': 121.6432,
#     'satalt': 16142.147},
#    {'satid': 22098,
#     'satname': 'DELTA 2 R/B(2)',
#     'intDesignator': '1992-057C',
#     'launchDate': '1992-08-31',
#     'satlat': 19.1395,
#     'satlng': 58.8928,
#     'satalt': 35691.2613},
#    {'satid': 22248,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1992-082D',
#     'launchDate': '1992-11-27',
#     'satlat': 2.0915,
#     'satlng': 51.5696,
#     'satalt': 36457.2691},
#    {'satid': 22513,
#     'satname': 'COSMOS 2236 (GLONASS)',
#     'intDesignator': '1993-010B',
#     'launchDate': '1993-02-17',
#     'satlat': 58.9351,
#     'satlng': 69.6758,
#     'satalt': 19127.0235},
#    {'satid': 22517,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1993-010F',
#     'launchDate': '1993-02-17',
#     'satlat': 58.1043,
#     'satlng': 66.1296,
#     'satalt': 19164.7856},
#    {'satid': 22581,
#     'satname': 'NAVSTAR 31 (USA 90)',
#     'intDesignator': '1993-017A',
#     'launchDate': '1993-03-30',
#     'satlat': 21.2166,
#     'satlng': 50.98,
#     'satalt': 21262.8932},
#    {'satid': 22657,
#     'satname': 'NAVSTAR 32 (USA 91)',
#     'intDesignator': '1993-032A',
#     'launchDate': '1993-05-13',
#     'satlat': 22.4255,
#     'satlng': 32.0699,
#     'satalt': 21402.5182},
#    {'satid': 22694,
#     'satname': 'HGS 4 (GALAXY 4)',
#     'intDesignator': '1993-039A',
#     'launchDate': '1993-06-25',
#     'satlat': -1.2289,
#     'satlng': 72.2706,
#     'satalt': 35780.5745},
#    {'satid': 22719,
#     'satname': 'USA 93',
#     'intDesignator': '1993-046A',
#     'launchDate': '1993-07-19',
#     'satlat': 5.9567,
#     'satlng': 55.6501,
#     'satalt': 36148.1202},
#    {'satid': 22836,
#     'satname': 'RADUGA 30',
#     'intDesignator': '1993-062A',
#     'launchDate': '1993-09-30',
#     'satlat': -2.6868,
#     'satlng': 69.77,
#     'satalt': 35802.1953},
#    {'satid': 22930,
#     'satname': 'DIRECTV 1 (DBS 1)',
#     'intDesignator': '1993-078A',
#     'launchDate': '1993-12-18',
#     'satlat': 1.4053,
#     'satlng': 94.3429,
#     'satalt': 36123.8474},
#    {'satid': 22949,
#     'satname': 'MOLNIYA 1-87',
#     'intDesignator': '1993-079A',
#     'launchDate': '1993-12-22',
#     'satlat': 58.7511,
#     'satlng': 85.6218,
#     'satalt': 25586.6572},
#    {'satid': 22952,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1993-079D',
#     'launchDate': '1993-12-22',
#     'satlat': 63.2732,
#     'satlng': 54.3957,
#     'satalt': 32919.323},
#    {'satid': 22981,
#     'satname': 'RADUGA 1-3',
#     'intDesignator': '1994-008A',
#     'launchDate': '1994-02-05',
#     'satlat': -1.7938,
#     'satlng': 67.5107,
#     'satalt': 35813.5108},
#    {'satid': 22989,
#     'satname': 'TITAN 4 CENTAUR R/B',
#     'intDesignator': '1994-009B',
#     'launchDate': '1994-02-07',
#     'satlat': 7.5559,
#     'satlng': 67.5681,
#     'satalt': 35663.0644},
#    {'satid': 23223,
#     'satname': 'USA 105',
#     'intDesignator': '1994-054A',
#     'launchDate': '1994-08-27',
#     'satlat': -0.92,
#     'satlng': 84.8759,
#     'satalt': 35698.5687},
#    {'satid': 23356,
#     'satname': 'USA 40 R/B DEB',
#     'intDesignator': '1989-061AC',
#     'launchDate': '1989-08-08',
#     'satlat': 54.3325,
#     'satlng': 103.4515,
#     'satalt': 5615.662},
#    {'satid': 23372,
#     'satname': 'USA 40 R/B DEB',
#     'intDesignator': '1989-061AU',
#     'launchDate': '1989-08-08',
#     'satlat': 20.8561,
#     'satlng': 81.3759,
#     'satalt': 4454.1973},
#    {'satid': 23388,
#     'satname': 'USA 40 R/B DEB',
#     'intDesignator': '1989-061BL',
#     'launchDate': '1989-08-08',
#     'satlat': 33.335,
#     'satlng': 86.1688,
#     'satalt': 4560.6414},
#    {'satid': 23413,
#     'satname': 'TELSTAR 11 (ORION 1)',
#     'intDesignator': '1994-079A',
#     'launchDate': '1994-11-29',
#     'satlat': 5.2392,
#     'satlng': 60.9468,
#     'satalt': 36344.2225},
#    {'satid': 23429,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1994-082D',
#     'launchDate': '1994-12-16',
#     'satlat': 4.6243,
#     'satlng': 49.1071,
#     'satalt': 35619.2865},
#    {'satid': 23448,
#     'satname': 'RADUGA 32',
#     'intDesignator': '1994-087A',
#     'launchDate': '1994-12-28',
#     'satlat': -2.0101,
#     'satlng': 71.0359,
#     'satalt': 35777.3771},
#    {'satid': 23461,
#     'satname': 'INTELSAT 704',
#     'intDesignator': '1995-001A',
#     'launchDate': '1995-01-10',
#     'satlat': 4.1989,
#     'satlng': 75.3963,
#     'satalt': 36090.5854},
#    {'satid': 23484,
#     'satname': 'SL-19 DEB',
#     'intDesignator': '1994-085G',
#     'launchDate': '1994-12-26',
#     'satlat': 39.7626,
#     'satlng': 58.1699,
#     'satalt': 1981.0328},
#    {'satid': 23512,
#     'satname': 'COSMOS 2308 (GLONASS)',
#     'intDesignator': '1995-009B',
#     'launchDate': '1995-03-07',
#     'satlat': 12.7987,
#     'satlng': 62.2655,
#     'satalt': 19140.8757},
#    {'satid': 23516,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1995-009F',
#     'launchDate': '1995-03-07',
#     'satlat': 53.4505,
#     'satlng': 28.4683,
#     'satalt': 19154.0885},
#    {'satid': 23528,
#     'satname': 'INTELSAT 705',
#     'intDesignator': '1995-013A',
#     'launchDate': '1995-03-22',
#     'satlat': 7.0212,
#     'satlng': 47.3352,
#     'satalt': 36133.9493},
#    {'satid': 23647,
#     'satname': 'TITAN 34B DEB',
#     'intDesignator': '1981-038C',
#     'launchDate': '1981-04-24',
#     'satlat': 59.5616,
#     'satlng': 46.9418,
#     'satalt': 28793.2977},
#    {'satid': 23680,
#     'satname': 'LUCH 1',
#     'intDesignator': '1995-054A',
#     'launchDate': '1995-10-11',
#     'satlat': -0.4282,
#     'satlng': 73.6962,
#     'satalt': 35798.5926},
#    {'satid': 23715,
#     'satname': 'ISO',
#     'intDesignator': '1995-062A',
#     'launchDate': '1995-11-17',
#     'satlat': 0.7715,
#     'satlng': 62.8287,
#     'satalt': 67020.1889},
#    {'satid': 23732,
#     'satname': 'ARIANE 44L+3 R/B',
#     'intDesignator': '1995-067C',
#     'launchDate': '1995-12-06',
#     'satlat': 5.7682,
#     'satlng': 64.4776,
#     'satalt': 21187.2132},
#    {'satid': 23816,
#     'satname': 'INTELSAT 707',
#     'intDesignator': '1996-015A',
#     'launchDate': '1996-03-14',
#     'satlat': 5.4334,
#     'satlng': 59.797,
#     'satalt': 36583.3454},
#    {'satid': 23880,
#     'satname': 'GORIZONT 32',
#     'intDesignator': '1996-034A',
#     'launchDate': '1996-05-25',
#     'satlat': -2.8351,
#     'satlng': 78.2963,
#     'satalt': 35862.8292},
#    {'satid': 23943,
#     'satname': 'APSTAR 1A',
#     'intDesignator': '1996-039A',
#     'launchDate': '1996-07-03',
#     'satlat': 6.2334,
#     'satlng': 52.3524,
#     'satalt': 36184.8291},
#    {'satid': 23948,
#     'satname': 'ARABSAT 2A',
#     'intDesignator': '1996-040A',
#     'launchDate': '1996-07-09',
#     'satlat': 3.9805,
#     'satlng': 62.4061,
#     'satalt': 36087.6955},
#    {'satid': 24209,
#     'satname': 'TELECOM 2D',
#     'intDesignator': '1996-044B',
#     'launchDate': '1996-08-08',
#     'satlat': 4.8919,
#     'satlng': 66.1882,
#     'satalt': 36378.3061},
#    {'satid': 24293,
#     'satname': 'INTERBALL AURORA',
#     'intDesignator': '1996-050C',
#     'launchDate': '1996-08-29',
#     'satlat': 25.0571,
#     'satlng': 48.3368,
#     'satalt': 15172.5446},
#    {'satid': 24296,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1996-050F',
#     'launchDate': '1996-08-29',
#     'satlat': 49.5023,
#     'satlng': 94.5944,
#     'satalt': 18705.6547},
#    {'satid': 24435,
#     'satname': 'EXPRESS 2',
#     'intDesignator': '1996-058A',
#     'launchDate': '1996-09-26',
#     'satlat': 4.1198,
#     'satlng': 50.9112,
#     'satalt': 35842.1027},
#    {'satid': 24438,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1996-058D',
#     'launchDate': '1996-09-26',
#     'satlat': -1.9704,
#     'satlng': 71.066,
#     'satalt': 35839.3445},
#    {'satid': 24665,
#     'satname': 'EUTE 48A (HB2)',
#     'intDesignator': '1996-067A',
#     'launchDate': '1996-11-21',
#     'satlat': 6.2109,
#     'satlng': 57.8968,
#     'satalt': 36309.0347},
#    {'satid': 24675,
#     'satname': 'ATLAS 2A CENTAUR R/B',
#     'intDesignator': '1996-070B',
#     'launchDate': '1996-12-18',
#     'satlat': 20.8531,
#     'satlng': 51.6541,
#     'satalt': 24981.7547},
#    {'satid': 24732,
#     'satname': 'INTELSAT 26 (JCSAT 4)',
#     'intDesignator': '1997-007A',
#     'launchDate': '1997-02-17',
#     'satlat': 5.2995,
#     'satlng': 63.971,
#     'satalt': 35784.4079},
#    {'satid': 24768,
#     'satname': 'THAICOM 3',
#     'intDesignator': '1997-016A',
#     'launchDate': '1997-04-16',
#     'satlat': 3.6256,
#     'satlng': 74.426,
#     'satalt': 36565.1218},
#    {'satid': 24786,
#     'satname': 'GOES 10',
#     'intDesignator': '1997-019A',
#     'launchDate': '1997-04-25',
#     'satlat': 1.1107,
#     'satlng': 84.7922,
#     'satalt': 36006.2847},
#    {'satid': 24833,
#     'satname': 'SL-12 DEB',
#     'intDesignator': '1997-028F',
#     'launchDate': '1997-06-06',
#     'satlat': 41.718,
#     'satlng': 71.833,
#     'satalt': 2271.3129},
#    {'satid': 24871,
#     'satname': 'IRIDIUM 920',
#     'intDesignator': '1997-034C',
#     'launchDate': '1997-07-09',
#     'satlat': 46.4441,
#     'satlng': 71.8837,
#     'satalt': 764.1354},
#    {'satid': 24897,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1997-041D',
#     'launchDate': '1997-08-14',
#     'satlat': -0.0606,
#     'satlng': 70.4664,
#     'satalt': 35329.0813},
#    {'satid': 24957,
#     'satname': 'NSS 5 (INTELSAT 803)',
#     'intDesignator': '1997-053A',
#     'launchDate': '1997-09-23',
#     'satlat': 5.894,
#     'satlng': 50.5397,
#     'satalt': 35782.489},
#    {'satid': 25021,
#     'satname': 'IABS R/B',
#     'intDesignator': '1997-065C',
#     'launchDate': '1997-10-25',
#     'satlat': 1.6168,
#     'satlng': 58.6387,
#     'satalt': 35491.4724},
#    {'satid': 25045,
#     'satname': 'KUPON',
#     'intDesignator': '1997-070A',
#     'launchDate': '1997-11-12',
#     'satlat': 2.2852,
#     'satlng': 58.2896,
#     'satalt': 35804.1347},
#    {'satid': 25050,
#     'satname': 'INDOSTAR 1',
#     'intDesignator': '1997-071B',
#     'launchDate': '1997-11-11',
#     'satlat': 7.8699,
#     'satlng': 43.2317,
#     'satalt': 35817.1121},
#    {'satid': 25067,
#     'satname': 'JCSAT 5',
#     'intDesignator': '1997-075A',
#     'launchDate': '1997-12-02',
#     'satlat': 3.0809,
#     'satlng': 85.7688,
#     'satalt': 36178.5451},
#    {'satid': 25071,
#     'satname': 'ASTRA 1G',
#     'intDesignator': '1997-076A',
#     'launchDate': '1997-12-02',
#     'satlat': 4.5427,
#     'satlng': 63.2683,
#     'satalt': 35780.3044},
#    {'satid': 25086,
#     'satname': 'GALAXY 8',
#     'intDesignator': '1997-078A',
#     'launchDate': '1997-12-08',
#     'satlat': 3.1344,
#     'satlng': 66.7952,
#     'satalt': 35984.7154},
#    {'satid': 25149,
#     'satname': 'ATLAS 2A R/B',
#     'intDesignator': '1998-005B',
#     'launchDate': '1998-01-29',
#     'satlat': 52.7822,
#     'satlng': 27.1277,
#     'satalt': 35623.5966},
#    {'satid': 25237,
#     'satname': 'EUTE 16B (HB 4)',
#     'intDesignator': '1998-013A',
#     'launchDate': '1998-02-27',
#     'satlat': 3.5788,
#     'satlng': 85.6109,
#     'satalt': 36366.6533},
#    {'satid': 25312,
#     'satname': 'BSAT-1B',
#     'intDesignator': '1998-024B',
#     'launchDate': '1998-04-28',
#     'satlat': 4.6469,
#     'satlng': 77.6102,
#     'satalt': 36113.1275},
#    {'satid': 25315,
#     'satname': 'COSMOS 2350',
#     'intDesignator': '1998-025A',
#     'launchDate': '1998-04-29',
#     'satlat': -1.0564,
#     'satlng': 79.4499,
#     'satalt': 35794.7737},
#    {'satid': 25339,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1996-053D',
#     'launchDate': '1996-09-06',
#     'satlat': -1.0591,
#     'satlng': 78.7489,
#     'satalt': 36389.317},
#    {'satid': 25358,
#     'satname': 'THOR 3',
#     'intDesignator': '1998-035A',
#     'launchDate': '1998-06-10',
#     'satlat': 4.2292,
#     'satlng': 77.7552,
#     'satalt': 36191.6198},
#    {'satid': 25460,
#     'satname': 'ST 1',
#     'intDesignator': '1998-049A',
#     'launchDate': '1998-08-25',
#     'satlat': 2.2448,
#     'satlng': 97.2208,
#     'satalt': 36213.0705},
#    {'satid': 25492,
#     'satname': 'SIRIUS 3',
#     'intDesignator': '1998-056B',
#     'launchDate': '1998-10-05',
#     'satlat': 5.053,
#     'satlng': 66.563,
#     'satalt': 36152.2942},
#    {'satid': 25495,
#     'satname': 'EUTE 25A (HB 5)',
#     'intDesignator': '1998-057A',
#     'launchDate': '1998-10-09',
#     'satlat': 5.7025,
#     'satlng': 52.1356,
#     'satalt': 36317.6719},
#    {'satid': 25516,
#     'satname': 'AMC-5 (GE-5)',
#     'intDesignator': '1998-063B',
#     'launchDate': '1998-10-28',
#     'satlat': 4.4432,
#     'satlng': 74.9365,
#     'satalt': 36068.2471},
#    {'satid': 25548,
#     'satname': 'DELTA 2 R/B(2)',
#     'intDesignator': '1998-068C',
#     'launchDate': '1998-11-22',
#     'satlat': 13.389,
#     'satlng': 78.1355,
#     'satalt': 13924.7194},
#    {'satid': 25588,
#     'satname': 'TITAN 34B AGENA D DEB',
#     'intDesignator': '1983-078E',
#     'launchDate': '1983-07-31',
#     'satlat': 53.0403,
#     'satlng': 27.1805,
#     'satalt': 29317.5493},
#    {'satid': 25593,
#     'satname': 'COSMOS 2364 (GLONASS)',
#     'intDesignator': '1998-077A',
#     'launchDate': '1998-12-30',
#     'satlat': 63.3931,
#     'satlng': 97.1432,
#     'satalt': 19083.1366},
#    {'satid': 25634,
#     'satname': 'ARGOS',
#     'intDesignator': '1999-008A',
#     'launchDate': '1999-02-23',
#     'satlat': 34.7771,
#     'satlng': 75.5093,
#     'satalt': 824.2571},
#    {'satid': 25645,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1999-010D',
#     'launchDate': '1999-02-28',
#     'satlat': 5.3306,
#     'satlng': 57.819,
#     'satalt': 36495.0356},
#    {'satid': 25673,
#     'satname': 'EUTE 21A (EUTE W3)',
#     'intDesignator': '1999-018A',
#     'launchDate': '1999-04-12',
#     'satlat': 5.5568,
#     'satlng': 56.5723,
#     'satalt': 36320.3616},
#    {'satid': 25684,
#     'satname': 'SL-12 DEB',
#     'intDesignator': '1985-118X',
#     'launchDate': '1985-12-24',
#     'satlat': 53.4258,
#     'satlng': 63.3941,
#     'satalt': 3262.9716},
#    {'satid': 25785,
#     'satname': 'ASTRA 1H',
#     'intDesignator': '1999-033A',
#     'launchDate': '1999-06-18',
#     'satlat': 3.1728,
#     'satlng': 89.4914,
#     'satalt': 36142.8547},
#    {'satid': 25847,
#     'satname': 'MOLNIYA 3-50',
#     'intDesignator': '1999-036A',
#     'launchDate': '1999-07-08',
#     'satlat': 50.039,
#     'satlng': 82.6383,
#     'satalt': 31422.36},
#    {'satid': 25850,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1999-036D',
#     'launchDate': '1999-07-08',
#     'satlat': 55.7782,
#     'satlng': 128.9028,
#     'satalt': 35540.8657},
#    {'satid': 25880,
#     'satname': 'TELKOM 1',
#     'intDesignator': '1999-042A',
#     'launchDate': '1999-08-12',
#     'satlat': 2.6421,
#     'satlng': 63.5737,
#     'satalt': 35797.7356},
#    {'satid': 25894,
#     'satname': 'ABS-7 (KOREASAT 3)',
#     'intDesignator': '1999-046A',
#     'launchDate': '1999-09-04',
#     'satlat': 1.2376,
#     'satlng': 85.1594,
#     'satalt': 35812.4749},
#    {'satid': 25922,
#     'satname': 'GALAXY 27 (TELSTAR 7)',
#     'intDesignator': '1999-052A',
#     'launchDate': '1999-09-25',
#     'satlat': 4.9236,
#     'satlng': 64.8687,
#     'satalt': 36180.9584},
#    {'satid': 25936,
#     'satname': 'CZ-3 DEB',
#     'intDesignator': '1986-010D',
#     'launchDate': '1986-02-01',
#     'satlat': 27.9773,
#     'satlng': 90.1149,
#     'satalt': 15478.2144},
#    {'satid': 26090,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '2000-011B',
#     'launchDate': '2000-02-12',
#     'satlat': 16.5974,
#     'satlng': 75.1638,
#     'satalt': 29116.2518},
#    {'satid': 26298,
#     'satname': 'GALAXY 4R',
#     'intDesignator': '2000-020A',
#     'launchDate': '2000-04-19',
#     'satlat': 4.5843,
#     'satlng': 67.2728,
#     'satalt': 35904.1977},
#    {'satid': 26360,
#     'satname': 'NAVSTAR 47 (USA 150)',
#     'intDesignator': '2000-025A',
#     'launchDate': '2000-05-11',
#     'satlat': 48.2186,
#     'satlng': 103.2198,
#     'satalt': 20087.3953},
#    {'satid': 26369,
#     'satname': 'EUTE 36A (EUTE W4)',
#     'intDesignator': '2000-028A',
#     'launchDate': '2000-05-24',
#     'satlat': 3.7848,
#     'satlng': 48.194,
#     'satalt': 35784.0164},
#    {'satid': 26388,
#     'satname': 'TDRS 8',
#     'intDesignator': '2000-034A',
#     'launchDate': '2000-06-30',
#     'satlat': 2.2193,
#     'satlng': 89.4885,
#     'satalt': 35845.5559},
#    {'satid': 26394,
#     'satname': 'COSMOS 2371',
#     'intDesignator': '2000-036A',
#     'launchDate': '2000-07-04',
#     'satlat': 0.3878,
#     'satlng': 76.9341,
#     'satalt': 35793.493},
#    {'satid': 26477,
#     'satname': 'RADUGA 1-5',
#     'intDesignator': '2000-049A',
#     'launchDate': '2000-08-28',
#     'satlat': 1.1971,
#     'satlng': 73.9152,
#     'satalt': 35786.5804},
#    {'satid': 26486,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '2000-051D',
#     'launchDate': '2000-09-05',
#     'satlat': 62.5711,
#     'satlng': 12.868,
#     'satalt': 50866.6417},
#    {'satid': 26565,
#     'satname': 'COSMOS 2376 (GLONASS)',
#     'intDesignator': '2000-063B',
#     'launchDate': '2000-10-13',
#     'satlat': 17.4881,
#     'satlng': 70.3802,
#     'satalt': 19134.4341},
#    {'satid': 26590,
#     'satname': 'INTELSAT 12 (PAS 12)',
#     'intDesignator': '2000-068A',
#     'launchDate': '2000-10-29',
#     'satlat': 3.245,
#     'satlng': 64.2231,
#     'satalt': 35782.3583},
#    {'satid': 26599,
#     'satname': 'BEIDOU 1',
#     'intDesignator': '2000-069A',
#     'launchDate': '2000-10-30',
#     'satlat': 7.3422,
#     'satlng': 48.4275,
#     'satalt': 36234.0203},
#    {'satid': 26629,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '2000-077D',
#     'launchDate': '2000-11-30',
#     'satlat': 23.3768,
#     'satlng': 45.8645,
#     'satalt': 31233.6725},
#    {'satid': 26635,
#     'satname': 'USA 155',
#     'intDesignator': '2000-080A',
#     'launchDate': '2000-12-06',
#     'satlat': 0.1839,
#     'satlng': 85.2309,
#     'satalt': 35773.7226},
#    {'satid': 26638,
#     'satname': 'ASTRA 2D',
#     'intDesignator': '2000-081A',
#     'launchDate': '2000-12-20',
#     'satlat': 5.4754,
#     'satlng': 57.3436,
#     'satalt': 35783.9654},
#    {'satid': 26684,
#     'satname': 'ARIANE 1 DEB',
#     'intDesignator': '1985-056J',
#     'launchDate': '1985-07-02',
#     'satlat': 3.842,
#     'satlng': 74.8815,
#     'satalt': 19315.9652},
#    {'satid': 26765,
#     'satname': 'TITAN 3C TRANSTAGE DEB',
#     'intDesignator': '1965-108AU',
#     'launchDate': '1965-12-21',
#     'satlat': 6.4401,
#     'satlng': 97.3532,
#     'satalt': 28339.5757},
#    {'satid': 26766,
#     'satname': 'INTELSAT 10 (PAS 10)',
#     'intDesignator': '2001-019A',
#     'launchDate': '2001-05-15',
#     'satlat': 4.2774,
#     'satlng': 47.462,
#     'satalt': 35786.7453},
#    {'satid': 26779,
#     'satname': 'TITAN 3C TRANSTAGE DEB',
#     'intDesignator': '1965-108AX',
#     'launchDate': '1965-12-21',
#     'satlat': 26.6435,
#     'satlng': 89.8457,
#     'satalt': 5946.5913},
#    {'satid': 26883,
#     'satname': 'IUS R/B(2)',
#     'intDesignator': '2001-033D',
#     'launchDate': '2001-08-06',
#     'satlat': 4.0198,
#     'satlng': 64.9135,
#     'satalt': 35936.933},
#    {'satid': 26948,
#     'satname': 'USA 162',
#     'intDesignator': '2001-046A',
#     'launchDate': '2001-10-11',
#     'satlat': 3.631,
#     'satlng': 80.7385,
#     'satalt': 35794.5408},
#    {'satid': 26988,
#     'satname': 'COSMOS 2381 (GLONASS)',
#     'intDesignator': '2001-053B',
#     'launchDate': '2001-12-01',
#     'satlat': 45.0221,
#     'satlng': 36.7411,
#     'satalt': 19237.346},
#    {'satid': 27371,
#     'satname': 'PEGASUS R/B',
#     'intDesignator': '2002-004B',
#     'launchDate': '2002-02-05',
#     'satlat': 38.1464,
#     'satlng': 76.3618,
#     'satalt': 543.697},
#    {'satid': 27441,
#     'satname': 'EXPRESS 4A',
#     'intDesignator': '2002-029A',
#     'launchDate': '2002-06-10',
#     'satlat': 4.8118,
#     'satlng': 69.7959,
#     'satalt': 36097.2927},
#    {'satid': 27499,
#     'satname': 'EUTE HOT BIRD 13A (HB 6)',
#     'intDesignator': '2002-038A',
#     'launchDate': '2002-08-21',
#     'satlat': 3.0348,
#     'satlng': 81.3999,
#     'satalt': 36055.9799},
#    {'satid': 27513,
#     'satname': 'INTELSAT 906',
#     'intDesignator': '2002-041A',
#     'launchDate': '2002-09-06',
#     'satlat': 0.6865,
#     'satlng': 64.0993,
#     'satalt': 35782.464},
#    {'satid': 27601,
#     'satname': 'H-2A R/B',
#     'intDesignator': '2002-056E',
#     'launchDate': '2002-12-14',
#     'satlat': 40.4955,
#     'satlng': 72.4718,
#     'satalt': 740.5348},
#    {'satid': 27620,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '2002-060D',
#     'launchDate': '2002-12-25',
#     'satlat': 29.1535,
#     'satlng': 64.6249,
#     'satalt': 19103.841},
#    {'satid': 27692,
#     'satname': 'DELTA 4 R/B',
#     'intDesignator': '2003-008B',
#     'launchDate': '2003-03-11',
#     'satlat': 23.5464,
#     'satlng': 113.5291,
#     'satalt': 21940.3593},
#    {'satid': 27731,
#     'satname': 'M-3H DEB',
#     'intDesignator': '1978-087C',
#     'launchDate': '1978-09-16',
#     'satlat': 14.331,
#     'satlng': 73.0073,
#     'satalt': 10103.3699},
#    {'satid': 27745,
#     'satname': 'SL-8 DEB',
#     'intDesignator': '1991-009DA',
#     'launchDate': '1991-02-12',
#     'satlat': 43.7357,
#     'satlng': 72.3332,
#     'satalt': 1446.9172},
#    {'satid': 27780,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '2003-015F',
#     'launchDate': '2003-04-24',
#     'satlat': 0.484,
#     'satlng': 87.3646,
#     'satalt': 35874.0425},
#    {'satid': 27805,
#     'satname': 'SL-12 DEB',
#     'intDesignator': '1992-047L',
#     'launchDate': '1992-07-30',
#     'satlat': 43.5507,
#     'satlng': 96.3264,
#     'satalt': 6185.8113},
#    {'satid': 27866,
#     'satname': 'TITAN 3C TRANSTAGE DEB',
#     'intDesignator': '1965-108BM',
#     'launchDate': '1965-12-21',
#     'satlat': 23.3554,
#     'satlng': 50.8921,
#     'satalt': 20110.2468},
#    {'satid': 27907,
#     'satname': 'COSMOS 1481 DEB',
#     'intDesignator': '1983-070J',
#     'launchDate': '1983-07-08',
#     'satlat': 15.4234,
#     'satlng': 36.272,
#     'satalt': 36129.524},
#    {'satid': 27937,
#     'satname': 'USA 171',
#     'intDesignator': '2003-041A',
#     'launchDate': '2003-09-09',
#     'satlat': 6.9932,
#     'satlng': 72.3649,
#     'satalt': 35773.0411},
#    {'satid': 28094,
#     'satname': 'YAMAL 201',
#     'intDesignator': '2003-053B',
#     'launchDate': '2003-11-24',
#     'satlat': 3.4562,
#     'satlng': 85.4288,
#     'satalt': 35800.0367},
#    {'satid': 28113,
#     'satname': 'COSMOS 2402 (GLONASS)',
#     'intDesignator': '2003-056B',
#     'launchDate': '2003-12-10',
#     'satlat': 63.0842,
#     'satlng': 109.2794,
#     'satalt': 19046.932},
#    {'satid': 28117,
#     'satname': 'UFO 11 (USA 174)',
#     'intDesignator': '2003-057A',
#     'launchDate': '2003-12-18',
#     'satlat': 2.0089,
#     'satlng': 75.4936,
#     'satalt': 35790.7979},
#    {'satid': 28132,
#     'satname': 'AMOS 2',
#     'intDesignator': '2003-059A',
#     'launchDate': '2003-12-27',
#     'satlat': 3.0533,
#     'satlng': 80.1192,
#     'satalt': 36032.646},
#    {'satid': 28134,
#     'satname': 'SESAT 2 (EXPRESS AM-22)',
#     'intDesignator': '2003-060A',
#     'launchDate': '2003-12-28',
#     'satlat': 2.8693,
#     'satlng': 79.5652,
#     'satalt': 36021.2468},
#    {'satid': 28158,
#     'satname': 'USA 176',
#     'intDesignator': '2004-004A',
#     'launchDate': '2004-02-14',
#     'satlat': 1.2089,
#     'satlng': 87.4758,
#     'satalt': 35785.4373},
#    {'satid': 28184,
#     'satname': 'MBSAT',
#     'intDesignator': '2004-007A',
#     'launchDate': '2004-03-13',
#     'satlat': 0.9367,
#     'satlng': 60.8855,
#     'satalt': 35777.9076},
#    {'satid': 28527,
#     'satname': 'BREEZE-M R/B',
#     'intDesignator': '2005-003B',
#     'launchDate': '2005-02-03',
#     'satlat': 1.2238,
#     'satlng': 87.9244,
#     'satalt': 34755.2698},
#    {'satid': 28551,
#     'satname': 'TITAN 3C TRANSTAGE DEB',
#     'intDesignator': '1965-108BS',
#     'launchDate': '1965-12-21',
#     'satlat': 24.0041,
#     'satlng': 107.7724,
#     'satalt': 20126.6005},
#    {'satid': 28629,
#     'satname': 'EXPRESS AM-2',
#     'intDesignator': '2005-010A',
#     'launchDate': '2005-03-29',
#     'satlat': 3.7394,
#     'satlng': 80.2693,
#     'satalt': 36125.5283},
#    {'satid': 28899,
#     'satname': 'INMARSAT 4-F2',
#     'intDesignator': '2005-044A',
#     'launchDate': '2005-11-08',
#     'satlat': 1.2801,
#     'satlng': 63.8907,
#     'satalt': 35783.6844},
#    {'satid': 28904,
#     'satname': 'ARIANE 5 R/B',
#     'intDesignator': '2005-046C',
#     'launchDate': '2005-11-16',
#     'satlat': 2.1853,
#     'satlng': 90.4492,
#     'satalt': 31269.6419},
#    {'satid': 28915,
#     'satname': 'COSMOS 2419 (GLONASS)',
#     'intDesignator': '2005-050A',
#     'launchDate': '2005-12-25',
#     'satlat': 29.2005,
#     'satlng': 65.5795,
#     'satalt': 19167.825},
#    {'satid': 28916,
#     'satname': 'COSMOS 2418 (GLONASS)',
#     'intDesignator': '2005-050B',
#     'launchDate': '2005-12-25',
#     'satlat': 7.7158,
#     'satlng': 76.6343,
#     'satalt': 19152.2971},
#    {'satid': 28919,
#     'satname': 'SL-12 R/B(AUX MOTOR)',
#     'intDesignator': '2005-050E',
#     'launchDate': '2005-12-25',
#     'satlat': 27.6421,
#     'satlng': 91.1089,
#     'satalt': 14869.1537},
#    {'satid': 28922,
#     'satname': 'GIOVE-A',
#     'intDesignator': '2005-051A',
#     'launchDate': '2005-12-28',
#     'satlat': 41.2191,
#     'satlng': 70.0337,
#     'satalt': 23344.5236},
#    {'satid': 28985,
#     'satname': 'SL-12 DEB',
#     'intDesignator': '1992-047AN',
#     'launchDate': '1992-07-30',
#     'satlat': 64.2434,
#     'satlng': 40.2073,
#     'satalt': 10354.7736},
#    {'satid': 29026,
#     'satname': 'ARIANE 44L+ DEB',
#     'intDesignator': '1992-021S',
#     'launchDate': '1992-04-15',
#     'satlat': 3.289,
#     'satlng': 86.0166,
#     'satalt': 34132.9829},
#    {'satid': 29155,
#     'satname': 'GOES 13',
#     'intDesignator': '2006-018A',
#     'launchDate': '2006-05-24',
#     'satlat': 0.243,
#     'satlng': 61.3656,
#     'satalt': 35762.3584},
#    {'satid': 29163,
#     'satname': 'THAICOM 5',
#     'intDesignator': '2006-020B',
#     'launchDate': '2006-05-27',
#     'satlat': 0.8469,
#     'satlng': 60.2232,
#     'satalt': 36078.3945},
#    {'satid': 29171,
#     'satname': 'SCOUT B DEB',
#     'intDesignator': '1965-063V',
#     'launchDate': '1965-08-10',
#     'satlat': 34.0028,
#     'satlng': 60.9978,
#     'satalt': 2313.8454},
#    {'satid': 29199,
#     'satname': 'METEOR 2-6 DEB',
#     'intDesignator': '1980-073E',
#     'launchDate': '1980-09-09',
#     'satlat': 43.8152,
#     'satlng': 67.55,
#     'satalt': 822.7788},
#    {'satid': 29250,
#     'satname': 'DELTA 4 R/B',
#     'intDesignator': '2006-027B',
#     'launchDate': '2006-06-28',
#     'satlat': 63.8536,
#     'satlng': 101.6347,
#     'satalt': 34105.8741},
#    {'satid': 29328,
#     'satname': 'SL-12 DEB',
#     'intDesignator': '1989-039AK',
#     'launchDate': '1989-05-31',
#     'satlat': 1.6454,
#     'satlng': 79.4176,
#     'satalt': 18618.7745},
#    {'satid': 29398,
#     'satname': 'CHINASAT 22A',
#     'intDesignator': '2006-038A',
#     'launchDate': '2006-09-12',
#     'satlat': 2.7636,
#     'satlng': 87.0244,
#     'satalt': 35857.1969},
#    {'satid': 29416,
#     'satname': 'SL-12 DEB',
#     'intDesignator': '1989-039BU',
#     'launchDate': '1989-05-31',
#     'satlat': 48.288,
#     'satlng': 107.2782,
#     'satalt': 11496.4524},
#    {'satid': 29448,
#     'satname': 'CZ-3 DEB',
#     'intDesignator': '1986-010G',
#     'launchDate': '1986-02-01',
#     'satlat': 16.0081,
#     'satlng': 39.7779,
#     'satalt': 28044.8469},
#    {'satid': 29640,
#     'satname': 'FENGYUN 2D',
#     'intDesignator': '2006-053A',
#     'launchDate': '2006-12-08',
#     'satlat': 5.3098,
#     'satlng': 61.2653,
#     'satalt': 36423.1252},
#    {'satid': 29648,
#     'satname': 'MEASAT 3',
#     'intDesignator': '2006-056A',
#     'launchDate': '2006-12-11',
#     'satlat': 0.0466,
#     'satlng': 91.495,
#     'satalt': 35778.774},
#    {'satid': 29656,
#     'satname': 'ETS 8',
#     'intDesignator': '2006-059A',
#     'launchDate': '2006-12-18',
#     'satlat': 7.1712,
#     'satlng': 42.7892,
#     'satalt': 36154.3255},
#    {'satid': 29680,
#     'satname': 'SL-12 R/B(AUX MOTOR)',
#     'intDesignator': '2006-062G',
#     'launchDate': '2006-12-25',
#     'satlat': 38.6473,
#     'satlng': 61.4828,
#     'satalt': 18844.5353},
#    {'satid': 29765,
#     'satname': 'FENGYUN 1C DEB',
#     'intDesignator': '1999-025BF',
#     'launchDate': '1999-05-10',
#     'satlat': 42.86,
#     'satlng': 78.4764,
#     'satalt': 852.8721},
#    {'satid': 29937,
#     'satname': 'FENGYUN 1C DEB',
#     'intDesignator': '1999-025JK',
#     'launchDate': '1999-05-10',
#     'satlat': 36.7048,
#     'satlng': 76.6744,
#     'satalt': 870.3806},
#    {'satid': 30073,
# ...
#     'launchDate': '2006-12-25',
#     'satlat': 23.76,
#     'satlng': 104.6205,
#     'satalt': 10320.9359},
#    {'satid': 41840,
#     'satname': 'YZ-2 R/B',
#     'intDesignator': '2016-065C',
#     'launchDate': '2016-11-03',
#     'satlat': 3.7292,
#     'satlng': 73.2623,
#     'satalt': 37070.7605},
#    {'satid': 41940,
#     'satname': 'DSN-2',
#     'intDesignator': '2017-005A',
#     'launchDate': '2017-01-24',
#     'satlat': 0.168,
#     'satlng': 88.5475,
#     'satalt': 35802.9476},
#    {'satid': 42075,
#     'satname': 'WGS 9 (USA 275)',
#     'intDesignator': '2017-016A',
#     'launchDate': '2017-03-19',
#     'satlat': -0.0041,
#     'satlng': 56.6397,
#     'satalt': 35787.2477},
#    {'satid': 42370,
#     'satname': 'NOAA 16 DEB',
#     'intDesignator': '2000-055RN',
#     'launchDate': '2000-09-21',
#     'satlat': 43.3087,
#     'satlng': 82.5259,
#     'satalt': 982.5542},
#    {'satid': 42461,
#     'satname': 'CZ-3B DEB',
#     'intDesignator': '2010-042AC',
#     'launchDate': '2010-09-04',
#     'satlat': 19.8449,
#     'satlng': 50.8676,
#     'satalt': 28675.6165},
#    {'satid': 42471,
#     'satname': 'CZ-3B DEB',
#     'intDesignator': '2011-077AL',
#     'launchDate': '2011-12-19',
#     'satlat': 25.0086,
#     'satlng': 115.5936,
#     'satalt': 41516.1318},
#    {'satid': 42475,
#     'satname': 'CZ-3B DEB',
#     'intDesignator': '2011-077AQ',
#     'launchDate': '2011-12-19',
#     'satlat': 24.4867,
#     'satlng': 120.7929,
#     'satalt': 40487.4582},
#    {'satid': 42476,
#     'satname': 'CZ-3B DEB',
#     'intDesignator': '2011-077AR',
#     'launchDate': '2011-12-19',
#     'satlat': 21.9048,
#     'satlng': 109.892,
#     'satalt': 30641.8138},
#    {'satid': 42665,
#     'satname': 'MIDAS 4 DEB',
#     'intDesignator': '1961-028L',
#     'launchDate': '1961-10-21',
#     'satlat': 41.8776,
#     'satlng': 92.2808,
#     'satalt': 4411.4715},
#    {'satid': 42698,
#     'satname': 'INMARSAT 5-F4',
#     'intDesignator': '2017-025A',
#     'launchDate': '2017-05-15',
#     'satlat': -0.0179,
#     'satlng': 56.4962,
#     'satalt': 35787.3484},
#    {'satid': 42699,
#     'satname': 'FALCON 9 R/B',
#     'intDesignator': '2017-025B',
#     'launchDate': '2017-05-15',
#     'satlat': -0.3414,
#     'satlng': 88.4657,
#     'satalt': 56391.3325},
#    {'satid': 42720,
#     'satname': 'FREGAT R/B',
#     'intDesignator': '2017-027B',
#     'launchDate': '2017-05-25',
#     'satlat': 63.0539,
#     'satlng': 106.5548,
#     'satalt': 38019.2633},
#    {'satid': 43004,
#     'satname': 'CZ-3B R/B',
#     'intDesignator': '2017-069D',
#     'launchDate': '2017-11-05',
#     'satlat': 51.9235,
#     'satlng': 55.0509,
#     'satalt': 12157.8624},
#    {'satid': 43107,
#     'satname': 'BEIDOU 3M3',
#     'intDesignator': '2018-003A',
#     'launchDate': '2018-01-11',
#     'satlat': 46.6096,
#     'satlng': 21.4425,
#     'satalt': 21532.4219},
#    {'satid': 43108,
#     'satname': 'BEIDOU 3M4',
#     'intDesignator': '2018-003B',
#     'launchDate': '2018-01-11',
#     'satlat': 13.8122,
#     'satlng': 58.5066,
#     'satalt': 21524.9504},
#    {'satid': 43210,
#     'satname': 'YZ-1 R/B',
#     'intDesignator': '2018-018D',
#     'launchDate': '2018-02-12',
#     'satlat': 32.9355,
#     'satlng': 36.5707,
#     'satalt': 22202.3845},
#    {'satid': 43286,
#     'satname': 'IRNSS 1I',
#     'intDesignator': '2018-035A',
#     'launchDate': '2018-04-11',
#     'satlat': 27.1673,
#     'satlng': 52.5915,
#     'satalt': 35813.9464},
#    {'satid': 43342,
#     'satname': 'ATLAS CENTAUR DEB',
#     'intDesignator': '2018-036D',
#     'launchDate': '2018-04-14',
#     'satlat': 2.1822,
#     'satlng': 55.3692,
#     'satalt': 35151.305},
#    {'satid': 43355,
#     'satname': 'FENGYUN 2A DEB',
#     'intDesignator': '1997-029D',
#     'launchDate': '1997-06-10',
#     'satlat': 6.1973,
#     'satlng': 45.2583,
#     'satalt': 36133.1634},
#    {'satid': 43372,
#     'satname': 'COSMOS 2392 DEB',
#     'intDesignator': '2002-037BW',
#     'launchDate': '2002-07-25',
#     'satlat': 49.6144,
#     'satlng': 80.6519,
#     'satalt': 1864.3143},
#    {'satid': 43433,
#     'satname': 'BREEZE-M R/B',
#     'intDesignator': '2018-037B',
#     'launchDate': '2018-04-18',
#     'satlat': 2.171,
#     'satlng': 82.1872,
#     'satalt': 40721.7242},
#    {'satid': 43446,
#     'satname': 'USA 286',
#     'intDesignator': '2018-036F',
#     'launchDate': '2018-04-14',
#     'satlat': 2.1549,
#     'satlng': 65.1866,
#     'satalt': 35244.4765},
#    {'satid': 43470,
#     'satname': 'QUEQIAO',
#     'intDesignator': '2018-045A',
#     'launchDate': '2018-05-20',
#     'satlat': 4.3314,
#     'satlng': 100.2939,
#     'satalt': 220170.6507},
#    {'satid': 43471,
#     'satname': 'LONGJIANG 1',
#     'intDesignator': '2018-045B',
#     'launchDate': '2018-05-20',
#     'satlat': 4.3314,
#     'satlng': 100.2939,
#     'satalt': 220170.6507},
#    {'satid': 43491,
#     'satname': 'FENGYUN 2H',
#     'intDesignator': '2018-050A',
#     'launchDate': '2018-06-05',
#     'satlat': -0.2329,
#     'satlng': 79.2812,
#     'satalt': 35778.6345},
#    {'satid': 43498,
#     'satname': 'ISS DEB',
#     'intDesignator': '1998-067NS',
#     'launchDate': '1998-11-20',
#     'satlat': 32.3488,
#     'satlng': 123.9288,
#     'satalt': 7236305836101302},
#    {'satid': 43539,
#     'satname': 'BEIDOU IGSO-7',
#     'intDesignator': '2018-057A',
#     'launchDate': '2018-07-09',
#     'satlat': 43.8677,
#     'satlng': 99.5085,
#     'satalt': 35909.5898},
#    {'satid': 43542,
#     'satname': 'SL-12 DEB',
#     'intDesignator': '2010-007AB',
#     'launchDate': '2010-03-01',
#     'satlat': 39.4936,
#     'satlng': 78.6303,
#     'satalt': 3182.6699},
#    {'satid': 43565,
#     'satname': 'GALILEO 26 (2C2)',
#     'intDesignator': '2018-060B',
#     'launchDate': '2018-07-25',
#     'satlat': 4.6158,
#     'satlng': 89.9034,
#     'satalt': 23222.4495},
#    {'satid': 43623,
#     'satname': 'BEIDOU 3M14',
#     'intDesignator': '2018-072B',
#     'launchDate': '2018-09-19',
#     'satlat': 55.2138,
#     'satlng': 94.5134,
#     'satalt': 21539.3298},
#    {'satid': 43646,
#     'satname': 'FENGYUN 2G DEB',
#     'intDesignator': '2014-090D',
#     'launchDate': '2014-12-31',
#     'satlat': 2.3784,
#     'satlng': 75.7727,
#     'satalt': 35863.4772},
#    {'satid': 43824,
#     'satname': 'GSAT 11',
#     'intDesignator': '2018-100B',
#     'launchDate': '2018-12-04',
#     'satlat': -0.0656,
#     'satlng': 74.0404,
#     'satalt': 35781.1152},
#    {'satid': 43864,
#     'satname': 'GSAT 7A',
#     'intDesignator': '2018-104R',
#     'launchDate': '2018-12-16',
#     'satlat': 0.0033,
#     'satlng': 62.7776,
#     'satalt': 35781.4121},
#    {'satid': 43867,
#     'satname': 'COSMOS 2533',
#     'intDesignator': '2018-107A',
#     'launchDate': '2018-12-21',
#     'satlat': 0.0163,
#     'satlng': 70.0038,
#     'satalt': 35789.0457},
#    {'satid': 43917,
#     'satname': 'TJS-3 AKM',
#     'intDesignator': '2018-110C',
#     'launchDate': '2018-12-24',
#     'satlat': 0.2955,
#     'satlng': 59.0339,
#     'satalt': 35782.0736},
#    {'satid': 44068,
#     'satname': 'CZ-3B R/B',
#     'intDesignator': '2019-012B',
#     'launchDate': '2019-03-09',
#     'satlat': 20.1929,
#     'satlng': 96.3174,
#     'satalt': 30717.8106},
#    {'satid': 44071,
#     'satname': 'WGS 10 (USA 291)',
#     'intDesignator': '2019-014A',
#     'launchDate': '2019-03-16',
#     'satlat': 0.0969,
#     'satlng': 60.2914,
#     'satalt': 35785.6442},
#    {'satid': 44076,
#     'satname': 'TIANLIAN 2-01',
#     'intDesignator': '2019-017A',
#     'launchDate': '2019-03-31',
#     'satlat': -1.5953,
#     'satlng': 80.3093,
#     'satalt': 35712.9829},
#    {'satid': 44321,
#     'satname': 'TITAN 34B DEB',
#     'intDesignator': '1981-038G',
#     'launchDate': '1981-04-24',
#     'satlat': 61.8433,
#     'satlng': 43.8112,
#     'satalt': 25210.5174},
#    {'satid': 44337,
#     'satname': 'BEIDOU 3 IGSO-2',
#     'intDesignator': '2019-035A',
#     'launchDate': '2019-06-24',
#     'satlat': 40.7862,
#     'satlng': 90.3867,
#     'satalt': 35832.1232},
#    {'satid': 44362,
#     'satname': 'TITAN 34D TRANSTAGE DEB',
#     'intDesignator': '1988-077V',
#     'launchDate': '1988-09-02',
#     'satlat': 13.5918,
#     'satlng': 106.048,
#     'satalt': 32359.7326},
#    {'satid': 44476,
#     'satname': 'INTELSAT 39',
#     'intDesignator': '2019-049B',
#     'launchDate': '2019-08-06',
#     'satlat': -0.0229,
#     'satlng': 61.953,
#     'satalt': 35784.3737},
#    {'satid': 44498,
#     'satname': 'PEARL WHITE 2',
#     'intDesignator': '2019-054D',
#     'launchDate': '2019-08-19',
#     'satlat': 43.8605,
#     'satlng': 77.8698,
#     'satalt': 538.5222},
#    {'satid': 44506,
#     'satname': 'NAVSTAR 78 (USA 293)',
#     'intDesignator': '2019-056A',
#     'launchDate': '2019-08-22',
#     'satlat': 11.1137,
#     'satlng': 100.1038,
#     'satalt': 20152.3455},
#    {'satid': 44521,
#     'satname': 'KZ-1/A R/B',
#     'intDesignator': '2019-058C',
#     'launchDate': '2019-08-30',
#     'satlat': 41.7326,
#     'satlng': 70.3022,
#     'satalt': 547.8919},
#    {'satid': 44547,
#     'satname': 'YUNHAI 1-02',
#     'intDesignator': '2019-063A',
#     'launchDate': '2019-09-25',
#     'satlat': 41.975,
#     'satlng': 69.7028,
#     'satalt': 790.2763},
#    {'satid': 44573,
#     'satname': 'ARIANE 44LP DEB',
#     'intDesignator': '1992-060J',
#     'launchDate': '1992-09-10',
#     'satlat': -2.1472,
#     'satlng': 69.7891,
#     'satalt': 34737.7526},
#    {'satid': 44582,
#     'satname': 'LUCH DEB',
#     'intDesignator': '1994-082G',
#     'launchDate': '1994-12-16',
#     'satlat': 0.8782,
#     'satlng': 63.6188,
#     'satalt': 35716.7711},
#    {'satid': 44614,
#     'satname': 'CZ-4C DEB',
#     'intDesignator': '2017-027E',
#     'launchDate': '2017-11-14',
#     'satlat': 46.0001,
#     'satlng': 75.1641,
#     'satalt': 824.8597},
#    {'satid': 44626,
#     'satname': 'BREEZE-M R/B',
#     'intDesignator': '2019-067C',
#     'launchDate': '2019-10-09',
#     'satlat': 6.2182,
#     'satlng': 67.4767,
#     'satalt': 64309.7288},
#    {'satid': 44637,
#     'satname': 'TJS-4',
#     'intDesignator': '2019-070A',
#     'launchDate': '2019-10-17',
#     'satlat': 0.017,
#     'satlng': 83.5334,
#     'satalt': 35781.2259},
#    {'satid': 44795,
#     'satname': 'YZ-1 R/B',
#     'intDesignator': '2019-078C',
#     'launchDate': '2019-11-23',
#     'satlat': 0.9605,
#     'satlng': 67.0614,
#     'satalt': 22572.3082},
#    {'satid': 44864,
#     'satname': 'BEIDOU 3M19',
#     'intDesignator': '2019-090A',
#     'launchDate': '2019-12-16',
#     'satlat': 34.7209,
#     'satlng': 35.7317,
#     'satalt': 21561.1891},
#    {'satid': 44866,
#     'satname': 'YZ-1 R/B',
#     'intDesignator': '2019-090C',
#     'launchDate': '2019-12-16',
#     'satlat': 49.0765,
#     'satlng': 61.6941,
#     'satalt': 22274.2986},
#    {'satid': 44903,
#     'satname': 'ELEKTRO-L 3',
#     'intDesignator': '2019-095A',
#     'launchDate': '2019-12-24',
#     'satlat': -0.0046,
#     'satlng': 76.0278,
#     'satalt': 35784.3673},
#    {'satid': 44984,
#     'satname': 'SL-12 DEB',
#     'intDesignator': '2006-062U',
#     'launchDate': '2006-12-25',
#     'satlat': 20.8715,
#     'satlng': 68.8386,
#     'satalt': 17406.2447},
#    {'satid': 45010,
#     'satname': 'COSMOS 2535 DEB',
#     'intDesignator': '2019-039AB',
#     'launchDate': '2019-07-10',
#     'satlat': 53.7865,
#     'satlng': 24.4474,
#     'satalt': 12301693938833.375},
#    {'satid': 45026,
#     'satname': 'GSAT 30',
#     'intDesignator': '2020-005A',
#     'launchDate': '2020-01-16',
#     'satlat': 0.0156,
#     'satlng': 82.9957,
#     'satalt': 35786.0255},
#    {'satid': 45344,
#     'satname': 'BEIDOU 3 G2',
#     'intDesignator': '2020-017A',
#     'launchDate': '2020-03-09',
#     'satlat': -2.1352,
#     'satlng': 79.9896,
#     'satalt': 35783.7619},
#    {'satid': 45358,
#     'satname': 'COSMOS 2545 (GLONASS)',
#     'intDesignator': '2020-018A',
#     'launchDate': '2020-03-16',
#     'satlat': 27.9973,
#     'satlng': 64.7734,
#     'satalt': 19135.0709},
#    {'satid': 45570,
#     'satname': 'STARLINK-1376',
#     'intDesignator': '2020-025AR',
#     'launchDate': '2020-04-22',
#     'satlat': 41.3573,
#     'satlng': 74.6535,
#     'satalt': 552.952},
#    {'satid': 45628,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037U',
#     'launchDate': '2011-07-18',
#     'satlat': 37.0693,
#     'satlng': 57.1292,
#     'satalt': 4903.2828},
#    {'satid': 45854,
#     'satname': 'NAVSTAR 79 (USA 304)',
#     'intDesignator': '2020-041A',
#     'launchDate': '2020-06-30',
#     'satlat': 52.0615,
#     'satlng': 101.9982,
#     'satalt': 20166.8369},
#    {'satid': 45865,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037CP',
#     'launchDate': '2011-07-18',
#     'satlat': 37.3942,
#     'satlng': 54.5491,
#     'satalt': 4383.1394},
#    {'satid': 45881,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037DA',
#     'launchDate': '2011-07-18',
#     'satlat': 25.5597,
#     'satlng': 73.2668,
#     'satalt': 3603.5617},
#    {'satid': 45905,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037EA',
#     'launchDate': '2011-07-18',
#     'satlat': 43.8871,
#     'satlng': 68.2103,
#     'satalt': 4445.1957},
#    {'satid': 45912,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037EH',
#     'launchDate': '2011-07-18',
#     'satlat': 49.2474,
#     'satlng': 90.5109,
#     'satalt': 3781.5669},
#    {'satid': 45986,
#     'satname': 'OBJECT B',
#     'intDesignator': '2020-053B',
#     'launchDate': '2020-07-30',
#     'satlat': -0.143,
#     'satlng': 88.7797,
#     'satalt': 36673.9836},
#    {'satid': 45999,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037HA',
#     'launchDate': '2011-07-18',
#     'satlat': 36.2233,
#     'satlng': 51.8714,
#     'satalt': 4432.0933},
#    {'satid': 46002,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037HD',
#     'launchDate': '2011-07-18',
#     'satlat': 39.532,
#     'satlng': 52.9758,
#     'satalt': 4513.0598},
#    {'satid': 46023,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037JA',
#     'launchDate': '2011-07-18',
#     'satlat': 46.6638,
#     'satlng': 72.7607,
#     'satalt': 4771.1335},
#    {'satid': 46103,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037JN',
#     'launchDate': '2011-07-18',
#     'satlat': 49.5259,
#     'satlng': 41.1526,
#     'satalt': 5870.8738},
#    {'satid': 46115,
#     'satname': 'ARIANE 5 DEB (SYLDA)',
#     'intDesignator': '2020-056D',
#     'launchDate': '2020-08-15',
#     'satlat': 6.1109,
#     'satlng': 56.2978,
#     'satalt': 33472.9661},
#    {'satid': 46243,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037KD',
#     'launchDate': '2011-07-18',
#     'satlat': 40.8124,
#     'satlng': 92.6928,
#     'satalt': 4236.1679},
#    {'satid': 46252,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037KN',
#     'launchDate': '2011-07-18',
#     'satlat': 29.4411,
#     'satlng': 90.1642,
#     'satalt': 3773.2406},
#    {'satid': 46258,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037KU',
#     'launchDate': '2011-07-18',
#     'satlat': 45.4583,
#     'satlng': 67.0535,
#     'satalt': 4439.1173},
#    {'satid': 46323,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037LB',
#     'launchDate': '2011-07-18',
#     'satlat': 51.4959,
#     'satlng': 46.3048,
#     'satalt': 4707.9774},
#    {'satid': 46406,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037LK',
#     'launchDate': '2011-07-18',
#     'satlat': 33.0995,
#     'satlng': 48.2998,
#     'satalt': 4217.9927},
#    {'satid': 46517,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037LV',
#     'launchDate': '2011-07-18',
#     'satlat': 48.5672,
#     'satlng': 46.5777,
#     'satalt': 5787.376},
#    {'satid': 46521,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037LZ',
#     'launchDate': '2011-07-18',
#     'satlat': 30.7469,
#     'satlng': 93.5138,
#     'satalt': 3670.9212},
#    {'satid': 46523,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037MB',
#     'launchDate': '2011-07-18',
#     'satlat': 40.2162,
#     'satlng': 76.0829,
#     'satalt': 4208.5898},
#    {'satid': 46621,
#     'satname': 'FREGAT DEB',
#     'intDesignator': '2011-037MM',
#     'launchDate': '2011-07-18',
#     'satlat': 33.8867,
#     'satlng': 52.499,
#     'satalt': 4140.461},
#    {'satid': 46736,
#     'satname': 'FREGAT R/B',
#     'intDesignator': '2011-037ND',
#     'launchDate': '2011-07-18',
#     'satlat': 44.628,
#     'satlng': 13.8766,
#     'satalt': 311362.1886},
#    {'satid': 47011,
#     'satname': 'FENGYUN 1C DEB',
#     'intDesignator': '1999-025FAM',
#     'launchDate': '1999-05-10',
#     'satlat': 45.1794,
#     'satlng': 78.0223,
#     'satalt': 847.0426}]}]

# %%
with open('satlaunch.json', 'a+') as f:
   json.dump(earth_sat,f)

# %%
earth_sat2 = []

search_url = f"https://api.n2yo.com/rest/v1/satellite/above/40.0583/74.4057/0/90/0/&apiKey={API_Key}"
response_earth = requests.get(search_url)
earth_data2 = response_earth.json()
earth_sat2.append(earth_data2)
earth_sat2
# Out:
# [{'info': {'category': 'ANY', 'transactionscount': 3, 'satcount': 2891},
#   'above': [{'satid': 12,
#     'satname': 'VANGUARD R/B',
#     'intDesignator': '1959-001B',
#     'launchDate': '1959-02-17',
#     'satlat': 29.9503,
#     'satlng': 45.8203,
#     'satalt': 3237.9316},
#    {'satid': 118,
#     'satname': 'THOR ABLESTAR R/B',
#     'intDesignator': '1961-015C',
#     'launchDate': '1961-06-29',
#     'satlat': 60.8904,
#     'satlng': 55.7625,
#     'satalt': 950.8223},
#    {'satid': 131,
#     'satname': 'THOR ABLESTAR DEB',
#     'intDesignator': '1961-015R',
#     'launchDate': '1961-06-29',
#     'satlat': 57.8296,
#     'satlng': 103.7752,
#     'satalt': 890.9913},
#    {'satid': 162,
#     'satname': 'TIROS 3',
#     'intDesignator': '1961-017A',
#     'launchDate': '1961-07-12',
#     'satlat': 23.7051,
#     'satlng': 75.8729,
#     'satalt': 731.4407},
#    {'satid': 273,
#     'satname': 'MIDAS 5 DEB',
#     'intDesignator': '1962-010C',
#     'launchDate': '1962-04-09',
#     'satlat': 42.8499,
#     'satlng': 111.575,
#     'satalt': 3338.2394},
#    {'satid': 309,
#     'satname': 'TIROS 5',
#     'intDesignator': '1962-025A',
#     'launchDate': '1962-06-19',
#     'satlat': 40.2379,
#     'satlng': 75.7463,
#     'satalt': 764.9949},
#    {'satid': 467,
#     'satname': 'THOR ABLESTAR DEB',
#     'intDesignator': '1961-015FD',
#     'launchDate': '1961-06-29',
#     'satlat': 49.3382,
#     'satlng': 102.5623,
#     'satalt': 897.2394},
#    {'satid': 469,
#     'satname': 'THOR ABLESTAR DEB',
#     'intDesignator': '1961-015FF',
#     'launchDate': '1961-06-29',
#     'satlat': 38.1214,
#     'satlng': 53.0285,
#     'satalt': 836.3727},
#    {'satid': 510,
#     'satname': 'THOR AGENA B DEB',
#     'intDesignator': '1962-049C',
#     'launchDate': '1962-09-29',
#     'satlat': 52.3129,
#     'satlng': 42.7032,
#     'satalt': 1017.825},
#    {'satid': 515,
#     'satname': 'DELTA 1 R/B',
#     'intDesignator': '1962-068B',
#     'launchDate': '1962-12-13',
#     'satlat': 38.3342,
#     'satlng': 76.9193,
#     'satalt': 6088.6605},
#    {'satid': 538,
#     'satname': 'THOR ABLESTAR DEB',
#     'intDesignator': '1961-015FX',
#     'launchDate': '1961-06-29',
#     'satlat': 58.7826,
#     'satlng': 66.8653,
#     'satalt': 756.7148},
#    {'satid': 553,
#     'satname': 'SYNCOM 1',
#     'intDesignator': '1963-004A',
#     'launchDate': '1963-02-14',
#     'satlat': -24.8204,
#     'satlng': 60.3253,
#     'satalt': 32107.1798},
#    {'satid': 608,
#     'satname': 'ERS 6',
#     'intDesignator': '1963-014C',
#     'launchDate': '1963-05-09',
#     'satlat': 80.5198,
#     'satlng': 66.5176,
#     'satalt': 3755.3312},
#    {'satid': 630,
#     'satname': 'ATLAS AGENA B DEB',
#     'intDesignator': '1963-030C',
#     'launchDate': '1963-07-19',
#     'satlat': 48.5565,
#     'satlng': 11.2317,
#     'satalt': 3688.911},
#    {'satid': 634,
#     'satname': 'SYNCOM 2 (A 26)',
#     'intDesignator': '1963-031A',
#     'launchDate': '1963-07-26',
#     'satlat': -29.0705,
#     'satlng': 80.6338,
#     'satalt': 35792.981},
#    {'satid': 657,
#     'satname': 'THOR ABLESTAR DEB',
#     'intDesignator': '1961-015HJ',
#     'launchDate': '1961-06-29',
#     'satlat': 66.2796,
#     'satlng': 55.7105,
#     'satalt': 1353.7142},
#    {'satid': 660,
#     'satname': 'THOR ABLESTAR DEB',
#     'intDesignator': '1961-015HM',
#     'launchDate': '1961-06-29',
#     'satlat': 64.6156,
#     'satlng': 75.7405,
#     'satalt': 731.7679},
#    {'satid': 692,
#     'satname': 'VELA 1',
#     'intDesignator': '1963-039C',
#     'launchDate': '1963-10-17',
#     'satlat': -9.1383,
#     'satlng': 48.7112,
#     'satalt': 50809.4128},
#    {'satid': 702,
#     'satname': 'WESTFORD NEEDLES',
#     'intDesignator': '1963-014H',
#     'launchDate': '1963-05-09',
#     'satlat': 56.291,
#     'satlng': 75.5692,
#     'satalt': 3902.1457},
#    {'satid': 743,
#     'satname': 'THOR AGENA B DEB',
#     'intDesignator': '1964-004D',
#     'launchDate': '1964-01-25',
#     'satlat': 41.6387,
#     'satlng': 65.5556,
#     'satalt': 1295.6849},
#    {'satid': 836,
#     'satname': 'OPS 3662 (VELA 3)',
#     'intDesignator': '1964-040A',
#     'launchDate': '1964-07-17',
#     'satlat': 19.1355,
#     'satlng': 157.1432,
#     'satalt': 126270.9372},
#    {'satid': 837,
#     'satname': 'OPS 3674 (VELA 4)',
#     'intDesignator': '1964-040B',
#     'launchDate': '1964-07-17',
#     'satlat': 40.0338,
#     'satlng': 145.6415,
#     'satalt': 136617.9303},
#    {'satid': 900,
#     'satname': 'CALSPHERE 1',
#     'intDesignator': '1964-063C',
#     'launchDate': '1964-10-06',
#     'satlat': 46.9163,
#     'satlng': 87.9413,
#     'satalt': 1004.4465},
#    {'satid': 956,
#     'satname': 'THOR ABLESTAR DEB',
#     'intDesignator': '1964-083B',
#     'launchDate': '1964-12-13',
#     'satlat': 50.4215,
#     'satlng': 56.2197,
#     'satalt': 1037.8808},
#    {'satid': 976,
#     'satname': 'SCOUT X-4 DEB',
#     'intDesignator': '1964-064C',
#     'launchDate': '1964-10-10',
#     'satlat': 64.1542,
#     'satlng': 76.2279,
#     'satalt': 915.037},
#    {'satid': 979,
#     'satname': 'DELTA 1 R/B',
#     'intDesignator': '1965-004B',
#     'launchDate': '1965-01-22',
#     'satlat': 32.3838,
#     'satlng': 118.8361,
#     'satalt': 2527.1407},
#    {'satid': 1208,
#     'satname': 'SECOR 3',
#     'intDesignator': '1965-016E',
#     'launchDate': '1965-03-09',
#     'satlat': 27.905,
#     'satlng': 47.9269,
#     'satalt': 927.5065},
#    {'satid': 1318,
#     'satname': 'DELTA 1 R/B(2)',
#     'intDesignator': '1965-028B',
#     'launchDate': '1965-04-06',
#     'satlat': 14.0959,
#     'satlng': 31.9336,
#     'satalt': 24686.3886},
#    {'satid': 1399,
#     'satname': 'OPS 4682 DEB',
#     'intDesignator': '1965-027E',
#     'launchDate': '1965-04-03',
#     'satlat': 51.2994,
#     'satlng': 33.7393,
#     'satalt': 1274.3365},
#    {'satid': 1459,
#     'satname': 'OPS 6564 (VELA 6)',
#     'intDesignator': '1965-058B',
#     'launchDate': '1965-07-20',
#     'satlat': -23.7514,
#     'satlng': 137.5769,
#     'satalt': 133067.1},
#    {'satid': 1478,
#     'satname': 'SL-8 DEB',
#     'intDesignator': '1965-020BC',
#     'launchDate': '1965-03-15',
#     'satlat': 24.9346,
#     'satlng': 98.8099,
#     'satalt': 821.3067},
#    {'satid': 1506,
#     'satname': 'SECOR 5 (EGRS 5)',
#     'intDesignator': '1965-063A',
#     'launchDate': '1965-08-10',
#     'satlat': 26.1925,
#     'satlng': 105.2671,
#     'satalt': 2417.9682},
#    {'satid': 1577,
#     'satname': 'PORCUPINE 2',
#     'intDesignator': '1965-065J',
#     'launchDate': '1965-08-13',
#     'satlat': 37.3566,
#     'satlng': 93.413,
#     'satalt': 1076.8259},
#    {'satid': 1588,
#     'satname': 'COSMOS 90',
#     'intDesignator': '1965-073E',
#     'launchDate': '1965-09-18',
#     'satlat': 50.6681,
#     'satlng': 96.4193,
#     'satalt': 1585.195},
#    {'satid': 1682,
#     'satname': 'TITAN 3C TRANSTAGE DEB',
#     'intDesignator': '1965-082AV',
#     'launchDate': '1965-10-15',
#     'satlat': 32.1887,
#     'satlng': 87.8551,
#     'satalt': 717.2433},
#    {'satid': 1806,
#     'satname': 'EXPLORER 31 (ISIS-X)',
#     'intDesignator': '1965-098B',
#     'launchDate': '1965-11-29',
#     'satlat': 20.3605,
#     'satlng': 87.0437,
#     'satalt': 1712.1365},
#    {'satid': 1863,
#     'satname': 'TITAN 3C TRANSTAGE R/B',
#     'intDesignator': '1965-108A',
#     'launchDate': '1965-12-21',
#     'satlat': 18.9178,
#     'satlng': 146.3517,
#     'satalt': 21118.5591},
#    {'satid': 2088,
#     'satname': 'SCOUT X-4 DEB',
#     'intDesignator': '1965-093D',
#     'launchDate': '1965-11-19',
#     'satlat': 48.5551,
#     'satlng': 41.7967,
#     'satalt': 765.6408},
#    {'satid': 2120,
#     'satname': 'SCOUT A R/B',
#     'intDesignator': '1966-024B',
#     'launchDate': '1966-03-26',
#     'satlat': 44.5762,
#     'satlng': 88.3686,
#     'satalt': 1038.168},
#    {'satid': 2153,
#     'satname': 'THOR AGENA B DEB',
#     'intDesignator': '1965-098J',
#     'launchDate': '1965-11-29',
#     'satlat': 47.2927,
#     'satlng': 67.255,
#     'satalt': 1444.7495},
#    {'satid': 2206,
#     'satname': 'SCOUT B R/B',
#     'intDesignator': '1966-052B',
#     'launchDate': '1966-06-10',
#     'satlat': -7.0656,
#     'satlng': 73.1189,
#     'satalt': 4219.4967},
#    {'satid': 2222,
#     'satname': 'TITAN 3C TRANSTAGE R/B',
#     'intDesignator': '1966-053J',
#     'launchDate': '1966-06-16',
#     'satlat': 0.477,
#     'satlng': 111.7736,
#     'satalt': 33749.1133},
#    {'satid': 2224,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1966-016D',
#     'launchDate': '1966-02-28',
#     'satlat': 12.2656,
#     'satlng': 69.753,
#     'satalt': 1465.4556},
#    {'satid': 2328,
#     'satname': 'ATLAS D R/B',
#     'intDesignator': '1966-063C',
#     'launchDate': '1966-07-14',
#     'satlat': 32.5544,
#     'satlng': 61.6537,
#     'satalt': 1003.0353},
#    {'satid': 2361,
#     'satname': 'WESTFORD NEEDLES',
#     'intDesignator': '1963-014L',
#     'launchDate': '1963-05-09',
#     'satlat': 2.5707,
#     'satlng': 70.1574,
#     'satalt': 3709.4089},
#    {'satid': 2362,
#     'satname': 'WESTFORD NEEDLES',
#     'intDesignator': '1963-014M',
#     'launchDate': '1963-05-09',
#     'satlat': 25.9996,
#     'satlng': 37.4142,
#     'satalt': 3118.27},
#    {'satid': 2364,
#     'satname': 'WESTFORD NEEDLES',
#     'intDesignator': '1963-014P',
#     'launchDate': '1963-05-09',
#     'satlat': 72.9281,
#     'satlng': 148.9087,
#     'satalt': 3883.7171},
#    {'satid': 2375,
#     'satname': 'WESTFORD NEEDLES',
#     'intDesignator': '1963-014W',
#     'launchDate': '1963-05-09',
#     'satlat': 34.6887,
#     'satlng': 34.8253,
#     'satalt': 4328.771},
#    {'satid': 2529,
#     'satname': 'LES 2 DEB',
#     'intDesignator': '1965-034D',
#     'launchDate': '1965-05-06',
#     'satlat': 24.7553,
#     'satlng': 112.2995,
#     'satalt': 3645.3892},
#    {'satid': 2608,
#     'satname': 'ATS 1',
#     'intDesignator': '1966-110A',
#     'launchDate': '1966-12-07',
#     'satlat': 0.3453,
#     'satlng': 5.3468,
#     'satalt': 35772.4858},
#    {'satid': 2610,
#     'satname': 'OV1-9',
#     'intDesignator': '1966-111A',
#     'launchDate': '1966-12-11',
#     'satlat': 62.1012,
#     'satlng': 18.0229,
#     'satalt': 2312.0756},
#    {'satid': 2645,
#     'satname': 'OPS 9321 (IDSCS 8)',
#     'intDesignator': '1967-003A',
#     'launchDate': '1967-01-18',
#     'satlat': 3.3419,
#     'satlng': 68.0243,
#     'satalt': 33620.7889},
#    {'satid': 2649,
#     'satname': 'OPS 9322 (IDSCS 9)',
#     'intDesignator': '1967-003B',
#     'launchDate': '1967-01-18',
#     'satlat': 0.7358,
#     'satlng': 104.518,
#     'satalt': 33727.4171},
#    {'satid': 2653,
#     'satname': 'OPS 9326 (IDSCS 13)',
#     'intDesignator': '1967-003F',
#     'launchDate': '1967-01-18',
#     'satlat': -1.742,
#     'satlng': 138.3589,
#     'satalt': 33999.4289},
#    {'satid': 2655,
#     'satname': 'OPS 9328 (IDSCS 15)',
#     'intDesignator': '1967-003H',
#     'launchDate': '1967-01-18',
#     'satlat': 2.8984,
#     'satlng': 72.2164,
#     'satalt': 34184.3379},
#    {'satid': 2684,
#     'satname': 'DIAMANT DEB',
#     'intDesignator': '1967-014C',
#     'launchDate': '1967-02-15',
#     'satlat': 35.5469,
#     'satlng': 79.6411,
#     'satalt': 1271.492},
#    {'satid': 2741,
#     'satname': 'THOR BURNER 2 R/B',
#     'intDesignator': '1967-010B',
#     'launchDate': '1967-02-08',
#     'satlat': 43.8218,
#     'satlng': 85.7243,
#     'satalt': 769.036},
#    {'satid': 2754,
#     'satname': 'OPS 0100 (TRANSIT 15)',
#     'intDesignator': '1967-034A',
#     'launchDate': '1967-04-14',
#     'satlat': 67.1818,
#     'satlng': 49.0207,
#     'satalt': 1072.0959},
#    {'satid': 2766,
#     'satname': 'OPS 6679 (VELA 8)',
#     'intDesignator': '1967-040B',
#     'launchDate': '1967-04-28',
#     'satlat': 24.5913,
#     'satlng': 8.6063,
#     'satalt': 70441.6352},
#    {'satid': 2777,
#     'satname': 'SCOUT A DEB',
#     'intDesignator': '1967-034C',
#     'launchDate': '1967-04-14',
#     'satlat': 50.7153,
#     'satlng': 68.1045,
#     'satalt': 817.9433},
#    {'satid': 2863,
#     'satname': 'OPS 9332 (IDSCS 17)',
#     'intDesignator': '1967-066B',
#     'launchDate': '1967-07-01',
#     'satlat': 0.0999,
#     'satlng': 145.2936,
#     'satalt': 33053.3679},
#    {'satid': 2865,
#     'satname': 'OPS 9334 (IDSCS 19)',
#     'intDesignator': '1967-066D',
#     'launchDate': '1967-07-01',
#     'satlat': -2.3372,
#     'satlng': 67.5579,
#     'satalt': 33363.9546},
#    {'satid': 2866,
#     'satname': 'LES 5',
#     'intDesignator': '1967-066E',
#     'launchDate': '1967-07-01',
#     'satlat': -1.9279,
#     'satlng': 95.3095,
#     'satalt': 33264.2193},
#    {'satid': 2867,
#     'satname': 'DODGE 1',
#     'intDesignator': '1967-066F',
#     'launchDate': '1967-07-01',
#     'satlat': -2.4157,
#     'satlng': 33.8759,
#     'satalt': 33494.0079},
#    {'satid': 2876,
#     'satname': 'AURORA 1',
#     'intDesignator': '1967-065B',
#     'launchDate': '1967-06-29',
#     'satlat': 59.7373,
#     'satlng': 7.3124,
#     'satalt': 3893.7854},
#    {'satid': 2909,
#     'satname': 'SURCAL 150B',
#     'intDesignator': '1967-053J',
#     'launchDate': '1967-05-31',
#     'satlat': 53.6878,
#     'satlng': 76.5197,
#     'satalt': 694.931},
#    {'satid': 3081,
#     'satname': 'COSMOS 198',
#     'intDesignator': '1967-127A',
#     'launchDate': '1967-12-27',
#     'satlat': 43.7819,
#     'satlng': 64.0189,
#     'satalt': 917.3916},
#    {'satid': 3239,
#     'satname': 'WESTFORD NEEDLES',
#     'intDesignator': '1963-014BD',
#     'launchDate': '1963-05-09',
#     'satlat': 63.1631,
#     'satlng': 78.5372,
#     'satalt': 3663.2524},
#    {'satid': 3244,
#     'satname': 'WESTFORD NEEDLES',
#     'intDesignator': '1963-014BJ',
#     'launchDate': '1963-05-09',
#     'satlat': 56.1703,
#     'satlng': 79.7198,
#     'satalt': 3681.4253},
#    {'satid': 3255,
#     'satname': 'WESTFORD NEEDLES',
#     'intDesignator': '1963-014BV',
#     'launchDate': '1963-05-09',
#     'satlat': 59.6425,
#     'satlng': 54.8284,
#     'satalt': 3934.2265},
#    {'satid': 3271,
#     'satname': 'THOR BURNER 2 R/B',
#     'intDesignator': '1968-042B',
#     'launchDate': '1968-05-23',
#     'satlat': 27.6882,
#     'satlng': 66.7509,
#     'satalt': 871.61},
#    {'satid': 3284,
#     'satname': 'OPS 9341 (IDSCS 20)',
#     'intDesignator': '1968-050A',
#     'launchDate': '1968-06-13',
#     'satlat': 1.242,
#     'satlng': 94.531,
#     'satalt': 33763.4116},
#    {'satid': 3287,
#     'satname': 'OPS 9344 (IDSCS 23)',
#     'intDesignator': '1968-050D',
#     'launchDate': '1968-06-13',
#     'satlat': 1.4962,
#     'satlng': 89.4517,
#     'satalt': 33791.4929},
#    {'satid': 3288,
#     'satname': 'OPS 9345 (IDSCS 24)',
#     'intDesignator': '1968-050E',
#     'launchDate': '1968-06-13',
#     'satlat': 2.0707,
#     'satlng': 74.8385,
#     'satalt': 33790.0817},
#    {'satid': 3290,
#     'satname': 'OPS 9347 (IDSCS 26)',
#     'intDesignator': '1968-050G',
#     'launchDate': '1968-06-13',
#     'satlat': 0.12,
#     'satlng': 115.9937,
#     'satalt': 34003.784},
#    {'satid': 3292,
#     'satname': 'TITAN 3C TRANSTAGE R/B',
#     'intDesignator': '1968-050J',
#     'launchDate': '1968-06-13',
#     'satlat': 2.9919,
#     'satlng': -0.0842,
#     'satalt': 34486.7964},
#    {'satid': 3334,
#     'satname': 'OPS 2222',
#     'intDesignator': '1968-063A',
#     'launchDate': '1968-08-06',
#     'satlat': -10.7977,
#     'satlng': 105.3383,
#     'satalt': 36938.426},
#    {'satid': 3346,
#     'satname': 'DELTA 1 R/B',
#     'intDesignator': '1968-069B',
#     'launchDate': '1968-08-16',
#     'satlat': 72.4569,
#     'satlng': 85.77,
#     'satalt': 1464.8568},
#    {'satid': 3597,
#     'satname': 'OAO 2',
#     'intDesignator': '1968-110A',
#     'launchDate': '1968-12-07',
#     'satlat': 32.8926,
#     'satlng': 104.3921,
#     'satalt': 741.7745},
#    {'satid': 3616,
#     'satname': 'DELTA 1 R/B',
#     'intDesignator': '1968-114B',
#     'launchDate': '1968-12-15',
#     'satlat': 73.3274,
#     'satlng': 58.6519,
#     'satalt': 1477.0934},
#    {'satid': 3623,
#     'satname': 'INTELSAT 3-F2',
#     'intDesignator': '1968-116A',
#     'launchDate': '1968-12-19',
#     'satlat': -9.243,
#     'satlng': 88.9847,
#     'satalt': 39192.9916},
#    {'satid': 3669,
#     'satname': 'ISIS 1',
#     'intDesignator': '1969-009A',
#     'launchDate': '1969-01-30',
#     'satlat': 51.8483,
#     'satlng': 62.0564,
#     'satalt': 2771.3399},
#    {'satid': 3673,
#     'satname': 'OPS 2644',
#     'intDesignator': '1969-010B',
#     'launchDate': '1969-02-05',
#     'satlat': 67.215,
#     'satlng': 70.4107,
#     'satalt': 1403.9368},
#    {'satid': 3745,
#     'satname': 'SL-8 DEB *',
#     'intDesignator': '1965-020ET',
#     'launchDate': '1965-03-15',
#     'satlat': 52.869,
#     'satlng': 36.6423,
#     'satalt': 1345.5405},
#    {'satid': 3814,
#     'satname': 'COSMOS 252 DEB',
#     'intDesignator': '1968-097BC',
#     'launchDate': '1968-11-01',
#     'satlat': 60.5099,
#     'satlng': 46.5876,
#     'satalt': 1573.6337},
#    {'satid': 3912,
#     'satname': 'COSMOS 249 DEB',
#     'intDesignator': '1968-091BQ',
#     'launchDate': '1968-10-20',
#     'satlat': 33.8205,
#     'satlng': 56.9946,
#     'satalt': 1791.3892},
#    {'satid': 3931,
#     'satname': 'SL-8 DEB *',
#     'intDesignator': '1965-020EV',
#     'launchDate': '1965-03-15',
#     'satlat': 52.8306,
#     'satlng': 116.041,
#     'satalt': 1660.8781},
#    {'satid': 3974,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1968-069E',
#     'launchDate': '1968-08-16',
#     'satlat': 22.3281,
#     'satlng': 103.5122,
#     'satalt': 1440.5921},
#    {'satid': 4048,
#     'satname': 'THOR BURNER 2 R/B',
#     'intDesignator': '1969-062B',
#     'launchDate': '1969-07-23',
#     'satlat': 18.0062,
#     'satlng': 74.3312,
#     'satalt': 794.346},
#    {'satid': 4068,
#     'satname': 'ATS 5',
#     'intDesignator': '1969-069A',
#     'launchDate': '1969-08-12',
#     'satlat': -4.4098,
#     'satlng': 45.1808,
#     'satalt': 36008.5455},
#    {'satid': 4143,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1969-082M',
#     'launchDate': '1969-09-30',
#     'satlat': 30.1143,
#     'satlng': 74.0261,
#     'satalt': 854.1468},
#    {'satid': 4180,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1969-082AY',
#     'launchDate': '1969-09-30',
#     'satlat': 34.9494,
#     'satlng': 101.9505,
#     'satalt': 804.9642},
#    {'satid': 4187,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1969-082BA',
#     'launchDate': '1969-09-30',
#     'satlat': 40.7803,
#     'satlng': 64.0682,
#     'satalt': 672.2803},
#    {'satid': 4231,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1969-082CN',
#     'launchDate': '1969-09-30',
#     'satlat': 57.6445,
#     'satlng': 84.3266,
#     'satalt': 743.0111},
#    {'satid': 4251,
#     'satname': 'DELTA 1 R/B',
#     'intDesignator': '1969-101B',
#     'launchDate': '1969-11-22',
#     'satlat': 9.0106,
#     'satlng': 41.8387,
#     'satalt': 17134.4009},
#    {'satid': 4297,
#     'satname': 'INTELSAT 3-F6',
#     'intDesignator': '1970-003A',
#     'launchDate': '1970-01-15',
#     'satlat': -1.586,
#     'satlng': 7.1843,
#     'satalt': 36151.8652},
#    {'satid': 4327,
#     'satname': 'SERT 2',
#     'intDesignator': '1970-009A',
#     'launchDate': '1970-02-04',
#     'satlat': 22.5453,
#     'satlng': 78.5278,
#     'satalt': 1045.1604},
#    {'satid': 4354,
#     'satname': 'DELTA 1 R/B',
#     'intDesignator': '1970-021B',
#     'launchDate': '1970-03-20',
#     'satlat': 15.9602,
#     'satlng': 44.5892,
#     'satalt': 5663.7468},
#    {'satid': 4363,
#     'satname': 'TOPO 1',
#     'intDesignator': '1970-025B',
#     'launchDate': '1970-04-08',
#     'satlat': 67.124,
#     'satlng': 98.7222,
#     'satalt': 1097.2938},
#    {'satid': 4366,
#     'satname': 'OPS 7044 (VELA 12)',
#     'intDesignator': '1970-027A',
#     'launchDate': '1970-04-08',
#     'satlat': -9.2196,
#     'satlng': 116.3323,
#     'satalt': 11771.0683},
#    {'satid': 4376,
#     'satname': 'INTELSAT 3-F7',
#     'intDesignator': '1970-032A',
#     'launchDate': '1970-04-23',
#     'satlat': -0.9318,
#     'satlng': -3.0257,
#     'satalt': 35798.0488},
#    {'satid': 4418,
#     'satname': 'OPS 5346',
#     'intDesignator': '1970-046A',
#     'launchDate': '1970-06-19',
#     'satlat': -2.9217,
#     'satlng': 73.5797,
#     'satalt': 35806.8548},
#    {'satid': 4449,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1969-082EU',
#     'launchDate': '1969-09-30',
#     'satlat': 66.9424,
#     'satlng': 64.7021,
#     'satalt': 818.2493},
#    {'satid': 4555,
#     'satname': 'SCOUT A DEB',
#     'intDesignator': '1966-041F',
#     'launchDate': '1966-05-19',
#     'satlat': 41.249,
#     'satlng': 87.4984,
#     'satalt': 742.5746},
#    {'satid': 4597,
#     'satname': 'SL-11 R/B',
#     'intDesignator': '1970-089B',
#     'launchDate': '1970-10-23',
#     'satlat': 43.5865,
#     'satlng': 41.5943,
#     'satalt': 1975.528},
#    {'satid': 4621,
#     'satname': 'COSMOS 374 DEB',
#     'intDesignator': '1970-089H',
#     'launchDate': '1970-10-23',
#     'satlat': 62.3683,
#     'satlng': 96.5593,
#     'satalt': 918.0524},
#    {'satid': 4632,
#     'satname': 'TITAN 3C TRANSTAGE R/B',
#     'intDesignator': '1970-093B',
#     'launchDate': '1970-11-06',
#     'satlat': 8.1372,
#     'satlng': -4.5171,
#     'satalt': 35226.6521},
#    {'satid': 4649,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025AH',
#     'launchDate': '1970-04-08',
#     'satlat': 52.5533,
#     'satlng': 60.4522,
#     'satalt': 606.8968},
#    {'satid': 4665,
#     'satname': 'COSMOS 375 DEB',
#     'intDesignator': '1970-091S',
#     'launchDate': '1970-10-30',
#     'satlat': 21.225,
#     'satlng': 62.5862,
#     'satalt': 1489.929},
#    {'satid': 4668,
#     'satname': 'COSMOS 374 DEB',
#     'intDesignator': '1970-089L',
#     'launchDate': '1970-10-23',
#     'satlat': 30.2008,
#     'satlng': 85.6522,
#     'satalt': 555.4693},
#    {'satid': 4679,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025BC',
#     'launchDate': '1970-04-08',
#     'satlat': 33.7077,
#     'satlng': 103.6325,
#     'satalt': 1018.3421},
#    {'satid': 4685,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025BJ',
#     'launchDate': '1970-04-08',
#     'satlat': 43.8156,
#     'satlng': 70.0178,
#     'satalt': 1076.7256},
#    {'satid': 4719,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025CD',
#     'launchDate': '1970-04-08',
#     'satlat': 15.5688,
#     'satlng': 83.4467,
#     'satalt': 998.4742},
#    {'satid': 4749,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025CX',
#     'launchDate': '1970-04-08',
#     'satlat': 60.9904,
#     'satlng': 76.7354,
#     'satalt': 965.9834},
#    {'satid': 4755,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025DD',
#     'launchDate': '1970-04-08',
#     'satlat': 47.2835,
#     'satlng': 45.9616,
#     'satalt': 942.4498},
#    {'satid': 4772,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025DS',
#     'launchDate': '1970-04-08',
#     'satlat': 33.6246,
#     'satlng': 100.0252,
#     'satalt': 1033.6632},
#    {'satid': 4786,
#     'satname': 'COSMOS 382',
#     'intDesignator': '1970-103A',
#     'launchDate': '1970-12-02',
#     'satlat': 19.6285,
#     'satlng': 78.0103,
#     'satalt': 4113.2043},
#    {'satid': 4800,
#     'satname': 'SL-8 R/B',
#     'intDesignator': '1970-108B',
#     'launchDate': '1970-12-12',
#     'satlat': 46.7659,
#     'satlng': 103.005,
#     'satalt': 974.9607},
#    {'satid': 4819,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025EA',
#     'launchDate': '1970-04-08',
#     'satlat': 38.5741,
#     'satlng': 98.6382,
#     'satalt': 819.8243},
#    {'satid': 4855,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025EK',
#     'launchDate': '1970-04-08',
#     'satlat': 45.1208,
#     'satlng': 53.2326,
#     'satalt': 1008.5559},
#    {'satid': 4859,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025EP',
#     'launchDate': '1970-04-08',
#     'satlat': 27.3671,
#     'satlng': 78.1464,
#     'satalt': 1076.1133},
#    {'satid': 4881,
#     'satname': 'INTELSAT 4-F2',
#     'intDesignator': '1971-006A',
#     'launchDate': '1971-01-26',
#     'satlat': -7.1737,
#     'satlng': 47.1616,
#     'satalt': 36254.2753},
#    {'satid': 4903,
#     'satname': 'DELTA 1 R/B',
#     'intDesignator': '1971-009B',
#     'launchDate': '1971-02-03',
#     'satlat': -25.2709,
#     'satlng': 72.1919,
#     'satalt': 14334.1175},
#    {'satid': 5028,
#     'satname': 'COSMOS 374 DEB *',
#     'intDesignator': '1970-089Z',
#     'launchDate': '1970-10-23',
#     'satlat': 59.0434,
#     'satlng': 92.0074,
#     'satalt': 1690.5542},
#    {'satid': 5054,
#     'satname': 'TITAN 34B AGENA D R/B',
#     'intDesignator': '1971-021B',
#     'launchDate': '1971-03-21',
#     'satlat': 62.4995,
#     'satlng': -81.8943,
#     'satalt': 35168.7863},
#    {'satid': 5094,
#     'satname': 'COSMOS 397 DEB',
#     'intDesignator': '1971-015U',
#     'launchDate': '1971-02-25',
#     'satlat': 15.4518,
#     'satlng': 83.5247,
#     'satalt': 726.3},
#    {'satid': 5150,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025JT',
#     'launchDate': '1970-04-08',
#     'satlat': 58.1753,
#     'satlng': 58.531,
#     'satalt': 887.3559},
#    {'satid': 5155,
#     'satname': 'COSMOS 397 DEB',
#     'intDesignator': '1971-015AJ',
#     'launchDate': '1971-02-25',
#     'satlat': 42.6216,
#     'satlng': 53.1573,
#     'satalt': 950.5354},
#    {'satid': 5180,
#     'satname': 'COSMOS 409',
#     'intDesignator': '1971-038A',
#     'launchDate': '1971-04-28',
#     'satlat': 36.3431,
#     'satlng': 60.7672,
#     'satalt': 1186.8631},
#    {'satid': 5197,
#     'satname': 'COSMOS 397 DEB',
#     'intDesignator': '1971-015AT',
#     'launchDate': '1971-02-25',
#     'satlat': 48.7444,
#     'satlng': 74.5556,
#     'satalt': 812.6842},
#    {'satid': 5210,
#     'satname': 'COSMOS 411',
#     'intDesignator': '1971-041A',
#     'launchDate': '1971-05-07',
#     'satlat': 41.6512,
#     'satlng': 54.0435,
#     'satalt': 1495.7474},
#    {'satid': 5211,
#     'satname': 'COSMOS 412',
#     'intDesignator': '1971-041B',
#     'launchDate': '1971-05-07',
#     'satlat': 13.9878,
#     'satlng': 98.0938,
#     'satalt': 1536.6121},
#    {'satid': 5443,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1967-114E',
#     'launchDate': '1967-11-10',
#     'satlat': 55.6655,
#     'satlng': 65.993,
#     'satalt': 1422.2211},
#    {'satid': 5457,
#     'satname': 'TITAN 3C TRANSTAGE DEB',
#     'intDesignator': '1965-108J',
#     'launchDate': '1965-12-21',
#     'satlat': 7.8703,
#     'satlng': 2.6628,
#     'satalt': 20599.2836},
#    {'satid': 5498,
#     'satname': 'M-4S R/B',
#     'intDesignator': '1971-080B',
#     'launchDate': '1971-09-28',
#     'satlat': 32.1263,
#     'satlng': 49.5848,
#     'satalt': 917.6224},
#    {'satid': 5614,
#     'satname': 'COSMOS 457',
#     'intDesignator': '1971-099A',
#     'launchDate': '1971-11-20',
#     'satlat': 70.9604,
#     'satlng': 85.3313,
#     'satalt': 1195.5177},
#    {'satid': 5635,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1969-082JF',
#     'launchDate': '1969-09-30',
#     'satlat': 62.629,
#     'satlng': 65.8042,
#     'satalt': 793.3563},
#    {'satid': 5682,
#     'satname': 'OPS 7898 (P/L 4)',
#     'intDesignator': '1971-110E',
#     'launchDate': '1971-12-14',
#     'satlat': 13.9315,
#     'satlng': 90.8787,
#     'satalt': 991.7025},
#    {'satid': 5775,
#     'satname': 'INTELSAT 4-F4',
#     'intDesignator': '1972-003A',
#     'launchDate': '1972-01-23',
#     'satlat': -10.3609,
#     'satlng': 125.299,
#     'satalt': 35921.3184},
#    {'satid': 5907,
#     'satname': 'SL-8 R/B',
#     'intDesignator': '1972-019B',
#     'launchDate': '1972-03-25',
#     'satlat': 53.0828,
#     'satlng': 45.1934,
#     'satalt': 1185.8782},
#    {'satid': 5918,
#     'satname': 'SL-3 R/B',
#     'intDesignator': '1972-022B',
#     'launchDate': '1972-03-30',
#     'satlat': 55.1616,
#     'satlng': 67.5969,
#     'satalt': 857.1388},
#    {'satid': 5922,
#     'satname': 'TIROS 2 DEB *',
#     'intDesignator': '1960-016E',
#     'launchDate': '1960-11-23',
#     'satlat': 45.0996,
#     'satlng': 96.3687,
#     'satalt': 1033.7853},
#    {'satid': 5986,
#     'satname': 'TITAN 3C TRANSTAGE DEB',
#     'intDesignator': '1965-108Q',
#     'launchDate': '1965-12-21',
#     'satlat': 10.3078,
#     'satlng': 100.4499,
#     'satalt': 5015.7671},
#    {'satid': 5991,
#     'satname': 'TITAN 3C TRANSTAGE DEB',
#     'intDesignator': '1965-108R',
#     'launchDate': '1965-12-21',
#     'satlat': -27.449,
#     'satlng': 46.9929,
#     'satalt': 20319.0302},
#    {'satid': 5992,
#     'satname': 'TITAN 3C TRANSTAGE DEB',
#     'intDesignator': '1965-108S',
#     'launchDate': '1965-12-21',
#     'satlat': 19.9149,
#     'satlng': 133.3357,
#     'satalt': 26668.8003},
#    {'satid': 6118,
#     'satname': 'COSMOS 505',
#     'intDesignator': '1972-057B',
#     'launchDate': '1972-07-20',
#     'satlat': 29.6869,
#     'satlng': 112.2108,
#     'satalt': 1432.6666},
#    {'satid': 6192,
#     'satname': 'COSMOS 520',
#     'intDesignator': '1972-072A',
#     'launchDate': '1972-09-19',
#     'satlat': 52.892,
#     'satlng': -33.0231,
#     'satalt': 22923.2692},
#    {'satid': 6264,
#     'satname': 'COSMOS 529',
#     'intDesignator': '1972-087B',
#     'launchDate': '1972-11-01',
#     'satlat': 62.5882,
#     'satlng': 104.2082,
#     'satalt': 1448.0091},
#    {'satid': 6278,
#     'satname': 'ANIK A1 (TELESAT 1)',
#     'intDesignator': '1972-090A',
#     'launchDate': '1972-11-10',
#     'satlat': -8.5634,
#     'satlng': 60.1036,
#     'satalt': 36197.767},
#    {'satid': 6317,
#     'satname': 'OPS 9390',
#     'intDesignator': '1972-101A',
#     'launchDate': '1972-12-20',
#     'satlat': -13.6463,
#     'satlng': 78.0827,
#     'satalt': 37468.2168},
#    {'satid': 6380,
#     'satname': 'OPS 6063',
#     'intDesignator': '1973-013A',
#     'launchDate': '1973-03-06',
#     'satlat': -5.4701,
#     'satlng': 75.0901,
#     'satalt': 35732.8649},
#    {'satid': 6691,
#     'satname': 'OPS 6157',
#     'intDesignator': '1973-040A',
#     'launchDate': '1973-06-12',
#     'satlat': -4.9542,
#     'satlng': 40.3756,
#     'satalt': 35923.1636},
#    {'satid': 6791,
#     'satname': 'OPS 7724',
#     'intDesignator': '1973-056A',
#     'launchDate': '1973-08-21',
#     'satlat': 60.6586,
#     'satlng': -115.3602,
#     'satalt': 39313.3421},
#    {'satid': 6797,
#     'satname': 'ATLAS CENTAUR R/B',
#     'intDesignator': '1973-058B',
#     'launchDate': '1973-08-23',
#     'satlat': 26.5898,
#     'satlng': 93.0425,
#     'satalt': 35615.4986},
#    {'satid': 6850,
#     'satname': 'COSMOS 593',
#     'intDesignator': '1973-069F',
#     'launchDate': '1973-10-02',
#     'satlat': 54.2146,
#     'satlng': 66.7354,
#     'satalt': 1392.9065},
#    {'satid': 6916,
#     'satname': 'COSMOS 606',
#     'intDesignator': '1973-084A',
#     'launchDate': '1973-11-02',
#     'satlat': 18.1195,
#     'satlng': 41.1578,
#     'satalt': 35460.2774},
#    {'satid': 6973,
#     'satname': 'OPS 9433 (DSCS 2-3)',
#     'intDesignator': '1973-100A',
#     'launchDate': '1973-12-13',
#     'satlat': -8.8017,
#     'satlng': 56.8953,
#     'satalt': 36473.6233},
#    {'satid': 6976,
#     'satname': 'TITAN 3C TRANSTAGE R/B',
#     'intDesignator': '1973-100D',
#     'launchDate': '1973-12-13',
#     'satlat': -10.7306,
#     'satlng': 69.2152,
#     'satalt': 38437.245},
#    {'satid': 6992,
#     'satname': 'COSMOS 624',
#     'intDesignator': '1973-104H',
#     'launchDate': '1973-12-19',
#     'satlat': 17.7302,
#     'satlng': 57.7485,
#     'satalt': 1434.5509},
#    {'satid': 7003,
#     'satname': 'AUREOLE 2',
#     'intDesignator': '1973-107A',
#     'launchDate': '1973-12-26',
#     'satlat': 54.4379,
#     'satlng': 66.4773,
#     'satalt': 412.9998},
#    {'satid': 7008,
#     'satname': 'COSMOS 627',
#     'intDesignator': '1973-109A',
#     'launchDate': '1973-12-29',
#     'satlat': 49.3335,
#     'satlng': 53.9005,
#     'satalt': 1014.0613},
#    {'satid': 7012,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086C',
#     'launchDate': '1973-11-06',
#     'satlat': 50.3384,
#     'satlng': 42.2194,
#     'satalt': 1484.9907},
#    {'satid': 7017,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086H',
#     'launchDate': '1973-11-06',
#     'satlat': 39.7886,
#     'satlng': 62.0076,
#     'satalt': 1518.562},
#    {'satid': 7037,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086AD',
#     'launchDate': '1973-11-06',
#     'satlat': 27.2361,
#     'satlng': 79.9895,
#     'satalt': 1582.082},
#    {'satid': 7045,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086AM',
#     'launchDate': '1973-11-06',
#     'satlat': 74.076,
#     'satlng': 64.6005,
#     'satalt': 1634.6866},
#    {'satid': 7056,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086AY',
#     'launchDate': '1973-11-06',
#     'satlat': 69.8209,
#     'satlng': 36.174,
#     'satalt': 1518.0397},
#    {'satid': 7065,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086BH',
#     'launchDate': '1973-11-06',
#     'satlat': 20.9554,
#     'satlng': 69.421,
#     'satalt': 1519.5395},
#    {'satid': 7126,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086CQ',
#     'launchDate': '1973-11-06',
#     'satlat': 42.3525,
#     'satlng': 37.4487,
#     'satalt': 1364.8987},
#    {'satid': 7135,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086CZ',
#     'launchDate': '1973-11-06',
#     'satlat': 15.0708,
#     'satlng': 55.8027,
#     'satalt': 1344.1951},
#    {'satid': 7137,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086DB',
#     'launchDate': '1973-11-06',
#     'satlat': 71.3361,
#     'satlng': 50.7701,
#     'satalt': 1413.1711},
#    {'satid': 7153,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086DT',
#     'launchDate': '1973-11-06',
#     'satlat': 70.5009,
#     'satlng': 50.4615,
#     'satalt': 1562.4995},
#    {'satid': 7181,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086ES',
#     'launchDate': '1973-11-06',
#     'satlat': 19.0462,
#     'satlng': 51.6711,
#     'satalt': 1505.4552},
#    {'satid': 7183,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086EU',
#     'launchDate': '1973-11-06',
#     'satlat': 45.9363,
#     'satlng': 60.4008,
#     'satalt': 1477.8739},
#    {'satid': 7269,
#     'satname': 'COSMOS 645',
#     'intDesignator': '1974-024E',
#     'launchDate': '1974-04-23',
#     'satlat': 28.6911,
#     'satlng': 114.4989,
#     'satalt': 1475.1387},
#    {'satid': 7349,
#     'satname': 'COSMOS 663',
#     'intDesignator': '1974-048A',
#     'launchDate': '1974-06-27',
#     'satlat': 47.375,
#     'satlng': 113.9835,
#     'satalt': 982.9341},
#    {'satid': 7373,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1974-026E',
#     'launchDate': '1974-04-26',
#     'satlat': 62.6287,
#     'satlng': 178.5613,
#     'satalt': 37415.2349},
#    {'satid': 7376,
#     'satname': 'MOLNIYA 2-10',
#     'intDesignator': '1974-056A',
#     'launchDate': '1974-07-23',
#     'satlat': 55.5828,
#     'satlng': 73.9637,
#     'satalt': 21816.6649},
#    {'satid': 7392,
#     'satname': 'MOLNIYA 1-S',
#     'intDesignator': '1974-060A',
#     'launchDate': '1974-07-29',
#     'satlat': -5.2312,
#     'satlng': 41.1633,
#     'satalt': 35755.6447},
#    {'satid': 7433,
#     'satname': 'COSMOS 676',
#     'intDesignator': '1974-071A',
#     'launchDate': '1974-09-11',
#     'satlat': 31.1349,
#     'satlng': 73.1879,
#     'satalt': 794.3764},
#    {'satid': 7439,
#     'satname': 'COSMOS 681',
#     'intDesignator': '1974-072E',
#     'launchDate': '1974-09-19',
#     'satlat': 19.0351,
#     'satlng': 53.7143,
#     'satalt': 1473.8064},
#    {'satid': 7532,
#     'satname': 'THORAD DELTA 1 R/B',
#     'intDesignator': '1974-089D',
#     'launchDate': '1974-11-15',
#     'satlat': 41.3967,
#     'satlng': 76.0291,
#     'satalt': 1506.0418},
#    {'satid': 7545,
#     'satname': 'ATLAS CENTAUR R/B',
#     'intDesignator': '1974-093B',
#     'launchDate': '1974-11-21',
#     'satlat': 14.1114,
#     'satlng': 35.2409,
#     'satalt': 11389.5264},
#    {'satid': 7547,
#     'satname': 'SKYNET 2B',
#     'intDesignator': '1974-094A',
#     'launchDate': '1974-11-23',
#     'satlat': -2.3132,
#     'satlng': 14.9464,
#     'satalt': 35799.8378},
#    {'satid': 7578,
#     'satname': 'SYMPHONIE 1',
#     'intDesignator': '1974-101A',
#     'launchDate': '1974-12-19',
#     'satlat': -9.3914,
#     'satlng': 77.0629,
#     'satalt': 35877.5685},
#    {'satid': 7625,
#     'satname': 'COSMOS 706',
#     'intDesignator': '1975-007A',
#     'launchDate': '1975-01-30',
#     'satlat': 36.1907,
#     'satlng': 13.5882,
#     'satalt': 19555.8659},
#    {'satid': 7629,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1975-007D',
#     'launchDate': '1975-01-30',
#     'satlat': -3.8113,
#     'satlng': 35.3396,
#     'satalt': 32258.5457},
#    {'satid': 7648,
#     'satname': 'SMS 2',
#     'intDesignator': '1975-011A',
#     'launchDate': '1975-02-06',
#     'satlat': 0.2619,
#     'satlng': 1.6201,
#     'satalt': 35961.875},
#    {'satid': 7683,
#     'satname': 'COSMOS 716',
#     'intDesignator': '1975-016F',
#     'launchDate': '1975-02-28',
#     'satlat': 22.5906,
#     'satlng': 91.4987,
#     'satalt': 1516.2347},
#    {'satid': 7780,
#     'satname': 'MOLNIYA 1-29',
#     'intDesignator': '1975-036A',
#     'launchDate': '1975-04-29',
#     'satlat': 58.6147,
#     'satlng': -73.59,
#     'satalt': 39432.3309},
#    {'satid': 7800,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1975-036D',
#     'launchDate': '1975-04-29',
#     'satlat': 55.8681,
#     'satlng': -38.4391,
#     'satalt': 23484.0329},
#    {'satid': 7824,
#     'satname': 'COSMOS 735',
#     'intDesignator': '1975-045D',
#     'launchDate': '1975-05-28',
#     'satlat': 71.3298,
#     'satlng': 70.3104,
#     'satalt': 1474.1067},
#    {'satid': 7836,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1972-058G',
#     'launchDate': '1972-07-23',
#     'satlat': 22.1967,
#     'satlng': 91.6115,
#     'satalt': 833.7747},
#    {'satid': 7893,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1972-058BK',
#     'launchDate': '1972-07-23',
#     'satlat': 20.4129,
#     'satlng': 55.8148,
#     'satalt': 687.3622},
#    {'satid': 7902,
#     'satname': 'ATLAS CENTAUR R/B',
#     'intDesignator': '1975-042B',
#     'launchDate': '1975-05-22',
#     'satlat': 1.7633,
#     'satlng': 91.7181,
#     'satalt': 17853.1927},
#    {'satid': 7940,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1972-058CF',
#     'launchDate': '1972-07-23',
#     'satlat': 45.2921,
#     'satlng': 76.5912,
#     'satalt': 987.2586},
#    {'satid': 7963,
#     'satname': 'OPS 4966',
#     'intDesignator': '1975-055A',
#     'launchDate': '1975-06-18',
#     'satlat': -14.9419,
#     'satlng': 88.4183,
#     'satalt': 33495.4383},
#    {'satid': 7964,
#     'satname': 'ATLAS AGENA R/B',
#     'intDesignator': '1975-055B',
#     'launchDate': '1975-06-18',
#     'satlat': -12.1079,
#     'satlng': 33.6574,
#     'satalt': 40703.2941},
#    {'satid': 7979,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1972-058DA',
#     'launchDate': '1972-07-23',
#     'satlat': 48.7873,
#     'satlng': 44.4685,
#     'satalt': 1192.1863},
#    {'satid': 8018,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1975-063D',
#     'launchDate': '1975-07-08',
#     'satlat': 32.137,
#     'satlng': 41.2413,
#     'satalt': 20470.0419},
#    {'satid': 8132,
#     'satname': 'SYMPHONIE 2',
#     'intDesignator': '1975-077A',
#     'launchDate': '1975-08-27',
#     'satlat': -6.6349,
#     'satlng': 130.6716,
#     'satalt': 35849.6258},
#    {'satid': 8141,
#     'satname': 'THORAD DELTA 1 DEB',
#     'intDesignator': '1974-089K',
#     'launchDate': '1974-11-15',
#     'satlat': 55.5255,
#     'satlng': 114.0107,
#     'satalt': 1575.7613},
#    {'satid': 8156,
#     'satname': 'THORAD DELTA 1 DEB',
#     'intDesignator': '1974-089W',
#     'launchDate': '1974-11-15',
#     'satlat': 58.7963,
#     'satlng': 107.9216,
#     'satalt': 1360.9737},
#    {'satid': 8162,
#     'satname': 'THORAD DELTA 1 DEB',
#     'intDesignator': '1974-089AC',
#     'launchDate': '1974-11-15',
#     'satlat': 25.8479,
#     'satlng': 75.7412,
#     'satalt': 1464.7138},
#    {'satid': 8167,
#     'satname': 'THORAD DELTA 1 DEB',
#     'intDesignator': '1974-089AH',
#     'launchDate': '1974-11-15',
#     'satlat': 49.4872,
#     'satlng': 50.7731,
#     'satalt': 1126.3318},
#    {'satid': 8195,
#     'satname': 'MOLNIYA 2-14',
#     'intDesignator': '1975-081A',
#     'launchDate': '1975-09-09',
#     'satlat': 61.8581,
#     'satlng': -119.1957,
#     'satalt': 35534.771},
#    {'satid': 8285,
#     'satname': 'COSMOS 761',
#     'intDesignator': '1975-086A',
#     'launchDate': '1975-09-17',
#     'satlat': 22.2324,
#     'satlng': 103.8306,
#     'satalt': 1470.6524},
#    {'satid': 8286,
#     'satname': 'COSMOS 762',
#     'intDesignator': '1975-086B',
#     'launchDate': '1975-09-17',
#     'satlat': 54.9998,
#     'satlng': 95.7328,
#     'satalt': 1447.831},
#    {'satid': 8288,
#     'satname': 'COSMOS 764',
#     'intDesignator': '1975-086D',
#     'launchDate': '1975-09-17',
#     'satlat': 73.4116,
#     'satlng': 52.5383,
#     'satalt': 1515.8323},
#    {'satid': 8291,
#     'satname': 'COSMOS 767',
#     'intDesignator': '1975-086G',
#     'launchDate': '1975-09-17',
#     'satlat': 24.7211,
#     'satlng': 44.6548,
#     'satalt': 1480.9099},
#    {'satid': 8294,
#     'satname': 'SL-3 R/B',
#     'intDesignator': '1975-087B',
#     'launchDate': '1975-09-18',
#     'satlat': 39.1677,
#     'satlng': 109.4927,
#     'satalt': 799.1293},
#    {'satid': 8357,
#     'satname': 'COSMOS 775',
#     'intDesignator': '1975-097A',
#     'launchDate': '1975-10-08',
#     'satlat': -6.6841,
#     'satlng': 107.5026,
#     'satalt': 35844.3302},
#    {'satid': 8399,
#     'satname': 'THORAD DELTA 1 DEB',
#     'intDesignator': '1974-089CB',
#     'launchDate': '1974-11-15',
#     'satlat': 56.4378,
#     'satlng': 85.7733,
#     'satalt': 1420.4548},
#    {'satid': 8401,
#     'satname': 'THORAD DELTA 1 DEB',
#     'intDesignator': '1974-089CD',
#     'launchDate': '1974-11-15',
#     'satlat': 48.7969,
#     'satlng': 108.0227,
#     'satalt': 1352.961},
#    {'satid': 8439,
#     'satname': 'THORAD DELTA 1 DEB',
#     'intDesignator': '1974-089CQ',
#     'launchDate': '1974-11-15',
#     'satlat': 67.719,
#     'satlng': 62.7738,
#     'satalt': 1273.5938},
#    {'satid': 8482,
#     'satname': 'OPS 3165',
#     'intDesignator': '1975-118A',
#     'launchDate': '1975-12-14',
#     'satlat': -5.8967,
#     'satlng': 42.2679,
#     'satalt': 35728.9642},
#    {'satid': 8513,
#     'satname': 'RADUGA 1',
#     'intDesignator': '1975-123A',
#     'launchDate': '1975-12-22',
#     'satlat': -7.6325,
#     'satlng': 67.2862,
#     'satalt': 35767.0859},
#    {'satid': 8546,
#     'satname': 'SL-12 R/B(AUX MOTOR)',
#     'intDesignator': '1975-123D',
#     'launchDate': '1975-12-22',
#     'satlat': -21.0981,
#     'satlng': 106.0829,
#     'satalt': 16241.7296},
#    {'satid': 8556,
#     'satname': 'THORAD DELTA 1 DEB',
#     'intDesignator': '1974-089CT',
#     'launchDate': '1974-11-15',
#     'satlat': 51.7212,
#     'satlng': 55.0572,
#     'satalt': 1502.1106},
#    {'satid': 8599,
#     'satname': 'NTS 1 AKM',
#     'intDesignator': '1974-054C',
#     'launchDate': '1974-07-14',
#     'satlat': 54.8752,
#     'satlng': 176.9883,
#     'satalt': 13711.2269},
#    {'satid': 8620,
#     'satname': 'INTELSAT 4A-F2',
#     'intDesignator': '1976-010A',
#     'launchDate': '1976-01-29',
#     'satlat': -11.9259,
#     'satlng': 98.0069,
#     'satalt': 35938.2703},
#    {'satid': 8710,
#     'satname': 'N-1 R/B',
#     'intDesignator': '1976-019B',
#     'launchDate': '1976-02-29',
#     'satlat': 55.6585,
#     'satlng': 108.7656,
#     'satalt': 1010.0862},
#    {'satid': 8748,
#     'satname': 'SOLRAD 11A',
#     'intDesignator': '1976-023C',
#     'launchDate': '1976-03-15',
#     'satlat': 13.5242,
#     'satlng': 6.054,
#     'satalt': 118116.985},
#    {'satid': 8752,
#     'satname': 'SOLRAD 11A AKM',
#     'intDesignator': '1976-023G',
#     'launchDate': '1976-03-15',
#     'satlat': -23.3305,
#     'satlng': 127.9149,
#     'satalt': 77142.4954},
#    {'satid': 8753,
#     'satname': 'SOLRAD 11B AKM',
#     'intDesignator': '1976-023H',
#     'launchDate': '1976-03-15',
#     'satlat': -11.6722,
#     'satlng': 49.0356,
#     'satalt': 127915.4557},
#    {'satid': 8832,
#     'satname': 'TITAN 3C TRANSTAGE DEB',
#     'intDesignator': '1976-023J',
#     'launchDate': '1976-03-15',
#     'satlat': 17.0163,
#     'satlng': 20.8653,
#     'satalt': 35881.1125},
#    {'satid': 8882,
#     'satname': 'MARISAT 3',
#     'intDesignator': '1976-053A',
#     'launchDate': '1976-06-10',
#     'satlat': 3.5879,
#     'satlng': -2.4162,
#     'satalt': 37344.6272},
#    {'satid': 8893,
#     'satname': 'COSMOS 829',
#     'intDesignator': '1976-054E',
#     'launchDate': '1976-06-15',
#     'satlat': 72.8019,
#     'satlng': 87.9773,
#     'satalt': 1495.9997},
#    {'satid': 8916,
#     'satname': 'OPS 2112',
#     'intDesignator': '1976-059A',
#     'launchDate': '1976-06-26',
#     'satlat': -3.8595,
#     'satlng': 20.7883,
#     'satalt': 35998.3963},
#    {'satid': 8970,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1975-004BC',
#     'launchDate': '1975-01-22',
#     'satlat': 64.6655,
#     'satlng': 80.1009,
#     'satalt': 830.1421},
#    {'satid': 9271,
#     'satname': 'TITAN 34B AGENA R/B',
#     'intDesignator': '1976-080B',
#     'launchDate': '1976-08-06',
#     'satlat': 50.9148,
#     'satlng': -42.1254,
#     'satalt': 27730.1084},
#    {'satid': 9329,
#     'satname': 'ATLAS CENTAUR R/B',
#     'intDesignator': '1976-073B',
#     'launchDate': '1976-07-22',
#     'satlat': 0.9463,
#     'satlng': 41.2298,
#     'satalt': 35868.5057},
#    {'satid': 9416,
#     'satname': 'RADUGA 2',
#     'intDesignator': '1976-092A',
#     'launchDate': '1976-09-11',
#     'satlat': -8.5671,
#     'satlng': 84.6784,
#     'satalt': 35743.9009},
#    {'satid': 9478,
#     'satname': 'MARISAT 2',
#     'intDesignator': '1976-101A',
#     'launchDate': '1976-10-14',
#     'satlat': -9.4892,
#     'satlng': 125.7555,
#     'satalt': 36136.658},
#    {'satid': 9495,
#     'satname': 'COSMOS 862',
#     'intDesignator': '1976-105A',
#     'launchDate': '1976-10-22',
#     'satlat': 61.6139,
#     'satlng': 84.6527,
#     'satalt': 35704.9492},
#    {'satid': 9503,
#     'satname': 'EKRAN 1',
#     'intDesignator': '1976-107A',
#     'launchDate': '1976-10-26',
#     'satlat': -7.944,
#     'satlng': 61.3805,
#     'satalt': 35911.0931},
#    {'satid': 9598,
#     'satname': 'SL-8 R/B',
#     'intDesignator': '1976-118J',
#     'launchDate': '1976-12-07',
#     'satlat': 65.876,
#     'satlng': 58.4471,
#     'satalt': 1671.2535},
#    {'satid': 9638,
#     'satname': 'SL-8 R/B',
#     'intDesignator': '1976-128B',
#     'launchDate': '1976-12-28',
#     'satlat': 26.8898,
#     'satlng': 57.4656,
#     'satalt': 956.2193},
#    {'satid': 9666,
#     'satname': 'THORAD AGENA D DEB',
#     'intDesignator': '1970-025NK',
#     'launchDate': '1970-04-08',
#     'satlat': 35.9356,
#     'satlng': 76.6244,
#     'satalt': 961.2917},
#    {'satid': 9726,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086GC',
#     'launchDate': '1973-11-06',
#     'satlat': 47.9472,
#     'satlng': 26.9003,
#     'satalt': 1634.8898},
#    {'satid': 9730,
#     'satname': 'THORAD DELTA 1 DEB',
#     'intDesignator': '1974-089DZ',
#     'launchDate': '1974-11-15',
#     'satlat': 34.5476,
#     'satlng': 48.6142,
#     'satalt': 1152.8344},
#    {'satid': 9798,
#     'satname': 'COSMOS 886 DEB *',
#     'intDesignator': '1976-126Y',
#     'launchDate': '1976-12-27',
#     'satlat': 48.9941,
#     'satlng': 82.008,
#     'satalt': 955.5488},
#    {'satid': 9822,
#     'satname': 'COSMOS 886 DEB',
#     'intDesignator': '1976-126AJ',
#     'launchDate': '1976-12-27',
#     'satlat': 28.657,
#     'satlng': 28.1753,
#     'satalt': 1999.7947},
#    {'satid': 9880,
#     'satname': 'MOLNIYA 1-36',
#     'intDesignator': '1977-021A',
#     'launchDate': '1977-03-24',
#     'satlat': 14.7432,
#     'satlng': 41.1398,
#     'satalt': 13591.3385},
#    {'satid': 9896,
#     'satname': 'COSMOS 862 DEB',
#     'intDesignator': '1976-105N',
#     'launchDate': '1976-10-22',
#     'satlat': 54.3257,
#     'satlng': 22.3754,
#     'satalt': 33555.7088},
#    {'satid': 9921,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1977-027D',
#     'launchDate': '1977-04-11',
#     'satlat': 39.7568,
#     'satlng': 113.8606,
#     'satalt': 34428.6311},
#    {'satid': 9976,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086GF',
#     'launchDate': '1973-11-06',
#     'satlat': 70.5459,
#     'satlng': 54.7833,
#     'satalt': 1574.6904},
#    {'satid': 9977,
#     'satname': 'DELTA 1 DEB',
#     'intDesignator': '1973-086GG',
#     'launchDate': '1973-11-06',
#     'satlat': 33.9566,
#     'satlng': 93.4577,
#     'satalt': 1419.4577},
#    {'satid': 9998,
#     'satname': 'SMS 1 AKM',
#     'intDesignator': '1974-033F',
#     'launchDate': '1974-05-17',
#     'satlat': 0.5888,
#     'satlng': 7.9159,
#     'satalt': 31611.6589},
#    {'satid': 10000,
#     'satname': 'OPS 9437 (DSCS 2-7)',
#     'intDesignator': '1977-034A',
#     'launchDate': '1977-05-12',
#     'satlat': -9.2941,
#     'satlng': 55.6312,
#     'satalt': 36832.8735},
#    {'satid': 10016,
#     'satname': 'OPS 9751',
#     'intDesignator': '1977-038A',
#     'launchDate': '1977-05-23',
#     'satlat': -5.9703,
#     'satlng': 70.0374,
#     'satalt': 38423.7799},
#    {'satid': 10024,
#     'satname': 'INTELSAT 4A-F4',
#     'intDesignator': '1977-041A',
#     'launchDate': '1977-05-26',
#     'satlat': 5.359,
#     'satlng': -0.2282,
#     'satalt': 35998.9621},
#    {'satid': 10061,
#     'satname': 'GOES 2',
#     'intDesignator': '1977-048A',
#     'launchDate': '1977-06-16',
#     'satlat': -1.5135,
#     'satlng': 17.4751,
#     'satalt': 36096.5063},
#    {'satid': 10142,
#     'satname': 'SL-8 R/B',
#     'intDesignator': '1977-064B',
#     'launchDate': '1977-07-13',
#     'satlat': 62.8773,
#     'satlng': 46.5921,
#     'satalt': 959.9397},
#    {'satid': 10155,
# ...
#     'satlng': 28.5005,
#     'satalt': 19154.0451},
#    {'satid': 23527,
#     'satname': 'SL-8 R/B',
#     'intDesignator': '1995-012B',
#     'launchDate': '1995-03-21',
#     'satlat': 26.8293,
#     'satlng': 53.9565,
#     'satalt': 974.5793},
#    {'satid': 23528,
#     'satname': 'INTELSAT 705',
#     'intDesignator': '1995-013A',
#     'launchDate': '1995-03-22',
#     'satlat': 7.0198,
#     'satlng': 47.335,
#     'satalt': 36133.9751},
#    {'satid': 23567,
#     'satname': 'USA 110',
#     'intDesignator': '1995-022A',
#     'launchDate': '1995-05-14',
#     'satlat': -4.9126,
#     'satlng': 101.1296,
#     'satalt': 35863.3002},
#    {'satid': 23568,
#     'satname': 'TITAN 4 CENTAUR R/B',
#     'intDesignator': '1995-022B',
#     'launchDate': '1995-05-14',
#     'satlat': -8.0869,
#     'satlng': 110.4712,
#     'satalt': 35721.8037},
#    {'satid': 23587,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1995-026D',
#     'launchDate': '1995-05-24',
#     'satlat': 43.8875,
#     'satlng': 27.4588,
#     'satalt': 4723.5023},
#    {'satid': 23598,
#     'satname': 'DIRECTV 3 (DBS/NIMIQ 3)',
#     'intDesignator': '1995-029A',
#     'launchDate': '1995-06-10',
#     'satlat': -3.6007,
#     'satlng': 129.5776,
#     'satalt': 36167.9863},
#    {'satid': 23609,
#     'satname': 'USA 112',
#     'intDesignator': '1995-034A',
#     'launchDate': '1995-07-10',
#     'satlat': 59.0533,
#     'satlng': -17.2255,
#     'satalt': 35248.1884},
#    {'satid': 23613,
#     'satname': 'TDRS 7',
#     'intDesignator': '1995-035B',
#     'launchDate': '1995-07-13',
#     'satlat': -5.9447,
#     'satlng': 83.9347,
#     'satalt': 35896.1837},
#    {'satid': 23615,
#     'satname': 'IUS R/B(2)',
#     'intDesignator': '1995-035D',
#     'launchDate': '1995-07-13',
#     'satlat': -11.5419,
#     'satlng': 99.1763,
#     'satalt': 35748.2049},
#    {'satid': 23621,
#     'satname': 'COSMOS 2317 (GLONASS)',
#     'intDesignator': '1995-037B',
#     'launchDate': '1995-07-24',
#     'satlat': 0.5063,
#     'satlng': 145.4953,
#     'satalt': 19153.0879},
#    {'satid': 23628,
#     'satname': 'USA 113',
#     'intDesignator': '1995-038A',
#     'launchDate': '1995-07-31',
#     'satlat': -3.6163,
#     'satlng': 103.2491,
#     'satalt': 35780.1086},
#    {'satid': 23636,
#     'satname': 'INTELSAT 4 (PAS 4)',
#     'intDesignator': '1995-040A',
#     'launchDate': '1995-08-03',
#     'satlat': 1.1524,
#     'satlng': 101.894,
#     'satalt': 36573.2161},
#    {'satid': 23637,
#     'satname': 'ARIANE 42L+3 R/B',
#     'intDesignator': '1995-040B',
#     'launchDate': '1995-08-03',
#     'satlat': 1.462,
#     'satlng': 30.3976,
#     'satalt': 32973.8572},
#    {'satid': 23639,
#     'satname': 'KOREASAT 1',
#     'intDesignator': '1995-041A',
#     'launchDate': '1995-08-05',
#     'satlat': 8.9823,
#     'satlng': 32.8319,
#     'satalt': 35966.8742},
#    {'satid': 23647,
#     'satname': 'TITAN 34B DEB',
#     'intDesignator': '1981-038C',
#     'launchDate': '1981-04-24',
#     'satlat': 59.5684,
#     'satlng': 46.9485,
#     'satalt': 28797.2568},
#    {'satid': 23648,
#     'satname': 'ATLAS 2 CENTAUR R/B(2)',
#     'intDesignator': '1995-038C',
#     'launchDate': '1995-07-31',
#     'satlat': 12.5679,
#     'satlng': 0.1791,
#     'satalt': 35573.3945},
#    {'satid': 23680,
#     'satname': 'LUCH 1',
#     'intDesignator': '1995-054A',
#     'launchDate': '1995-10-11',
#     'satlat': -0.4335,
#     'satlng': 73.6955,
#     'satalt': 35798.6037},
#    {'satid': 23683,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1995-054D',
#     'launchDate': '1995-10-11',
#     'satlat': 12.3475,
#     'satlng': 15.0119,
#     'satalt': 35771.6652},
#    {'satid': 23686,
#     'satname': 'ASTRA 1E',
#     'intDesignator': '1995-055A',
#     'launchDate': '1995-10-19',
#     'satlat': -0.6833,
#     'satlng': 115.4081,
#     'satalt': 36227.7709},
#    {'satid': 23696,
#     'satname': 'UFO 6 (USA 114)',
#     'intDesignator': '1995-057A',
#     'launchDate': '1995-10-22',
#     'satlat': -3.7746,
#     'satlng': 101.7134,
#     'satalt': 36216.9544},
#    {'satid': 23713,
#     'satname': 'TITAN 401 CENTAUR R/B',
#     'intDesignator': '1995-060B',
#     'launchDate': '1995-11-06',
#     'satlat': 6.6537,
#     'satlng': 43.4157,
#     'satalt': 35571.4272},
#    {'satid': 23715,
#     'satname': 'ISO',
#     'intDesignator': '1995-062A',
#     'launchDate': '1995-11-17',
#     'satlat': 0.7715,
#     'satlng': 62.8116,
#     'satalt': 67017.3232},
#    {'satid': 23720,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1995-063D',
#     'launchDate': '1995-11-17',
#     'satlat': -14.2506,
#     'satlng': 133.5063,
#     'satalt': 35862.3661},
#    {'satid': 23730,
#     'satname': 'TELECOM 2C',
#     'intDesignator': '1995-067A',
#     'launchDate': '1995-12-06',
#     'satlat': -3.8425,
#     'satlng': 104.1233,
#     'satalt': 36418.4779},
#    {'satid': 23732,
#     'satname': 'ARIANE 44L+3 R/B',
#     'intDesignator': '1995-067C',
#     'launchDate': '1995-12-06',
#     'satlat': 5.7698,
#     'satlng': 64.4821,
#     'satalt': 21197.1222},
#    {'satid': 23736,
#     'satname': 'COSMOS 2323 (GLONASS)',
#     'intDesignator': '1995-068C',
#     'launchDate': '1995-12-14',
#     'satlat': 48.8115,
#     'satlng': 175.8969,
#     'satalt': 19150.7371},
#    {'satid': 23739,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1995-068F',
#     'launchDate': '1995-12-14',
#     'satlat': 1.4858,
#     'satlng': 144.8293,
#     'satalt': 19132.61},
#    {'satid': 23756,
#     'satname': 'ECHOSTAR 1 PKM',
#     'intDesignator': '1995-073C',
#     'launchDate': '1995-12-28',
#     'satlat': -9.9247,
#     'satlng': 112.2119,
#     'satalt': 17840.3897},
#    {'satid': 23764,
#     'satname': 'INTELSAT 3R (PAS 3R)',
#     'intDesignator': '1996-002A',
#     'launchDate': '1996-01-12',
#     'satlat': 8.1897,
#     'satlng': 18.2775,
#     'satalt': 36170.5137},
#    {'satid': 23770,
#     'satname': 'DELTA 2 R/B(2)',
#     'intDesignator': '1996-003C',
#     'launchDate': '1996-01-14',
#     'satlat': 14.1964,
#     'satlng': 7.5969,
#     'satalt': 11520.803},
#    {'satid': 23775,
#     'satname': 'GORIZONT 31',
#     'intDesignator': '1996-005A',
#     'launchDate': '1996-01-25',
#     'satlat': 9.3152,
#     'satlng': 27.3973,
#     'satalt': 35849.0855},
#    {'satid': 23778,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1996-005D',
#     'launchDate': '1996-01-25',
#     'satlat': -9.0235,
#     'satlng': 104.7595,
#     'satalt': 36536.8479},
#    {'satid': 23779,
#     'satname': 'PAKSAT 1 (ANATOLIA 1)',
#     'intDesignator': '1996-006A',
#     'launchDate': '1996-02-01',
#     'satlat': 6.2796,
#     'satlng': 6.2867,
#     'satalt': 35976.6765},
#    {'satid': 23781,
#     'satname': 'NSTAR B',
#     'intDesignator': '1996-007A',
#     'launchDate': '1996-02-05',
#     'satlat': -6.8073,
#     'satlng': 137.6454,
#     'satalt': 36031.6969},
#    {'satid': 23788,
#     'satname': 'GONETS D1 2',
#     'intDesignator': '1996-009B',
#     'launchDate': '1996-02-19',
#     'satlat': 52.1603,
#     'satlng': 41.8278,
#     'satalt': 1417.3126},
#    {'satid': 23806,
#     'satname': 'TITAN 34B DEB',
#     'intDesignator': '1981-038D',
#     'launchDate': '1981-04-24',
#     'satlat': 62.6894,
#     'satlng': -37.1689,
#     'satalt': 55513.1915},
#    {'satid': 23816,
#     'satname': 'INTELSAT 707',
#     'intDesignator': '1996-015A',
#     'launchDate': '1996-03-14',
#     'satlat': 5.4324,
#     'satlng': 59.7964,
#     'satalt': 36583.3663},
#    {'satid': 23821,
#     'satname': 'OPS 0856 DEB',
#     'intDesignator': '1966-077E',
#     'launchDate': '1966-08-19',
#     'satlat': 26.9077,
#     'satlng': 109.6636,
#     'satalt': 2408.4474},
#    {'satid': 23829,
#     'satname': 'OPS 0856 DEB',
#     'intDesignator': '1966-077F',
#     'launchDate': '1966-08-19',
#     'satlat': 75.6313,
#     'satlng': 95.0868,
#     'satalt': 5425.5494},
#    {'satid': 23841,
#     'satname': 'OPS 0856 DEB',
#     'intDesignator': '1966-077L',
#     'launchDate': '1966-08-19',
#     'satlat': 86.7061,
#     'satlng': 101.8845,
#     'satalt': 4875.4663},
#    {'satid': 23845,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1996-021D',
#     'launchDate': '1996-04-08',
#     'satlat': 2.1541,
#     'satlng': 32.597,
#     'satalt': 28359.9615},
#    {'satid': 23846,
#     'satname': 'MSAT M1',
#     'intDesignator': '1996-022A',
#     'launchDate': '1996-04-20',
#     'satlat': -2.9722,
#     'satlng': 115.1076,
#     'satalt': 36183.923},
#    {'satid': 23847,
#     'satname': 'ARIANE 42P+3 R/B',
#     'intDesignator': '1996-022B',
#     'launchDate': '1996-04-20',
#     'satlat': 4.684,
#     'satlng': 30.2497,
#     'satalt': 23340.0026},
#    {'satid': 23855,
#     'satname': 'USA 118',
#     'intDesignator': '1996-026A',
#     'launchDate': '1996-04-24',
#     'satlat': 1.1956,
#     'satlng': 43.6139,
#     'satalt': 35979.4779},
#    {'satid': 23862,
#     'satname': 'USA 122',
#     'intDesignator': '1996-029D',
#     'launchDate': '1996-05-12',
#     'satlat': 48.6494,
#     'satlng': 50.3091,
#     'satalt': 1159.7618},
#    {'satid': 23864,
#     'satname': 'PALAPA C2',
#     'intDesignator': '1996-030A',
#     'launchDate': '1996-05-16',
#     'satlat': -4.177,
#     'satlng': 139.8277,
#     'satalt': 36155.4315},
#    {'satid': 23866,
#     'satname': 'ARIANE 44L+3 R/B',
#     'intDesignator': '1996-030C',
#     'launchDate': '1996-05-16',
#     'satlat': -4.1436,
#     'satlng': 33.4849,
#     'satalt': 13596.2335},
#    {'satid': 23880,
#     'satname': 'GORIZONT 32',
#     'intDesignator': '1996-034A',
#     'launchDate': '1996-05-25',
#     'satlat': -2.8402,
#     'satlng': 78.2957,
#     'satalt': 35862.8196},
#    {'satid': 23893,
#     'satname': 'USA 119',
#     'intDesignator': '1996-029A',
#     'launchDate': '1996-05-12',
#     'satlat': 33.5368,
#     'satlng': 125.7005,
#     'satalt': 8350.9957},
#    {'satid': 23943,
#     'satname': 'APSTAR 1A',
#     'intDesignator': '1996-039A',
#     'launchDate': '1996-07-03',
#     'satlat': 6.2304,
#     'satlng': 52.352,
#     'satalt': 36184.8181},
#    {'satid': 23947,
#     'satname': 'USA 125 DEB',
#     'intDesignator': '1996-038C',
#     'launchDate': '1996-07-03',
#     'satlat': 11.7043,
#     'satlng': 123.88,
#     'satalt': 9295.1083},
#    {'satid': 23948,
#     'satname': 'ARABSAT 2A',
#     'intDesignator': '1996-040A',
#     'launchDate': '1996-07-09',
#     'satlat': 3.9761,
#     'satlng': 62.4054,
#     'satalt': 36087.6982},
#    {'satid': 23949,
#     'satname': 'TURKSAT 1C',
#     'intDesignator': '1996-040B',
#     'launchDate': '1996-07-09',
#     'satlat': -4.0015,
#     'satlng': 125.8639,
#     'satalt': 35767.1145},
#    {'satid': 23950,
#     'satname': 'ARIANE 44L+3 R/B',
#     'intDesignator': '1996-040C',
#     'launchDate': '1996-07-09',
#     'satlat': 2.9699,
#     'satlng': 112.4447,
#     'satalt': 5435.8766},
#    {'satid': 24209,
#     'satname': 'TELECOM 2D',
#     'intDesignator': '1996-044B',
#     'launchDate': '1996-08-08',
#     'satlat': 4.8886,
#     'satlng': 66.1875,
#     'satalt': 36378.3037},
#    {'satid': 24282,
#     'satname': 'CHINASAT 7',
#     'intDesignator': '1996-048A',
#     'launchDate': '1996-08-18',
#     'satlat': -4.7568,
#     'satlng': 109.1753,
#     'satalt': 45757.2516},
#    {'satid': 24284,
#     'satname': 'SL-16 DEB',
#     'intDesignator': '1995-058G',
#     'launchDate': '1995-10-31',
#     'satlat': 41.7575,
#     'satlng': 58.8134,
#     'satalt': 844.9591},
#    {'satid': 24292,
#     'satname': 'MAGION 5',
#     'intDesignator': '1996-050B',
#     'launchDate': '1996-08-29',
#     'satlat': 63.0868,
#     'satlng': 128.8702,
#     'satalt': 14916.3703},
#    {'satid': 24293,
#     'satname': 'INTERBALL AURORA',
#     'intDesignator': '1996-050C',
#     'launchDate': '1996-08-29',
#     'satlat': 25.0934,
#     'satlng': 48.3389,
#     'satalt': 15180.8088},
#    {'satid': 24296,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1996-050F',
#     'launchDate': '1996-08-29',
#     'satlat': 49.5247,
#     'satlng': 94.6067,
#     'satalt': 18704.8946},
#    {'satid': 24307,
#     'satname': 'INMARSAT 3-F2',
#     'intDesignator': '1996-053A',
#     'launchDate': '1996-09-06',
#     'satlat': 5.2225,
#     'satlng': 28.1567,
#     'satalt': 35869.9153},
#    {'satid': 24312,
#     'satname': 'OPS 0856 DEB',
#     'intDesignator': '1966-077N',
#     'launchDate': '1966-08-19',
#     'satlat': 33.2577,
#     'satlng': 18.7891,
#     'satalt': 3538.4269},
#    {'satid': 24435,
#     'satname': 'EXPRESS 2',
#     'intDesignator': '1996-058A',
#     'launchDate': '1996-09-26',
#     'satlat': 4.1147,
#     'satlng': 50.9106,
#     'satalt': 35842.1004},
#    {'satid': 24438,
#     'satname': 'SL-12 R/B(2)',
#     'intDesignator': '1996-058D',
#     'launchDate': '1996-09-26',
#     'satlat': -1.9757,
#     'satlng': 71.0653,
#     'satalt': 35839.3588},
#    {'satid': 24653,
#     'satname': 'MEASAT 2',
#     'intDesignator': '1996-063B',
#     'launchDate': '1996-11-13',
#     'satlat': 9.2964,
#     'satlng': 5.065,
#     'satalt': 35951.9321},
#    {'satid': 24654,
#     'satname': 'ARIANE 44L R/B',
#     'intDesignator': '1996-063C',
#     'launchDate': '1996-11-13',
#     'satlat': 3.7473,
#     'satlng': 122.0941,
#     'satalt': 20659.1976},
#    {'satid': 24665,
#     'satname': 'EUTE 48A (HB2)',
#     'intDesignator': '1996-067A',
#     'launchDate': '1996-11-21',
#     'satlat': 6.2089,
#     'satlng': 57.8965,
#     'satalt': 36309.0416},
#    {'satid': 24675,
#     'satname': 'ATLAS 2A CENTAUR R/B',
#     'intDesignator': '1996-070B',
#     'launchDate': '1996-12-18',
#     'satlat': 20.8497,
#     'satlng': 51.655,
#     'satalt': 24992.0246},
#    {'satid': 24676,
#     'satname': 'OPS 0856 DEB',
#     'intDesignator': '1966-077Q',
#     'launchDate': '1966-08-19',
#     'satlat': 37.2439,
#     'satlng': 39.5216,
#     'satalt': 5666.8239},
#    {'satid': 24712,
#     'satname': 'ARIANE 3 DEB',
#     'intDesignator': '1986-026G',
#     'launchDate': '1986-03-28',
#     'satlat': -6.1887,
#     'satlng': 61.6584,
#     'satalt': 25329.3349},
#    {'satid': 24714,
#     'satname': 'NAHUEL 1A',
#     'intDesignator': '1997-002B',
#     'launchDate': '1997-01-30',
#     'satlat': 9.4082,
#     'satlng': 18.6737,
#     'satalt': 36026.8412},
#    {'satid': 24721,
#     'satname': 'M-5 R/B',
#     'intDesignator': '1997-005B',
#     'launchDate': '1997-02-12',
#     'satlat': 26.2976,
#     'satlng': 101.6326,
#     'satalt': 863.0721},
#    {'satid': 24722,
#     'satname': 'ARIANE 44L DEB',
#     'intDesignator': '1991-003E',
#     'launchDate': '1991-01-15',
#     'satlat': 3.5426,
#     'satlng': 143.5247,
#     'satalt': 27354.1835},
#    {'satid': 24732,
#     'satname': 'INTELSAT 26 (JCSAT 4)',
#     'intDesignator': '1997-007A',
#     'launchDate': '1997-02-17',
#     'satlat': 5.2967,
#     'satlng': 63.9709,
#     'satalt': 35784.4037},
#    {'satid': 24737,
#     'satname': 'USA 130',
#     'intDesignator': '1997-008A',
#     'launchDate': '1997-02-23',
#     'satlat': 12.6025,
#     'satlng': 8.0885,
#     'satalt': 35785.7224},
#    {'satid': 24742,
#     'satname': 'INTELSAT 801',
#     'intDesignator': '1997-009A',
#     'launchDate': '1997-03-01',
#     'satlat': 8.7386,
#     'satlng': 0.7031,
#     'satalt': 36243.895},
#    {'satid': 24764,
#     'satname': 'SL-6 R/B(2)',
#     'intDesignator': '1997-015D',
#     'launchDate': '1997-04-09',
#     'satlat': -25.5729,
#     'satlng': 116.8496,
#     'satalt': 35661.2417},
#    {'satid': 24768,
#     'satname': 'THAICOM 3',
#     'intDesignator': '1997-016A',
#     'launchDate': '1997-04-16',
#     'satlat': 3.6221,
#     'satlng': 74.4251,
#     'satalt': 36565.1749},
#    {'satid': 24772,
#     'satname': 'COSMOS 2341',
#     'intDesignator': '1997-017A',
#     'launchDate': '1997-04-17',
#     'satlat': 34.0016,
#     'satlng': 56.5634,
#     'satalt': 989.3231},
#    {'satid': 24786,
#     'satname': 'GOES 10',
#     'intDesignator': '1997-019A',
#     'launchDate': '1997-04-25',
#     'satlat': 1.1068,
#     'satlng': 84.7917,
#     'satalt': 36006.2704},
#    {'satid': 24798,
#     'satname': 'DFH-3 2',
#     'intDesignator': '1997-021A',
#     'launchDate': '1997-05-11',
#     'satlat': -6.7611,
#     'satlng': 118.7765,
#     'satalt': 35831.0325},
#    {'satid': 24810,
#     'satname': 'DELTA 2 R/B(2)',
#     'intDesignator': '1997-025C',
#     'launchDate': '1997-05-20',
#     'satlat': 17.777,
#     'satlng': -2.2958,
#     'satalt': 23977.0745},
#    {'satid': 24812,
#     'satname': 'GALAXY 25 (TELSTAR 5)',
#     'intDesignator': '1997-026A',
#     'launchDate': '1997-05-24',
#     'satlat': 2.1561,
#     'satlng': 32.7962,
#     'satalt': 35795.213},
#    {'satid': 24818,
#     'satname': 'SL-8 DEB',
#     'intDesignator': '1977-087C',
#     'launchDate': '1977-09-13',
#     'satlat': 37.8158,
#     'satlng': 40.7008,
#     'satalt': 952.7555},
#    ...]}]

# %%
with open('satlaunch90.json', 'w') as f:
    json.dump(earth_sat2, f)
